# %% [markdown]
# # SQL for Analysis

# %%
import csv
import psycopg2
import sqlite3
import wget

# %%
dbname = 'emvhreqb'
user = 'emvhreqb'
password = 'aYJgOIHTqfh09pZ6tAp5gHqmwWaqxnhc'
host = 'salt.db.elephantsql.com'

# %%
pg_conn = psycopg2.connect(dbname=dbname, 
                           user=user, 
                           password=password, 
                           host=host)

# %%
pg_cursor = pg_conn.cursor()

# %%
pg_cursor.execute('SELECT * FROM playground;')

# %%
pg_cursor.fetchall()
# Out:
# [(1, 'A row name', None),
#  (2, 'A second row', {'a': 1, 'b': ['dog', 42], 'c': True})]

# %%
wget.download('https://github.com/ElisabethShah/DS-Unit-3-Sprint-2-SQL-and-Databases/blob/master/module1-introduction-to-sql/rpg_db.sqlite3?raw=true')
# Out:
# 100% [............................................................................] 253952 / 253952
# 'rpg_db (3).sqlite3'

# %%
sl_conn = sqlite3.connect('rpg_db.sqlite3')

# %%
sl_cursor = sl_conn.cursor()

# %%
sl_cursor.execute('SELECT COUNT(*) FROM charactercreator_character;')

# %%
sl_cursor.fetchall()
# Out:
# [(302,)]

# %%
characters = sl_cursor.execute('SELECT * FROM charactercreator_character;').fetchall()

# %%
characters
# Out:
# [(1, 'Aliquid iste optio reiciendi', 0, 0, 10, 1, 1, 1, 1),
#  (2, 'Optio dolorem ex a', 0, 0, 10, 1, 1, 1, 1),
#  (3, 'Minus c', 0, 0, 10, 1, 1, 1, 1),
#  (4, 'Sit ut repr', 0, 0, 10, 1, 1, 1, 1),
#  (5, 'At id recusandae expl', 0, 0, 10, 1, 1, 1, 1),
#  (6, 'Non nobis et of', 0, 0, 10, 1, 1, 1, 1),
#  (7, 'Perferendis', 0, 0, 10, 1, 1, 1, 1),
#  (8, 'Accusantium amet quidem eve', 0, 0, 10, 1, 1, 1, 1),
#  (9, 'Sed nostrum inventore error m', 0, 0, 10, 1, 1, 1, 1),
#  (10, 'Harum repellendus omnis od', 0, 0, 10, 1, 1, 1, 1),
#  (11, 'Itaque ut commodi,', 0, 0, 10, 1, 1, 1, 1),
#  (12, 'Molestiae quis', 0, 0, 10, 1, 1, 1, 1),
#  (13, 'Ali', 0, 0, 10, 1, 1, 1, 1),
#  (14, 'Tempora quod optio possimus il', 0, 0, 10, 1, 1, 1, 1),
#  (15, 'Sed itaque beatae pari', 0, 0, 10, 1, 1, 1, 1),
#  (16, 'Quam dolor', 0, 0, 10, 1, 1, 1, 1),
#  (17, 'Molestias expedita', 0, 0, 10, 1, 1, 1, 1),
#  (18, 'Lauda', 0, 0, 10, 1, 1, 1, 1),
#  (19, 'Incidunt sint perferen', 0, 0, 10, 1, 1, 1, 1),
# ...

# %%
create_character_table = ('CREATE TABLE character ('
                          'character_id SERIAL PRIMARY KEY, '
                          'name VARCHAR(30), '
                          'level INT NOT NULL, '
                          'exp INT NOT NULL, '
                          'hp INT NOT NULL, '
                          'strength INT NOT NULL, '
                          'intelligence INT NOT NULL, '
                          'dexterity INT NOT NULL, '
                          'wisdom INT NOT NULL );')

# %%
# pg_cursor.execute(create_character_table)

# %%
# pg_cursor.execute('ROLLBACK')

# %%
# for character in characters:
#     insert_query = 'INSERT INTO character VALUES ' + str(character) + ';'
#     pg_cursor.execute(insert_query)

# %%
# pg_conn.commit()

# %%
# pg_cursor.execute("CREATE TYPE sex AS ENUM ('male', 'female')")
# Out:
# ---------------------------------------------------------------------------
# DuplicateObject                           Traceback (most recent call last)
# <ipython-input-19-b6cbdadfe930> in <module>
# ----> 1 pg_cursor.execute("CREATE TYPE sex AS ENUM ('male', 'female')")
#
# DuplicateObject: type "sex" already exists

# %%
# pg_conn.commit()

# %%
create_passenger_table = ('CREATE TABLE passenger ('
                          'Survived BOOLEAN, '
                          'Pclass INT, '
                          'Name TEXT, '
                          'Sex SEX, '
                          'Age FLOAT8, '
                          'SameGenFamily INT, '
                          'OffByOneGenFamily INT, ' 
                          'Fare FLOAT);')

# %%
pg_cursor.execute(create_passenger_table)

# %%
pg_conn.commit()

# %%
with open('titanic.csv', 'r') as f:
    reader = csv.reader(f)
    next(reader) # Skip the header row.
    for row in reader:
        pg_cursor.execute(
            "INSERT INTO passenger VALUES (%s, %s, %s, %s, %s, %s, %s, %s)",
            row
        )

# %%
pg_conn.commit()
