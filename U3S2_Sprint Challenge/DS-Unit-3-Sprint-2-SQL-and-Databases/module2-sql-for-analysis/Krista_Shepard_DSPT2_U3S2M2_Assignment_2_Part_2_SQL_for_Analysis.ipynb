# %% [markdown]
# <a href="https://colab.research.google.com/github/KryssyCo/DS-Unit-3-Sprint-2-SQL-and-Databases/blob/master/Krista_Shepard_DSPT2_U3S2M2_Assignment_2_Part_2_SQL_for_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install pkg that allows me to pull from the elephantSQL  website
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: psycopg2-binary in /usr/local/lib/python3.6/dist-packages (2.8.4)

# %%
# Import pkg and explore its directory
import pandas as pd
import psycopg2
dir(psycopg2)
# Out:
# ['BINARY',
#  'Binary',
#  'DATETIME',
#  'DataError',
#  'DatabaseError',
#  'Date',
#  'DateFromTicks',
#  'Error',
#  'IntegrityError',
#  'InterfaceError',
#  'InternalError',
#  'NUMBER',
#  'NotSupportedError',
#  'OperationalError',
#  'ProgrammingError',
#  'ROWID',
#  'STRING',
#  'Time',
#  'TimeFromTicks',
#  'Timestamp',
#  'TimestampFromTicks',
#  'Warning',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__libpq_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_connect',
#  '_ext',
#  '_json',
#  '_psycopg',
#  '_range',
#  'apilevel',
#  'compat',
#  'connect',
#  'errors',
#  'extensions',
#  'paramstyle',
#  'threadsafety',
#  'tz']

# %%
# Pull necessary information from the elephantSQL website
dbname = 'zvineetb'
user = 'zvineetb'
password = 'TO DO' # Hide password before uploading to github
host = 'raja.db.elephantsql.com'

# %%
# Connect to the postgres connection that connects to elephantSQL
pg_conn = psycopg2.connect(dbname = dbname, user = user, password = password,
                           host = host)

# %%
# Created Cursor
pg_curs = pg_conn.cursor()

# %%
# Now you can use the cursor to execute commands, this and the cell below selects all the rows from
# selects all the rows from a previously made table to make sure it is working.
pg_curs.execute('SELECT * FROM  test_table;')

# %%
pg_curs.fetchall()
# Out:
# [(2, 'Another row with JSON', {'a': 1, 'b': ['dog', 'cat', 42], 'c': True})]

# %%
# Pull the titanic csv from github and use sqlite to look at it
df = pd.read_csv('https://raw.githubusercontent.com/KryssyCo/'
                'DS-Unit-3-Sprint-2-SQL-and-Databases/master/'
                'module2-sql-for-analysis/titanic.csv')

# %%
# Replaced ' with an open str throughout df and used regex to pull information
# from the repo
df = df.replace("'", " ", regex=True)

# %%
# Listed all files including hidden files
# !ls -alh
# Out:
# total 472K
# drwxr-xr-x 1 root root 4.0K Nov 16 15:36 .
# drwxr-xr-x 1 root root 4.0K Nov 16 12:48 ..
# drwxr-xr-x 1 root root 4.0K Nov 12 16:16 .config
# drwxr-xr-x 1 root root 4.0K Nov  6 16:17 sample_data
# -rw-r--r-- 1 root root  44K Nov 16 13:05 titanic.csv
# -rw-r--r-- 1 root root  44K Nov 16 13:35 titanic.csv.1
# -rw-r--r-- 1 root root  44K Nov 16 14:43 titanic.csv.2
# -rw-r--r-- 1 root root  44K Nov 16 15:14 titanic.csv.3
# -rw-r--r-- 1 root root  44K Nov 16 15:23 titanic.csv.4
# -rw-r--r-- 1 root root  44K Nov 16 15:28 titanic.csv.5
# -rw-r--r-- 1 root root  44K Nov 16 15:34 titanic.csv.6
# -rw-r--r-- 1 root root  44K Nov 16 15:34 titanic.csv.7
# -rw-r--r-- 1 root root  44K Nov 16 15:36 titanic.csv.8
# -rw-r--r-- 1 root root  60K Nov 16 15:36 titanic.sqlite3

# %%
# Used !wget to pull data into python from, github
# !wget https://raw.githubusercontent.com/KryssyCo/DS-Unit-3-Sprint-2-SQL-and-Databases/master/module2-sql-for-analysis/titanic.csv
# Out:
# --2019-11-16 15:39:58--  https://raw.githubusercontent.com/KryssyCo/DS-Unit-3-Sprint-2-SQL-and-Databases/master/module2-sql-for-analysis/titanic.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44225 (43K) [text/plain]
# Saving to: ‘titanic.csv.9’
#
# titanic.csv.9       100%[===================>]  43.19K  --.-KB/s    in 0.01s
#
# 2019-11-16 15:39:58 (2.96 MB/s) - ‘titanic.csv.9’ saved [44225/44225]

# %%
# List all files again (inc. hidden files)
# !ls -alh
# Out:
# total 516K
# drwxr-xr-x 1 root root 4.0K Nov 16 15:39 .
# drwxr-xr-x 1 root root 4.0K Nov 16 12:48 ..
# drwxr-xr-x 1 root root 4.0K Nov 12 16:16 .config
# drwxr-xr-x 1 root root 4.0K Nov  6 16:17 sample_data
# -rw-r--r-- 1 root root  44K Nov 16 13:05 titanic.csv
# -rw-r--r-- 1 root root  44K Nov 16 13:35 titanic.csv.1
# -rw-r--r-- 1 root root  44K Nov 16 14:43 titanic.csv.2
# -rw-r--r-- 1 root root  44K Nov 16 15:14 titanic.csv.3
# -rw-r--r-- 1 root root  44K Nov 16 15:23 titanic.csv.4
# -rw-r--r-- 1 root root  44K Nov 16 15:28 titanic.csv.5
# -rw-r--r-- 1 root root  44K Nov 16 15:34 titanic.csv.6
# -rw-r--r-- 1 root root  44K Nov 16 15:34 titanic.csv.7
# -rw-r--r-- 1 root root  44K Nov 16 15:36 titanic.csv.8
# -rw-r--r-- 1 root root  44K Nov 16 15:39 titanic.csv.9
# -rw-r--r-- 1 root root  60K Nov 16 15:36 titanic.sqlite3

# %%
# Take a look at first row
df.loc[0]
# Out:
# Survived                                        0
# Pclass                                          3
# Name                       Mr. Owen Harris Braund
# Sex                                          male
# Age                                            22
# Siblings/Spouses Aboard                         1
# Parents/Children Aboard                         0
# Fare                                         7.25
# Name: 0, dtype: object

# %%
# !wget https://github.com/KryssyCo/DS-Unit-3-Sprint-2-SQL-and-Databases/blob/master/module2-sql-for-analysis/titanic.sqlite3?raw=true
# Out:
# --2019-11-16 15:40:00--  https://github.com/KryssyCo/DS-Unit-3-Sprint-2-SQL-and-Databases/blob/master/module2-sql-for-analysis/titanic.sqlite3?raw=true
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/KryssyCo/DS-Unit-3-Sprint-2-SQL-and-Databases/raw/master/module2-sql-for-analysis/titanic.sqlite3 [following]
# --2019-11-16 15:40:01--  https://github.com/KryssyCo/DS-Unit-3-Sprint-2-SQL-and-Databases/raw/master/module2-sql-for-analysis/titanic.sqlite3
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/KryssyCo/DS-Unit-3-Sprint-2-SQL-and-Databases/master/module2-sql-for-analysis/titanic.sqlite3 [following]
# --2019-11-16 15:40:01--  https://raw.githubusercontent.com/KryssyCo/DS-Unit-3-Sprint-2-SQL-and-Databases/master/module2-sql-for-analysis/titanic.sqlite3
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61440 (60K) [application/octet-stream]
# Saving to: ‘titanic.sqlite3?raw=true’
#
# titanic.sqlite3?raw 100%[===================>]  60.00K  --.-KB/s    in 0.01s
#
# 2019-11-16 15:40:01 (4.35 MB/s) - ‘titanic.sqlite3?raw=true’ saved [61440/61440]

# %%
# !ls -alh
# Out:
# total 576K
# drwxr-xr-x 1 root root 4.0K Nov 16 15:40  .
# drwxr-xr-x 1 root root 4.0K Nov 16 12:48  ..
# drwxr-xr-x 1 root root 4.0K Nov 12 16:16  .config
# drwxr-xr-x 1 root root 4.0K Nov  6 16:17  sample_data
# -rw-r--r-- 1 root root  44K Nov 16 13:05  titanic.csv
# -rw-r--r-- 1 root root  44K Nov 16 13:35  titanic.csv.1
# -rw-r--r-- 1 root root  44K Nov 16 14:43  titanic.csv.2
# -rw-r--r-- 1 root root  44K Nov 16 15:14  titanic.csv.3
# -rw-r--r-- 1 root root  44K Nov 16 15:23  titanic.csv.4
# -rw-r--r-- 1 root root  44K Nov 16 15:28  titanic.csv.5
# -rw-r--r-- 1 root root  44K Nov 16 15:34  titanic.csv.6
# -rw-r--r-- 1 root root  44K Nov 16 15:34  titanic.csv.7
# -rw-r--r-- 1 root root  44K Nov 16 15:36  titanic.csv.8
# -rw-r--r-- 1 root root  44K Nov 16 15:39  titanic.csv.9
# -rw-r--r-- 1 root root  60K Nov 16 15:36  titanic.sqlite3
# -rw-r--r-- 1 root root  60K Nov 16 15:40 'titanic.sqlite3?raw=true'

# %%
# Rename database 
# !mv 'titanic.sqlite3?raw=true' titanic.sqlite3

# %%
import sqlite3

# %%
# Established connection
sl_conn = sqlite3.connect('titanic.sqlite3')

# %%
# Create cursor
sl_curs = sl_conn.cursor()

# %%
# Execute command from cursor to count how many rows in the table
sl_curs.execute('SELECT COUNT (*) FROM titanic;').fetchall()
# Out:
# [(888,)]

# %%
passengers = sl_curs.execute('SELECT * FROM titanic;').fetchall()

# %%
# Look at first row to see if it matches above
passengers[1]
# Out:
# ('0', '3', 'Mr. Owen Harris Braund', 'male', '22', '1', '0', '7.25')

# %%
# Look at the last row in the database
passengers[-1]
# Out:
# ('0', '3', 'Mr. Patrick Dooley', 'male', '32', '0', '0', '7.75')

# %%
# Used sqkite3 ti grab the scema for the table from titanic db
sl_curs.execute('PRAGMA table_info(titanic);').fetchall()
# Out:
# [(0, 'field1', 'TEXT', 0, None, 0),
#  (1, 'field2', 'TEXT', 0, None, 0),
#  (2, 'field3', 'TEXT', 0, None, 0),
#  (3, 'field4', 'TEXT', 0, None, 0),
#  (4, 'field5', 'TEXT', 0, None, 0),
#  (5, 'field6', 'TEXT', 0, None, 0),
#  (6, 'field7', 'TEXT', 0, None, 0),
#  (7, 'field8', 'TEXT', 0, None, 0)]

# %%
# Change types for the move to postgres
create_titanic_table = """
  CREATE TABLE titanic (
    passenger_id SERIAL PRIMARY KEY,
    survived INT,
    pclass INT,
    name VARCHAR(90),
    sex VARCHAR(10),
    age FLOAT,
    siblings_spouses_aboard INT,
    parents_children INT,
    fare FLOAT
  );
"""

# %%
# Switch back to elephantSQL and create an empty table in called titanic
pg_curs.execute(create_titanic_table)

# %%
# Insert passengers into the table
passengers[1]
# Out:
# ('0', '3', 'Mr. Owen Harris Braund', 'male', '22', '1', '0', '7.25')

# %%
# Slice it and take off the id before we ass it into the postgres
str(passengers[1][1:])
# Out:
# "('3', 'Mr. Owen Harris Braund', 'male', '22', '1', '0', '7.25')"

# %%
# Prepping a single character to be moved to postgres
example_insert = """
INSERT INTO create_titanic_table
(field)
VALUES """ + str(passengers[1][1:]) + ';'

print(example_insert)
# Out:
# INSERT INTO create_titanic_table
# (field)
# VALUES ('3', 'Mr. Owen Harris Braund', 'male', '22', '1', '0', '7.25');

# %%
# But I want to insert all 888 characters from sqlite3 to elephantSQL
# I can do this by using a for loop
for index,row in df.iterrows():
  insert_record =  """ 
    INSERT INTO titanic
    (survived, pclass, name, sex, age, siblings_spouses_aboard, parents_children, fare)
    VALUES """ + str(tuple(row.values)) + ';'
  pg_curs.execute(insert_record)

# %%
pg_curs.execute('SELECT * FROM titanic;')
pg_curs.fetchall()
# Out:
# [(1, 0, 3, 'Mr. Owen Harris Braund', 'male', 22.0, 1, 0, 7.25),
#  (2,
#   1,
#   1,
#   'Mrs. John Bradley (Florence Briggs Thayer) Cumings',
#   'female',
#   38.0,
#   1,
#   0,
#   71.2833),
#  (3, 1, 3, 'Miss. Laina Heikkinen', 'female', 26.0, 0, 0, 7.925),
#  (4,
#   1,
#   1,
#   'Mrs. Jacques Heath (Lily May Peel) Futrelle',
#   'female',
#   35.0,
#   1,
#   0,
#   53.1),
#  (5, 0, 3, 'Mr. William Henry Allen', 'male', 35.0, 0, 0, 8.05),
#  (6, 0, 3, 'Mr. James Moran', 'male', 27.0, 0, 0, 8.4583),
#  (7, 0, 1, 'Mr. Timothy J McCarthy', 'male', 54.0, 0, 0, 51.8625),
#  (8, 0, 3, 'Master. Gosta Leonard Palsson', 'male', 2.0, 3, 1, 21.075),
#  (9,
#   1,
#   3,
#   'Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson',
#   'female',
#   27.0,
#   0,
#   2,
#   11.1333),
#  (10,
#   1,
#   2,
#   'Mrs. Nicholas (Adele Achem) Nasser',
#   'female',
#   14.0,
#   1,
#   0,
#   30.0708),
#  (11, 1, 3, 'Miss. Marguerite Rut Sandstrom', 'female', 4.0, 1, 1, 16.7),
#  (12, 1, 1, 'Miss. Elizabeth Bonnell', 'female', 58.0, 0, 0, 26.55),
#  (13, 0, 3, 'Mr. William Henry Saundercock', 'male', 20.0, 0, 0, 8.05),
#  (14, 0, 3, 'Mr. Anders Johan Andersson', 'male', 39.0, 1, 5, 31.275),
#  (15,
#   0,
#   3,
#   'Miss. Hulda Amanda Adolfina Vestrom',
#   'female',
#   14.0,
#   0,
#   0,
#   7.8542),
#  (16, 1, 2, 'Mrs. (Mary D Kingcome) Hewlett', 'female', 55.0, 0, 0, 16.0),
#  (17, 0, 3, 'Master. Eugene Rice', 'male', 2.0, 4, 1, 29.125),
#  (18, 1, 2, 'Mr. Charles Eugene Williams', 'male', 23.0, 0, 0, 13.0),
#  (19,
#   0,
#   3,
#   'Mrs. Julius (Emelia Maria Vandemoortele) Vander Planke',
#   'female',
#   31.0,
#   1,
#   0,
#   18.0),
#  (20, 1, 3, 'Mrs. Fatima Masselmani', 'female', 22.0, 0, 0, 7.225),
#  (21, 0, 2, 'Mr. Joseph J Fynney', 'male', 35.0, 0, 0, 26.0),
#  (22, 1, 2, 'Mr. Lawrence Beesley', 'male', 34.0, 0, 0, 13.0),
#  (23, 1, 3, 'Miss. Anna McGowan', 'female', 15.0, 0, 0, 8.0292),
#  (24, 1, 1, 'Mr. William Thompson Sloper', 'male', 28.0, 0, 0, 35.5),
#  (25, 0, 3, 'Miss. Torborg Danira Palsson', 'female', 8.0, 3, 1, 21.075),
#  (26,
#   1,
#   3,
#   'Mrs. Carl Oscar (Selma Augusta Emilia Johansson) Asplund',
#   'female',
#   38.0,
#   1,
#   5,
#   31.3875),
#  (27, 0, 3, 'Mr. Farred Chehab Emir', 'male', 26.0, 0, 0, 7.225),
#  (28, 0, 1, 'Mr. Charles Alexander Fortune', 'male', 19.0, 3, 2, 263.0),
#  (29, 1, 3, 'Miss. Ellen O Dwyer', 'female', 24.0, 0, 0, 7.8792),
#  (30, 0, 3, 'Mr. Lalio Todoroff', 'male', 23.0, 0, 0, 7.8958),
#  (31, 0, 1, 'Don. Manuel E Uruchurtu', 'male', 40.0, 0, 0, 27.7208),
#  (32,
#   1,
#   1,
#   'Mrs. William Augustus (Marie Eugenie) Spencer',
#   'female',
#   48.0,
#   1,
#   0,
#   146.5208),
#  (33, 1, 3, 'Miss. Mary Agatha Glynn', 'female', 18.0, 0, 0, 7.75),
#  (34, 0, 2, 'Mr. Edward H Wheadon', 'male', 66.0, 0, 0, 10.5),
#  (35, 0, 1, 'Mr. Edgar Joseph Meyer', 'male', 28.0, 1, 0, 82.1708),
#  (36, 0, 1, 'Mr. Alexander Oskar Holverson', 'male', 42.0, 1, 0, 52.0),
#  (37, 1, 3, 'Mr. Hanna Mamee', 'male', 18.0, 0, 0, 7.2292),
#  (38, 0, 3, 'Mr. Ernest Charles Cann', 'male', 21.0, 0, 0, 8.05),
#  (39, 0, 3, 'Miss. Augusta Maria Vander Planke', 'female', 18.0, 2, 0, 18.0),
#  (40, 1, 3, 'Miss. Jamila Nicola-Yarred', 'female', 14.0, 1, 0, 11.2417),
#  (41,
#   0,
#   3,
#   'Mrs. Johan (Johanna Persdotter Larsson) Ahlin',
#   'female',
#   40.0,
#   1,
#   0,
#   9.475),
#  (42,
#   0,
#   2,
#   'Mrs. William John Robert (Dorothy Ann Wonnacott) Turpin',
#   'female',
#   27.0,
#   1,
#   0,
#   21.0),
#  (43,
#   1,
#   2,
#   'Miss. Simonne Marie Anne Andree Laroche',
#   'female',
#   3.0,
#   1,
#   2,
#   41.5792),
#  (44, 1, 3, 'Miss. Margaret Delia Devaney', 'female', 19.0, 0, 0, 7.8792),
#  (45, 0, 3, 'Mr. William John Rogers', 'male', 30.0, 0, 0, 8.05),
#  (46, 0, 3, 'Mr. Denis Lennon', 'male', 20.0, 1, 0, 15.5),
#  (47, 1, 3, 'Miss. Bridget O Driscoll', 'female', 27.0, 0, 0, 7.75),
#  (48, 0, 3, 'Mr. Youssef Samaan', 'male', 16.0, 2, 0, 21.6792),
#  (49,
#   0,
#   3,
#   'Mrs. Josef (Josefine Franchi) Arnold-Franchi',
#   'female',
#   18.0,
#   1,
#   0,
#   17.8),
#  (50, 0, 3, 'Master. Juha Niilo Panula', 'male', 7.0, 4, 1, 39.6875),
#  (51, 0, 3, 'Mr. Richard Cater Nosworthy', 'male', 21.0, 0, 0, 7.8),
#  (52,
#   1,
#   1,
#   'Mrs. Henry Sleeper (Myna Haxtun) Harper',
#   'female',
#   49.0,
#   1,
#   0,
#   76.7292),
#  (53,
#   1,
#   2,
#   'Mrs. Lizzie (Elizabeth Anne Wilkinson) Faunthorpe',
#   'female',
#   29.0,
#   1,
#   0,
#   26.0),
#  (54, 0, 1, 'Mr. Engelhart Cornelius Ostby', 'male', 65.0, 0, 1, 61.9792),
#  (55, 1, 1, 'Mr. Hugh Woolner', 'male', 46.0, 0, 0, 35.5),
#  (56, 1, 2, 'Miss. Emily Rugg', 'female', 21.0, 0, 0, 10.5),
#  (57, 0, 3, 'Mr. Mansouer Novel', 'male', 28.5, 0, 0, 7.2292),
#  (58, 1, 2, 'Miss. Constance Mirium West', 'female', 5.0, 1, 2, 27.75),
#  (59, 0, 3, 'Master. William Frederick Goodwin', 'male', 11.0, 5, 2, 46.9),
#  (60, 0, 3, 'Mr. Orsen Sirayanian', 'male', 22.0, 0, 0, 7.2292),
#  (61, 1, 1, 'Miss. Amelie Icard', 'female', 38.0, 0, 0, 80.0),
#  (62, 0, 1, 'Mr. Henry Birkhardt Harris', 'male', 45.0, 1, 0, 83.475),
#  (63, 0, 3, 'Master. Harald Skoog', 'male', 4.0, 3, 2, 27.9),
#  (64, 0, 1, 'Mr. Albert A Stewart', 'male', 64.0, 0, 0, 27.7208),
#  (65, 1, 3, 'Master. Gerios Moubarek', 'male', 7.0, 1, 1, 15.2458),
#  (66, 1, 2, 'Mrs. (Elizabeth Ramell) Nye', 'female', 29.0, 0, 0, 10.5),
#  (67, 0, 3, 'Mr. Ernest James Crease', 'male', 19.0, 0, 0, 8.1583),
#  (68, 1, 3, 'Miss. Erna Alexandra Andersson', 'female', 17.0, 4, 2, 7.925),
#  (69, 0, 3, 'Mr. Vincenz Kink', 'male', 26.0, 2, 0, 8.6625),
#  (70, 0, 2, 'Mr. Stephen Curnow Jenkin', 'male', 32.0, 0, 0, 10.5),
#  (71, 0, 3, 'Miss. Lillian Amy Goodwin', 'female', 16.0, 5, 2, 46.9),
#  (72, 0, 2, 'Mr. Ambrose Jr Hood', 'male', 21.0, 0, 0, 73.5),
#  (73, 0, 3, 'Mr. Apostolos Chronopoulos', 'male', 26.0, 1, 0, 14.4542),
#  (74, 1, 3, 'Mr. Lee Bing', 'male', 32.0, 0, 0, 56.4958),
#  (75, 0, 3, 'Mr. Sigurd Hansen Moen', 'male', 25.0, 0, 0, 7.65),
#  (76, 0, 3, 'Mr. Ivan Staneff', 'male', 23.0, 0, 0, 7.8958),
#  (77, 0, 3, 'Mr. Rahamin Haim Moutal', 'male', 28.0, 0, 0, 8.05),
#  (78, 1, 2, 'Master. Alden Gates Caldwell', 'male', 0.83, 0, 2, 29.0),
#  (79, 1, 3, 'Miss. Elizabeth Dowdell', 'female', 30.0, 0, 0, 12.475),
#  (80, 0, 3, 'Mr. Achille Waelens', 'male', 22.0, 0, 0, 9.0),
#  (81, 1, 3, 'Mr. Jan Baptist Sheerlinck', 'male', 29.0, 0, 0, 9.5),
#  (82, 1, 3, 'Miss. Brigdet Delia McDermott', 'female', 31.0, 0, 0, 7.7875),
#  (83, 0, 1, 'Mr. Francisco M Carrau', 'male', 28.0, 0, 0, 47.1),
#  (84, 1, 2, 'Miss. Bertha Ilett', 'female', 17.0, 0, 0, 10.5),
#  (85,
#   1,
#   3,
#   'Mrs. Karl Alfred (Maria Mathilda Gustafsson) Backstrom',
#   'female',
#   33.0,
#   3,
#   0,
#   15.85),
#  (86, 0, 3, 'Mr. William Neal Ford', 'male', 16.0, 1, 3, 34.375),
#  (87, 0, 3, 'Mr. Selman Francis Slocovski', 'male', 20.0, 0, 0, 8.05),
#  (88, 1, 1, 'Miss. Mabel Helen Fortune', 'female', 23.0, 3, 2, 263.0),
#  (89, 0, 3, 'Mr. Francesco Celotti', 'male', 24.0, 0, 0, 8.05),
#  (90, 0, 3, 'Mr. Emil Christmann', 'male', 29.0, 0, 0, 8.05),
#  (91, 0, 3, 'Mr. Paul Edvin Andreasson', 'male', 20.0, 0, 0, 7.8542),
#  (92, 0, 1, 'Mr. Herbert Fuller Chaffee', 'male', 46.0, 1, 0, 61.175),
#  (93, 0, 3, 'Mr. Bertram Frank Dean', 'male', 26.0, 1, 2, 20.575),
#  (94, 0, 3, 'Mr. Daniel Coxon', 'male', 59.0, 0, 0, 7.25),
#  (95, 0, 3, 'Mr. Charles Joseph Shorney', 'male', 22.0, 0, 0, 8.05),
#  (96, 0, 1, 'Mr. George B Goldschmidt', 'male', 71.0, 0, 0, 34.6542),
#  (97, 1, 1, 'Mr. William Bertram Greenfield', 'male', 23.0, 0, 1, 63.3583),
#  (98, 1, 2, 'Mrs. John T (Ada Julia Bone) Doling', 'female', 34.0, 0, 1, 23.0),
#  (99, 0, 2, 'Mr. Sinai Kantor', 'male', 34.0, 1, 0, 26.0),
#  (100, 0, 3, 'Miss. Matilda Petranec', 'female', 28.0, 0, 0, 7.8958),
#  (101, 0, 3, 'Mr. Pastcho Petroff', 'male', 29.0, 0, 0, 7.8958),
#  (102, 0, 1, 'Mr. Richard Frasar White', 'male', 21.0, 0, 1, 77.2875),
#  (103, 0, 3, 'Mr. Gustaf Joel Johansson', 'male', 33.0, 0, 0, 8.6542),
#  (104, 0, 3, 'Mr. Anders Vilhelm Gustafsson', 'male', 37.0, 2, 0, 7.925),
#  (105, 0, 3, 'Mr. Stoytcho Mionoff', 'male', 28.0, 0, 0, 7.8958),
#  (106, 1, 3, 'Miss. Anna Kristine Salkjelsvik', 'female', 21.0, 0, 0, 7.65),
#  (107, 1, 3, 'Mr. Albert Johan Moss', 'male', 29.0, 0, 0, 7.775),
#  (108, 0, 3, 'Mr. Tido Rekic', 'male', 38.0, 0, 0, 7.8958),
#  (109, 1, 3, 'Miss. Bertha Moran', 'female', 28.0, 1, 0, 24.15),
#  (110, 0, 1, 'Mr. Walter Chamberlain Porter', 'male', 47.0, 0, 0, 52.0),
#  (111, 0, 3, 'Miss. Hileni Zabour', 'female', 14.5, 1, 0, 14.4542),
#  (112, 0, 3, 'Mr. David John Barton', 'male', 22.0, 0, 0, 8.05),
#  (113, 0, 3, 'Miss. Katriina Jussila', 'female', 20.0, 1, 0, 9.825),
#  (114, 0, 3, 'Miss. Malake Attalah', 'female', 17.0, 0, 0, 14.4583),
#  (115, 0, 3, 'Mr. Edvard Pekoniemi', 'male', 21.0, 0, 0, 7.925),
#  (116, 0, 3, 'Mr. Patrick Connors', 'male', 70.5, 0, 0, 7.75),
#  (117, 0, 2, 'Mr. William John Robert Turpin', 'male', 29.0, 1, 0, 21.0),
#  (118, 0, 1, 'Mr. Quigg Edmond Baxter', 'male', 24.0, 0, 1, 247.5208),
#  (119, 0, 3, 'Miss. Ellis Anna Maria Andersson', 'female', 2.0, 4, 2, 31.275),
#  (120, 0, 2, 'Mr. Stanley George Hickman', 'male', 21.0, 2, 0, 73.5),
#  (121, 0, 3, 'Mr. Leonard Charles Moore', 'male', 19.0, 0, 0, 8.05),
#  (122, 0, 2, 'Mr. Nicholas Nasser', 'male', 32.5, 1, 0, 30.0708),
#  (123, 1, 2, 'Miss. Susan Webber', 'female', 32.5, 0, 0, 13.0),
#  (124, 0, 1, 'Mr. Percival Wayland White', 'male', 54.0, 0, 1, 77.2875),
#  (125, 1, 3, 'Master. Elias Nicola-Yarred', 'male', 12.0, 1, 0, 11.2417),
#  (126, 0, 3, 'Mr. Martin McMahon', 'male', 19.0, 0, 0, 7.75),
#  (127, 1, 3, 'Mr. Fridtjof Arne Madsen', 'male', 24.0, 0, 0, 7.1417),
#  (128, 1, 3, 'Miss. Anna Peter', 'female', 2.0, 1, 1, 22.3583),
#  (129, 0, 3, 'Mr. Johan Ekstrom', 'male', 45.0, 0, 0, 6.975),
#  (130, 0, 3, 'Mr. Jozef Drazenoic', 'male', 33.0, 0, 0, 7.8958),
#  (131, 0, 3, 'Mr. Domingos Fernandeo Coelho', 'male', 20.0, 0, 0, 7.05),
#  (132,
#   0,
#   3,
#   'Mrs. Alexander A (Grace Charity Laury) Robins',
#   'female',
#   47.0,
#   1,
#   0,
#   14.5),
#  (133,
#   1,
#   2,
#   'Mrs. Leopold (Mathilde Francoise Pede) Weisz',
#   'female',
#   29.0,
#   1,
#   0,
#   26.0),
#  (134, 0, 2, 'Mr. Samuel James Hayden Sobey', 'male', 25.0, 0, 0, 13.0),
#  (135, 0, 2, 'Mr. Emile Richard', 'male', 23.0, 0, 0, 15.0458),
#  (136, 1, 1, 'Miss. Helen Monypeny Newsom', 'female', 19.0, 0, 2, 26.2833),
#  (137, 0, 1, 'Mr. Jacques Heath Futrelle', 'male', 37.0, 1, 0, 53.1),
#  (138, 0, 3, 'Mr. Olaf Elon Osen', 'male', 16.0, 0, 0, 9.2167),
#  (139, 0, 1, 'Mr. Victor Giglio', 'male', 24.0, 0, 0, 79.2),
#  (140, 0, 3, 'Mrs. Joseph (Sultana) Boulos', 'female', 40.0, 0, 2, 15.2458),
#  (141, 1, 3, 'Miss. Anna Sofia Nysten', 'female', 22.0, 0, 0, 7.75),
#  (142,
#   1,
#   3,
#   'Mrs. Pekka Pietari (Elin Matilda Dolck) Hakkarainen',
#   'female',
#   24.0,
#   1,
#   0,
#   15.85),
#  (143, 0, 3, 'Mr. Jeremiah Burke', 'male', 19.0, 0, 0, 6.75),
#  (144, 0, 2, 'Mr. Edgardo Samuel Andrew', 'male', 18.0, 0, 0, 11.5),
#  (145, 0, 2, 'Mr. Joseph Charles Nicholls', 'male', 19.0, 1, 1, 36.75),
#  (146, 1, 3, 'Mr. August Edvard Andersson', 'male', 27.0, 0, 0, 7.7958),
#  (147, 0, 3, 'Miss. Robina Maggie Ford', 'female', 9.0, 2, 2, 34.375),
#  (148, 0, 2, 'Mr. Michel Navratil', 'male', 36.5, 0, 2, 26.0),
#  (149, 0, 2, 'Rev. Thomas Roussel Davids Byles', 'male', 42.0, 0, 0, 13.0),
#  (150, 0, 2, 'Rev. Robert James Bateman', 'male', 51.0, 0, 0, 12.525),
#  (151, 1, 1, 'Mrs. Thomas (Edith Wearne) Pears', 'female', 22.0, 1, 0, 66.6),
#  (152, 0, 3, 'Mr. Alfonzo Meo', 'male', 55.5, 0, 0, 8.05),
#  (153, 0, 3, 'Mr. Austin Blyler van Billiard', 'male', 40.5, 0, 2, 14.5),
#  (154, 0, 3, 'Mr. Ole Martin Olsen', 'male', 27.0, 0, 0, 7.3125),
#  (155, 0, 1, 'Mr. Charles Duane Williams', 'male', 51.0, 0, 1, 61.3792),
#  (156, 1, 3, 'Miss. Katherine Gilnagh', 'female', 16.0, 0, 0, 7.7333),
#  (157, 0, 3, 'Mr. Harry Corn', 'male', 30.0, 0, 0, 8.05),
#  (158, 0, 3, 'Mr. Mile Smiljanic', 'male', 37.0, 0, 0, 8.6625),
#  (159, 0, 3, 'Master. Thomas Henry Sage', 'male', 5.0, 8, 2, 69.55),
#  (160, 0, 3, 'Mr. John Hatfield Cribb', 'male', 44.0, 0, 1, 16.1),
#  (161,
#   1,
#   2,
#   'Mrs. James (Elizabeth Inglis Milne) Watt',
#   'female',
#   40.0,
#   0,
#   0,
#   15.75),
#  (162, 0, 3, 'Mr. John Viktor Bengtsson', 'male', 26.0, 0, 0, 7.775),
#  (163, 0, 3, 'Mr. Jovo Calic', 'male', 17.0, 0, 0, 8.6625),
#  (164, 0, 3, 'Master. Eino Viljami Panula', 'male', 1.0, 4, 1, 39.6875),
#  (165,
#   1,
#   3,
#   'Master. Frank John William Goldsmith',
#   'male',
#   9.0,
#   0,
#   2,
#   20.525),
#  (166,
#   1,
#   1,
#   'Mrs. (Edith Martha Bowerman) Chibnall',
#   'female',
#   48.0,
#   0,
#   1,
#   55.0),
#  (167,
#   0,
#   3,
#   'Mrs. William (Anna Bernhardina Karlsson) Skoog',
#   'female',
#   45.0,
#   1,
#   4,
#   27.9),
#  (168, 0, 1, 'Mr. John D Baumann', 'male', 60.0, 0, 0, 25.925),
#  (169, 0, 3, 'Mr. Lee Ling', 'male', 28.0, 0, 0, 56.4958),
#  (170, 0, 1, 'Mr. Wyckoff Van der hoef', 'male', 61.0, 0, 0, 33.5),
#  (171, 0, 3, 'Master. Arthur Rice', 'male', 4.0, 4, 1, 29.125),
#  (172, 1, 3, 'Miss. Eleanor Ileen Johnson', 'female', 1.0, 1, 1, 11.1333),
#  (173, 0, 3, 'Mr. Antti Wilhelm Sivola', 'male', 21.0, 0, 0, 7.925),
#  (174, 0, 1, 'Mr. James Clinch Smith', 'male', 56.0, 0, 0, 30.6958),
#  (175, 0, 3, 'Mr. Klas Albin Klasen', 'male', 18.0, 1, 1, 7.8542),
#  (176, 0, 3, 'Master. Henry Forbes Lefebre', 'male', 5.0, 3, 1, 25.4667),
#  (177, 0, 1, 'Miss. Ann Elizabeth Isham', 'female', 50.0, 0, 0, 28.7125),
#  (178, 0, 2, 'Mr. Reginald Hale', 'male', 30.0, 0, 0, 13.0),
#  (179, 0, 3, 'Mr. Lionel Leonard', 'male', 36.0, 0, 0, 0.0),
#  (180, 0, 3, 'Miss. Constance Gladys Sage', 'female', 8.0, 8, 2, 69.55),
#  (181, 0, 2, 'Mr. Rene Pernot', 'male', 39.0, 0, 0, 15.05),
#  (182,
#   0,
#   3,
#   'Master. Clarence Gustaf Hugo Asplund',
#   'male',
#   9.0,
#   4,
#   2,
#   31.3875),
#  (183, 1, 2, 'Master. Richard F Becker', 'male', 1.0, 2, 1, 39.0),
#  (184,
#   1,
#   3,
#   'Miss. Luise Gretchen Kink-Heilmann',
#   'female',
#   4.0,
#   0,
#   2,
#   22.025),
#  (185, 0, 1, 'Mr. Hugh Roscoe Rood', 'male', 39.0, 0, 0, 50.0),
#  (186,
#   1,
#   3,
#   'Mrs. Thomas (Johanna Godfrey) O Brien',
#   'female',
#   26.0,
#   1,
#   0,
#   15.5),
#  (187, 1, 1, 'Mr. Charles Hallace Romaine', 'male', 45.0, 0, 0, 26.55),
#  (188, 0, 3, 'Mr. John Bourke', 'male', 40.0, 1, 1, 15.5),
#  (189, 0, 3, 'Mr. Stjepan Turcin', 'male', 36.0, 0, 0, 7.8958),
#  (190, 1, 2, 'Mrs. (Rosa) Pinsky', 'female', 32.0, 0, 0, 13.0),
#  (191, 0, 2, 'Mr. William Carbines', 'male', 19.0, 0, 0, 13.0),
#  (192,
#   1,
#   3,
#   'Miss. Carla Christine Nielsine Andersen-Jensen',
#   'female',
#   19.0,
#   1,
#   0,
#   7.8542),
#  (193, 1, 2, 'Master. Michel M Navratil', 'male', 3.0, 1, 1, 26.0),
#  (194,
#   1,
#   1,
#   'Mrs. James Joseph (Margaret Tobin) Brown',
#   'female',
#   44.0,
#   0,
#   0,
#   27.7208),
#  (195, 1, 1, 'Miss. Elise Lurette', 'female', 58.0, 0, 0, 146.5208),
#  (196, 0, 3, 'Mr. Robert Mernagh', 'male', 28.0, 0, 0, 7.75),
#  (197, 0, 3, 'Mr. Karl Siegwart Andreas Olsen', 'male', 42.0, 0, 1, 8.4042),
#  (198, 1, 3, 'Miss. Margaret Madigan', 'female', 21.0, 0, 0, 7.75),
#  (199, 0, 2, 'Miss. Henriette Yrois', 'female', 24.0, 0, 0, 13.0),
#  (200, 0, 3, 'Mr. Nestor Cyriel Vande Walle', 'male', 28.0, 0, 0, 9.5),
#  (201, 0, 3, 'Mr. Frederick Sage', 'male', 17.0, 8, 2, 69.55),
#  (202, 0, 3, 'Mr. Jakob Alfred Johanson', 'male', 34.0, 0, 0, 6.4958),
#  (203, 0, 3, 'Mr. Gerious Youseff', 'male', 45.5, 0, 0, 7.225),
#  (204, 1, 3, 'Mr. Gurshon Cohen', 'male', 18.0, 0, 0, 8.05),
#  (205, 0, 3, 'Miss. Telma Matilda Strom', 'female', 2.0, 0, 1, 10.4625),
#  (206, 0, 3, 'Mr. Karl Alfred Backstrom', 'male', 32.0, 1, 0, 15.85),
#  (207, 1, 3, 'Mr. Nassef Cassem Albimona', 'male', 26.0, 0, 0, 18.7875),
#  (208, 1, 3, 'Miss. Helen Carr', 'female', 16.0, 0, 0, 7.75),
#  (209, 1, 1, 'Mr. Henry Blank', 'male', 40.0, 0, 0, 31.0),
#  (210, 0, 3, 'Mr. Ahmed Ali', 'male', 24.0, 0, 0, 7.05),
#  (211, 1, 2, 'Miss. Clear Annie Cameron', 'female', 35.0, 0, 0, 21.0),
#  (212, 0, 3, 'Mr. John Henry Perkin', 'male', 22.0, 0, 0, 7.25),
#  (213, 0, 2, 'Mr. Hans Kristensen Givard', 'male', 30.0, 0, 0, 13.0),
#  (214, 0, 3, 'Mr. Philip Kiernan', 'male', 22.0, 1, 0, 7.75),
#  (215, 1, 1, 'Miss. Madeleine Newell', 'female', 31.0, 1, 0, 113.275),
#  (216, 1, 3, 'Miss. Eliina Honkanen', 'female', 27.0, 0, 0, 7.925),
#  (217, 0, 2, 'Mr. Sidney Samuel Jacobsohn', 'male', 42.0, 1, 0, 27.0),
#  (218, 1, 1, 'Miss. Albina Bazzani', 'female', 32.0, 0, 0, 76.2917),
#  (219, 0, 2, 'Mr. Walter Harris', 'male', 30.0, 0, 0, 10.5),
#  (220, 1, 3, 'Mr. Victor Francis Sunderland', 'male', 16.0, 0, 0, 8.05),
#  (221, 0, 2, 'Mr. James H Bracken', 'male', 27.0, 0, 0, 13.0),
#  (222, 0, 3, 'Mr. George Henry Green', 'male', 51.0, 0, 0, 8.05),
#  (223, 0, 3, 'Mr. Christo Nenkoff', 'male', 22.0, 0, 0, 7.8958),
#  (224, 1, 1, 'Mr. Frederick Maxfield Hoyt', 'male', 38.0, 1, 0, 90.0),
#  (225, 0, 3, 'Mr. Karl Ivar Sven Berglund', 'male', 22.0, 0, 0, 9.35),
#  (226, 1, 2, 'Mr. William John Mellors', 'male', 19.0, 0, 0, 10.5),
#  (227, 0, 3, 'Mr. John Hall Lovell', 'male', 20.5, 0, 0, 7.25),
#  (228, 0, 2, 'Mr. Arne Jonas Fahlstrom', 'male', 18.0, 0, 0, 13.0),
#  (229, 0, 3, 'Miss. Mathilde Lefebre', 'female', 12.0, 3, 1, 25.4667),
#  (230,
#   1,
#   1,
#   'Mrs. Henry Birkhardt (Irene Wallach) Harris',
#   'female',
#   35.0,
#   1,
#   0,
#   83.475),
#  (231, 0, 3, 'Mr. Bengt Edvin Larsson', 'male', 29.0, 0, 0, 7.775),
#  (232, 0, 2, 'Mr. Ernst Adolf Sjostedt', 'male', 59.0, 0, 0, 13.5),
#  (233, 1, 3, 'Miss. Lillian Gertrud Asplund', 'female', 5.0, 4, 2, 31.3875),
#  (234, 0, 2, 'Mr. Robert William Norman Leyson', 'male', 24.0, 0, 0, 10.5),
#  (235, 0, 3, 'Miss. Alice Phoebe Harknett', 'female', 21.0, 0, 0, 7.55),
#  (236, 0, 2, 'Mr. Stephen Hold', 'male', 44.0, 1, 0, 26.0),
#  (237, 1, 2, 'Miss. Marjorie Collyer', 'female', 8.0, 0, 2, 26.25),
#  (238, 0, 2, 'Mr. Frederick William Pengelly', 'male', 19.0, 0, 0, 10.5),
#  (239, 0, 2, 'Mr. George Henry Hunt', 'male', 33.0, 0, 0, 12.275),
#  (240, 0, 3, 'Miss. Thamine Zabour', 'female', 19.0, 1, 0, 14.4542),
#  (241, 1, 3, 'Miss. Katherine Murphy', 'female', 18.0, 1, 0, 15.5),
#  (242, 0, 2, 'Mr. Reginald Charles Coleridge', 'male', 29.0, 0, 0, 10.5),
#  (243, 0, 3, 'Mr. Matti Alexanteri Maenpaa', 'male', 22.0, 0, 0, 7.125),
#  (244, 0, 3, 'Mr. Sleiman Attalah', 'male', 30.0, 0, 0, 7.225),
#  (245, 0, 1, 'Dr. William Edward Minahan', 'male', 44.0, 2, 0, 90.0),
#  (246,
#   0,
#   3,
#   'Miss. Agda Thorilda Viktoria Lindahl',
#   'female',
#   25.0,
#   0,
#   0,
#   7.775),
#  (247, 1, 2, 'Mrs. William (Anna) Hamalainen', 'female', 24.0, 0, 2, 14.5),
#  (248, 1, 1, 'Mr. Richard Leonard Beckwith', 'male', 37.0, 1, 1, 52.5542),
#  (249, 0, 2, 'Rev. Ernest Courtenay Carter', 'male', 54.0, 1, 0, 26.0),
#  (250, 0, 3, 'Mr. James George Reed', 'male', 18.0, 0, 0, 7.25),
#  (251,
#   0,
#   3,
#   'Mrs. Wilhelm (Elna Matilda Persson) Strom',
#   'female',
#   29.0,
#   1,
#   1,
#   10.4625),
#  (252, 0, 1, 'Mr. William Thomas Stead', 'male', 62.0, 0, 0, 26.55),
#  (253, 0, 3, 'Mr. William Arthur Lobb', 'male', 30.0, 1, 0, 16.1),
#  (254,
#   0,
#   3,
#   'Mrs. Viktor (Helena Wilhelmina) Rosblom',
#   'female',
#   41.0,
#   0,
#   2,
#   20.2125),
#  (255,
#   1,
#   3,
#   'Mrs. Darwis (Hanne Youssef Razi) Touma',
#   'female',
#   29.0,
#   0,
#   2,
#   15.2458),
#  (256, 1, 1, 'Mrs. Gertrude Maybelle Thorne', 'female', 38.0, 0, 0, 79.2),
#  (257, 1, 1, 'Miss. Gladys Cherry', 'female', 30.0, 0, 0, 86.5),
#  (258, 1, 1, 'Miss. Anna Ward', 'female', 35.0, 0, 0, 512.3292),
#  (259, 1, 2, 'Mrs. (Lutie Davis) Parrish', 'female', 50.0, 0, 1, 26.0),
#  (260, 1, 3, 'Master. Edvin Rojj Felix Asplund', 'male', 3.0, 4, 2, 31.3875),
#  (261, 0, 1, 'Mr. Emil Taussig', 'male', 52.0, 1, 1, 79.65),
#  (262, 0, 1, 'Mr. William Harrison', 'male', 40.0, 0, 0, 0.0),
#  (263, 0, 3, 'Miss. Delia Henry', 'female', 21.0, 0, 0, 7.75),
#  (264, 0, 2, 'Mr. David Reeves', 'male', 36.0, 0, 0, 10.5),
#  (265, 0, 3, 'Mr. Ernesti Arvid Panula', 'male', 16.0, 4, 1, 39.6875),
#  (266, 1, 3, 'Mr. Ernst Ulrik Persson', 'male', 25.0, 1, 0, 7.775),
#  (267,
#   1,
#   1,
#   'Mrs. William Thompson (Edith Junkins) Graham',
#   'female',
#   58.0,
#   0,
#   1,
#   153.4625),
#  (268, 1, 1, 'Miss. Amelia Bissette', 'female', 35.0, 0, 0, 135.6333),
#  (269, 0, 1, 'Mr. Alexander Cairns', 'male', 28.0, 0, 0, 31.0),
#  (270, 1, 3, 'Mr. William Henry Tornquist', 'male', 25.0, 0, 0, 0.0),
#  (271,
#   1,
#   2,
#   'Mrs. (Elizabeth Anne Maidment) Mellinger',
#   'female',
#   41.0,
#   0,
#   1,
#   19.5),
#  (272, 0, 1, 'Mr. Charles H Natsch', 'male', 37.0, 0, 1, 29.7),
#  (273, 1, 3, 'Miss. Hanora Healy', 'female', 33.0, 0, 0, 7.75),
#  (274,
#   1,
#   1,
#   'Miss. Kornelia Theodosia Andrews',
#   'female',
#   63.0,
#   1,
#   0,
#   77.9583),
#  (275, 0, 3, 'Miss. Augusta Charlotta Lindblom', 'female', 45.0, 0, 0, 7.75),
#  (276, 0, 2, 'Mr. Francis Parkes', 'male', 21.0, 0, 0, 0.0),
#  (277, 0, 3, 'Master. Eric Rice', 'male', 7.0, 4, 1, 29.125),
#  (278, 1, 3, 'Mrs. Stanton (Rosa Hunt) Abbott', 'female', 35.0, 1, 1, 20.25),
#  (279, 0, 3, 'Mr. Frank Duane', 'male', 65.0, 0, 0, 7.75),
#  (280, 0, 3, 'Mr. Nils Johan Goransson Olsson', 'male', 28.0, 0, 0, 7.8542),
#  (281, 0, 3, 'Mr. Alfons de Pelsmaeker', 'male', 16.0, 0, 0, 9.5),
#  (282, 1, 3, 'Mr. Edward Arthur Dorking', 'male', 19.0, 0, 0, 8.05),
#  (283, 0, 1, 'Mr. Richard William Smith', 'male', 57.0, 0, 0, 26.0),
#  (284, 0, 3, 'Mr. Ivan Stankovic', 'male', 33.0, 0, 0, 8.6625),
#  (285, 1, 3, 'Mr. Theodore de Mulder', 'male', 30.0, 0, 0, 9.5),
#  (286, 0, 3, 'Mr. Penko Naidenoff', 'male', 22.0, 0, 0, 7.8958),
#  (287, 1, 2, 'Mr. Masabumi Hosono', 'male', 42.0, 0, 0, 13.0),
#  (288, 1, 3, 'Miss. Kate Connolly', 'female', 22.0, 0, 0, 7.75),
#  (289, 1, 1, 'Miss. Ellen Barber', 'female', 26.0, 0, 0, 78.85),
#  (290,
#   1,
#   1,
#   'Mrs. Dickinson H (Helen Walton) Bishop',
#   'female',
#   19.0,
#   1,
#   0,
#   91.0792),
#  (291, 0, 2, 'Mr. Rene Jacques Levy', 'male', 36.0, 0, 0, 12.875),
#  (292, 0, 3, 'Miss. Aloisia Haas', 'female', 24.0, 0, 0, 8.85),
#  (293, 0, 3, 'Mr. Ivan Mineff', 'male', 24.0, 0, 0, 7.8958),
#  (294, 0, 1, 'Mr. Ervin G Lewy', 'male', 30.0, 0, 0, 27.7208),
#  (295, 0, 3, 'Mr. Mansour Hanna', 'male', 23.5, 0, 0, 7.2292),
#  (296, 0, 1, 'Miss. Helen Loraine Allison', 'female', 2.0, 1, 2, 151.55),
#  (297, 1, 1, 'Mr. Adolphe Saalfeld', 'male', 47.0, 0, 0, 30.5),
#  (298,
#   1,
#   1,
#   'Mrs. James (Helene DeLaudeniere Chaput) Baxter',
#   'female',
#   50.0,
#   0,
#   1,
#   247.5208),
#  (299, 1, 3, 'Miss. Anna Katherine Kelly', 'female', 20.0, 0, 0, 7.75),
#  (300, 1, 3, 'Mr. Bernard McCoy', 'male', 24.0, 2, 0, 23.25),
#  (301, 0, 3, 'Mr. William Cahoone Jr Johnson', 'male', 19.0, 0, 0, 0.0),
#  (302, 1, 2, 'Miss. Nora A Keane', 'female', 46.0, 0, 0, 12.35),
#  (303, 0, 3, 'Mr. Howard Hugh Williams', 'male', 28.0, 0, 0, 8.05),
#  (304, 1, 1, 'Master. Hudson Trevor Allison', 'male', 0.92, 1, 2, 151.55),
#  (305, 1, 1, 'Miss. Margaret Fleming', 'female', 42.0, 0, 0, 110.8833),
#  (306,
#   1,
#   1,
#   'Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo) Penasco y Castellana',
#   'female',
#   17.0,
#   1,
#   0,
#   108.9),
#  (307, 0, 2, 'Mr. Samuel Abelson', 'male', 30.0, 1, 0, 24.0),
#  (308, 1, 1, 'Miss. Laura Mabel Francatelli', 'female', 30.0, 0, 0, 56.9292),
#  (309, 1, 1, 'Miss. Margaret Bechstein Hays', 'female', 24.0, 0, 0, 83.1583),
#  (310, 1, 1, 'Miss. Emily Borie Ryerson', 'female', 18.0, 2, 2, 262.375),
#  (311,
#   0,
#   2,
#   'Mrs. William (Anna Sylfven) Lahtinen',
#   'female',
#   26.0,
#   1,
#   1,
#   26.0),
#  (312, 0, 3, 'Mr. Ignjac Hendekovic', 'male', 28.0, 0, 0, 7.8958),
#  (313, 0, 2, 'Mr. Benjamin Hart', 'male', 43.0, 1, 1, 26.25),
#  (314, 1, 3, 'Miss. Helmina Josefina Nilsson', 'female', 26.0, 0, 0, 7.8542),
#  (315, 1, 2, 'Mrs. Sinai (Miriam Sternin) Kantor', 'female', 24.0, 1, 0, 26.0),
#  (316, 0, 2, 'Dr. Ernest Moraweck', 'male', 54.0, 0, 0, 14.0),
#  (317, 1, 1, 'Miss. Mary Natalie Wick', 'female', 31.0, 0, 2, 164.8667),
#  (318,
#   1,
#   1,
#   'Mrs. Frederic Oakley (Margaretta Corning Stone) Spedden',
#   'female',
#   40.0,
#   1,
#   1,
#   134.5),
#  (319, 0, 3, 'Mr. Samuel Dennis', 'male', 22.0, 0, 0, 7.25),
#  (320, 0, 3, 'Mr. Yoto Danoff', 'male', 27.0, 0, 0, 7.8958),
#  (321, 1, 2, 'Miss. Hilda Mary Slayter', 'female', 30.0, 0, 0, 12.35),
#  (322,
#   1,
#   2,
#   'Mrs. Albert Francis (Sylvia Mae Harbaugh) Caldwell',
#   'female',
#   22.0,
#   1,
#   1,
#   29.0),
#  (323, 0, 3, 'Mr. George John Jr Sage', 'male', 20.0, 8, 2, 69.55),
#  (324, 1, 1, 'Miss. Marie Grice Young', 'female', 36.0, 0, 0, 135.6333),
#  (325, 0, 3, 'Mr. Johan Hansen Nysveen', 'male', 61.0, 0, 0, 6.2375),
#  (326, 1, 2, 'Mrs. (Ada E Hall) Ball', 'female', 36.0, 0, 0, 13.0),
#  (327,
#   1,
#   3,
#   'Mrs. Frank John (Emily Alice Brown) Goldsmith',
#   'female',
#   31.0,
#   1,
#   1,
#   20.525),
#  (328, 1, 1, 'Miss. Jean Gertrude Hippach', 'female', 16.0, 0, 1, 57.9792),
#  (329, 1, 3, 'Miss. Agnes McCoy', 'female', 28.0, 2, 0, 23.25),
#  (330, 0, 1, 'Mr. Austen Partner', 'male', 45.5, 0, 0, 28.5),
#  (331, 0, 1, 'Mr. George Edward Graham', 'male', 38.0, 0, 1, 153.4625),
#  (332, 0, 3, 'Mr. Leo Edmondus Vander Planke', 'male', 16.0, 2, 0, 18.0),
#  (333,
#   1,
#   1,
#   'Mrs. Henry William (Clara Heinsheimer) Frauenthal',
#   'female',
#   42.0,
#   1,
#   0,
#   133.65),
#  (334, 0, 3, 'Mr. Mitto Denkoff', 'male', 30.0, 0, 0, 7.8958),
#  (335, 0, 1, 'Mr. Thomas Clinton Pears', 'male', 29.0, 1, 0, 66.6),
#  (336, 1, 1, 'Miss. Elizabeth Margaret Burns', 'female', 41.0, 0, 0, 134.5),
#  (337, 1, 3, 'Mr. Karl Edwart Dahl', 'male', 45.0, 0, 0, 8.05),
#  (338, 0, 1, 'Mr. Stephen Weart Blackwell', 'male', 45.0, 0, 0, 35.5),
#  (339, 1, 2, 'Master. Edmond Roger Navratil', 'male', 2.0, 1, 1, 26.0),
#  (340, 1, 1, 'Miss. Alice Elizabeth Fortune', 'female', 24.0, 3, 2, 263.0),
#  (341, 0, 2, 'Mr. Erik Gustaf Collander', 'male', 28.0, 0, 0, 13.0),
#  (342,
#   0,
#   2,
#   'Mr. Charles Frederick Waddington Sedgwick',
#   'male',
#   25.0,
#   0,
#   0,
#   13.0),
#  (343, 0, 2, 'Mr. Stanley Hubert Fox', 'male', 36.0, 0, 0, 13.0),
#  (344, 1, 2, 'Miss. Amelia Brown', 'female', 24.0, 0, 0, 13.0),
#  (345, 1, 2, 'Miss. Marion Elsie Smith', 'female', 40.0, 0, 0, 13.0),
#  (346,
#   1,
#   3,
#   'Mrs. Thomas Henry (Mary E Finck) Davison',
#   'female',
#   34.0,
#   1,
#   0,
#   16.1),
#  (347, 1, 3, 'Master. William Loch Coutts', 'male', 3.0, 1, 1, 15.9),
#  (348, 0, 3, 'Mr. Jovan Dimic', 'male', 42.0, 0, 0, 8.6625),
#  (349, 0, 3, 'Mr. Nils Martin Odahl', 'male', 23.0, 0, 0, 9.225),
#  (350,
#   0,
#   1,
#   'Mr. Fletcher Fellows Williams-Lambert',
#   'male',
#   43.0,
#   0,
#   0,
#   35.0),
#  (351, 0, 3, 'Mr. Tannous Elias', 'male', 15.0, 1, 1, 7.2292),
#  (352, 0, 3, 'Mr. Josef Arnold-Franchi', 'male', 25.0, 1, 0, 17.8),
#  (353, 0, 3, 'Mr. Wazli Yousif', 'male', 23.0, 0, 0, 7.225),
#  (354, 0, 3, 'Mr. Leo Peter Vanden Steen', 'male', 28.0, 0, 0, 9.5),
#  (355, 1, 1, 'Miss. Elsie Edith Bowerman', 'female', 22.0, 0, 1, 55.0),
#  (356, 0, 2, 'Miss. Annie Clemmer Funk', 'female', 38.0, 0, 0, 13.0),
#  (357, 1, 3, 'Miss. Mary McGovern', 'female', 22.0, 0, 0, 7.8792),
#  (358, 1, 3, 'Miss. Helen Mary Mockler', 'female', 23.0, 0, 0, 7.8792),
#  (359, 0, 3, 'Mr. Wilhelm Skoog', 'male', 40.0, 1, 4, 27.9),
#  (360, 0, 2, 'Mr. Sebastiano del Carlo', 'male', 29.0, 1, 0, 27.7208),
#  (361, 0, 3, 'Mrs. (Catherine David) Barbara', 'female', 45.0, 0, 1, 14.4542),
#  (362, 0, 3, 'Mr. Adola Asim', 'male', 35.0, 0, 0, 7.05),
#  (363, 0, 3, 'Mr. Thomas O Brien', 'male', 27.0, 1, 0, 15.5),
#  (364, 0, 3, 'Mr. Mauritz Nils Martin Adahl', 'male', 30.0, 0, 0, 7.25),
#  (365,
#   1,
#   1,
#   'Mrs. Frank Manley (Anna Sophia Atkinson) Warren',
#   'female',
#   60.0,
#   1,
#   0,
#   75.25),
#  (366, 1, 3, 'Mrs. (Mantoura Boulos) Moussa', 'female', 35.0, 0, 0, 7.2292),
#  (367, 1, 3, 'Miss. Annie Jermyn', 'female', 22.0, 0, 0, 7.75),
#  (368, 1, 1, 'Mme. Leontine Pauline Aubart', 'female', 24.0, 0, 0, 69.3),
#  (369, 1, 1, 'Mr. George Achilles Harder', 'male', 25.0, 1, 0, 55.4417),
#  (370, 0, 3, 'Mr. Jakob Alfred Wiklund', 'male', 18.0, 1, 0, 6.4958),
#  (371, 0, 3, 'Mr. William Thomas Beavan', 'male', 19.0, 0, 0, 8.05),
#  (372, 0, 1, 'Mr. Sante Ringhini', 'male', 22.0, 0, 0, 135.6333),
#  (373, 0, 3, 'Miss. Stina Viola Palsson', 'female', 3.0, 3, 1, 21.075),
#  (374,
#   1,
#   1,
#   'Mrs. Edgar Joseph (Leila Saks) Meyer',
#   'female',
#   25.0,
#   1,
#   0,
#   82.1708),
#  (375, 1, 3, 'Miss. Aurora Adelia Landergren', 'female', 22.0, 0, 0, 7.25),
#  (376, 0, 1, 'Mr. Harry Elkins Widener', 'male', 27.0, 0, 2, 211.5),
#  (377, 0, 3, 'Mr. Tannous Betros', 'male', 20.0, 0, 0, 4.0125),
#  (378, 0, 3, 'Mr. Karl Gideon Gustafsson', 'male', 19.0, 0, 0, 7.775),
#  (379, 1, 1, 'Miss. Rosalie Bidois', 'female', 42.0, 0, 0, 227.525),
#  (380, 1, 3, 'Miss. Maria Nakid', 'female', 1.0, 0, 2, 15.7417),
#  (381, 0, 3, 'Mr. Juho Tikkanen', 'male', 32.0, 0, 0, 7.925),
#  (382,
#   1,
#   1,
#   'Mrs. Alexander Oskar (Mary Aline Towner) Holverson',
#   'female',
#   35.0,
#   1,
#   0,
#   52.0),
#  (383, 0, 3, 'Mr. Vasil Plotcharsky', 'male', 27.0, 0, 0, 7.8958),
#  (384, 0, 2, 'Mr. Charles Henry Davies', 'male', 18.0, 0, 0, 73.5),
#  (385, 0, 3, 'Master. Sidney Leonard Goodwin', 'male', 1.0, 5, 2, 46.9),
#  (386, 1, 2, 'Miss. Kate Buss', 'female', 36.0, 0, 0, 13.0),
#  (387, 0, 3, 'Mr. Matthew Sadlier', 'male', 19.0, 0, 0, 7.7292),
#  (388, 1, 2, 'Miss. Bertha Lehmann', 'female', 17.0, 0, 0, 12.0),
#  (389, 1, 1, 'Mr. William Ernest Carter', 'male', 36.0, 1, 2, 120.0),
#  (390, 1, 3, 'Mr. Carl Olof Jansson', 'male', 21.0, 0, 0, 7.7958),
#  (391, 0, 3, 'Mr. Johan Birger Gustafsson', 'male', 28.0, 2, 0, 7.925),
#  (392, 1, 1, 'Miss. Marjorie Newell', 'female', 23.0, 1, 0, 113.275),
#  (393,
#   1,
#   3,
#   'Mrs. Hjalmar (Agnes Charlotta Bengtsson) Sandstrom',
#   'female',
#   24.0,
#   0,
#   2,
#   16.7),
#  (394, 0, 3, 'Mr. Erik Johansson', 'male', 22.0, 0, 0, 7.7958),
#  (395, 0, 3, 'Miss. Elina Olsson', 'female', 31.0, 0, 0, 7.8542),
#  (396, 0, 2, 'Mr. Peter David McKane', 'male', 46.0, 0, 0, 26.0),
#  (397, 0, 2, 'Dr. Alfred Pain', 'male', 23.0, 0, 0, 10.5),
#  (398, 1, 2, 'Mrs. William H (Jessie L) Trout', 'female', 28.0, 0, 0, 12.65),
#  (399, 1, 3, 'Mr. Juha Niskanen', 'male', 39.0, 0, 0, 7.925),
#  (400, 0, 3, 'Mr. John Adams', 'male', 26.0, 0, 0, 8.05),
#  (401, 0, 3, 'Miss. Mari Aina Jussila', 'female', 21.0, 1, 0, 9.825),
#  (402, 0, 3, 'Mr. Pekka Pietari Hakkarainen', 'male', 28.0, 1, 0, 15.85),
#  (403, 0, 3, 'Miss. Marija Oreskovic', 'female', 20.0, 0, 0, 8.6625),
#  (404, 0, 2, 'Mr. Shadrach Gale', 'male', 34.0, 1, 0, 21.0),
#  (405, 0, 3, 'Mr. Carl/Charles Peter Widegren', 'male', 51.0, 0, 0, 7.75),
#  (406, 1, 2, 'Master. William Rowe Richards', 'male', 3.0, 1, 1, 18.75),
#  (407, 0, 3, 'Mr. Hans Martin Monsen Birkeland', 'male', 21.0, 0, 0, 7.775),
#  (408, 0, 3, 'Miss. Ida Lefebre', 'female', 3.0, 3, 1, 25.4667),
#  (409, 0, 3, 'Mr. Todor Sdycoff', 'male', 42.0, 0, 0, 7.8958),
#  (410, 0, 3, 'Mr. Henry Hart', 'male', 27.0, 0, 0, 6.8583),
#  (411, 1, 1, 'Miss. Daisy E Minahan', 'female', 33.0, 1, 0, 90.0),
#  (412, 0, 2, 'Mr. Alfred Fleming Cunningham', 'male', 22.0, 0, 0, 0.0),
#  (413, 1, 3, 'Mr. Johan Julian Sundman', 'male', 44.0, 0, 0, 7.925),
#  (414,
#   0,
#   3,
#   'Mrs. Thomas (Annie Louise Rowley) Meek',
#   'female',
#   32.0,
#   0,
#   0,
#   8.05),
#  (415,
#   1,
#   2,
#   'Mrs. James Vivian (Lulu Thorne Christian) Drew',
#   'female',
#   34.0,
#   1,
#   1,
#   32.5),
#  (416, 1, 2, 'Miss. Lyyli Karoliina Silven', 'female', 18.0, 0, 2, 13.0),
#  (417, 0, 2, 'Mr. William John Matthews', 'male', 30.0, 0, 0, 13.0),
#  (418, 0, 3, 'Miss. Catharina Van Impe', 'female', 10.0, 0, 2, 24.15),
#  (419, 0, 3, 'Mr. David Charters', 'male', 21.0, 0, 0, 7.7333),
#  (420, 0, 3, 'Mr. Leo Zimmerman', 'male', 29.0, 0, 0, 7.875),
#  (421,
#   0,
#   3,
#   'Mrs. Ernst Gilbert (Anna Sigrid Maria Brogren) Danbom',
#   'female',
#   28.0,
#   1,
#   1,
#   14.4),
#  (422, 0, 3, 'Mr. Viktor Richard Rosblom', 'male', 18.0, 1, 1, 20.2125),
#  (423, 0, 3, 'Mr. Phillippe Wiseman', 'male', 54.0, 0, 0, 7.25),
#  (424,
#   1,
#   2,
#   'Mrs. Charles V (Ada Maria Winfield) Clarke',
#   'female',
#   28.0,
#   1,
#   0,
#   26.0),
#  (425, 1, 2, 'Miss. Kate Florence Phillips', 'female', 19.0, 0, 0, 26.0),
#  (426, 0, 3, 'Mr. James Flynn', 'male', 28.0, 0, 0, 7.75),
#  (427, 1, 3, 'Mr. Berk (Berk Trembisky) Pickard', 'male', 32.0, 0, 0, 8.05),
#  (428,
#   1,
#   1,
#   'Mr. Mauritz Hakan Bjornstrom-Steffansson',
#   'male',
#   28.0,
#   0,
#   0,
#   26.55),
#  (429,
#   1,
#   3,
#   'Mrs. Percival (Florence Kate White) Thorneycroft',
#   'female',
#   33.0,
#   1,
#   0,
#   16.1),
#  (430,
#   1,
#   2,
#   'Mrs. Charles Alexander (Alice Adelaide Slow) Louch',
#   'female',
#   42.0,
#   1,
#   0,
#   26.0),
#  (431, 0, 3, 'Mr. Nikolai Erland Kallio', 'male', 17.0, 0, 0, 7.125),
#  (432, 0, 1, 'Mr. William Baird Silvey', 'male', 50.0, 1, 0, 55.9),
#  (433, 1, 1, 'Miss. Lucile Polk Carter', 'female', 14.0, 1, 2, 120.0),
#  (434, 0, 3, 'Miss. Doolina Margaret Ford', 'female', 21.0, 2, 2, 34.375),
#  (435,
#   1,
#   2,
#   'Mrs. Sidney (Emily Hocking) Richards',
#   'female',
#   24.0,
#   2,
#   3,
#   18.75),
#  (436, 0, 1, 'Mr. Mark Fortune', 'male', 64.0, 1, 4, 263.0),
#  (437,
#   0,
#   2,
#   'Mr. Johan Henrik Johannesson Kvillner',
#   'male',
#   31.0,
#   0,
#   0,
#   10.5),
#  (438,
#   1,
#   2,
#   'Mrs. Benjamin (Esther Ada Bloomfield) Hart',
#   'female',
#   45.0,
#   1,
#   1,
#   26.25),
#  (439, 0, 3, 'Mr. Leon Hampe', 'male', 20.0, 0, 0, 9.5),
#  (440, 0, 3, 'Mr. Johan Emil Petterson', 'male', 25.0, 1, 0, 7.775),
#  (441, 1, 2, 'Ms. Encarnacion Reynaldo', 'female', 28.0, 0, 0, 13.0),
#  (442, 1, 3, 'Mr. Bernt Johannesen-Bratthammer', 'male', 29.0, 0, 0, 8.1125),
#  (443, 1, 1, 'Master. Washington Dodge', 'male', 4.0, 0, 2, 81.8583),
#  (444, 1, 2, 'Miss. Madeleine Violet Mellinger', 'female', 13.0, 0, 1, 19.5),
#  (445, 1, 1, 'Mr. Frederic Kimber Seward', 'male', 34.0, 0, 0, 26.55),
#  (446, 1, 3, 'Miss. Marie Catherine Baclini', 'female', 5.0, 2, 1, 19.2583),
#  (447, 1, 1, 'Major. Arthur Godfrey Peuchen', 'male', 52.0, 0, 0, 30.5),
#  (448, 0, 2, 'Mr. Edwy Arthur West', 'male', 36.0, 1, 2, 27.75),
#  (449, 0, 3, 'Mr. Ingvald Olai Olsen Hagland', 'male', 28.0, 1, 0, 19.9667),
#  (450, 0, 1, 'Mr. Benjamin Laventall Foreman', 'male', 30.0, 0, 0, 27.75),
#  (451, 1, 1, 'Mr. Samuel L Goldenberg', 'male', 49.0, 1, 0, 89.1042),
#  (452, 0, 3, 'Mr. Joseph Peduzzi', 'male', 24.0, 0, 0, 8.05),
#  (453, 1, 3, 'Mr. Ivan Jalsevac', 'male', 29.0, 0, 0, 7.8958),
#  (454, 0, 1, 'Mr. Francis Davis Millet', 'male', 65.0, 0, 0, 26.55),
#  (455,
#   1,
#   1,
#   'Mrs. Frederick R (Marion) Kenyon',
#   'female',
#   41.0,
#   1,
#   0,
#   51.8625),
#  (456, 1, 2, 'Miss. Ellen Toomey', 'female', 50.0, 0, 0, 10.5),
#  (457, 0, 3, 'Mr. Maurice O Connor', 'male', 17.0, 0, 0, 7.75),
#  (458, 1, 1, 'Mr. Harry Anderson', 'male', 48.0, 0, 0, 26.55),
#  (459, 0, 3, 'Mr. William Morley', 'male', 34.0, 0, 0, 8.05),
#  (460, 0, 1, 'Mr. Arthur H Gee', 'male', 47.0, 0, 0, 38.5),
#  (461, 0, 2, 'Mr. Jacob Christian Milling', 'male', 48.0, 0, 0, 13.0),
#  (462, 0, 3, 'Mr. Simon Maisner', 'male', 34.0, 0, 0, 8.05),
#  (463, 0, 3, 'Mr. Manuel Estanslas Goncalves', 'male', 38.0, 0, 0, 7.05),
#  (464, 0, 2, 'Mr. William Campbell', 'male', 21.0, 0, 0, 0.0),
#  (465, 0, 1, 'Mr. John Montgomery Smart', 'male', 56.0, 0, 0, 26.55),
#  (466, 0, 3, 'Mr. James Scanlan', 'male', 22.0, 0, 0, 7.725),
#  (467, 1, 3, 'Miss. Helene Barbara Baclini', 'female', 0.75, 2, 1, 19.2583),
#  (468, 0, 3, 'Mr. Arthur Keefe', 'male', 39.0, 0, 0, 7.25),
#  (469, 0, 3, 'Mr. Luka Cacic', 'male', 38.0, 0, 0, 8.6625),
#  (470,
#   1,
#   2,
#   'Mrs. Edwy Arthur (Ada Mary Worth) West',
#   'female',
#   33.0,
#   1,
#   2,
#   27.75),
#  (471,
#   1,
#   2,
#   'Mrs. Amin S (Marie Marthe Thuillard) Jerwan',
#   'female',
#   23.0,
#   0,
#   0,
#   13.7917),
#  (472, 0, 3, 'Miss. Ida Sofia Strandberg', 'female', 22.0, 0, 0, 9.8375),
#  (473, 0, 1, 'Mr. George Quincy Clifford', 'male', 40.0, 0, 0, 52.0),
#  (474, 0, 2, 'Mr. Peter Henry Renouf', 'male', 34.0, 1, 0, 21.0),
#  (475, 0, 3, 'Mr. Lewis Richard Braund', 'male', 29.0, 1, 0, 7.0458),
#  (476, 0, 3, 'Mr. Nils August Karlsson', 'male', 22.0, 0, 0, 7.5208),
#  (477, 1, 3, 'Miss. Hildur E Hirvonen', 'female', 2.0, 0, 1, 12.2875),
#  (478, 0, 3, 'Master. Harold Victor Goodwin', 'male', 9.0, 5, 2, 46.9),
#  (479, 0, 2, 'Mr. Anthony Wood Frost', 'male', 37.0, 0, 0, 0.0),
#  (480, 0, 3, 'Mr. Richard Henry Rouse', 'male', 50.0, 0, 0, 8.05),
#  (481, 1, 3, 'Mrs. (Hedwig) Turkula', 'female', 63.0, 0, 0, 9.5875),
#  (482, 1, 1, 'Mr. Dickinson H Bishop', 'male', 25.0, 1, 0, 91.0792),
#  (483, 0, 3, 'Miss. Jeannie Lefebre', 'female', 8.0, 3, 1, 25.4667),
#  (484,
#   1,
#   1,
#   'Mrs. Frederick Maxfield (Jane Anne Forby) Hoyt',
#   'female',
#   35.0,
#   1,
#   0,
#   90.0),
#  (485, 0, 1, 'Mr. Edward Austin Kent', 'male', 58.0, 0, 0, 29.7),
#  (486, 0, 3, 'Mr. Francis William Somerton', 'male', 30.0, 0, 0, 8.05),
#  (487, 1, 3, 'Master. Eden Leslie Coutts', 'male', 9.0, 1, 1, 15.9),
#  (488,
#   0,
#   3,
#   'Mr. Konrad Mathias Reiersen Hagland',
#   'male',
#   19.0,
#   1,
#   0,
#   19.9667),
#  (489, 0, 3, 'Mr. Einar Windelov', 'male', 21.0, 0, 0, 7.25),
#  (490, 0, 1, 'Mr. Harry Markland Molson', 'male', 55.0, 0, 0, 30.5),
#  (491, 0, 1, 'Mr. Ramon Artagaveytia', 'male', 71.0, 0, 0, 49.5042),
#  (492, 0, 3, 'Mr. Edward Roland Stanley', 'male', 21.0, 0, 0, 8.05),
#  (493, 0, 3, 'Mr. Gerious Yousseff', 'male', 26.0, 0, 0, 14.4583),
#  (494, 1, 1, 'Miss. Elizabeth Mussey Eustis', 'female', 54.0, 1, 0, 78.2667),
#  (495, 0, 3, 'Mr. Frederick William Shellard', 'male', 55.0, 0, 0, 15.1),
#  (496,
#   0,
#   1,
#   'Mrs. Hudson J C (Bessie Waldo Daniels) Allison',
#   'female',
#   25.0,
#   1,
#   2,
#   151.55),
#  (497, 0, 3, 'Mr. Olof Svensson', 'male', 24.0, 0, 0, 7.7958),
#  (498, 0, 3, 'Mr. Petar Calic', 'male', 17.0, 0, 0, 8.6625),
#  (499, 0, 3, 'Miss. Mary Canavan', 'female', 21.0, 0, 0, 7.75),
#  (500, 0, 3, 'Miss. Bridget Mary O Sullivan', 'female', 21.0, 0, 0, 7.6292),
#  (501, 0, 3, 'Miss. Kristina Sofia Laitinen', 'female', 37.0, 0, 0, 9.5875),
#  (502, 1, 1, 'Miss. Roberta Maioni', 'female', 16.0, 0, 0, 86.5),
#  (503,
#   0,
#   1,
#   'Mr. Victor de Satode Penasco y Castellana',
#   'male',
#   18.0,
#   1,
#   0,
#   108.9),
#  (504,
#   1,
#   2,
#   'Mrs. Frederick Charles (Jane Richards) Quick',
#   'female',
#   33.0,
#   0,
#   2,
#   26.0),
#  (505, 1, 1, 'Mr. George Bradley', 'male', 37.0, 0, 0, 26.55),
#  (506, 0, 3, 'Mr. Henry Margido Olsen', 'male', 28.0, 0, 0, 22.525),
#  (507, 1, 3, 'Mr. Fang Lang', 'male', 26.0, 0, 0, 56.4958),
#  (508, 1, 3, 'Mr. Eugene Patrick Daly', 'male', 29.0, 0, 0, 7.75),
#  (509, 0, 3, 'Mr. James Webber', 'male', 66.0, 0, 0, 8.05),
#  (510, 1, 1, 'Mr. James Robert McGough', 'male', 36.0, 0, 0, 26.2875),
#  (511,
#   1,
#   1,
#   'Mrs. Martin (Elizabeth L. Barrett) Rothschild',
#   'female',
#   54.0,
#   1,
#   0,
#   59.4),
#  (512, 0, 3, 'Mr. Satio Coleff', 'male', 24.0, 0, 0, 7.4958),
#  (513, 0, 1, 'Mr. William Anderson Walker', 'male', 47.0, 0, 0, 34.0208),
#  (514, 1, 2, 'Mrs. (Amelia Milley) Lemore', 'female', 34.0, 0, 0, 10.5),
#  (515, 0, 3, 'Mr. Patrick Ryan', 'male', 30.0, 0, 0, 24.15),
#  (516,
#   1,
#   2,
#   'Mrs. William A (Florence Agnes Hughes) Angle',
#   'female',
#   36.0,
#   1,
#   0,
#   26.0),
#  (517, 0, 3, 'Mr. Stefo Pavlovic', 'male', 32.0, 0, 0, 7.8958),
#  (518, 1, 1, 'Miss. Anne Perreault', 'female', 30.0, 0, 0, 93.5),
#  (519, 0, 3, 'Mr. Janko Vovk', 'male', 22.0, 0, 0, 7.8958),
#  (520, 0, 3, 'Mr. Sarkis Lahoud', 'male', 35.0, 0, 0, 7.225),
#  (521,
#   1,
#   1,
#   'Mrs. Louis Albert (Ida Sophia Fischer) Hippach',
#   'female',
#   44.0,
#   0,
#   1,
#   57.9792),
#  (522, 0, 3, 'Mr. Fared Kassem', 'male', 18.0, 0, 0, 7.2292),
#  (523, 0, 3, 'Mr. James Farrell', 'male', 40.5, 0, 0, 7.75),
#  (524, 1, 2, 'Miss. Lucy Ridsdale', 'female', 50.0, 0, 0, 10.5),
#  (525, 0, 1, 'Mr. John Farthing', 'male', 49.0, 0, 0, 221.7792),
#  (526, 0, 3, 'Mr. Johan Werner Salonen', 'male', 39.0, 0, 0, 7.925),
#  (527, 0, 2, 'Mr. Richard George Hocking', 'male', 23.0, 2, 1, 11.5),
#  (528, 1, 2, 'Miss. Phyllis May Quick', 'female', 2.0, 1, 1, 26.0),
#  (529, 0, 3, 'Mr. Nakli Toufik', 'male', 17.0, 0, 0, 7.2292),
#  (530, 0, 3, 'Mr. Joseph Jr Elias', 'male', 17.0, 1, 1, 7.2292),
#  (531,
#   1,
#   3,
#   'Mrs. Catherine (Catherine Rizk) Peter',
#   'female',
#   24.0,
#   0,
#   2,
#   22.3583),
#  (532, 0, 3, 'Miss. Marija Cacic', 'female', 30.0, 0, 0, 8.6625),
#  (533, 1, 2, 'Miss. Eva Miriam Hart', 'female', 7.0, 0, 2, 26.25),
#  (534, 0, 1, 'Major. Archibald Willingham Butt', 'male', 45.0, 0, 0, 26.55),
#  (535, 1, 1, 'Miss. Bertha LeRoy', 'female', 30.0, 0, 0, 106.425),
#  (536, 0, 3, 'Mr. Samuel Beard Risien', 'male', 69.0, 0, 0, 14.5),
#  (537, 1, 1, 'Miss. Hedwig Margaritha Frolicher', 'female', 22.0, 0, 2, 49.5),
#  (538, 1, 1, 'Miss. Harriet R Crosby', 'female', 36.0, 0, 2, 71.0),
#  (539,
#   0,
#   3,
#   'Miss. Ingeborg Constanzia Andersson',
#   'female',
#   9.0,
#   4,
#   2,
#   31.275),
#  (540, 0, 3, 'Miss. Sigrid Elisabeth Andersson', 'female', 11.0, 4, 2, 31.275),
#  (541, 1, 2, 'Mr. Edward Beane', 'male', 32.0, 1, 0, 26.0),
#  (542, 0, 1, 'Mr. Walter Donald Douglas', 'male', 50.0, 1, 0, 106.425),
#  (543, 0, 1, 'Mr. Arthur Ernest Nicholson', 'male', 64.0, 0, 0, 26.0),
#  (544, 1, 2, 'Mrs. Edward (Ethel Clarke) Beane', 'female', 19.0, 1, 0, 26.0),
#  (545, 1, 2, 'Mr. Julian Padro y Manent', 'male', 27.0, 0, 0, 13.8625),
#  (546, 0, 3, 'Mr. Frank John Goldsmith', 'male', 33.0, 1, 1, 20.525),
#  (547, 1, 2, 'Master. John Morgan Jr Davies', 'male', 8.0, 1, 1, 36.75),
#  (548, 1, 1, 'Mr. John Borland Jr Thayer', 'male', 17.0, 0, 2, 110.8833),
#  (549, 0, 2, 'Mr. Percival James R Sharp', 'male', 27.0, 0, 0, 26.0),
#  (550, 0, 3, 'Mr. Timothy O Brien', 'male', 21.0, 0, 0, 7.8292),
#  (551, 1, 3, 'Mr. Fahim Leeni', 'male', 22.0, 0, 0, 7.225),
#  (552, 1, 3, 'Miss. Velin Ohman', 'female', 22.0, 0, 0, 7.775),
#  (553, 0, 1, 'Mr. George Wright', 'male', 62.0, 0, 0, 26.55),
#  (554,
#   1,
#   1,
#   'Lady. (Lucille Christiana Sutherland)Duff Gordon',
#   'female',
#   48.0,
#   1,
#   0,
#   39.6),
#  (555, 0, 1, 'Mr. Victor Robbins', 'male', 45.0, 0, 0, 227.525),
#  (556,
#   1,
#   1,
#   'Mrs. Emil (Tillie Mandelbaum) Taussig',
#   'female',
#   39.0,
#   1,
#   1,
#   79.65),
#  (557,
#   1,
#   3,
#   'Mrs. Guillaume Joseph (Emma) de Messemaeker',
#   'female',
#   36.0,
#   1,
#   0,
#   17.4),
#  (558, 0, 3, 'Mr. Thomas Rowan Morrow', 'male', 30.0, 0, 0, 7.75),
#  (559, 0, 3, 'Mr. Husein Sivic', 'male', 40.0, 0, 0, 7.8958),
#  (560, 0, 2, 'Mr. Robert Douglas Norman', 'male', 28.0, 0, 0, 13.5),
#  (561, 0, 3, 'Mr. John Simmons', 'male', 40.0, 0, 0, 8.05),
#  (562, 0, 3, 'Miss. (Marion Ogden) Meanwell', 'female', 62.0, 0, 0, 8.05),
#  (563, 0, 3, 'Mr. Alfred J Davies', 'male', 24.0, 2, 0, 24.15),
#  (564, 0, 3, 'Mr. Ilia Stoytcheff', 'male', 19.0, 0, 0, 7.8958),
#  (565,
#   0,
#   3,
#   'Mrs. Nils (Alma Cornelia Berglund) Palsson',
#   'female',
#   29.0,
#   0,
#   4,
#   21.075),
#  (566, 0, 3, 'Mr. Tannous Doharr', 'male', 28.0, 0, 0, 7.2292),
#  (567, 1, 3, 'Mr. Carl Jonsson', 'male', 32.0, 0, 0, 7.8542),
#  (568, 1, 2, 'Mr. George Harris', 'male', 62.0, 0, 0, 10.5),
#  (569,
#   1,
#   1,
#   'Mrs. Edward Dale (Charlotte Lamson) Appleton',
#   'female',
#   53.0,
#   2,
#   0,
#   51.4792),
#  (570, 1, 1, 'Mr. John Irwin Flynn', 'male', 36.0, 0, 0, 26.3875),
#  (571, 1, 3, 'Miss. Mary Kelly', 'female', 22.0, 0, 0, 7.75),
#  (572, 0, 3, 'Mr. Alfred George John Rush', 'male', 16.0, 0, 0, 8.05),
#  (573, 0, 3, 'Mr. George Patchett', 'male', 19.0, 0, 0, 14.5),
#  (574, 1, 2, 'Miss. Ethel Garside', 'female', 34.0, 0, 0, 13.0),
#  (575,
#   1,
#   1,
#   'Mrs. William Baird (Alice Munger) Silvey',
#   'female',
#   39.0,
#   1,
#   0,
#   55.9),
#  (576, 0, 3, 'Mrs. Joseph (Maria Elias) Caram', 'female', 18.0, 1, 0, 14.4583),
#  (577, 1, 3, 'Mr. Eiriik Jussila', 'male', 32.0, 0, 0, 7.925),
#  (578, 1, 2, 'Miss. Julie Rachel Christy', 'female', 25.0, 1, 1, 30.0),
#  (579,
#   1,
#   1,
#   'Mrs. John Borland (Marian Longstreth Morris) Thayer',
#   'female',
#   39.0,
#   1,
#   1,
#   110.8833),
#  (580, 0, 2, 'Mr. William James Downton', 'male', 54.0, 0, 0, 26.0),
#  (581, 0, 1, 'Mr. John Hugo Ross', 'male', 36.0, 0, 0, 40.125),
#  (582, 0, 3, 'Mr. Uscher Paulner', 'male', 16.0, 0, 0, 8.7125),
#  (583, 1, 1, 'Miss. Ruth Taussig', 'female', 18.0, 0, 2, 79.65),
#  (584, 0, 2, 'Mr. John Denzil Jarvis', 'male', 47.0, 0, 0, 15.0),
#  (585, 1, 1, 'Mr. Maxmillian Frolicher-Stehli', 'male', 60.0, 1, 1, 79.2),
#  (586, 0, 3, 'Mr. Eliezer Gilinski', 'male', 22.0, 0, 0, 8.05),
#  (587, 0, 3, 'Mr. Joseph Murdlin', 'male', 22.0, 0, 0, 8.05),
#  (588, 0, 3, 'Mr. Matti Rintamaki', 'male', 35.0, 0, 0, 7.125),
#  (589,
#   1,
#   1,
#   'Mrs. Walter Bertram (Martha Eustis) Stephenson',
#   'female',
#   52.0,
#   1,
#   0,
#   78.2667),
#  (590, 0, 3, 'Mr. William James Elsbury', 'male', 47.0, 0, 0, 7.25),
#  (591, 0, 3, 'Miss. Mary Bourke', 'female', 40.0, 0, 2, 7.75),
#  (592, 0, 2, 'Mr. John Henry Chapman', 'male', 37.0, 1, 0, 26.0),
#  (593, 0, 3, 'Mr. Jean Baptiste Van Impe', 'male', 36.0, 1, 1, 24.15),
#  (594, 1, 2, 'Miss. Jessie Wills Leitch', 'female', 31.0, 0, 0, 33.0),
#  (595, 0, 3, 'Mr. Alfred Johnson', 'male', 49.0, 0, 0, 0.0),
#  (596, 0, 3, 'Mr. Hanna Boulos', 'male', 18.0, 0, 0, 7.225),
#  (597, 1, 1, 'Sir. Cosmo Edmund Duff Gordon', 'male', 49.0, 1, 0, 56.9292),
#  (598,
#   1,
#   2,
#   'Mrs. Sidney Samuel (Amy Frances Christy) Jacobsohn',
#   'female',
#   24.0,
#   2,
#   1,
#   27.0),
#  (599, 0, 3, 'Mr. Petco Slabenoff', 'male', 42.0, 0, 0, 7.8958),
#  (600, 0, 1, 'Mr. Charles H Harrington', 'male', 37.0, 0, 0, 42.4),
#  (601, 0, 3, 'Mr. Ernst William Torber', 'male', 44.0, 0, 0, 8.05),
#  (602, 1, 1, 'Mr. Harry Homer', 'male', 35.0, 0, 0, 26.55),
#  (603, 0, 3, 'Mr. Edvard Bengtsson Lindell', 'male', 36.0, 1, 0, 15.55),
#  (604, 0, 3, 'Mr. Milan Karaic', 'male', 30.0, 0, 0, 7.8958),
#  (605, 1, 1, 'Mr. Robert Williams Daniel', 'male', 27.0, 0, 0, 30.5),
#  (606,
#   1,
#   2,
#   'Mrs. Joseph (Juliette Marie Louise Lafargue) Laroche',
#   'female',
#   22.0,
#   1,
#   2,
#   41.5792),
#  (607, 1, 1, 'Miss. Elizabeth W Shutes', 'female', 40.0, 0, 0, 153.4625),
#  (608,
#   0,
#   3,
#   'Mrs. Anders Johan (Alfrida Konstantia Brogren) Andersson',
#   'female',
#   39.0,
#   1,
#   5,
#   31.275),
#  (609, 0, 3, 'Mr. Jose Neto Jardin', 'male', 21.0, 0, 0, 7.05),
#  (610, 1, 3, 'Miss. Margaret Jane Murphy', 'female', 18.0, 1, 0, 15.5),
#  (611, 0, 3, 'Mr. John Horgan', 'male', 22.0, 0, 0, 7.75),
#  (612, 0, 3, 'Mr. William Alfred Brocklebank', 'male', 35.0, 0, 0, 8.05),
#  (613, 1, 2, 'Miss. Alice Herman', 'female', 24.0, 1, 2, 65.0),
#  (614, 0, 3, 'Mr. Ernst Gilbert Danbom', 'male', 34.0, 1, 1, 14.4),
#  (615,
#   0,
#   3,
#   'Mrs. William Arthur (Cordelia K Stanlick) Lobb',
#   'female',
#   26.0,
#   1,
#   0,
#   16.1),
#  (616, 1, 2, 'Miss. Marion Louise Becker', 'female', 4.0, 2, 1, 39.0),
#  (617, 0, 2, 'Mr. Lawrence Gavey', 'male', 26.0, 0, 0, 10.5),
#  (618, 0, 3, 'Mr. Antoni Yasbeck', 'male', 27.0, 1, 0, 14.4542),
#  (619, 1, 1, 'Mr. Edwin Nelson Jr Kimball', 'male', 42.0, 1, 0, 52.5542),
#  (620, 1, 3, 'Mr. Sahid Nakid', 'male', 20.0, 1, 1, 15.7417),
#  (621, 0, 3, 'Mr. Henry Damsgaard Hansen', 'male', 21.0, 0, 0, 7.8542),
#  (622, 0, 3, 'Mr. David John Bowen', 'male', 21.0, 0, 0, 16.1),
#  (623, 0, 1, 'Mr. Frederick Sutton', 'male', 61.0, 0, 0, 32.3208),
#  (624, 0, 2, 'Rev. Charles Leonard Kirkland', 'male', 57.0, 0, 0, 12.35),
#  (625, 1, 1, 'Miss. Gretchen Fiske Longley', 'female', 21.0, 0, 0, 77.9583),
#  (626, 0, 3, 'Mr. Guentcho Bostandyeff', 'male', 26.0, 0, 0, 7.8958),
#  (627, 0, 3, 'Mr. Patrick D O Connell', 'male', 18.0, 0, 0, 7.7333),
#  (628, 1, 1, 'Mr. Algernon Henry Wilson Barkworth', 'male', 80.0, 0, 0, 30.0),
#  (629, 0, 3, 'Mr. Johan Svensson Lundahl', 'male', 51.0, 0, 0, 7.0542),
#  (630, 1, 1, 'Dr. Max Stahelin-Maeglin', 'male', 32.0, 0, 0, 30.5),
#  (631, 0, 1, 'Mr. William Henry Marsh Parr', 'male', 30.0, 0, 0, 0.0),
#  (632, 0, 3, 'Miss. Mabel Skoog', 'female', 9.0, 3, 2, 27.9),
#  (633, 1, 2, 'Miss. Mary Davis', 'female', 28.0, 0, 0, 13.0),
#  (634, 0, 3, 'Mr. Antti Gustaf Leinonen', 'male', 32.0, 0, 0, 7.925),
#  (635, 0, 2, 'Mr. Harvey Collyer', 'male', 31.0, 1, 1, 26.25),
#  (636,
#   0,
#   3,
#   'Mrs. Juha (Maria Emilia Ojala) Panula',
#   'female',
#   41.0,
#   0,
#   5,
#   39.6875),
#  (637, 0, 3, 'Mr. Percival Thorneycroft', 'male', 37.0, 1, 0, 16.1),
#  (638, 0, 3, 'Mr. Hans Peder Jensen', 'male', 20.0, 0, 0, 7.8542),
#  (639, 1, 1, 'Mlle. Emma Sagesser', 'female', 24.0, 0, 0, 69.3),
#  (640, 0, 3, 'Miss. Margit Elizabeth Skoog', 'female', 2.0, 3, 2, 27.9),
#  (641, 1, 3, 'Mr. Choong Foo', 'male', 32.0, 0, 0, 56.4958),
#  (642, 1, 3, 'Miss. Eugenie Baclini', 'female', 0.75, 2, 1, 19.2583),
#  (643, 1, 1, 'Mr. Henry Sleeper Harper', 'male', 48.0, 1, 0, 76.7292),
#  (644, 0, 3, 'Mr. Liudevit Cor', 'male', 19.0, 0, 0, 7.8958),
#  (645, 1, 1, 'Col. Oberst Alfons Simonius-Blumer', 'male', 56.0, 0, 0, 35.5),
#  (646, 0, 3, 'Mr. Edward Willey', 'male', 21.0, 0, 0, 7.55),
#  (647, 1, 3, 'Miss. Amy Zillah Elsie Stanley', 'female', 23.0, 0, 0, 7.55),
#  (648, 0, 3, 'Mr. Mito Mitkoff', 'male', 23.0, 0, 0, 7.8958),
#  (649, 1, 2, 'Miss. Elsie Doling', 'female', 18.0, 0, 1, 23.0),
#  (650, 0, 3, 'Mr. Johannes Halvorsen Kalvik', 'male', 21.0, 0, 0, 8.4333),
#  (651, 1, 3, 'Miss. Hanora O Leary', 'female', 16.0, 0, 0, 7.8292),
#  (652, 0, 3, 'Miss. Hanora Hegarty', 'female', 18.0, 0, 0, 6.75),
#  (653, 0, 2, 'Mr. Leonard Mark Hickman', 'male', 24.0, 2, 0, 73.5),
#  (654, 0, 3, 'Mr. Alexander Radeff', 'male', 27.0, 0, 0, 7.8958),
#  (655, 0, 3, 'Mrs. John (Catherine) Bourke', 'female', 32.0, 1, 1, 15.5),
#  (656, 0, 2, 'Mr. George Floyd Eitemiller', 'male', 23.0, 0, 0, 13.0),
#  (657, 0, 1, 'Mr. Arthur Webster Newell', 'male', 58.0, 0, 2, 113.275),
# ...
#  (671, 1, 2, 'Mr. Charles Wilhelms', 'male', 31.0, 0, 0, 13.0),
#  (672, 0, 2, 'Mr. Ennis Hastings Watson', 'male', 19.0, 0, 0, 0.0),
#  (673, 0, 3, 'Mr. Gustaf Hjalmar Edvardsson', 'male', 18.0, 0, 0, 7.775),
#  (674, 0, 3, 'Mr. Frederick Charles Sawyer', 'male', 24.5, 0, 0, 8.05),
#  (675, 1, 3, 'Miss. Anna Sofia Turja', 'female', 18.0, 0, 0, 9.8417),
#  (676,
#   0,
#   3,
#   'Mrs. Frederick (Augusta Tyler) Goodwin',
#   'female',
#   43.0,
#   1,
#   6,
#   46.9),
#  (677,
#   1,
#   1,
#   'Mr. Thomas Drake Martinez Cardeza',
#   'male',
#   36.0,
#   0,
#   1,
#   512.3292),
#  (678, 0, 3, 'Miss. Katie Peters', 'female', 28.0, 0, 0, 8.1375),
#  (679, 1, 1, 'Mr. Hammad Hassab', 'male', 27.0, 0, 0, 76.7292),
#  (680, 0, 3, 'Mr. Thor Anderson Olsvigen', 'male', 20.0, 0, 0, 9.225),
#  (681, 0, 3, 'Mr. Charles Edward Goodwin', 'male', 14.0, 5, 2, 46.9),
#  (682, 0, 2, 'Mr. Thomas William Solomon Brown', 'male', 60.0, 1, 1, 39.0),
#  (683,
#   0,
#   2,
#   'Mr. Joseph Philippe Lemercier Laroche',
#   'male',
#   25.0,
#   1,
#   2,
#   41.5792),
#  (684, 0, 3, 'Mr. Jaako Arnold Panula', 'male', 14.0, 4, 1, 39.6875),
#  (685, 0, 3, 'Mr. Branko Dakic', 'male', 19.0, 0, 0, 10.1708),
#  (686, 0, 3, 'Mr. Eberhard Thelander Fischer', 'male', 18.0, 0, 0, 7.7958),
#  (687,
#   1,
#   1,
#   'Miss. Georgette Alexandra Madill',
#   'female',
#   15.0,
#   0,
#   1,
#   211.3375),
#  (688, 1, 1, 'Mr. Albert Adrian Dick', 'male', 31.0, 1, 0, 57.0),
#  (689, 1, 3, 'Miss. Manca Karun', 'female', 4.0, 0, 1, 13.4167),
#  (690, 1, 3, 'Mr. Ali Lam', 'male', 37.0, 0, 0, 56.4958),
#  (691, 0, 3, 'Mr. Khalil Saad', 'male', 25.0, 0, 0, 7.225),
#  (692, 0, 1, 'Col. John Weir', 'male', 60.0, 0, 0, 26.55),
#  (693, 0, 2, 'Mr. Charles Henry Chapman', 'male', 52.0, 0, 0, 13.5),
#  (694, 0, 3, 'Mr. James Kelly', 'male', 44.0, 0, 0, 8.05),
#  (695, 1, 3, 'Miss. Katherine Mullens', 'female', 19.0, 0, 0, 7.7333),
#  (696, 0, 1, 'Mr. John Borland Thayer', 'male', 49.0, 1, 1, 110.8833),
#  (697,
#   0,
#   3,
#   'Mr. Adolf Mathias Nicolai Olsen Humblen',
#   'male',
#   42.0,
#   0,
#   0,
#   7.65),
#  (698,
#   1,
#   1,
#   'Mrs. John Jacob (Madeleine Talmadge Force) Astor',
#   'female',
#   18.0,
#   1,
#   0,
#   227.525),
#  (699, 1, 1, 'Mr. Spencer Victor Silverthorne', 'male', 35.0, 0, 0, 26.2875),
#  (700, 0, 3, 'Miss. Saiide Barbara', 'female', 18.0, 0, 1, 14.4542),
#  (701, 0, 3, 'Mr. Martin Gallagher', 'male', 25.0, 0, 0, 7.7417),
#  (702, 0, 3, 'Mr. Henrik Juul Hansen', 'male', 26.0, 1, 0, 7.8542),
#  (703, 0, 2, 'Mr. Henry Samuel Morley', 'male', 39.0, 0, 0, 26.0),
#  (704, 1, 2, 'Mrs. Florence Kelly', 'female', 45.0, 0, 0, 13.5),
#  (705, 1, 1, 'Mr. Edward Pennington Calderhead', 'male', 42.0, 0, 0, 26.2875),
#  (706, 1, 1, 'Miss. Alice Cleaver', 'female', 22.0, 0, 0, 151.55),
#  (707, 1, 3, 'Master. Halim Gonios Moubarek', 'male', 4.0, 1, 1, 15.2458),
#  (708, 1, 1, 'Mlle. Berthe Antonine Mayne', 'female', 24.0, 0, 0, 49.5042),
#  (709, 0, 1, 'Mr. Herman Klaber', 'male', 41.0, 0, 0, 26.55),
#  (710, 1, 1, 'Mr. Elmer Zebley Taylor', 'male', 48.0, 1, 0, 52.0),
#  (711, 0, 3, 'Mr. August Viktor Larsson', 'male', 29.0, 0, 0, 9.4833),
#  (712, 0, 2, 'Mr. Samuel Greenberg', 'male', 52.0, 0, 0, 13.0),
#  (713,
#   0,
#   3,
#   'Mr. Peter Andreas Lauritz Andersen Soholt',
#   'male',
#   19.0,
#   0,
#   0,
#   7.65),
#  (714, 1, 1, 'Miss. Caroline Louise Endres', 'female', 38.0, 0, 0, 227.525),
#  (715, 1, 2, 'Miss. Edwina Celia Troutt', 'female', 27.0, 0, 0, 10.5),
#  (716, 0, 3, 'Mr. Malkolm Joackim Johnson', 'male', 33.0, 0, 0, 7.775),
#  (717, 1, 2, 'Miss. Annie Jessie Harper', 'female', 6.0, 0, 1, 33.0),
#  (718, 0, 3, 'Mr. Svend Lauritz Jensen', 'male', 17.0, 1, 0, 7.0542),
#  (719, 0, 2, 'Mr. William Henry Gillespie', 'male', 34.0, 0, 0, 13.0),
#  (720, 0, 2, 'Mr. Henry Price Hodges', 'male', 50.0, 0, 0, 13.0),
#  (721, 1, 1, 'Mr. Norman Campbell Chambers', 'male', 27.0, 1, 0, 53.1),
#  (722, 0, 3, 'Mr. Luka Oreskovic', 'male', 20.0, 0, 0, 8.6625),
#  (723,
#   1,
#   2,
#   'Mrs. Peter Henry (Lillian Jefferys) Renouf',
#   'female',
#   30.0,
#   3,
#   0,
#   21.0),
#  (724, 1, 3, 'Miss. Margareth Mannion', 'female', 28.0, 0, 0, 7.7375),
#  (725, 0, 2, 'Mr. Kurt Arnold Gottfrid Bryhl', 'male', 25.0, 1, 0, 26.0),
#  (726, 0, 3, 'Miss. Pieta Sofia Ilmakangas', 'female', 25.0, 1, 0, 7.925),
#  (727, 1, 1, 'Miss. Elisabeth Walton Allen', 'female', 29.0, 0, 0, 211.3375),
#  (728, 0, 3, 'Mr. Houssein G N Hassan', 'male', 11.0, 0, 0, 18.7875),
#  (729, 0, 2, 'Mr. Robert J Knight', 'male', 41.0, 0, 0, 0.0),
#  (730, 0, 2, 'Mr. William John Berriman', 'male', 23.0, 0, 0, 13.0),
#  (731, 0, 2, 'Mr. Moses Aaron Troupiansky', 'male', 23.0, 0, 0, 13.0),
#  (732, 0, 3, 'Mr. Leslie Williams', 'male', 28.5, 0, 0, 16.1),
#  (733,
#   0,
#   3,
#   'Mrs. Edward (Margaret Ann Watson) Ford',
#   'female',
#   48.0,
#   1,
#   3,
#   34.375),
#  (734, 1, 1, 'Mr. Gustave J Lesurer', 'male', 35.0, 0, 0, 512.3292),
#  (735, 0, 3, 'Mr. Kanio Ivanoff', 'male', 20.0, 0, 0, 7.8958),
#  (736, 0, 3, 'Mr. Minko Nankoff', 'male', 32.0, 0, 0, 7.8958),
#  (737, 1, 1, 'Mr. Walter James Hawksford', 'male', 45.0, 0, 0, 30.0),
#  (738, 0, 1, 'Mr. Tyrell William Cavendish', 'male', 36.0, 1, 0, 78.85),
#  (739, 1, 1, 'Miss. Susan Parker Ryerson', 'female', 21.0, 2, 2, 262.375),
#  (740, 0, 3, 'Mr. Neal McNamee', 'male', 24.0, 1, 0, 16.1),
#  (741, 1, 3, 'Mr. Juho Stranden', 'male', 31.0, 0, 0, 7.925),
#  (742, 0, 1, 'Capt. Edward Gifford Crosby', 'male', 70.0, 1, 1, 71.0),
#  (743, 0, 3, 'Mr. Rossmore Edward Abbott', 'male', 16.0, 1, 1, 20.25),
#  (744, 1, 2, 'Miss. Anna Sinkkonen', 'female', 30.0, 0, 0, 13.0),
#  (745, 0, 1, 'Mr. Daniel Warner Marvin', 'male', 19.0, 1, 0, 53.1),
#  (746, 0, 3, 'Mr. Michael Connaghton', 'male', 31.0, 0, 0, 7.75),
#  (747, 1, 2, 'Miss. Joan Wells', 'female', 4.0, 1, 1, 23.0),
#  (748, 1, 3, 'Master. Meier Moor', 'male', 6.0, 0, 1, 12.475),
#  (749, 0, 3, 'Mr. Johannes Joseph Vande Velde', 'male', 33.0, 0, 0, 9.5),
#  (750, 0, 3, 'Mr. Lalio Jonkoff', 'male', 23.0, 0, 0, 7.8958),
#  (751, 1, 2, 'Mrs. Samuel (Jane Laver) Herman', 'female', 48.0, 1, 2, 65.0),
#  (752, 1, 2, 'Master. Viljo Hamalainen', 'male', 0.67, 1, 1, 14.5),
#  (753, 0, 3, 'Mr. August Sigfrid Carlsson', 'male', 28.0, 0, 0, 7.7958),
#  (754, 0, 2, 'Mr. Percy Andrew Bailey', 'male', 18.0, 0, 0, 11.5),
#  (755, 0, 3, 'Mr. Thomas Leonard Theobald', 'male', 34.0, 0, 0, 8.05),
#  (756,
#   1,
#   1,
#   'the Countess. of (Lucy Noel Martha Dyer-Edwards) Rothes',
#   'female',
#   33.0,
#   0,
#   0,
#   86.5),
#  (757, 0, 3, 'Mr. John Garfirth', 'male', 23.0, 0, 0, 14.5),
#  (758, 0, 3, 'Mr. Iisakki Antino Aijo Nirva', 'male', 41.0, 0, 0, 7.125),
#  (759, 1, 3, 'Mr. Hanna Assi Barah', 'male', 20.0, 0, 0, 7.2292),
#  (760,
#   1,
#   1,
#   'Mrs. William Ernest (Lucile Polk) Carter',
#   'female',
#   36.0,
#   1,
#   2,
#   120.0),
#  (761, 0, 3, 'Mr. Hans Linus Eklund', 'male', 16.0, 0, 0, 7.775),
#  (762,
#   1,
#   1,
#   'Mrs. John C (Anna Andrews) Hogeboom',
#   'female',
#   51.0,
#   1,
#   0,
#   77.9583),
#  (763, 0, 1, 'Dr. Arthur Jackson Brewe', 'male', 46.0, 0, 0, 39.6),
#  (764, 0, 3, 'Miss. Mary Mangan', 'female', 30.5, 0, 0, 7.75),
#  (765, 0, 3, 'Mr. Daniel J Moran', 'male', 28.0, 1, 0, 24.15),
#  (766, 0, 3, 'Mr. Daniel Danielsen Gronnestad', 'male', 32.0, 0, 0, 8.3625),
#  (767, 0, 3, 'Mr. Rene Aime Lievens', 'male', 24.0, 0, 0, 9.5),
#  (768, 0, 3, 'Mr. Niels Peder Jensen', 'male', 48.0, 0, 0, 7.8542),
#  (769, 0, 2, 'Mrs. (Mary) Mack', 'female', 57.0, 0, 0, 10.5),
#  (770, 0, 3, 'Mr. Dibo Elias', 'male', 29.0, 0, 0, 7.225),
#  (771,
#   1,
#   2,
#   'Mrs. Elizabeth (Eliza Needs) Hocking',
#   'female',
#   54.0,
#   1,
#   3,
#   23.0),
#  (772,
#   0,
#   3,
#   'Mr. Pehr Fabian Oliver Malkolm Myhrman',
#   'male',
#   18.0,
#   0,
#   0,
#   7.75),
#  (773, 0, 3, 'Mr. Roger Tobin', 'male', 20.0, 0, 0, 7.75),
#  (774, 1, 3, 'Miss. Virginia Ethel Emanuel', 'female', 5.0, 0, 0, 12.475),
#  (775, 0, 3, 'Mr. Thomas J Kilgannon', 'male', 22.0, 0, 0, 7.7375),
#  (776,
#   1,
#   1,
#   'Mrs. Edward Scott (Elisabeth Walton McMillan) Robert',
#   'female',
#   43.0,
#   0,
#   1,
#   211.3375),
#  (777, 1, 3, 'Miss. Banoura Ayoub', 'female', 13.0, 0, 0, 7.2292),
#  (778,
#   1,
#   1,
#   'Mrs. Albert Adrian (Vera Gillespie) Dick',
#   'female',
#   17.0,
#   1,
#   0,
#   57.0),
#  (779, 0, 1, 'Mr. Milton Clyde Long', 'male', 29.0, 0, 0, 30.0),
#  (780, 0, 3, 'Mr. Andrew G Johnston', 'male', 35.0, 1, 2, 23.45),
#  (781, 0, 3, 'Mr. William Ali', 'male', 25.0, 0, 0, 7.05),
#  (782, 0, 3, 'Mr. Abraham (David Lishin) Harmer', 'male', 25.0, 0, 0, 7.25),
#  (783, 1, 3, 'Miss. Anna Sofia Sjoblom', 'female', 18.0, 0, 0, 7.4958),
#  (784, 0, 3, 'Master. George Hugh Rice', 'male', 8.0, 4, 1, 29.125),
#  (785, 1, 3, 'Master. Bertram Vere Dean', 'male', 1.0, 1, 2, 20.575),
#  (786, 0, 1, 'Mr. Benjamin Guggenheim', 'male', 46.0, 0, 0, 79.2),
#  (787, 0, 3, 'Mr. Andrew Keane', 'male', 20.0, 0, 0, 7.75),
#  (788, 0, 2, 'Mr. Alfred Gaskell', 'male', 16.0, 0, 0, 26.0),
#  (789, 0, 3, 'Miss. Stella Anna Sage', 'female', 21.0, 8, 2, 69.55),
#  (790, 0, 1, 'Mr. William Fisher Hoyt', 'male', 43.0, 0, 0, 30.6958),
#  (791, 0, 3, 'Mr. Ristiu Dantcheff', 'male', 25.0, 0, 0, 7.8958),
#  (792, 0, 2, 'Mr. Richard Otter', 'male', 39.0, 0, 0, 13.0),
#  (793, 1, 1, 'Dr. Alice (Farnham) Leader', 'female', 49.0, 0, 0, 25.9292),
#  (794, 1, 3, 'Mrs. Mara Osman', 'female', 31.0, 0, 0, 8.6833),
#  (795, 0, 3, 'Mr. Yousseff Ibrahim Shawah', 'male', 30.0, 0, 0, 7.2292),
#  (796,
#   0,
#   3,
#   'Mrs. Jean Baptiste (Rosalie Paula Govaert) Van Impe',
#   'female',
#   30.0,
#   1,
#   1,
#   24.15),
#  (797, 0, 2, 'Mr. Martin Ponesell', 'male', 34.0, 0, 0, 13.0),
#  (798,
#   1,
#   2,
#   'Mrs. Harvey (Charlotte Annie Tate) Collyer',
#   'female',
#   31.0,
#   1,
#   1,
#   26.25),
#  (799, 1, 1, 'Master. William Thornton II Carter', 'male', 11.0, 1, 2, 120.0),
#  (800, 1, 3, 'Master. Assad Alexander Thomas', 'male', 0.42, 0, 1, 8.5167),
#  (801, 1, 3, 'Mr. Oskar Arvid Hedman', 'male', 27.0, 0, 0, 6.975),
#  (802, 0, 3, 'Mr. Karl Johan Johansson', 'male', 31.0, 0, 0, 7.775),
#  (803, 0, 1, 'Mr. Thomas Jr Andrews', 'male', 39.0, 0, 0, 0.0),
#  (804, 0, 3, 'Miss. Ellen Natalia Pettersson', 'female', 18.0, 0, 0, 7.775),
#  (805, 0, 2, 'Mr. August Meyer', 'male', 39.0, 0, 0, 13.0),
#  (806,
#   1,
#   1,
#   'Mrs. Norman Campbell (Bertha Griggs) Chambers',
#   'female',
#   33.0,
#   1,
#   0,
#   53.1),
#  (807, 0, 3, 'Mr. William Alexander', 'male', 26.0, 0, 0, 7.8875),
#  (808, 0, 3, 'Mr. James Lester', 'male', 39.0, 0, 0, 24.15),
#  (809, 0, 2, 'Mr. Richard James Slemen', 'male', 35.0, 0, 0, 10.5),
#  (810, 0, 3, 'Miss. Ebba Iris Alfrida Andersson', 'female', 6.0, 4, 2, 31.275),
#  (811, 0, 3, 'Mr. Ernest Portage Tomlin', 'male', 30.5, 0, 0, 8.05),
#  (812, 0, 1, 'Mr. Richard Fry', 'male', 39.0, 0, 0, 0.0),
#  (813, 0, 3, 'Miss. Wendla Maria Heininen', 'female', 23.0, 0, 0, 7.925),
#  (814, 0, 2, 'Mr. Albert Mallet', 'male', 31.0, 1, 1, 37.0042),
#  (815, 0, 3, 'Mr. John Fredrik Alexander Holm', 'male', 43.0, 0, 0, 6.45),
#  (816, 0, 3, 'Master. Karl Thorsten Skoog', 'male', 10.0, 3, 2, 27.9),
#  (817,
#   1,
#   1,
#   'Mrs. Charles Melville (Clara Jennings Gregg) Hays',
#   'female',
#   52.0,
#   1,
#   1,
#   93.5),
#  (818, 1, 3, 'Mr. Nikola Lulic', 'male', 27.0, 0, 0, 8.6625),
#  (819, 0, 1, 'Jonkheer. John George Reuchlin', 'male', 38.0, 0, 0, 0.0),
#  (820, 1, 3, 'Mrs. (Beila) Moor', 'female', 27.0, 0, 1, 12.475),
#  (821, 0, 3, 'Master. Urho Abraham Panula', 'male', 2.0, 4, 1, 39.6875),
#  (822, 0, 3, 'Mr. John Flynn', 'male', 36.0, 0, 0, 6.95),
#  (823, 0, 3, 'Mr. Len Lam', 'male', 23.0, 0, 0, 56.4958),
#  (824, 1, 2, 'Master. Andre Mallet', 'male', 1.0, 0, 2, 37.0042),
#  (825, 1, 3, 'Mr. Thomas Joseph McCormack', 'male', 19.0, 0, 0, 7.75),
#  (826,
#   1,
#   1,
#   'Mrs. George Nelson (Martha Evelyn) Stone',
#   'female',
#   62.0,
#   0,
#   0,
#   80.0),
#  (827,
#   1,
#   3,
#   'Mrs. Antoni (Selini Alexander) Yasbeck',
#   'female',
#   15.0,
#   1,
#   0,
#   14.4542),
#  (828, 1, 2, 'Master. George Sibley Richards', 'male', 0.83, 1, 1, 18.75),
#  (829, 0, 3, 'Mr. Amin Saad', 'male', 30.0, 0, 0, 7.2292),
#  (830, 0, 3, 'Mr. Albert Augustsson', 'male', 23.0, 0, 0, 7.8542),
#  (831, 0, 3, 'Mr. Owen George Allum', 'male', 18.0, 0, 0, 8.3),
#  (832, 1, 1, 'Miss. Sara Rebecca Compton', 'female', 39.0, 1, 1, 83.1583),
#  (833, 0, 3, 'Mr. Jakob Pasic', 'male', 21.0, 0, 0, 8.6625),
#  (834, 0, 3, 'Mr. Maurice Sirota', 'male', 20.0, 0, 0, 8.05),
#  (835, 1, 3, 'Mr. Chang Chip', 'male', 32.0, 0, 0, 56.4958),
#  (836, 1, 1, 'Mr. Pierre Marechal', 'male', 29.0, 0, 0, 29.7),
#  (837, 0, 3, 'Mr. Ilmari Rudolf Alhomaki', 'male', 20.0, 0, 0, 7.925),
#  (838, 0, 2, 'Mr. Thomas Charles Mudd', 'male', 16.0, 0, 0, 10.5),
#  (839, 1, 1, 'Miss. Augusta Serepeca', 'female', 30.0, 0, 0, 31.0),
#  (840, 0, 3, 'Mr. Peter L Lemberopolous', 'male', 34.5, 0, 0, 6.4375),
#  (841, 0, 3, 'Mr. Jeso Culumovic', 'male', 17.0, 0, 0, 8.6625),
#  (842, 0, 3, 'Mr. Anthony Abbing', 'male', 42.0, 0, 0, 7.55),
#  (843, 0, 3, 'Mr. Douglas Bullen Sage', 'male', 18.0, 8, 2, 69.55),
#  (844, 0, 3, 'Mr. Marin Markoff', 'male', 35.0, 0, 0, 7.8958),
#  (845, 0, 2, 'Rev. John Harper', 'male', 28.0, 0, 1, 33.0),
#  (846,
#   1,
#   1,
#   'Mrs. Samuel L (Edwiga Grabowska) Goldenberg',
#   'female',
#   40.0,
#   1,
#   0,
#   89.1042),
#  (847,
#   0,
#   3,
#   'Master. Sigvard Harald Elias Andersson',
#   'male',
#   4.0,
#   4,
#   2,
#   31.275),
#  (848, 0, 3, 'Mr. Johan Svensson', 'male', 74.0, 0, 0, 7.775),
#  (849, 0, 3, 'Miss. Nourelain Boulos', 'female', 9.0, 1, 1, 15.2458),
#  (850, 1, 1, 'Miss. Mary Conover Lines', 'female', 16.0, 0, 1, 39.4),
#  (851,
#   0,
#   2,
#   'Mrs. Ernest Courtenay (Lilian Hughes) Carter',
#   'female',
#   44.0,
#   1,
#   0,
#   26.0),
#  (852, 1, 3, 'Mrs. Sam (Leah Rosen) Aks', 'female', 18.0, 0, 1, 9.35),
#  (853,
#   1,
#   1,
#   'Mrs. George Dennick (Mary Hitchcock) Wick',
#   'female',
#   45.0,
#   1,
#   1,
#   164.8667),
#  (854, 1, 1, 'Mr. Peter Denis Daly', 'male', 51.0, 0, 0, 26.55),
#  (855,
#   1,
#   3,
#   'Mrs. Solomon (Latifa Qurban) Baclini',
#   'female',
#   24.0,
#   0,
#   3,
#   19.2583),
#  (856, 0, 3, 'Mr. Raihed Razi', 'male', 30.0, 0, 0, 7.2292),
#  (857, 0, 3, 'Mr. Claus Peter Hansen', 'male', 41.0, 2, 0, 14.1083),
#  (858, 0, 2, 'Mr. Frederick Edward Giles', 'male', 21.0, 1, 0, 11.5),
#  (859,
#   1,
#   1,
#   'Mrs. Frederick Joel (Margaret Welles Barron) Swift',
#   'female',
#   48.0,
#   0,
#   0,
#   25.9292),
#  (860, 0, 3, 'Miss. Dorothy Edith Sage', 'female', 14.0, 8, 2, 69.55),
#  (861, 0, 2, 'Mr. John William Gill', 'male', 24.0, 0, 0, 13.0),
#  (862, 1, 2, 'Mrs. (Karolina) Bystrom', 'female', 42.0, 0, 0, 13.0),
#  (863, 1, 2, 'Miss. Asuncion Duran y More', 'female', 27.0, 1, 0, 13.8583),
#  (864,
#   0,
#   1,
#   'Mr. Washington Augustus II Roebling',
#   'male',
#   31.0,
#   0,
#   0,
#   50.4958),
#  (865, 0, 3, 'Mr. Philemon van Melkebeke', 'male', 23.0, 0, 0, 9.5),
#  (866, 1, 3, 'Master. Harold Theodor Johnson', 'male', 4.0, 1, 1, 11.1333),
#  (867, 0, 3, 'Mr. Cerin Balkic', 'male', 26.0, 0, 0, 7.8958),
#  (868,
#   1,
#   1,
#   'Mrs. Richard Leonard (Sallie Monypeny) Beckwith',
#   'female',
#   47.0,
#   1,
#   1,
#   52.5542),
#  (869, 0, 1, 'Mr. Frans Olof Carlsson', 'male', 33.0, 0, 0, 5.0),
#  (870, 0, 3, 'Mr. Victor Vander Cruyssen', 'male', 47.0, 0, 0, 9.0),
#  (871,
#   1,
#   2,
#   'Mrs. Samuel (Hannah Wizosky) Abelson',
#   'female',
#   28.0,
#   1,
#   0,
#   24.0),
#  (872, 1, 3, 'Miss. Adele Kiamie Najib', 'female', 15.0, 0, 0, 7.225),
#  (873, 0, 3, 'Mr. Alfred Ossian Gustafsson', 'male', 20.0, 0, 0, 9.8458),
#  (874, 0, 3, 'Mr. Nedelio Petroff', 'male', 19.0, 0, 0, 7.8958),
#  (875, 0, 3, 'Mr. Kristo Laleff', 'male', 23.0, 0, 0, 7.8958),
#  (876,
#   1,
#   1,
#   'Mrs. Thomas Jr (Lily Alexenia Wilson) Potter',
#   'female',
#   56.0,
#   0,
#   1,
#   83.1583),
#  (877,
#   1,
#   2,
#   'Mrs. William (Imanita Parrish Hall) Shelley',
#   'female',
#   25.0,
#   0,
#   1,
#   26.0),
#  (878, 0, 3, 'Mr. Johann Markun', 'male', 33.0, 0, 0, 7.8958),
#  (879, 0, 3, 'Miss. Gerda Ulrika Dahlberg', 'female', 22.0, 0, 0, 10.5167),
#  (880, 0, 2, 'Mr. Frederick James Banfield', 'male', 28.0, 0, 0, 10.5),
#  (881, 0, 3, 'Mr. Henry Jr Sutehall', 'male', 25.0, 0, 0, 7.05),
#  (882,
#   0,
#   3,
#   'Mrs. William (Margaret Norton) Rice',
#   'female',
#   39.0,
#   0,
#   5,
#   29.125),
#  (883, 0, 2, 'Rev. Juozas Montvila', 'male', 27.0, 0, 0, 13.0),
#  (884, 1, 1, 'Miss. Margaret Edith Graham', 'female', 19.0, 0, 0, 30.0),
#  (885, 0, 3, 'Miss. Catherine Helen Johnston', 'female', 7.0, 1, 2, 23.45),
#  (886, 1, 1, 'Mr. Karl Howell Behr', 'male', 26.0, 0, 0, 30.0),
#  (887, 0, 3, 'Mr. Patrick Dooley', 'male', 32.0, 0, 0, 7.75)]

# %%
pg_curs.close()
pg_conn.commit()
