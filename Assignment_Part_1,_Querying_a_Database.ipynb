# %% [markdown]
# <a href="https://colab.research.google.com/github/JefNtungila/DS-Unit-3-Sprint-2-SQL-and-Databases/blob/master/Assignment_Part_1%2C_Querying_a_Database.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0e71704f-6953-4bb3-ba30-ac5131b24cad" name="files[]" multiple disabled />
#      <output id="result-0e71704f-6953-4bb3-ba30-ac5131b24cad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving rpg_db.sqlite3 to rpg_db.sqlite3
# ...

# %%
import sqlite3
conn = sqlite3.connect('rpg_db.sqlite3')
