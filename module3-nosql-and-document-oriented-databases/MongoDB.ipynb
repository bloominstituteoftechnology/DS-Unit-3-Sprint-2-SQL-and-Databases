# %% [markdown]
# ### Lecture Notes

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (3.7.2)

# %%
# !curl ipecho.net/plain

# %%
URL = 'mongodb://<USERNAME>:<PASSWORD>@cluster0-shard-00-00-bbxlp.mongodb.net:27017,cluster0-shard-00-01-bbxlp.mongodb.net:27017,cluster0-shard-00-02-bbxlp.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true'

# %%
connection_string = URL

# %%
import pymongo
client = pymongo.MongoClient(connection_string)

# %%
client.nodes
# Out:
# frozenset({('cluster0-shard-00-00-bbxlp.mongodb.net', 27017),
#            ('cluster0-shard-00-01-bbxlp.mongodb.net', 27017),
#            ('cluster0-shard-00-02-bbxlp.mongodb.net', 27017)})

# %%
client.server_info()

# %%
db = client.test3

# %%
dir(db)

# %%
db.test.insert
# Out:
# <bound method Collection.insert of Collection(Database(MongoClient(host=['cluster0-shard-00-02-bbxlp.mongodb.net:27017', 'cluster0-shard-00-01-bbxlp.mongodb.net:27017', 'cluster0-shard-00-00-bbxlp.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='Cluster0-shard-0', authsource='admin', retrywrites=True), 'test'), 'test')>

# %%
help(db.test.insert_one)

# %%
my_doc = {'cat': 'cute'}
if not db.test.find_one(my_doc):
  db.test.insert_one(my_doc)

# %%
db.test.find_one(my_doc)
# Out:
# {'_id': ObjectId('5c6d9e77265ae8009a4269ab'), 'cat': 'cute'}

# %%
db.test.insert_one({'cat': 'cute'})

# %%
results = db.test.find()
list(results)
# Out:
# [{'_id': ObjectId('5c6d9e77265ae8009a4269ab'), 'cat': 'cute'},
#  {'_id': ObjectId('5c6d9f1c265ae8009a4269ac'), 'cat': 'cute'}]

# %%
list(db.test.find({}))

# %%
# !pip install requests

# %% [markdown]
# ### Assignment

# %%
import requests
import json

# %%
data_url = 'https://raw.githubusercontent.com/LambdaSchool/Django-RPG/master/testdata.json'

# %%
# Request API data
res = requests.get(data_url)

# %%
#Check if API data has been received 
res.status_code

# %%
#Check the headers:
res.headers

# %%
#Convert res to json format
data = res.json()
data

# %%
#Check the data
for item in data[:1]:
  print(item.keys())
  print(item)
  print(item['fields'])
  print(type(item['fields']))
  print(item['fields'].keys())
  print(item['fields']['name'])
  for i in item['fields']:
    print(item['fields'][i])

# %%
db_game = client.test3
list(db_game.test.find({}))

# %%
#Insert API data into MongoDB
for item in data:
  for key in item.keys():
    if key == 0:
      key = '0'
  if not db_game.test.find_one(item):
    db_game.test.insert_one(item)

# %%
list(db_game.test.find({}))
# Out:
# [{'_id': ObjectId('5c6dc055265ae8009a4269ad'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [20, 58, 85],
#    'level': 0,
#    'name': 'Aliquid iste optio reiciendi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 1},
#  {'_id': ObjectId('5c6dc055265ae8009a4269ae'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [93, 115, 133],
#    'level': 0,
#    'name': 'Optio dolorem ex a',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 2},
#  {'_id': ObjectId('5c6dc055265ae8009a4269af'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [8, 43],
#    'level': 0,
#    'name': 'Minus c',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 3},
#  {'_id': ObjectId('5c6dc055265ae8009a4269b0'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [21, 82, 85, 135],
#    'level': 0,
#    'name': 'Sit ut repr',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 4},
#  {'_id': ObjectId('5c6dc056265ae8009a4269b1'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [7, 96, 140, 145],
#    'level': 0,
#    'name': 'At id recusandae expl',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 5},
#  {'_id': ObjectId('5c6dc056265ae8009a4269b2'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [93],
#    'level': 0,
#    'name': 'Non nobis et of',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 6},
#  {'_id': ObjectId('5c6dc056265ae8009a4269b3'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [38, 42, 85, 123, 166],
#    'level': 0,
#    'name': 'Perferendis',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 7},
#  {'_id': ObjectId('5c6dc056265ae8009a4269b4'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [43, 48, 119],
#    'level': 0,
#    'name': 'Accusantium amet quidem eve',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 8},
#  {'_id': ObjectId('5c6dc056265ae8009a4269b5'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [32, 106, 116, 125],
#    'level': 0,
#    'name': 'Sed nostrum inventore error m',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 9},
#  {'_id': ObjectId('5c6dc056265ae8009a4269b6'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [117, 129, 131, 135],
#    'level': 0,
#    'name': 'Harum repellendus omnis od',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 10},
#  {'_id': ObjectId('5c6dc056265ae8009a4269b7'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [54, 108, 158],
#    'level': 0,
#    'name': 'Itaque ut commodi,',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 11},
#  {'_id': ObjectId('5c6dc056265ae8009a4269b8'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [65, 115, 126],
#    'level': 0,
#    'name': 'Molestiae quis',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 12},
#  {'_id': ObjectId('5c6dc057265ae8009a4269b9'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [38, 44, 62, 125],
#    'level': 0,
#    'name': 'Ali',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 13},
#  {'_id': ObjectId('5c6dc057265ae8009a4269ba'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [34, 41, 65, 68],
#    'level': 0,
#    'name': 'Tempora quod optio possimus il',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 14},
#  {'_id': ObjectId('5c6dc057265ae8009a4269bb'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [34, 56, 74, 84],
#    'level': 0,
#    'name': 'Sed itaque beatae pari',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 15},
#  {'_id': ObjectId('5c6dc057265ae8009a4269bc'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [87],
#    'level': 0,
#    'name': 'Quam dolor',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 16},
#  {'_id': ObjectId('5c6dc057265ae8009a4269bd'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [64, 68, 116, 128, 136],
#    'level': 0,
#    'name': 'Molestias expedita',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 17},
#  {'_id': ObjectId('5c6dc057265ae8009a4269be'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [17, 60, 62, 64, 90],
#    'level': 0,
#    'name': 'Lauda',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 18},
#  {'_id': ObjectId('5c6dc057265ae8009a4269bf'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [5, 52, 113],
#    'level': 0,
#    'name': 'Incidunt sint perferen',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 19},
#  {'_id': ObjectId('5c6dc058265ae8009a4269c0'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [156],
#    'level': 0,
#    'name': 'Laboriosa',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 20},
#  {'_id': ObjectId('5c6dc058265ae8009a4269c1'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [33, 34, 51, 117],
#    'level': 0,
#    'name': 'Dolore esse nesciunt fugit com',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 21},
#  {'_id': ObjectId('5c6dc058265ae8009a4269c2'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [41, 43, 164],
#    'level': 0,
#    'name': 'Dolorum nam reic',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 22},
#  {'_id': ObjectId('5c6dc058265ae8009a4269c3'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [33, 61, 160],
#    'level': 0,
#    'name': 'Repellat ad numquam volu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 23},
#  {'_id': ObjectId('5c6dc058265ae8009a4269c4'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [8],
#    'level': 0,
#    'name': 'Facere enim velit eligend',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 24},
#  {'_id': ObjectId('5c6dc058265ae8009a4269c5'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [50, 122],
#    'level': 0,
#    'name': 'Sed ratione quis rep',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 25},
#  {'_id': ObjectId('5c6dc058265ae8009a4269c6'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [112, 149],
#    'level': 0,
#    'name': 'Doloribus neque',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 26},
#  {'_id': ObjectId('5c6dc058265ae8009a4269c7'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [10, 104, 148, 157, 172],
#    'level': 0,
#    'name': 'Ab voluptas se',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 27},
#  {'_id': ObjectId('5c6dc059265ae8009a4269c8'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [51],
#    'level': 0,
#    'name': 'Molestias m',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 28},
#  {'_id': ObjectId('5c6dc059265ae8009a4269c9'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [107, 120, 157, 170],
#    'level': 0,
#    'name': 'In pariatur corpori',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 29},
#  {'_id': ObjectId('5c6dc059265ae8009a4269ca'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [69, 109, 114, 138],
#    'level': 0,
#    'name': 'Possimus ad dignissimos vel, a',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 30},
#  {'_id': ObjectId('5c6dc059265ae8009a4269cb'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [9, 45, 61],
#    'level': 0,
#    'name': 'At minus accusa',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 31},
#  {'_id': ObjectId('5c6dc059265ae8009a4269cc'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [111, 142],
#    'level': 0,
#    'name': 'Ad necess',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 32},
#  {'_id': ObjectId('5c6dc059265ae8009a4269cd'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [64, 110],
#    'level': 0,
#    'name': 'Expedita c',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 33},
#  {'_id': ObjectId('5c6dc059265ae8009a4269ce'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [5, 90, 132, 160],
#    'level': 0,
#    'name': 'Voluptates sunt voluptas volu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 34},
#  {'_id': ObjectId('5c6dc05a265ae8009a4269cf'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [3, 62, 101, 165, 166],
#    'level': 0,
#    'name': 'Autem mollitia fuga lauda',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 35},
#  {'_id': ObjectId('5c6dc05a265ae8009a4269d0'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [29, 34, 141, 153, 155],
#    'level': 0,
#    'name': 'Sint quibusdam ob',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 36},
#  {'_id': ObjectId('5c6dc05a265ae8009a4269d1'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [20, 42, 54, 169, 174],
#    'level': 0,
#    'name': 'Rerum et o',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 37},
#  {'_id': ObjectId('5c6dc05a265ae8009a4269d2'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [80, 115, 124, 146, 165],
#    'level': 0,
#    'name': 'Doloribus dolore r',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 38},
#  {'_id': ObjectId('5c6dc05a265ae8009a4269d3'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [58, 150, 168],
#    'level': 0,
#    'name': 'Eaque su',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 39},
#  {'_id': ObjectId('5c6dc05a265ae8009a4269d4'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [26, 32, 147],
#    'level': 0,
#    'name': 'Vel molestias numqua',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 40},
#  {'_id': ObjectId('5c6dc05a265ae8009a4269d5'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [112, 168],
#    'level': 0,
#    'name': 'Iste assumenda repellat q',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 41},
#  {'_id': ObjectId('5c6dc05a265ae8009a4269d6'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [65, 92, 131],
#    'level': 0,
#    'name': 'Animi labo',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 42},
#  {'_id': ObjectId('5c6dc05b265ae8009a4269d7'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [131],
#    'level': 0,
#    'name': 'Eum culpa eaque ea omn',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 43},
#  {'_id': ObjectId('5c6dc05b265ae8009a4269d8'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [38],
#    'level': 0,
#    'name': 'Harum provident vel quam',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 44},
#  {'_id': ObjectId('5c6dc05b265ae8009a4269d9'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [12, 16, 66, 76],
#    'level': 0,
#    'name': 'Aspe',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 45},
#  {'_id': ObjectId('5c6dc05b265ae8009a4269da'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [84],
#    'level': 0,
#    'name': 'Nisi nequ',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 46},
#  {'_id': ObjectId('5c6dc05b265ae8009a4269db'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [35, 94, 136, 161],
#    'level': 0,
#    'name': 'Quod tempora',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 47},
#  {'_id': ObjectId('5c6dc05b265ae8009a4269dc'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [45, 47, 126, 137],
#    'level': 0,
#    'name': 'Porro aliq',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 48},
#  {'_id': ObjectId('5c6dc05b265ae8009a4269dd'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [2, 41, 86, 113],
#    'level': 0,
#    'name': 'Quas',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 49},
#  {'_id': ObjectId('5c6dc05b265ae8009a4269de'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [29],
#    'level': 0,
#    'name': 'Magnam eligendi quia animi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 50},
#  {'_id': ObjectId('5c6dc05c265ae8009a4269df'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [73, 79, 153],
#    'level': 0,
#    'name': 'Officiis se',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 51},
#  {'_id': ObjectId('5c6dc05c265ae8009a4269e0'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [115, 131],
#    'level': 0,
#    'name': 'Id assumend',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 52},
#  {'_id': ObjectId('5c6dc05c265ae8009a4269e1'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [3, 26, 54, 119, 170],
#    'level': 0,
#    'name': 'Voluptatibus fu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 53},
#  {'_id': ObjectId('5c6dc05c265ae8009a4269e2'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [55],
#    'level': 0,
#    'name': 'Odit rat',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 54},
#  {'_id': ObjectId('5c6dc05c265ae8009a4269e3'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [49, 81, 141, 160],
#    'level': 0,
#    'name': 'Debit',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 55},
#  {'_id': ObjectId('5c6dc05c265ae8009a4269e4'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [156],
#    'level': 0,
#    'name': 'Cum aut quas repudia',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 56},
#  {'_id': ObjectId('5c6dc05c265ae8009a4269e5'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [36, 156, 168],
#    'level': 0,
#    'name': 'Deleniti qui quae quidem',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 57},
#  {'_id': ObjectId('5c6dc05d265ae8009a4269e6'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [5, 46, 62, 159],
#    'level': 0,
#    'name': 'Adipisci voluptas',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 58},
#  {'_id': ObjectId('5c6dc05d265ae8009a4269e7'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [87, 89, 166, 174],
#    'level': 0,
#    'name': 'Debitis sit ratione eos nam',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 59},
#  {'_id': ObjectId('5c6dc05d265ae8009a4269e8'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [87, 129, 130, 141],
#    'level': 0,
#    'name': 'Esse illo molestias archi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 60},
#  {'_id': ObjectId('5c6dc05d265ae8009a4269e9'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [95, 116],
#    'level': 0,
#    'name': 'Sunt at itaque voluptatum d',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 61},
#  {'_id': ObjectId('5c6dc05d265ae8009a4269ea'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [115],
#    'level': 0,
#    'name': 'Est totam',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 62},
#  {'_id': ObjectId('5c6dc05d265ae8009a4269eb'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [5, 19, 151, 158, 163],
#    'level': 0,
#    'name': 'Reprehenderit commodi eius',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 63},
#  {'_id': ObjectId('5c6dc05d265ae8009a4269ec'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [66, 134, 160],
#    'level': 0,
#    'name': 'Debit',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 64},
#  {'_id': ObjectId('5c6dc05d265ae8009a4269ed'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [8, 18, 116, 136, 157],
#    'level': 0,
#    'name': 'Soluta dol',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 65},
#  {'_id': ObjectId('5c6dc05e265ae8009a4269ee'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [3, 83, 113, 123, 145],
#    'level': 0,
#    'name': 'Vel nesc',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 66},
#  {'_id': ObjectId('5c6dc05e265ae8009a4269ef'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [89],
#    'level': 0,
#    'name': 'Ratione quia ali',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 67},
#  {'_id': ObjectId('5c6dc05e265ae8009a4269f0'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [54, 93, 114, 147],
#    'level': 0,
#    'name': 'Rerum recusandae minima',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 68},
#  {'_id': ObjectId('5c6dc05e265ae8009a4269f1'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [43, 90, 146],
#    'level': 0,
#    'name': 'Totam natus eius fugiat volu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 69},
#  {'_id': ObjectId('5c6dc05e265ae8009a4269f2'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [139, 151, 172],
#    'level': 0,
#    'name': 'Perferendis commodi null',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 70},
#  {'_id': ObjectId('5c6dc05e265ae8009a4269f3'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [11, 83, 167],
#    'level': 0,
#    'name': 'Laudantiu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 71},
#  {'_id': ObjectId('5c6dc05e265ae8009a4269f4'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [128],
#    'level': 0,
#    'name': 'Voluptat',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 72},
#  {'_id': ObjectId('5c6dc05f265ae8009a4269f5'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [19],
#    'level': 0,
#    'name': 'Incidunt nesciun',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 73},
#  {'_id': ObjectId('5c6dc05f265ae8009a4269f6'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [106, 139],
#    'level': 0,
#    'name': 'Illum amet vero',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 74},
#  {'_id': ObjectId('5c6dc05f265ae8009a4269f7'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [99],
#    'level': 0,
#    'name': 'Suscipit exercitationem re',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 75},
#  {'_id': ObjectId('5c6dc05f265ae8009a4269f8'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [24],
#    'level': 0,
#    'name': 'Quas enim error maxime nisi m',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 76},
#  {'_id': ObjectId('5c6dc05f265ae8009a4269f9'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [2, 22, 68, 133],
#    'level': 0,
#    'name': 'Labore qu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 77},
#  {'_id': ObjectId('5c6dc05f265ae8009a4269fa'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [21, 25, 141],
#    'level': 0,
#    'name': 'Repudiandae deleniti unde',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 78},
#  {'_id': ObjectId('5c6dc05f265ae8009a4269fb'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [106],
#    'level': 0,
#    'name': 'Ut do',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 79},
#  {'_id': ObjectId('5c6dc05f265ae8009a4269fc'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [8, 102, 149],
#    'level': 0,
#    'name': 'Quaerat esse labore q',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 80},
#  {'_id': ObjectId('5c6dc060265ae8009a4269fd'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [4, 24, 101, 155, 158],
#    'level': 0,
#    'name': 'Quidem aliq',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 81},
#  {'_id': ObjectId('5c6dc060265ae8009a4269fe'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [12, 30, 93, 136],
#    'level': 0,
#    'name': 'Aperiam vitae eos dolor sed',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 82},
#  {'_id': ObjectId('5c6dc060265ae8009a4269ff'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [9, 101, 115],
#    'level': 0,
#    'name': 'Minus nobis porro',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 83},
#  {'_id': ObjectId('5c6dc060265ae8009a426a00'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [3, 97, 143, 162],
#    'level': 0,
#    'name': 'In similique',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 84},
#  {'_id': ObjectId('5c6dc060265ae8009a426a01'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [65, 72, 116, 153, 165],
#    'level': 0,
#    'name': 'Culpa repellat unde',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 85},
#  {'_id': ObjectId('5c6dc060265ae8009a426a02'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [15, 20, 24, 46, 148],
#    'level': 0,
#    'name': 'Architecto i',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 86},
#  {'_id': ObjectId('5c6dc060265ae8009a426a03'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [40],
#    'level': 0,
#    'name': 'A sed pariatur qua',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 87},
#  {'_id': ObjectId('5c6dc061265ae8009a426a04'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [97, 108, 137, 170],
#    'level': 0,
#    'name': 'Tempore assumenda aperiam',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 88},
#  {'_id': ObjectId('5c6dc061265ae8009a426a05'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [38, 91],
#    'level': 0,
#    'name': 'Sed ullam tempora iusto co',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 89},
#  {'_id': ObjectId('5c6dc061265ae8009a426a06'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [4, 166],
#    'level': 0,
#    'name': 'Ipsa',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 90},
#  {'_id': ObjectId('5c6dc061265ae8009a426a07'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [5, 41, 51, 128, 135],
#    'level': 0,
#    'name': 'Fugiat incidun',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 91},
#  {'_id': ObjectId('5c6dc061265ae8009a426a08'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [16, 59, 77, 95, 151],
#    'level': 0,
#    'name': 'Molestiae of',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 92},
#  {'_id': ObjectId('5c6dc061265ae8009a426a09'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [5, 12, 60, 131],
#    'level': 0,
#    'name': 'Quae quisquam cons',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 93},
#  {'_id': ObjectId('5c6dc061265ae8009a426a0a'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [58, 73, 100, 139],
#    'level': 0,
#    'name': 'Repellendus ea non facil',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 94},
#  {'_id': ObjectId('5c6dc061265ae8009a426a0b'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [14, 58, 67, 99, 112],
#    'level': 0,
#    'name': 'Quod non quibu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 95},
#  {'_id': ObjectId('5c6dc062265ae8009a426a0c'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [77, 130, 135, 142, 170],
#    'level': 0,
#    'name': 'Numquam velit distinctio',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 96},
#  {'_id': ObjectId('5c6dc062265ae8009a426a0d'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [17, 72, 101],
#    'level': 0,
#    'name': 'Necessitatibus nihil ex debi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 97},
#  {'_id': ObjectId('5c6dc062265ae8009a426a0e'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [10, 87],
#    'level': 0,
#    'name': 'Velit tempore nemo, na',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 98},
#  {'_id': ObjectId('5c6dc062265ae8009a426a0f'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [158],
#    'level': 0,
#    'name': 'Nesciunt v',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 99},
#  {'_id': ObjectId('5c6dc062265ae8009a426a10'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [40, 57, 85, 107, 146],
#    'level': 0,
#    'name': 'Dicta enim debitis accusantiu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 100},
#  {'_id': ObjectId('5c6dc062265ae8009a426a11'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [22, 30, 39, 40, 170],
#    'level': 0,
#    'name': 'Vitae a',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 101},
#  {'_id': ObjectId('5c6dc062265ae8009a426a12'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [26, 52, 84],
#    'level': 0,
#    'name': 'Praesentium voluptas u',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 102},
#  {'_id': ObjectId('5c6dc063265ae8009a426a13'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [45, 111, 113, 120, 158],
#    'level': 0,
#    'name': 'Unde ullam mollitia? Nu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 103},
#  {'_id': ObjectId('5c6dc063265ae8009a426a14'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [40, 64, 71, 122, 129],
#    'level': 0,
#    'name': 'Neque molestias qu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 104},
#  {'_id': ObjectId('5c6dc063265ae8009a426a15'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [43, 137, 146],
#    'level': 0,
#    'name': 'Officiis es',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 105},
#  {'_id': ObjectId('5c6dc063265ae8009a426a16'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [84, 112, 126, 148],
#    'level': 0,
#    'name': 'Beatae mi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 106},
#  {'_id': ObjectId('5c6dc063265ae8009a426a17'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [116],
#    'level': 0,
#    'name': 'Mollitia nam corporis temp',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 107},
#  {'_id': ObjectId('5c6dc063265ae8009a426a18'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [47, 75, 160, 166],
#    'level': 0,
#    'name': 'Repudiandae repellat i',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 108},
#  {'_id': ObjectId('5c6dc063265ae8009a426a19'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [92],
#    'level': 0,
#    'name': 'Laboriosam',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 109},
#  {'_id': ObjectId('5c6dc063265ae8009a426a1a'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [90],
#    'level': 0,
#    'name': 'Nam minus amet',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 110},
#  {'_id': ObjectId('5c6dc064265ae8009a426a1b'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [122],
#    'level': 0,
#    'name': 'Harum quae volup',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 111},
#  {'_id': ObjectId('5c6dc064265ae8009a426a1c'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [127, 157],
#    'level': 0,
#    'name': 'Impedit facere ulla',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 112},
#  {'_id': ObjectId('5c6dc064265ae8009a426a1d'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [142, 166],
#    'level': 0,
#    'name': 'Enim',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 113},
#  {'_id': ObjectId('5c6dc064265ae8009a426a1e'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [10, 50, 61, 91, 153],
#    'level': 0,
#    'name': 'Dolore magni',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 114},
#  {'_id': ObjectId('5c6dc064265ae8009a426a1f'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [10, 18, 68, 101, 144],
#    'level': 0,
#    'name': 'Eaque at corpori',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 115},
#  {'_id': ObjectId('5c6dc064265ae8009a426a20'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [20],
#    'level': 0,
#    'name': 'Fug',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 116},
#  {'_id': ObjectId('5c6dc064265ae8009a426a21'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [15, 21, 116, 160],
#    'level': 0,
#    'name': 'Dolorum laudanti',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 117},
#  {'_id': ObjectId('5c6dc064265ae8009a426a22'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [9, 71, 128, 133, 174],
#    'level': 0,
#    'name': 'Perferendis nat',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 118},
#  {'_id': ObjectId('5c6dc065265ae8009a426a23'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [1, 15, 31, 54, 95],
#    'level': 0,
#    'name': 'Cupidi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 119},
#  {'_id': ObjectId('5c6dc065265ae8009a426a24'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [50, 91, 94],
#    'level': 0,
#    'name': 'Commodi eius dicta digniss',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 120},
#  {'_id': ObjectId('5c6dc065265ae8009a426a25'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [59, 63, 100],
#    'level': 0,
#    'name': 'Debitis eu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 121},
#  {'_id': ObjectId('5c6dc065265ae8009a426a26'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [87, 162],
#    'level': 0,
#    'name': 'Nihil repella',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 122},
#  {'_id': ObjectId('5c6dc065265ae8009a426a27'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [46, 56, 90],
#    'level': 0,
#    'name': 'Rem quasi minima hic sed anim',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 123},
#  {'_id': ObjectId('5c6dc065265ae8009a426a28'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [98],
#    'level': 0,
#    'name': 'Sed ali',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 124},
#  {'_id': ObjectId('5c6dc065265ae8009a426a29'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [8, 110, 131],
#    'level': 0,
#    'name': 'Earum vol',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 125},
#  {'_id': ObjectId('5c6dc066265ae8009a426a2a'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [162],
#    'level': 0,
#    'name': 'Inventore tempore com',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 126},
#  {'_id': ObjectId('5c6dc066265ae8009a426a2b'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [133, 154, 171],
#    'level': 0,
#    'name': 'Repell',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 127},
#  {'_id': ObjectId('5c6dc066265ae8009a426a2c'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [111, 138, 171],
#    'level': 0,
#    'name': 'Consequatur quis recusandae qu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 128},
#  {'_id': ObjectId('5c6dc066265ae8009a426a2d'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [4, 51, 108, 138, 149],
#    'level': 0,
#    'name': 'Dolores ea velit mi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 129},
#  {'_id': ObjectId('5c6dc066265ae8009a426a2e'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [63],
#    'level': 0,
#    'name': 'Atque blanditiis a aperiam',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 130},
#  {'_id': ObjectId('5c6dc066265ae8009a426a2f'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [4, 17, 147],
#    'level': 0,
#    'name': 'Reprehenderit sequi iu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 131},
#  {'_id': ObjectId('5c6dc066265ae8009a426a30'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [15, 16, 89, 133],
#    'level': 0,
#    'name': 'Natus architecto eos, hic blan',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 132},
#  {'_id': ObjectId('5c6dc066265ae8009a426a31'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [8, 19, 28],
#    'level': 0,
#    'name': 'Ipsa illo quas',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 133},
#  {'_id': ObjectId('5c6dc067265ae8009a426a32'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [127, 132, 144, 173],
#    'level': 0,
#    'name': 'Voluptas ali',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 134},
#  {'_id': ObjectId('5c6dc067265ae8009a426a33'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [13, 20, 40, 43, 72],
#    'level': 0,
#    'name': 'Voluptates obcaecati quod e',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 135},
#  {'_id': ObjectId('5c6dc067265ae8009a426a34'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [18, 53, 87, 166],
#    'level': 0,
#    'name': 'Dolor adipisci a voluptate',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 136},
#  {'_id': ObjectId('5c6dc067265ae8009a426a35'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [53, 55, 101],
#    'level': 0,
#    'name': 'Repellendus natus quae, n',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 137},
#  {'_id': ObjectId('5c6dc067265ae8009a426a36'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [65, 69, 133],
#    'level': 0,
#    'name': 'Laudantium earum nam in dol',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 138},
#  {'_id': ObjectId('5c6dc067265ae8009a426a37'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [23, 54, 109, 116, 174],
#    'level': 0,
#    'name': 'Molestias face',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 139},
#  {'_id': ObjectId('5c6dc067265ae8009a426a38'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [7, 42, 103],
#    'level': 0,
#    'name': 'Maiores suscipit exc',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 140},
#  {'_id': ObjectId('5c6dc068265ae8009a426a39'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [171],
#    'level': 0,
#    'name': 'Illum dolore perferen',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 141},
#  {'_id': ObjectId('5c6dc068265ae8009a426a3a'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [50, 51, 155, 173, 174],
#    'level': 0,
#    'name': 'Explicabo recusandae ma',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 142},
#  {'_id': ObjectId('5c6dc068265ae8009a426a3b'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [55, 152],
#    'level': 0,
#    'name': 'Odio obcaecati hic nostrum n',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 143},
#  {'_id': ObjectId('5c6dc068265ae8009a426a3c'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [117],
#    'level': 0,
#    'name': 'Voluptate ali',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 144},
#  {'_id': ObjectId('5c6dc068265ae8009a426a3d'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [25, 26, 116, 163],
#    'level': 0,
#    'name': 'Repudiandae vitae sapiente mol',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 145},
#  {'_id': ObjectId('5c6dc068265ae8009a426a3e'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [18, 26, 56, 106],
#    'level': 0,
#    'name': 'Ipsam cumque',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 146},
#  {'_id': ObjectId('5c6dc068265ae8009a426a3f'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [163],
#    'level': 0,
#    'name': 'Fugiat quos alias eos dese',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 147},
#  {'_id': ObjectId('5c6dc068265ae8009a426a40'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [26, 62, 130, 147],
#    'level': 0,
#    'name': 'Eaque impe',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 148},
#  {'_id': ObjectId('5c6dc069265ae8009a426a41'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [121, 128, 142],
#    'level': 0,
#    'name': 'Elige',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 149},
#  {'_id': ObjectId('5c6dc069265ae8009a426a42'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [31, 97, 134],
#    'level': 0,
#    'name': 'Adip',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 150},
#  {'_id': ObjectId('5c6dc069265ae8009a426a43'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [57, 87, 153],
#    'level': 0,
#    'name': 'Fuga nemo vel mo',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 151},
#  {'_id': ObjectId('5c6dc069265ae8009a426a44'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [5, 106, 158],
#    'level': 0,
#    'name': 'Libero cumque impedit eveniet',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 152},
#  {'_id': ObjectId('5c6dc069265ae8009a426a45'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [20, 54, 122, 160],
#    'level': 0,
#    'name': 'Odio soluta',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 153},
#  {'_id': ObjectId('5c6dc069265ae8009a426a46'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [1, 27, 69],
#    'level': 0,
#    'name': 'Vero nostrum duc',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 154},
#  {'_id': ObjectId('5c6dc069265ae8009a426a47'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [15, 79, 90, 122],
#    'level': 0,
#    'name': 'Repellend',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 155},
#  {'_id': ObjectId('5c6dc06a265ae8009a426a48'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [29, 102, 120, 130, 162],
#    'level': 0,
#    'name': 'Quod',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 156},
#  {'_id': ObjectId('5c6dc06a265ae8009a426a49'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [110],
#    'level': 0,
#    'name': 'Suscipit reiciend',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 157},
#  {'_id': ObjectId('5c6dc06a265ae8009a426a4a'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [71],
#    'level': 0,
#    'name': 'Voluptat',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 158},
#  {'_id': ObjectId('5c6dc06a265ae8009a426a4b'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [40, 86, 115],
#    'level': 0,
#    'name': 'Porro dolor fuga quam',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 159},
#  {'_id': ObjectId('5c6dc06a265ae8009a426a4c'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [53, 65, 78, 109, 174],
#    'level': 0,
#    'name': 'Amet quo fugit aliquam sequi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 160},
#  {'_id': ObjectId('5c6dc06a265ae8009a426a4d'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [83, 115],
#    'level': 0,
#    'name': 'Magni adipisci veritatis sit q',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 161},
#  {'_id': ObjectId('5c6dc06a265ae8009a426a4e'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [66, 136],
#    'level': 0,
#    'name': 'Debitis enim cumque cum qu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 162},
#  {'_id': ObjectId('5c6dc06a265ae8009a426a4f'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [21, 50, 65],
#    'level': 0,
#    'name': 'Dolorem eligend',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 163},
#  {'_id': ObjectId('5c6dc06b265ae8009a426a50'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [174],
#    'level': 0,
#    'name': 'Autem lib',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 164},
#  {'_id': ObjectId('5c6dc06b265ae8009a426a51'),
#   'fields': {'dexterity': 1,
# ...
#   'fields': {'name': 'Facere q', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 99},
#  {'_id': ObjectId('5c6dc0b3265ae8009a426c77'),
#   'fields': {'name': 'Incidunt libero assumen', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 100},
#  {'_id': ObjectId('5c6dc0b4265ae8009a426c78'),
#   'fields': {'name': 'Earum suscipit ea voluptates i',
#    'value': 0,
#    'weight': 0},
#   'model': 'armory.item',
#   'pk': 101},
#  {'_id': ObjectId('5c6dc0b4265ae8009a426c79'),
#   'fields': {'name': 'Sint dolorum', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 102},
#  {'_id': ObjectId('5c6dc0b4265ae8009a426c7a'),
#   'fields': {'name': 'Incidunt fugiat ea, ea', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 103},
#  {'_id': ObjectId('5c6dc0b4265ae8009a426c7b'),
#   'fields': {'name': 'Molestiae r', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 104},
#  {'_id': ObjectId('5c6dc0b4265ae8009a426c7c'),
#   'fields': {'name': 'Voluptatem labore laboriosa', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 105},
#  {'_id': ObjectId('5c6dc0b4265ae8009a426c7d'),
#   'fields': {'name': 'Et ducimus cumque aut perspic', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 106},
#  {'_id': ObjectId('5c6dc0b4265ae8009a426c7e'),
#   'fields': {'name': 'Corrupti ap', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 107},
#  {'_id': ObjectId('5c6dc0b4265ae8009a426c7f'),
#   'fields': {'name': 'Perferendis nesciunt quae dolo',
#    'value': 0,
#    'weight': 0},
#   'model': 'armory.item',
#   'pk': 108},
#  {'_id': ObjectId('5c6dc0b5265ae8009a426c80'),
#   'fields': {'name': 'Sunt doloremque recusanda', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 109},
#  {'_id': ObjectId('5c6dc0b5265ae8009a426c81'),
#   'fields': {'name': 'Deleniti similique obc', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 110},
#  {'_id': ObjectId('5c6dc0b5265ae8009a426c82'),
#   'fields': {'name': 'Numquam tempor', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 111},
#  {'_id': ObjectId('5c6dc0b5265ae8009a426c83'),
#   'fields': {'name': 'Quibusdam deleniti quasi provi',
#    'value': 0,
#    'weight': 0},
#   'model': 'armory.item',
#   'pk': 112},
#  {'_id': ObjectId('5c6dc0b5265ae8009a426c84'),
#   'fields': {'name': 'Accusamus exercitat', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 113},
#  {'_id': ObjectId('5c6dc0b5265ae8009a426c85'),
#   'fields': {'name': 'Error eveniet ipsum, expedi', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 114},
#  {'_id': ObjectId('5c6dc0b5265ae8009a426c86'),
#   'fields': {'name': 'Sapiente do', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 115},
#  {'_id': ObjectId('5c6dc0b6265ae8009a426c87'),
#   'fields': {'name': 'Fuga necessitatibus', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 116},
#  {'_id': ObjectId('5c6dc0b6265ae8009a426c88'),
#   'fields': {'name': 'Nam excepturi placeat asperna', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 117},
#  {'_id': ObjectId('5c6dc0b6265ae8009a426c89'),
#   'fields': {'name': 'Dolore fugit itaq', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 118},
#  {'_id': ObjectId('5c6dc0b6265ae8009a426c8a'),
#   'fields': {'name': 'Beatae ve', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 119},
#  {'_id': ObjectId('5c6dc0b6265ae8009a426c8b'),
#   'fields': {'name': 'Blanditiis corporis exerci', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 120},
#  {'_id': ObjectId('5c6dc0b6265ae8009a426c8c'),
#   'fields': {'name': 'Nesciunt quia nobi', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 121},
#  {'_id': ObjectId('5c6dc0b6265ae8009a426c8d'),
#   'fields': {'name': 'Quisquam e', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 122},
#  {'_id': ObjectId('5c6dc0b6265ae8009a426c8e'),
#   'fields': {'name': 'Illo q', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 123},
#  {'_id': ObjectId('5c6dc0b7265ae8009a426c8f'),
#   'fields': {'name': 'Repellat voluptates ea,', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 124},
#  {'_id': ObjectId('5c6dc0b7265ae8009a426c90'),
#   'fields': {'name': 'Labore architecto tempora d', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 125},
#  {'_id': ObjectId('5c6dc0b7265ae8009a426c91'),
#   'fields': {'name': 'Porro impedit enim earum nam n',
#    'value': 0,
#    'weight': 0},
#   'model': 'armory.item',
#   'pk': 126},
#  {'_id': ObjectId('5c6dc0b7265ae8009a426c92'),
#   'fields': {'name': 'Evenie', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 127},
#  {'_id': ObjectId('5c6dc0b7265ae8009a426c93'),
#   'fields': {'name': 'Similique do', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 128},
#  {'_id': ObjectId('5c6dc0b7265ae8009a426c94'),
#   'fields': {'name': 'Quos voluptates at n', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 129},
#  {'_id': ObjectId('5c6dc0b7265ae8009a426c95'),
#   'fields': {'name': 'Neq', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 130},
#  {'_id': ObjectId('5c6dc0b8265ae8009a426c96'),
#   'fields': {'name': 'Neq', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 131},
#  {'_id': ObjectId('5c6dc0b8265ae8009a426c97'),
#   'fields': {'name': 'Optio dolore itaque', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 132},
#  {'_id': ObjectId('5c6dc0b8265ae8009a426c98'),
#   'fields': {'name': 'Libero saepe accusantium', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 133},
#  {'_id': ObjectId('5c6dc0b8265ae8009a426c99'),
#   'fields': {'name': 'Illum nequ', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 134},
#  {'_id': ObjectId('5c6dc0b8265ae8009a426c9a'),
#   'fields': {'name': 'Culpa accusantium fugit id', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 135},
#  {'_id': ObjectId('5c6dc0b8265ae8009a426c9b'),
#   'fields': {'name': 'Fugit pariatur vero nesciu', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 136},
#  {'_id': ObjectId('5c6dc0b8265ae8009a426c9c'),
#   'fields': {'name': 'Numqu', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 137},
#  {'_id': ObjectId('5c6dc0b8265ae8009a426c9d'),
#   'fields': {'name': 'Corrupti sit at cum', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 138},
#  {'_id': ObjectId('5c6dc0b9265ae8009a426c9e'),
#   'fields': {'name': 'Est fugit incidunt co', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 139},
#  {'_id': ObjectId('5c6dc0b9265ae8009a426c9f'),
#   'fields': {'name': 'Quos nihil quibusdam', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 140},
#  {'_id': ObjectId('5c6dc0b9265ae8009a426ca0'),
#   'fields': {'name': 'Sit quidem tempora doloribus r',
#    'value': 0,
#    'weight': 0},
#   'model': 'armory.item',
#   'pk': 141},
#  {'_id': ObjectId('5c6dc0b9265ae8009a426ca1'),
#   'fields': {'name': 'Amet vel distinctio mo', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 142},
#  {'_id': ObjectId('5c6dc0b9265ae8009a426ca2'),
#   'fields': {'name': 'Illum eaque atque recusand', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 143},
#  {'_id': ObjectId('5c6dc0b9265ae8009a426ca3'),
#   'fields': {'name': 'Dignissi', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 144},
#  {'_id': ObjectId('5c6dc0b9265ae8009a426ca4'),
#   'fields': {'name': 'Corporis fug', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 145},
#  {'_id': ObjectId('5c6dc0ba265ae8009a426ca5'),
#   'fields': {'name': 'Sequi nesciunt', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 146},
#  {'_id': ObjectId('5c6dc0ba265ae8009a426ca6'),
#   'fields': {'name': 'Facere neque qu', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 147},
#  {'_id': ObjectId('5c6dc0ba265ae8009a426ca7'),
#   'fields': {'name': 'Corporis voluptas provi', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 148},
#  {'_id': ObjectId('5c6dc0ba265ae8009a426ca8'),
#   'fields': {'name': 'Repella', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 149},
#  {'_id': ObjectId('5c6dc0ba265ae8009a426ca9'),
#   'fields': {'name': 'Culpa cumque quo vel', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 150},
#  {'_id': ObjectId('5c6dc0ba265ae8009a426caa'),
#   'fields': {'name': 'Magni totam q', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 151},
#  {'_id': ObjectId('5c6dc0ba265ae8009a426cab'),
#   'fields': {'name': 'Illu', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 152},
#  {'_id': ObjectId('5c6dc0ba265ae8009a426cac'),
#   'fields': {'name': 'Sit quibusdam ab, enim in ex', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 153},
#  {'_id': ObjectId('5c6dc0bb265ae8009a426cad'),
#   'fields': {'name': 'Consequuntur at earum d', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 154},
#  {'_id': ObjectId('5c6dc0bb265ae8009a426cae'),
#   'fields': {'name': 'Voluptatum doloremque to', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 155},
#  {'_id': ObjectId('5c6dc0bb265ae8009a426caf'),
#   'fields': {'name': 'Expedita nam est in l', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 156},
#  {'_id': ObjectId('5c6dc0bb265ae8009a426cb0'),
#   'fields': {'name': 'Repelle', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 157},
#  {'_id': ObjectId('5c6dc0bb265ae8009a426cb1'),
#   'fields': {'name': 'Sit numqu', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 158},
#  {'_id': ObjectId('5c6dc0bb265ae8009a426cb2'),
#   'fields': {'name': 'Ipsum sit praesentium cum ame', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 159},
#  {'_id': ObjectId('5c6dc0bb265ae8009a426cb3'),
#   'fields': {'name': 'Totam delectus sed fugiat o', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 160},
#  {'_id': ObjectId('5c6dc0bc265ae8009a426cb4'),
#   'fields': {'name': 'Doloremq', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 161},
#  {'_id': ObjectId('5c6dc0bc265ae8009a426cb5'),
#   'fields': {'name': 'Id reprehenderit ullam rat', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 162},
#  {'_id': ObjectId('5c6dc0bc265ae8009a426cb6'),
#   'fields': {'name': 'Dignissimos dolo', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 163},
#  {'_id': ObjectId('5c6dc0bc265ae8009a426cb7'),
#   'fields': {'name': 'Inventore re', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 164},
#  {'_id': ObjectId('5c6dc0bc265ae8009a426cb8'),
#   'fields': {'name': 'Nemo expl', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 165},
#  {'_id': ObjectId('5c6dc0bc265ae8009a426cb9'),
#   'fields': {'name': 'Distinctio tene', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 166},
#  {'_id': ObjectId('5c6dc0bc265ae8009a426cba'),
#   'fields': {'name': 'Recusandae fug', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 167},
#  {'_id': ObjectId('5c6dc0bc265ae8009a426cbb'),
#   'fields': {'name': 'Officiis illo cum acc', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 168},
#  {'_id': ObjectId('5c6dc0bd265ae8009a426cbc'),
#   'fields': {'name': 'Repudiandae molestias be', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 169},
#  {'_id': ObjectId('5c6dc0bd265ae8009a426cbd'),
#   'fields': {'name': 'Iure nob', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 170},
#  {'_id': ObjectId('5c6dc0bd265ae8009a426cbe'),
#   'fields': {'name': 'Ea dolor exercitation', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 171},
#  {'_id': ObjectId('5c6dc0bd265ae8009a426cbf'),
#   'fields': {'name': 'Omnis maxime deserunt', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 172},
#  {'_id': ObjectId('5c6dc0bd265ae8009a426cc0'),
#   'fields': {'name': 'Eum error eveni', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 173},
#  {'_id': ObjectId('5c6dc0bd265ae8009a426cc1'),
#   'fields': {'name': 'Atque repudiandae molestiae v', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 174},
#  {'_id': ObjectId('5c6dc0bd265ae8009a426cc2'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 138},
#  {'_id': ObjectId('5c6dc0bd265ae8009a426cc3'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 139},
#  {'_id': ObjectId('5c6dc0be265ae8009a426cc4'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 140},
#  {'_id': ObjectId('5c6dc0be265ae8009a426cc5'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 141},
#  {'_id': ObjectId('5c6dc0be265ae8009a426cc6'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 142},
#  {'_id': ObjectId('5c6dc0be265ae8009a426cc7'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 143},
#  {'_id': ObjectId('5c6dc0be265ae8009a426cc8'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 144},
#  {'_id': ObjectId('5c6dc0be265ae8009a426cc9'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 145},
#  {'_id': ObjectId('5c6dc0be265ae8009a426cca'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 146},
#  {'_id': ObjectId('5c6dc0bf265ae8009a426ccb'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 147},
#  {'_id': ObjectId('5c6dc0bf265ae8009a426ccc'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 148},
#  {'_id': ObjectId('5c6dc0bf265ae8009a426ccd'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 149},
#  {'_id': ObjectId('5c6dc0bf265ae8009a426cce'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 150},
#  {'_id': ObjectId('5c6dc0bf265ae8009a426ccf'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 151},
#  {'_id': ObjectId('5c6dc0bf265ae8009a426cd0'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 152},
#  {'_id': ObjectId('5c6dc0bf265ae8009a426cd1'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 153},
#  {'_id': ObjectId('5c6dc0bf265ae8009a426cd2'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 154},
#  {'_id': ObjectId('5c6dc0c0265ae8009a426cd3'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 155},
#  {'_id': ObjectId('5c6dc0c0265ae8009a426cd4'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 156},
#  {'_id': ObjectId('5c6dc0c0265ae8009a426cd5'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 157},
#  {'_id': ObjectId('5c6dc0c0265ae8009a426cd6'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 158},
#  {'_id': ObjectId('5c6dc0c0265ae8009a426cd7'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 159},
#  {'_id': ObjectId('5c6dc0c0265ae8009a426cd8'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 160},
#  {'_id': ObjectId('5c6dc0c0265ae8009a426cd9'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 161},
#  {'_id': ObjectId('5c6dc0c1265ae8009a426cda'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 162},
#  {'_id': ObjectId('5c6dc0c1265ae8009a426cdb'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 163},
#  {'_id': ObjectId('5c6dc0c1265ae8009a426cdc'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 164},
#  {'_id': ObjectId('5c6dc0c1265ae8009a426cdd'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 165},
#  {'_id': ObjectId('5c6dc0c1265ae8009a426cde'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 166},
#  {'_id': ObjectId('5c6dc0c1265ae8009a426cdf'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 167},
#  {'_id': ObjectId('5c6dc0c1265ae8009a426ce0'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 168},
#  {'_id': ObjectId('5c6dc0c1265ae8009a426ce1'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 169},
#  {'_id': ObjectId('5c6dc0c2265ae8009a426ce2'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 170},
#  {'_id': ObjectId('5c6dc0c2265ae8009a426ce3'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 171},
#  {'_id': ObjectId('5c6dc0c2265ae8009a426ce4'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 172},
#  {'_id': ObjectId('5c6dc0c2265ae8009a426ce5'),
#   'fields': {'power': 0},
#   'model': 'armory.weapon',
#   'pk': 173}]

# %%
list(db_game.test.find( { "model": "charactercreator.character" }))
# Out:
# [{'_id': ObjectId('5c6dc055265ae8009a4269ad'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [20, 58, 85],
#    'level': 0,
#    'name': 'Aliquid iste optio reiciendi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 1},
#  {'_id': ObjectId('5c6dc055265ae8009a4269ae'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [93, 115, 133],
#    'level': 0,
#    'name': 'Optio dolorem ex a',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 2},
#  {'_id': ObjectId('5c6dc055265ae8009a4269af'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [8, 43],
#    'level': 0,
#    'name': 'Minus c',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 3},
#  {'_id': ObjectId('5c6dc055265ae8009a4269b0'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [21, 82, 85, 135],
#    'level': 0,
#    'name': 'Sit ut repr',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 4},
#  {'_id': ObjectId('5c6dc056265ae8009a4269b1'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [7, 96, 140, 145],
#    'level': 0,
#    'name': 'At id recusandae expl',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 5},
#  {'_id': ObjectId('5c6dc056265ae8009a4269b2'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [93],
#    'level': 0,
#    'name': 'Non nobis et of',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 6},
#  {'_id': ObjectId('5c6dc056265ae8009a4269b3'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [38, 42, 85, 123, 166],
#    'level': 0,
#    'name': 'Perferendis',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 7},
#  {'_id': ObjectId('5c6dc056265ae8009a4269b4'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [43, 48, 119],
#    'level': 0,
#    'name': 'Accusantium amet quidem eve',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 8},
#  {'_id': ObjectId('5c6dc056265ae8009a4269b5'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [32, 106, 116, 125],
#    'level': 0,
#    'name': 'Sed nostrum inventore error m',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 9},
#  {'_id': ObjectId('5c6dc056265ae8009a4269b6'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [117, 129, 131, 135],
#    'level': 0,
#    'name': 'Harum repellendus omnis od',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 10},
#  {'_id': ObjectId('5c6dc056265ae8009a4269b7'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [54, 108, 158],
#    'level': 0,
#    'name': 'Itaque ut commodi,',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 11},
#  {'_id': ObjectId('5c6dc056265ae8009a4269b8'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [65, 115, 126],
#    'level': 0,
#    'name': 'Molestiae quis',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 12},
#  {'_id': ObjectId('5c6dc057265ae8009a4269b9'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [38, 44, 62, 125],
#    'level': 0,
#    'name': 'Ali',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 13},
#  {'_id': ObjectId('5c6dc057265ae8009a4269ba'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [34, 41, 65, 68],
#    'level': 0,
#    'name': 'Tempora quod optio possimus il',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 14},
#  {'_id': ObjectId('5c6dc057265ae8009a4269bb'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [34, 56, 74, 84],
#    'level': 0,
#    'name': 'Sed itaque beatae pari',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 15},
#  {'_id': ObjectId('5c6dc057265ae8009a4269bc'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [87],
#    'level': 0,
#    'name': 'Quam dolor',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 16},
#  {'_id': ObjectId('5c6dc057265ae8009a4269bd'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [64, 68, 116, 128, 136],
#    'level': 0,
#    'name': 'Molestias expedita',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 17},
#  {'_id': ObjectId('5c6dc057265ae8009a4269be'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [17, 60, 62, 64, 90],
#    'level': 0,
#    'name': 'Lauda',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 18},
#  {'_id': ObjectId('5c6dc057265ae8009a4269bf'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [5, 52, 113],
#    'level': 0,
#    'name': 'Incidunt sint perferen',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 19},
#  {'_id': ObjectId('5c6dc058265ae8009a4269c0'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [156],
#    'level': 0,
#    'name': 'Laboriosa',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 20},
#  {'_id': ObjectId('5c6dc058265ae8009a4269c1'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [33, 34, 51, 117],
#    'level': 0,
#    'name': 'Dolore esse nesciunt fugit com',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 21},
#  {'_id': ObjectId('5c6dc058265ae8009a4269c2'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [41, 43, 164],
#    'level': 0,
#    'name': 'Dolorum nam reic',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 22},
#  {'_id': ObjectId('5c6dc058265ae8009a4269c3'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [33, 61, 160],
#    'level': 0,
#    'name': 'Repellat ad numquam volu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 23},
#  {'_id': ObjectId('5c6dc058265ae8009a4269c4'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [8],
#    'level': 0,
#    'name': 'Facere enim velit eligend',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 24},
#  {'_id': ObjectId('5c6dc058265ae8009a4269c5'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [50, 122],
#    'level': 0,
#    'name': 'Sed ratione quis rep',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 25},
#  {'_id': ObjectId('5c6dc058265ae8009a4269c6'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [112, 149],
#    'level': 0,
#    'name': 'Doloribus neque',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 26},
#  {'_id': ObjectId('5c6dc058265ae8009a4269c7'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [10, 104, 148, 157, 172],
#    'level': 0,
#    'name': 'Ab voluptas se',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 27},
#  {'_id': ObjectId('5c6dc059265ae8009a4269c8'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [51],
#    'level': 0,
#    'name': 'Molestias m',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 28},
#  {'_id': ObjectId('5c6dc059265ae8009a4269c9'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [107, 120, 157, 170],
#    'level': 0,
#    'name': 'In pariatur corpori',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 29},
#  {'_id': ObjectId('5c6dc059265ae8009a4269ca'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [69, 109, 114, 138],
#    'level': 0,
#    'name': 'Possimus ad dignissimos vel, a',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 30},
#  {'_id': ObjectId('5c6dc059265ae8009a4269cb'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [9, 45, 61],
#    'level': 0,
#    'name': 'At minus accusa',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 31},
#  {'_id': ObjectId('5c6dc059265ae8009a4269cc'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [111, 142],
#    'level': 0,
#    'name': 'Ad necess',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 32},
#  {'_id': ObjectId('5c6dc059265ae8009a4269cd'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [64, 110],
#    'level': 0,
#    'name': 'Expedita c',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 33},
#  {'_id': ObjectId('5c6dc059265ae8009a4269ce'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [5, 90, 132, 160],
#    'level': 0,
#    'name': 'Voluptates sunt voluptas volu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 34},
#  {'_id': ObjectId('5c6dc05a265ae8009a4269cf'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [3, 62, 101, 165, 166],
#    'level': 0,
#    'name': 'Autem mollitia fuga lauda',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 35},
#  {'_id': ObjectId('5c6dc05a265ae8009a4269d0'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [29, 34, 141, 153, 155],
#    'level': 0,
#    'name': 'Sint quibusdam ob',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 36},
#  {'_id': ObjectId('5c6dc05a265ae8009a4269d1'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [20, 42, 54, 169, 174],
#    'level': 0,
#    'name': 'Rerum et o',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 37},
#  {'_id': ObjectId('5c6dc05a265ae8009a4269d2'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [80, 115, 124, 146, 165],
#    'level': 0,
#    'name': 'Doloribus dolore r',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 38},
#  {'_id': ObjectId('5c6dc05a265ae8009a4269d3'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [58, 150, 168],
#    'level': 0,
#    'name': 'Eaque su',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 39},
#  {'_id': ObjectId('5c6dc05a265ae8009a4269d4'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [26, 32, 147],
#    'level': 0,
#    'name': 'Vel molestias numqua',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 40},
#  {'_id': ObjectId('5c6dc05a265ae8009a4269d5'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [112, 168],
#    'level': 0,
#    'name': 'Iste assumenda repellat q',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 41},
#  {'_id': ObjectId('5c6dc05a265ae8009a4269d6'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [65, 92, 131],
#    'level': 0,
#    'name': 'Animi labo',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 42},
#  {'_id': ObjectId('5c6dc05b265ae8009a4269d7'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [131],
#    'level': 0,
#    'name': 'Eum culpa eaque ea omn',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 43},
#  {'_id': ObjectId('5c6dc05b265ae8009a4269d8'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [38],
#    'level': 0,
#    'name': 'Harum provident vel quam',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 44},
#  {'_id': ObjectId('5c6dc05b265ae8009a4269d9'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [12, 16, 66, 76],
#    'level': 0,
#    'name': 'Aspe',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 45},
#  {'_id': ObjectId('5c6dc05b265ae8009a4269da'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [84],
#    'level': 0,
#    'name': 'Nisi nequ',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 46},
#  {'_id': ObjectId('5c6dc05b265ae8009a4269db'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [35, 94, 136, 161],
#    'level': 0,
#    'name': 'Quod tempora',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 47},
#  {'_id': ObjectId('5c6dc05b265ae8009a4269dc'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [45, 47, 126, 137],
#    'level': 0,
#    'name': 'Porro aliq',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 48},
#  {'_id': ObjectId('5c6dc05b265ae8009a4269dd'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [2, 41, 86, 113],
#    'level': 0,
#    'name': 'Quas',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 49},
#  {'_id': ObjectId('5c6dc05b265ae8009a4269de'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [29],
#    'level': 0,
#    'name': 'Magnam eligendi quia animi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 50},
#  {'_id': ObjectId('5c6dc05c265ae8009a4269df'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [73, 79, 153],
#    'level': 0,
#    'name': 'Officiis se',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 51},
#  {'_id': ObjectId('5c6dc05c265ae8009a4269e0'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [115, 131],
#    'level': 0,
#    'name': 'Id assumend',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 52},
#  {'_id': ObjectId('5c6dc05c265ae8009a4269e1'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [3, 26, 54, 119, 170],
#    'level': 0,
#    'name': 'Voluptatibus fu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 53},
#  {'_id': ObjectId('5c6dc05c265ae8009a4269e2'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [55],
#    'level': 0,
#    'name': 'Odit rat',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 54},
#  {'_id': ObjectId('5c6dc05c265ae8009a4269e3'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [49, 81, 141, 160],
#    'level': 0,
#    'name': 'Debit',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 55},
#  {'_id': ObjectId('5c6dc05c265ae8009a4269e4'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [156],
#    'level': 0,
#    'name': 'Cum aut quas repudia',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 56},
#  {'_id': ObjectId('5c6dc05c265ae8009a4269e5'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [36, 156, 168],
#    'level': 0,
#    'name': 'Deleniti qui quae quidem',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 57},
#  {'_id': ObjectId('5c6dc05d265ae8009a4269e6'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [5, 46, 62, 159],
#    'level': 0,
#    'name': 'Adipisci voluptas',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 58},
#  {'_id': ObjectId('5c6dc05d265ae8009a4269e7'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [87, 89, 166, 174],
#    'level': 0,
#    'name': 'Debitis sit ratione eos nam',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 59},
#  {'_id': ObjectId('5c6dc05d265ae8009a4269e8'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [87, 129, 130, 141],
#    'level': 0,
#    'name': 'Esse illo molestias archi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 60},
#  {'_id': ObjectId('5c6dc05d265ae8009a4269e9'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [95, 116],
#    'level': 0,
#    'name': 'Sunt at itaque voluptatum d',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 61},
#  {'_id': ObjectId('5c6dc05d265ae8009a4269ea'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [115],
#    'level': 0,
#    'name': 'Est totam',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 62},
#  {'_id': ObjectId('5c6dc05d265ae8009a4269eb'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [5, 19, 151, 158, 163],
#    'level': 0,
#    'name': 'Reprehenderit commodi eius',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 63},
#  {'_id': ObjectId('5c6dc05d265ae8009a4269ec'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [66, 134, 160],
#    'level': 0,
#    'name': 'Debit',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 64},
#  {'_id': ObjectId('5c6dc05d265ae8009a4269ed'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [8, 18, 116, 136, 157],
#    'level': 0,
#    'name': 'Soluta dol',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 65},
#  {'_id': ObjectId('5c6dc05e265ae8009a4269ee'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [3, 83, 113, 123, 145],
#    'level': 0,
#    'name': 'Vel nesc',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 66},
#  {'_id': ObjectId('5c6dc05e265ae8009a4269ef'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [89],
#    'level': 0,
#    'name': 'Ratione quia ali',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 67},
#  {'_id': ObjectId('5c6dc05e265ae8009a4269f0'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [54, 93, 114, 147],
#    'level': 0,
#    'name': 'Rerum recusandae minima',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 68},
#  {'_id': ObjectId('5c6dc05e265ae8009a4269f1'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [43, 90, 146],
#    'level': 0,
#    'name': 'Totam natus eius fugiat volu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 69},
#  {'_id': ObjectId('5c6dc05e265ae8009a4269f2'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [139, 151, 172],
#    'level': 0,
#    'name': 'Perferendis commodi null',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 70},
#  {'_id': ObjectId('5c6dc05e265ae8009a4269f3'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [11, 83, 167],
#    'level': 0,
#    'name': 'Laudantiu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 71},
#  {'_id': ObjectId('5c6dc05e265ae8009a4269f4'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [128],
#    'level': 0,
#    'name': 'Voluptat',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 72},
#  {'_id': ObjectId('5c6dc05f265ae8009a4269f5'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [19],
#    'level': 0,
#    'name': 'Incidunt nesciun',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 73},
#  {'_id': ObjectId('5c6dc05f265ae8009a4269f6'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [106, 139],
#    'level': 0,
#    'name': 'Illum amet vero',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 74},
#  {'_id': ObjectId('5c6dc05f265ae8009a4269f7'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [99],
#    'level': 0,
#    'name': 'Suscipit exercitationem re',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 75},
#  {'_id': ObjectId('5c6dc05f265ae8009a4269f8'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [24],
#    'level': 0,
#    'name': 'Quas enim error maxime nisi m',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 76},
#  {'_id': ObjectId('5c6dc05f265ae8009a4269f9'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [2, 22, 68, 133],
#    'level': 0,
#    'name': 'Labore qu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 77},
#  {'_id': ObjectId('5c6dc05f265ae8009a4269fa'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [21, 25, 141],
#    'level': 0,
#    'name': 'Repudiandae deleniti unde',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 78},
#  {'_id': ObjectId('5c6dc05f265ae8009a4269fb'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [106],
#    'level': 0,
#    'name': 'Ut do',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 79},
#  {'_id': ObjectId('5c6dc05f265ae8009a4269fc'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [8, 102, 149],
#    'level': 0,
#    'name': 'Quaerat esse labore q',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 80},
#  {'_id': ObjectId('5c6dc060265ae8009a4269fd'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [4, 24, 101, 155, 158],
#    'level': 0,
#    'name': 'Quidem aliq',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 81},
#  {'_id': ObjectId('5c6dc060265ae8009a4269fe'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [12, 30, 93, 136],
#    'level': 0,
#    'name': 'Aperiam vitae eos dolor sed',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 82},
#  {'_id': ObjectId('5c6dc060265ae8009a4269ff'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [9, 101, 115],
#    'level': 0,
#    'name': 'Minus nobis porro',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 83},
#  {'_id': ObjectId('5c6dc060265ae8009a426a00'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [3, 97, 143, 162],
#    'level': 0,
#    'name': 'In similique',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 84},
#  {'_id': ObjectId('5c6dc060265ae8009a426a01'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [65, 72, 116, 153, 165],
#    'level': 0,
#    'name': 'Culpa repellat unde',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 85},
#  {'_id': ObjectId('5c6dc060265ae8009a426a02'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [15, 20, 24, 46, 148],
#    'level': 0,
#    'name': 'Architecto i',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 86},
#  {'_id': ObjectId('5c6dc060265ae8009a426a03'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [40],
#    'level': 0,
#    'name': 'A sed pariatur qua',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 87},
#  {'_id': ObjectId('5c6dc061265ae8009a426a04'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [97, 108, 137, 170],
#    'level': 0,
#    'name': 'Tempore assumenda aperiam',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 88},
#  {'_id': ObjectId('5c6dc061265ae8009a426a05'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [38, 91],
#    'level': 0,
#    'name': 'Sed ullam tempora iusto co',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 89},
#  {'_id': ObjectId('5c6dc061265ae8009a426a06'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [4, 166],
#    'level': 0,
#    'name': 'Ipsa',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 90},
#  {'_id': ObjectId('5c6dc061265ae8009a426a07'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [5, 41, 51, 128, 135],
#    'level': 0,
#    'name': 'Fugiat incidun',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 91},
#  {'_id': ObjectId('5c6dc061265ae8009a426a08'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [16, 59, 77, 95, 151],
#    'level': 0,
#    'name': 'Molestiae of',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 92},
#  {'_id': ObjectId('5c6dc061265ae8009a426a09'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [5, 12, 60, 131],
#    'level': 0,
#    'name': 'Quae quisquam cons',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 93},
#  {'_id': ObjectId('5c6dc061265ae8009a426a0a'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [58, 73, 100, 139],
#    'level': 0,
#    'name': 'Repellendus ea non facil',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 94},
#  {'_id': ObjectId('5c6dc061265ae8009a426a0b'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [14, 58, 67, 99, 112],
#    'level': 0,
#    'name': 'Quod non quibu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 95},
#  {'_id': ObjectId('5c6dc062265ae8009a426a0c'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [77, 130, 135, 142, 170],
#    'level': 0,
#    'name': 'Numquam velit distinctio',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 96},
#  {'_id': ObjectId('5c6dc062265ae8009a426a0d'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [17, 72, 101],
#    'level': 0,
#    'name': 'Necessitatibus nihil ex debi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 97},
#  {'_id': ObjectId('5c6dc062265ae8009a426a0e'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [10, 87],
#    'level': 0,
#    'name': 'Velit tempore nemo, na',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 98},
#  {'_id': ObjectId('5c6dc062265ae8009a426a0f'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [158],
#    'level': 0,
#    'name': 'Nesciunt v',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 99},
#  {'_id': ObjectId('5c6dc062265ae8009a426a10'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [40, 57, 85, 107, 146],
#    'level': 0,
#    'name': 'Dicta enim debitis accusantiu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 100},
#  {'_id': ObjectId('5c6dc062265ae8009a426a11'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [22, 30, 39, 40, 170],
#    'level': 0,
#    'name': 'Vitae a',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 101},
#  {'_id': ObjectId('5c6dc062265ae8009a426a12'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [26, 52, 84],
#    'level': 0,
#    'name': 'Praesentium voluptas u',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 102},
#  {'_id': ObjectId('5c6dc063265ae8009a426a13'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [45, 111, 113, 120, 158],
#    'level': 0,
#    'name': 'Unde ullam mollitia? Nu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 103},
#  {'_id': ObjectId('5c6dc063265ae8009a426a14'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [40, 64, 71, 122, 129],
#    'level': 0,
#    'name': 'Neque molestias qu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 104},
#  {'_id': ObjectId('5c6dc063265ae8009a426a15'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [43, 137, 146],
#    'level': 0,
#    'name': 'Officiis es',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 105},
#  {'_id': ObjectId('5c6dc063265ae8009a426a16'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [84, 112, 126, 148],
#    'level': 0,
#    'name': 'Beatae mi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 106},
#  {'_id': ObjectId('5c6dc063265ae8009a426a17'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [116],
#    'level': 0,
#    'name': 'Mollitia nam corporis temp',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 107},
#  {'_id': ObjectId('5c6dc063265ae8009a426a18'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [47, 75, 160, 166],
#    'level': 0,
#    'name': 'Repudiandae repellat i',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 108},
#  {'_id': ObjectId('5c6dc063265ae8009a426a19'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [92],
#    'level': 0,
#    'name': 'Laboriosam',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 109},
#  {'_id': ObjectId('5c6dc063265ae8009a426a1a'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [90],
#    'level': 0,
#    'name': 'Nam minus amet',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 110},
#  {'_id': ObjectId('5c6dc064265ae8009a426a1b'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [122],
#    'level': 0,
#    'name': 'Harum quae volup',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 111},
#  {'_id': ObjectId('5c6dc064265ae8009a426a1c'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [127, 157],
#    'level': 0,
#    'name': 'Impedit facere ulla',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 112},
#  {'_id': ObjectId('5c6dc064265ae8009a426a1d'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [142, 166],
#    'level': 0,
#    'name': 'Enim',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 113},
#  {'_id': ObjectId('5c6dc064265ae8009a426a1e'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [10, 50, 61, 91, 153],
#    'level': 0,
#    'name': 'Dolore magni',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 114},
#  {'_id': ObjectId('5c6dc064265ae8009a426a1f'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [10, 18, 68, 101, 144],
#    'level': 0,
#    'name': 'Eaque at corpori',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 115},
#  {'_id': ObjectId('5c6dc064265ae8009a426a20'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [20],
#    'level': 0,
#    'name': 'Fug',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 116},
#  {'_id': ObjectId('5c6dc064265ae8009a426a21'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [15, 21, 116, 160],
#    'level': 0,
#    'name': 'Dolorum laudanti',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 117},
#  {'_id': ObjectId('5c6dc064265ae8009a426a22'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [9, 71, 128, 133, 174],
#    'level': 0,
#    'name': 'Perferendis nat',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 118},
#  {'_id': ObjectId('5c6dc065265ae8009a426a23'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [1, 15, 31, 54, 95],
#    'level': 0,
#    'name': 'Cupidi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 119},
#  {'_id': ObjectId('5c6dc065265ae8009a426a24'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [50, 91, 94],
#    'level': 0,
#    'name': 'Commodi eius dicta digniss',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 120},
#  {'_id': ObjectId('5c6dc065265ae8009a426a25'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [59, 63, 100],
#    'level': 0,
#    'name': 'Debitis eu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 121},
#  {'_id': ObjectId('5c6dc065265ae8009a426a26'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [87, 162],
#    'level': 0,
#    'name': 'Nihil repella',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 122},
#  {'_id': ObjectId('5c6dc065265ae8009a426a27'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [46, 56, 90],
#    'level': 0,
#    'name': 'Rem quasi minima hic sed anim',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 123},
#  {'_id': ObjectId('5c6dc065265ae8009a426a28'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [98],
#    'level': 0,
#    'name': 'Sed ali',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 124},
#  {'_id': ObjectId('5c6dc065265ae8009a426a29'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [8, 110, 131],
#    'level': 0,
#    'name': 'Earum vol',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 125},
#  {'_id': ObjectId('5c6dc066265ae8009a426a2a'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [162],
#    'level': 0,
#    'name': 'Inventore tempore com',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 126},
#  {'_id': ObjectId('5c6dc066265ae8009a426a2b'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [133, 154, 171],
#    'level': 0,
#    'name': 'Repell',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 127},
#  {'_id': ObjectId('5c6dc066265ae8009a426a2c'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [111, 138, 171],
#    'level': 0,
#    'name': 'Consequatur quis recusandae qu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 128},
#  {'_id': ObjectId('5c6dc066265ae8009a426a2d'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [4, 51, 108, 138, 149],
#    'level': 0,
#    'name': 'Dolores ea velit mi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 129},
#  {'_id': ObjectId('5c6dc066265ae8009a426a2e'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [63],
#    'level': 0,
#    'name': 'Atque blanditiis a aperiam',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 130},
#  {'_id': ObjectId('5c6dc066265ae8009a426a2f'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [4, 17, 147],
#    'level': 0,
#    'name': 'Reprehenderit sequi iu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 131},
#  {'_id': ObjectId('5c6dc066265ae8009a426a30'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [15, 16, 89, 133],
#    'level': 0,
#    'name': 'Natus architecto eos, hic blan',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 132},
#  {'_id': ObjectId('5c6dc066265ae8009a426a31'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [8, 19, 28],
#    'level': 0,
#    'name': 'Ipsa illo quas',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 133},
#  {'_id': ObjectId('5c6dc067265ae8009a426a32'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [127, 132, 144, 173],
#    'level': 0,
#    'name': 'Voluptas ali',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 134},
#  {'_id': ObjectId('5c6dc067265ae8009a426a33'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [13, 20, 40, 43, 72],
#    'level': 0,
#    'name': 'Voluptates obcaecati quod e',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 135},
#  {'_id': ObjectId('5c6dc067265ae8009a426a34'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [18, 53, 87, 166],
#    'level': 0,
#    'name': 'Dolor adipisci a voluptate',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 136},
#  {'_id': ObjectId('5c6dc067265ae8009a426a35'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [53, 55, 101],
#    'level': 0,
#    'name': 'Repellendus natus quae, n',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 137},
#  {'_id': ObjectId('5c6dc067265ae8009a426a36'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [65, 69, 133],
#    'level': 0,
#    'name': 'Laudantium earum nam in dol',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 138},
#  {'_id': ObjectId('5c6dc067265ae8009a426a37'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [23, 54, 109, 116, 174],
#    'level': 0,
#    'name': 'Molestias face',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 139},
#  {'_id': ObjectId('5c6dc067265ae8009a426a38'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [7, 42, 103],
#    'level': 0,
#    'name': 'Maiores suscipit exc',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 140},
#  {'_id': ObjectId('5c6dc068265ae8009a426a39'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [171],
#    'level': 0,
#    'name': 'Illum dolore perferen',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 141},
#  {'_id': ObjectId('5c6dc068265ae8009a426a3a'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [50, 51, 155, 173, 174],
#    'level': 0,
#    'name': 'Explicabo recusandae ma',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 142},
#  {'_id': ObjectId('5c6dc068265ae8009a426a3b'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [55, 152],
#    'level': 0,
#    'name': 'Odio obcaecati hic nostrum n',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 143},
#  {'_id': ObjectId('5c6dc068265ae8009a426a3c'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [117],
#    'level': 0,
#    'name': 'Voluptate ali',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 144},
#  {'_id': ObjectId('5c6dc068265ae8009a426a3d'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [25, 26, 116, 163],
#    'level': 0,
#    'name': 'Repudiandae vitae sapiente mol',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 145},
#  {'_id': ObjectId('5c6dc068265ae8009a426a3e'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [18, 26, 56, 106],
#    'level': 0,
#    'name': 'Ipsam cumque',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 146},
#  {'_id': ObjectId('5c6dc068265ae8009a426a3f'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [163],
#    'level': 0,
#    'name': 'Fugiat quos alias eos dese',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 147},
#  {'_id': ObjectId('5c6dc068265ae8009a426a40'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [26, 62, 130, 147],
#    'level': 0,
#    'name': 'Eaque impe',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 148},
#  {'_id': ObjectId('5c6dc069265ae8009a426a41'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [121, 128, 142],
#    'level': 0,
#    'name': 'Elige',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 149},
#  {'_id': ObjectId('5c6dc069265ae8009a426a42'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [31, 97, 134],
#    'level': 0,
#    'name': 'Adip',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 150},
#  {'_id': ObjectId('5c6dc069265ae8009a426a43'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [57, 87, 153],
#    'level': 0,
#    'name': 'Fuga nemo vel mo',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 151},
#  {'_id': ObjectId('5c6dc069265ae8009a426a44'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [5, 106, 158],
#    'level': 0,
#    'name': 'Libero cumque impedit eveniet',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 152},
#  {'_id': ObjectId('5c6dc069265ae8009a426a45'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [20, 54, 122, 160],
#    'level': 0,
#    'name': 'Odio soluta',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 153},
#  {'_id': ObjectId('5c6dc069265ae8009a426a46'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [1, 27, 69],
#    'level': 0,
#    'name': 'Vero nostrum duc',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 154},
#  {'_id': ObjectId('5c6dc069265ae8009a426a47'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [15, 79, 90, 122],
#    'level': 0,
#    'name': 'Repellend',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 155},
#  {'_id': ObjectId('5c6dc06a265ae8009a426a48'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [29, 102, 120, 130, 162],
#    'level': 0,
#    'name': 'Quod',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 156},
#  {'_id': ObjectId('5c6dc06a265ae8009a426a49'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [110],
#    'level': 0,
#    'name': 'Suscipit reiciend',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 157},
#  {'_id': ObjectId('5c6dc06a265ae8009a426a4a'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [71],
#    'level': 0,
#    'name': 'Voluptat',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 158},
#  {'_id': ObjectId('5c6dc06a265ae8009a426a4b'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [40, 86, 115],
#    'level': 0,
#    'name': 'Porro dolor fuga quam',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 159},
#  {'_id': ObjectId('5c6dc06a265ae8009a426a4c'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [53, 65, 78, 109, 174],
#    'level': 0,
#    'name': 'Amet quo fugit aliquam sequi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 160},
#  {'_id': ObjectId('5c6dc06a265ae8009a426a4d'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [83, 115],
#    'level': 0,
#    'name': 'Magni adipisci veritatis sit q',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 161},
#  {'_id': ObjectId('5c6dc06a265ae8009a426a4e'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [66, 136],
#    'level': 0,
#    'name': 'Debitis enim cumque cum qu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 162},
#  {'_id': ObjectId('5c6dc06a265ae8009a426a4f'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [21, 50, 65],
#    'level': 0,
#    'name': 'Dolorem eligend',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 163},
#  {'_id': ObjectId('5c6dc06b265ae8009a426a50'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [174],
#    'level': 0,
#    'name': 'Autem lib',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 164},
#  {'_id': ObjectId('5c6dc06b265ae8009a426a51'),
#   'fields': {'dexterity': 1,
# ...
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [20],
#    'level': 0,
#    'name': 'Distinctio',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 248},
#  {'_id': ObjectId('5c6dc076265ae8009a426aa5'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [25, 53, 76, 87],
#    'level': 0,
#    'name': 'Repudiandae ip',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 249},
#  {'_id': ObjectId('5c6dc076265ae8009a426aa6'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [4, 62, 150, 155],
#    'level': 0,
#    'name': 'Iste debitis dolorum amet m',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 250},
#  {'_id': ObjectId('5c6dc076265ae8009a426aa7'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [17, 63, 109, 112, 162],
#    'level': 0,
#    'name': 'Non qui vo',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 251},
#  {'_id': ObjectId('5c6dc076265ae8009a426aa8'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [6, 169],
#    'level': 0,
#    'name': 'Dolorem ma',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 252},
#  {'_id': ObjectId('5c6dc076265ae8009a426aa9'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [13, 140],
#    'level': 0,
#    'name': 'Molestias labore tempore ita',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 253},
#  {'_id': ObjectId('5c6dc076265ae8009a426aaa'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [158],
#    'level': 0,
#    'name': 'Vol',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 254},
#  {'_id': ObjectId('5c6dc077265ae8009a426aab'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [48, 79],
#    'level': 0,
#    'name': 'Adipisci molest',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 255},
#  {'_id': ObjectId('5c6dc077265ae8009a426aac'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [165, 173],
#    'level': 0,
#    'name': 'Omni',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 256},
#  {'_id': ObjectId('5c6dc077265ae8009a426aad'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [54, 123, 149],
#    'level': 0,
#    'name': 'Voluptatibus dolor',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 257},
#  {'_id': ObjectId('5c6dc077265ae8009a426aae'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [12, 36, 70, 119],
#    'level': 0,
#    'name': 'Quo',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 258},
#  {'_id': ObjectId('5c6dc077265ae8009a426aaf'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [27, 40, 60, 86, 89],
#    'level': 0,
#    'name': 'Atque aspernatur possi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 259},
#  {'_id': ObjectId('5c6dc077265ae8009a426ab0'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [50, 68, 97, 115],
#    'level': 0,
#    'name': 'Ullam c',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 260},
#  {'_id': ObjectId('5c6dc077265ae8009a426ab1'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [7, 34, 101, 169, 174],
#    'level': 0,
#    'name': 'Iusto quas voluptatibu',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 261},
#  {'_id': ObjectId('5c6dc078265ae8009a426ab2'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [8, 51, 60, 161],
#    'level': 0,
#    'name': 'Optio qui sunt dolores, ab',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 262},
#  {'_id': ObjectId('5c6dc078265ae8009a426ab3'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [13, 30, 132, 146],
#    'level': 0,
#    'name': 'Illum recusandae nulla re',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 263},
#  {'_id': ObjectId('5c6dc078265ae8009a426ab4'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [26, 106, 111, 134, 145],
#    'level': 0,
#    'name': 'Verita',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 264},
#  {'_id': ObjectId('5c6dc078265ae8009a426ab5'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [116, 117, 155],
#    'level': 0,
#    'name': 'Expedita quod blanditiis',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 265},
#  {'_id': ObjectId('5c6dc078265ae8009a426ab6'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [11, 66, 82, 85, 89],
#    'level': 0,
#    'name': 'Mag',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 266},
#  {'_id': ObjectId('5c6dc078265ae8009a426ab7'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [14, 47, 86, 150],
#    'level': 0,
#    'name': 'Omnis quos aspernatur d',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 267},
#  {'_id': ObjectId('5c6dc078265ae8009a426ab8'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [68],
#    'level': 0,
#    'name': 'Sunt impedit co',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 268},
#  {'_id': ObjectId('5c6dc078265ae8009a426ab9'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [81],
#    'level': 0,
#    'name': 'Minima quam ea ad',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 269},
#  {'_id': ObjectId('5c6dc079265ae8009a426aba'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [12],
#    'level': 0,
#    'name': 'Suscipit quidem e',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 270},
#  {'_id': ObjectId('5c6dc079265ae8009a426abb'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [68, 161],
#    'level': 0,
#    'name': 'Harum',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 271},
#  {'_id': ObjectId('5c6dc079265ae8009a426abc'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [37, 106],
#    'level': 0,
#    'name': 'Dolore laborum ips',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 272},
#  {'_id': ObjectId('5c6dc079265ae8009a426abd'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [43, 82, 121],
#    'level': 0,
#    'name': 'Magni veniam earum corporis',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 273},
#  {'_id': ObjectId('5c6dc079265ae8009a426abe'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [84, 97, 98],
#    'level': 0,
#    'name': 'Optio',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 274},
#  {'_id': ObjectId('5c6dc079265ae8009a426abf'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [8, 147],
#    'level': 0,
#    'name': 'Nam fugit vel.',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 275},
#  {'_id': ObjectId('5c6dc079265ae8009a426ac0'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [101],
#    'level': 0,
#    'name': 'Ut numquam quam eum, alias ius',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 276},
#  {'_id': ObjectId('5c6dc07a265ae8009a426ac1'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [23],
#    'level': 0,
#    'name': 'Error amet tempore nulla',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 277},
#  {'_id': ObjectId('5c6dc07a265ae8009a426ac2'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [99],
#    'level': 0,
#    'name': 'Deserunt a',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 278},
#  {'_id': ObjectId('5c6dc07a265ae8009a426ac3'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [34, 156],
#    'level': 0,
#    'name': 'Aperiam sit',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 279},
#  {'_id': ObjectId('5c6dc07a265ae8009a426ac4'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [73, 87, 137, 156, 169],
#    'level': 0,
#    'name': 'Asperi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 280},
#  {'_id': ObjectId('5c6dc07a265ae8009a426ac5'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [19, 27, 76, 136, 174],
#    'level': 0,
#    'name': 'Similique aperiam earum expli',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 281},
#  {'_id': ObjectId('5c6dc07a265ae8009a426ac6'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [16, 77, 131, 161],
#    'level': 0,
#    'name': 'Iure h',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 282},
#  {'_id': ObjectId('5c6dc07a265ae8009a426ac7'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [29, 96, 106, 165],
#    'level': 0,
#    'name': 'At sint ducimus nostrum i',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 283},
#  {'_id': ObjectId('5c6dc07a265ae8009a426ac8'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [55],
#    'level': 0,
#    'name': 'Reprehenderit temporib',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 284},
#  {'_id': ObjectId('5c6dc07b265ae8009a426ac9'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [3, 113, 116, 137, 171],
#    'level': 0,
#    'name': 'Molestiae quaerat maxim',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 285},
#  {'_id': ObjectId('5c6dc07b265ae8009a426aca'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [32],
#    'level': 0,
#    'name': 'Maior',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 286},
#  {'_id': ObjectId('5c6dc07b265ae8009a426acb'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [32, 92, 118, 130, 156],
#    'level': 0,
#    'name': 'Unde natus ut ipsa cupi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 287},
#  {'_id': ObjectId('5c6dc07b265ae8009a426acc'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [37, 41, 134],
#    'level': 0,
#    'name': 'Praesentium atque ear',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 288},
#  {'_id': ObjectId('5c6dc07b265ae8009a426acd'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [52, 56, 81, 104, 132],
#    'level': 0,
#    'name': 'Rem minima',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 289},
#  {'_id': ObjectId('5c6dc07b265ae8009a426ace'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [96, 107, 115, 131, 141],
#    'level': 0,
#    'name': 'Provident sed soluta, sed si',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 290},
#  {'_id': ObjectId('5c6dc07b265ae8009a426acf'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [10, 37, 74, 79],
#    'level': 0,
#    'name': 'Natus quia veritatis',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 291},
#  {'_id': ObjectId('5c6dc07b265ae8009a426ad0'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [128, 150],
#    'level': 0,
#    'name': 'Vero a',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 292},
#  {'_id': ObjectId('5c6dc07c265ae8009a426ad1'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [112, 158],
#    'level': 0,
#    'name': 'Optio harum labori',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 293},
#  {'_id': ObjectId('5c6dc07c265ae8009a426ad2'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [49, 66, 102, 156, 164],
#    'level': 0,
#    'name': 'Duci',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 294},
#  {'_id': ObjectId('5c6dc07c265ae8009a426ad3'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [113, 167],
#    'level': 0,
#    'name': 'Ipsa elige',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 295},
#  {'_id': ObjectId('5c6dc07c265ae8009a426ad4'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [12, 90, 169],
#    'level': 0,
#    'name': 'Sunt blanditiis i',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 296},
#  {'_id': ObjectId('5c6dc07c265ae8009a426ad5'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [31, 70, 74, 88],
#    'level': 0,
#    'name': 'Doloremque',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 297},
#  {'_id': ObjectId('5c6dc07c265ae8009a426ad6'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [15, 29],
#    'level': 0,
#    'name': 'Autem ratione vitae quos, do',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 298},
#  {'_id': ObjectId('5c6dc07c265ae8009a426ad7'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [19, 67, 109],
#    'level': 0,
#    'name': 'Voluptatibus aliquid',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 299},
#  {'_id': ObjectId('5c6dc07d265ae8009a426ad8'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [119],
#    'level': 0,
#    'name': 'Quaerat sequi sit eius corpori',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 300},
#  {'_id': ObjectId('5c6dc07d265ae8009a426ad9'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [52, 150],
#    'level': 0,
#    'name': 'Libe',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 301},
#  {'_id': ObjectId('5c6dc07d265ae8009a426ada'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [21, 28, 51, 106, 141],
#    'level': 0,
#    'name': 'Aliquam n',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 302}]

# %%
list(db_game.test.find( { "pk": 174 }))
# Out:
# [{'_id': ObjectId('5c6dc06c265ae8009a426a5a'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [46, 56],
#    'level': 0,
#    'name': 'Optio quas e',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 174},
#  {'_id': ObjectId('5c6dc095265ae8009a426b93'),
#   'fields': {'inventory': [46, 56], 'mana': 100, 'using_shield': False},
#   'model': 'charactercreator.cleric',
#   'pk': 174},
#  {'_id': ObjectId('5c6dc0bd265ae8009a426cc1'),
#   'fields': {'name': 'Atque repudiandae molestiae v', 'value': 0, 'weight': 0},
#   'model': 'armory.item',
#   'pk': 174}]

# %% [markdown]
# ### Upload Titanic Data into MongoDB

# %%
#Create titanic db
db_titanic = client.test2

# %%
dir(db_titanic)

# %%
#check if it's empty
list(db_titanic.test.find({}))

# %%
import pandas as pd

# %%
#load csv data to pandas dataframe
csv_url = 'https://raw.githubusercontent.com/zarrinan/DS-Unit-3-Sprint-2-SQL-and-Databases/master/module2-sql-for-analysis/titanic.csv'
t = pd.read_csv(csv_url)

# %%
#convert pandas dataframe to json string -> json object
js = t.to_json(orient='records')
d = json.loads(js)

# %%
#insert data into titanic db
for passenger in d:
  if not db_titanic.test.find_one(passenger):
    db_titanic.test.insert_one(passenger)

# %%
#Check titanic db
list(db_titanic.test.find({}))
# Out:
# [{'Age': 22.0,
#   'Fare': 7.25,
#   'Name': 'Mr. Owen Harris Braund',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd4265ae8009a426ce8')},
#  {'Age': 38.0,
#   'Fare': 71.2833,
#   'Name': 'Mrs. John Bradley (Florence Briggs Thayer) Cumings',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccd5265ae8009a426ce9')},
#  {'Age': 26.0,
#   'Fare': 7.925,
#   'Name': 'Miss. Laina Heikkinen',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccd5265ae8009a426cea')},
#  {'Age': 35.0,
#   'Fare': 53.1,
#   'Name': 'Mrs. Jacques Heath (Lily May Peel) Futrelle',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccd5265ae8009a426ceb')},
#  {'Age': 35.0,
#   'Fare': 8.05,
#   'Name': 'Mr. William Henry Allen',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd5265ae8009a426cec')},
#  {'Age': 27.0,
#   'Fare': 8.4583,
#   'Name': 'Mr. James Moran',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd5265ae8009a426ced')},
#  {'Age': 54.0,
#   'Fare': 51.8625,
#   'Name': 'Mr. Timothy J McCarthy',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd5265ae8009a426cee')},
#  {'Age': 2.0,
#   'Fare': 21.075,
#   'Name': 'Master. Gosta Leonard Palsson',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 3,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd5265ae8009a426cef')},
#  {'Age': 27.0,
#   'Fare': 11.1333,
#   'Name': 'Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccd5265ae8009a426cf0')},
#  {'Age': 14.0,
#   'Fare': 30.0708,
#   'Name': 'Mrs. Nicholas (Adele Achem) Nasser',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccd6265ae8009a426cf1')},
#  {'Age': 4.0,
#   'Fare': 16.7,
#   'Name': 'Miss. Marguerite Rut Sandstrom',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccd6265ae8009a426cf2')},
#  {'Age': 58.0,
#   'Fare': 26.55,
#   'Name': 'Miss. Elizabeth Bonnell',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccd6265ae8009a426cf3')},
#  {'Age': 20.0,
#   'Fare': 8.05,
#   'Name': 'Mr. William Henry Saundercock',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd6265ae8009a426cf4')},
#  {'Age': 39.0,
#   'Fare': 31.275,
#   'Name': 'Mr. Anders Johan Andersson',
#   'Parents/Children Aboard': 5,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd6265ae8009a426cf5')},
#  {'Age': 14.0,
#   'Fare': 7.8542,
#   'Name': 'Miss. Hulda Amanda Adolfina Vestrom',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd6265ae8009a426cf6')},
#  {'Age': 55.0,
#   'Fare': 16.0,
#   'Name': 'Mrs. (Mary D Kingcome) Hewlett',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccd6265ae8009a426cf7')},
#  {'Age': 2.0,
#   'Fare': 29.125,
#   'Name': 'Master. Eugene Rice',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 4,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd7265ae8009a426cf8')},
#  {'Age': 23.0,
#   'Fare': 13.0,
#   'Name': 'Mr. Charles Eugene Williams',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccd7265ae8009a426cf9')},
#  {'Age': 31.0,
#   'Fare': 18.0,
#   'Name': 'Mrs. Julius (Emelia Maria Vandemoortele) Vander Planke',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd7265ae8009a426cfa')},
#  {'Age': 22.0,
#   'Fare': 7.225,
#   'Name': 'Mrs. Fatima Masselmani',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccd7265ae8009a426cfb')},
#  {'Age': 35.0,
#   'Fare': 26.0,
#   'Name': 'Mr. Joseph J Fynney',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd7265ae8009a426cfc')},
#  {'Age': 34.0,
#   'Fare': 13.0,
#   'Name': 'Mr. Lawrence Beesley',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccd7265ae8009a426cfd')},
#  {'Age': 15.0,
#   'Fare': 8.0292,
#   'Name': 'Miss. Anna McGowan',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccd7265ae8009a426cfe')},
#  {'Age': 28.0,
#   'Fare': 35.5,
#   'Name': 'Mr. William Thompson Sloper',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccd8265ae8009a426cff')},
#  {'Age': 8.0,
#   'Fare': 21.075,
#   'Name': 'Miss. Torborg Danira Palsson',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 3,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd8265ae8009a426d00')},
#  {'Age': 38.0,
#   'Fare': 31.3875,
#   'Name': 'Mrs. Carl Oscar (Selma Augusta Emilia Johansson) Asplund',
#   'Parents/Children Aboard': 5,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccd8265ae8009a426d01')},
#  {'Age': 26.0,
#   'Fare': 7.225,
#   'Name': 'Mr. Farred Chehab Emir',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd8265ae8009a426d02')},
#  {'Age': 19.0,
#   'Fare': 263.0,
#   'Name': 'Mr. Charles Alexander Fortune',
#   'Parents/Children Aboard': 2,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 3,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd8265ae8009a426d03')},
#  {'Age': 24.0,
#   'Fare': 7.8792,
#   'Name': "Miss. Ellen O'Dwyer",
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccd8265ae8009a426d04')},
#  {'Age': 23.0,
#   'Fare': 7.8958,
#   'Name': 'Mr. Lalio Todoroff',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd8265ae8009a426d05')},
#  {'Age': 40.0,
#   'Fare': 27.7208,
#   'Name': 'Don. Manuel E Uruchurtu',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd8265ae8009a426d06')},
#  {'Age': 48.0,
#   'Fare': 146.5208,
#   'Name': 'Mrs. William Augustus (Marie Eugenie) Spencer',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccd9265ae8009a426d07')},
#  {'Age': 18.0,
#   'Fare': 7.75,
#   'Name': 'Miss. Mary Agatha Glynn',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccd9265ae8009a426d08')},
#  {'Age': 66.0,
#   'Fare': 10.5,
#   'Name': 'Mr. Edward H Wheadon',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd9265ae8009a426d09')},
#  {'Age': 28.0,
#   'Fare': 82.1708,
#   'Name': 'Mr. Edgar Joseph Meyer',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd9265ae8009a426d0a')},
#  {'Age': 42.0,
#   'Fare': 52.0,
#   'Name': 'Mr. Alexander Oskar Holverson',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd9265ae8009a426d0b')},
#  {'Age': 18.0,
#   'Fare': 7.2292,
#   'Name': 'Mr. Hanna Mamee',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccd9265ae8009a426d0c')},
#  {'Age': 21.0,
#   'Fare': 8.05,
#   'Name': 'Mr. Ernest Charles Cann',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccd9265ae8009a426d0d')},
#  {'Age': 18.0,
#   'Fare': 18.0,
#   'Name': 'Miss. Augusta Maria Vander Planke',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 2,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccda265ae8009a426d0e')},
#  {'Age': 14.0,
#   'Fare': 11.2417,
#   'Name': 'Miss. Jamila Nicola-Yarred',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccda265ae8009a426d0f')},
#  {'Age': 40.0,
#   'Fare': 9.475,
#   'Name': 'Mrs. Johan (Johanna Persdotter Larsson) Ahlin',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccda265ae8009a426d10')},
#  {'Age': 27.0,
#   'Fare': 21.0,
#   'Name': 'Mrs. William John Robert (Dorothy Ann Wonnacott) Turpin',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccda265ae8009a426d11')},
#  {'Age': 3.0,
#   'Fare': 41.5792,
#   'Name': 'Miss. Simonne Marie Anne Andree Laroche',
#   'Parents/Children Aboard': 2,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccda265ae8009a426d12')},
#  {'Age': 19.0,
#   'Fare': 7.8792,
#   'Name': 'Miss. Margaret Delia Devaney',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccda265ae8009a426d13')},
#  {'Age': 30.0,
#   'Fare': 8.05,
#   'Name': 'Mr. William John Rogers',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccda265ae8009a426d14')},
#  {'Age': 20.0,
#   'Fare': 15.5,
#   'Name': 'Mr. Denis Lennon',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccdb265ae8009a426d15')},
#  {'Age': 27.0,
#   'Fare': 7.75,
#   'Name': "Miss. Bridget O'Driscoll",
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccdb265ae8009a426d16')},
#  {'Age': 16.0,
#   'Fare': 21.6792,
#   'Name': 'Mr. Youssef Samaan',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 2,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccdb265ae8009a426d17')},
#  {'Age': 18.0,
#   'Fare': 17.8,
#   'Name': 'Mrs. Josef (Josefine Franchi) Arnold-Franchi',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccdb265ae8009a426d18')},
#  {'Age': 7.0,
#   'Fare': 39.6875,
#   'Name': 'Master. Juha Niilo Panula',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 4,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccdb265ae8009a426d19')},
#  {'Age': 21.0,
#   'Fare': 7.8,
#   'Name': 'Mr. Richard Cater Nosworthy',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccdb265ae8009a426d1a')},
#  {'Age': 49.0,
#   'Fare': 76.7292,
#   'Name': 'Mrs. Henry Sleeper (Myna Haxtun) Harper',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccdb265ae8009a426d1b')},
#  {'Age': 29.0,
#   'Fare': 26.0,
#   'Name': 'Mrs. Lizzie (Elizabeth Anne Wilkinson) Faunthorpe',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccdb265ae8009a426d1c')},
#  {'Age': 65.0,
#   'Fare': 61.9792,
#   'Name': 'Mr. Engelhart Cornelius Ostby',
#   'Parents/Children Aboard': 1,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccdc265ae8009a426d1d')},
#  {'Age': 46.0,
#   'Fare': 35.5,
#   'Name': 'Mr. Hugh Woolner',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccdc265ae8009a426d1e')},
#  {'Age': 21.0,
#   'Fare': 10.5,
#   'Name': 'Miss. Emily Rugg',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccdc265ae8009a426d1f')},
#  {'Age': 28.5,
#   'Fare': 7.2292,
#   'Name': 'Mr. Mansouer Novel',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccdc265ae8009a426d20')},
#  {'Age': 5.0,
#   'Fare': 27.75,
#   'Name': 'Miss. Constance Mirium West',
#   'Parents/Children Aboard': 2,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccdc265ae8009a426d21')},
#  {'Age': 11.0,
#   'Fare': 46.9,
#   'Name': 'Master. William Frederick Goodwin',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 5,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccdc265ae8009a426d22')},
#  {'Age': 22.0,
#   'Fare': 7.2292,
#   'Name': 'Mr. Orsen Sirayanian',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccdc265ae8009a426d23')},
#  {'Age': 38.0,
#   'Fare': 80.0,
#   'Name': 'Miss. Amelie Icard',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccdd265ae8009a426d24')},
#  {'Age': 45.0,
#   'Fare': 83.475,
#   'Name': 'Mr. Henry Birkhardt Harris',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccdd265ae8009a426d25')},
#  {'Age': 4.0,
#   'Fare': 27.9,
#   'Name': 'Master. Harald Skoog',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 3,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccdd265ae8009a426d26')},
#  {'Age': 64.0,
#   'Fare': 27.7208,
#   'Name': 'Mr. Albert A Stewart',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccdd265ae8009a426d27')},
#  {'Age': 7.0,
#   'Fare': 15.2458,
#   'Name': 'Master. Gerios Moubarek',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccdd265ae8009a426d28')},
#  {'Age': 29.0,
#   'Fare': 10.5,
#   'Name': 'Mrs. (Elizabeth Ramell) Nye',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccdd265ae8009a426d29')},
#  {'Age': 19.0,
#   'Fare': 8.1583,
#   'Name': 'Mr. Ernest James Crease',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccdd265ae8009a426d2a')},
#  {'Age': 17.0,
#   'Fare': 7.925,
#   'Name': 'Miss. Erna Alexandra Andersson',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 4,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccde265ae8009a426d2b')},
#  {'Age': 26.0,
#   'Fare': 8.6625,
#   'Name': 'Mr. Vincenz Kink',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 2,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccde265ae8009a426d2c')},
#  {'Age': 32.0,
#   'Fare': 10.5,
#   'Name': 'Mr. Stephen Curnow Jenkin',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccde265ae8009a426d2d')},
#  {'Age': 16.0,
#   'Fare': 46.9,
#   'Name': 'Miss. Lillian Amy Goodwin',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 5,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccde265ae8009a426d2e')},
#  {'Age': 21.0,
#   'Fare': 73.5,
#   'Name': 'Mr. Ambrose Jr Hood',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccde265ae8009a426d2f')},
#  {'Age': 26.0,
#   'Fare': 14.4542,
#   'Name': 'Mr. Apostolos Chronopoulos',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccde265ae8009a426d30')},
#  {'Age': 32.0,
#   'Fare': 56.4958,
#   'Name': 'Mr. Lee Bing',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccde265ae8009a426d31')},
#  {'Age': 25.0,
#   'Fare': 7.65,
#   'Name': 'Mr. Sigurd Hansen Moen',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccde265ae8009a426d32')},
#  {'Age': 23.0,
#   'Fare': 7.8958,
#   'Name': 'Mr. Ivan Staneff',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccdf265ae8009a426d33')},
#  {'Age': 28.0,
#   'Fare': 8.05,
#   'Name': 'Mr. Rahamin Haim Moutal',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccdf265ae8009a426d34')},
#  {'Age': 0.83,
#   'Fare': 29.0,
#   'Name': 'Master. Alden Gates Caldwell',
#   'Parents/Children Aboard': 2,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccdf265ae8009a426d35')},
#  {'Age': 30.0,
#   'Fare': 12.475,
#   'Name': 'Miss. Elizabeth Dowdell',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccdf265ae8009a426d36')},
#  {'Age': 22.0,
#   'Fare': 9.0,
#   'Name': 'Mr. Achille Waelens',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccdf265ae8009a426d37')},
#  {'Age': 29.0,
#   'Fare': 9.5,
#   'Name': 'Mr. Jan Baptist Sheerlinck',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccdf265ae8009a426d38')},
#  {'Age': 31.0,
#   'Fare': 7.7875,
#   'Name': 'Miss. Brigdet Delia McDermott',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccdf265ae8009a426d39')},
#  {'Age': 28.0,
#   'Fare': 47.1,
#   'Name': 'Mr. Francisco M Carrau',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce0265ae8009a426d3a')},
#  {'Age': 17.0,
#   'Fare': 10.5,
#   'Name': 'Miss. Bertha Ilett',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcce0265ae8009a426d3b')},
#  {'Age': 33.0,
#   'Fare': 15.85,
#   'Name': 'Mrs. Karl Alfred (Maria Mathilda Gustafsson) Backstrom',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 3,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcce0265ae8009a426d3c')},
#  {'Age': 16.0,
#   'Fare': 34.375,
#   'Name': 'Mr. William Neal Ford',
#   'Parents/Children Aboard': 3,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce0265ae8009a426d3d')},
#  {'Age': 20.0,
#   'Fare': 8.05,
#   'Name': 'Mr. Selman Francis Slocovski',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce0265ae8009a426d3e')},
#  {'Age': 23.0,
#   'Fare': 263.0,
#   'Name': 'Miss. Mabel Helen Fortune',
#   'Parents/Children Aboard': 2,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 3,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcce0265ae8009a426d3f')},
#  {'Age': 24.0,
#   'Fare': 8.05,
#   'Name': 'Mr. Francesco Celotti',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce0265ae8009a426d40')},
#  {'Age': 29.0,
#   'Fare': 8.05,
#   'Name': 'Mr. Emil Christmann',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce1265ae8009a426d41')},
#  {'Age': 20.0,
#   'Fare': 7.8542,
#   'Name': 'Mr. Paul Edvin Andreasson',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce1265ae8009a426d42')},
#  {'Age': 46.0,
#   'Fare': 61.175,
#   'Name': 'Mr. Herbert Fuller Chaffee',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce1265ae8009a426d43')},
#  {'Age': 26.0,
#   'Fare': 20.575,
#   'Name': 'Mr. Bertram Frank Dean',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce1265ae8009a426d44')},
#  {'Age': 59.0,
#   'Fare': 7.25,
#   'Name': 'Mr. Daniel Coxon',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce1265ae8009a426d45')},
#  {'Age': 22.0,
#   'Fare': 8.05,
#   'Name': 'Mr. Charles Joseph Shorney',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce1265ae8009a426d46')},
#  {'Age': 71.0,
#   'Fare': 34.6542,
#   'Name': 'Mr. George B Goldschmidt',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce1265ae8009a426d47')},
#  {'Age': 23.0,
#   'Fare': 63.3583,
#   'Name': 'Mr. William Bertram Greenfield',
#   'Parents/Children Aboard': 1,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcce1265ae8009a426d48')},
#  {'Age': 34.0,
#   'Fare': 23.0,
#   'Name': 'Mrs. John T (Ada Julia Bone) Doling',
#   'Parents/Children Aboard': 1,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcce2265ae8009a426d49')},
#  {'Age': 34.0,
#   'Fare': 26.0,
#   'Name': 'Mr. Sinai Kantor',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce2265ae8009a426d4a')},
#  {'Age': 28.0,
#   'Fare': 7.8958,
#   'Name': 'Miss. Matilda Petranec',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce2265ae8009a426d4b')},
#  {'Age': 29.0,
#   'Fare': 7.8958,
#   'Name': 'Mr. Pastcho Petroff',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce2265ae8009a426d4c')},
#  {'Age': 21.0,
#   'Fare': 77.2875,
#   'Name': 'Mr. Richard Frasar White',
#   'Parents/Children Aboard': 1,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce2265ae8009a426d4d')},
#  {'Age': 33.0,
#   'Fare': 8.6542,
#   'Name': 'Mr. Gustaf Joel Johansson',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce2265ae8009a426d4e')},
#  {'Age': 37.0,
#   'Fare': 7.925,
#   'Name': 'Mr. Anders Vilhelm Gustafsson',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 2,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce2265ae8009a426d4f')},
#  {'Age': 28.0,
#   'Fare': 7.8958,
#   'Name': 'Mr. Stoytcho Mionoff',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce3265ae8009a426d50')},
#  {'Age': 21.0,
#   'Fare': 7.65,
#   'Name': 'Miss. Anna Kristine Salkjelsvik',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcce3265ae8009a426d51')},
#  {'Age': 29.0,
#   'Fare': 7.775,
#   'Name': 'Mr. Albert Johan Moss',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcce3265ae8009a426d52')},
#  {'Age': 38.0,
#   'Fare': 7.8958,
#   'Name': 'Mr. Tido Rekic',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce3265ae8009a426d53')},
#  {'Age': 28.0,
#   'Fare': 24.15,
#   'Name': 'Miss. Bertha Moran',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcce3265ae8009a426d54')},
#  {'Age': 47.0,
#   'Fare': 52.0,
#   'Name': 'Mr. Walter Chamberlain Porter',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce3265ae8009a426d55')},
#  {'Age': 14.5,
#   'Fare': 14.4542,
#   'Name': 'Miss. Hileni Zabour',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce3265ae8009a426d56')},
#  {'Age': 22.0,
#   'Fare': 8.05,
#   'Name': 'Mr. David John Barton',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce4265ae8009a426d57')},
#  {'Age': 20.0,
#   'Fare': 9.825,
#   'Name': 'Miss. Katriina Jussila',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce4265ae8009a426d58')},
#  {'Age': 17.0,
#   'Fare': 14.4583,
#   'Name': 'Miss. Malake Attalah',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce4265ae8009a426d59')},
#  {'Age': 21.0,
#   'Fare': 7.925,
#   'Name': 'Mr. Edvard Pekoniemi',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce4265ae8009a426d5a')},
#  {'Age': 70.5,
#   'Fare': 7.75,
#   'Name': 'Mr. Patrick Connors',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce4265ae8009a426d5b')},
#  {'Age': 29.0,
#   'Fare': 21.0,
#   'Name': 'Mr. William John Robert Turpin',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce4265ae8009a426d5c')},
#  {'Age': 24.0,
#   'Fare': 247.5208,
#   'Name': 'Mr. Quigg Edmond Baxter',
#   'Parents/Children Aboard': 1,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce4265ae8009a426d5d')},
#  {'Age': 2.0,
#   'Fare': 31.275,
#   'Name': 'Miss. Ellis Anna Maria Andersson',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 4,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce4265ae8009a426d5e')},
#  {'Age': 21.0,
#   'Fare': 73.5,
#   'Name': 'Mr. Stanley George Hickman',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 2,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce5265ae8009a426d5f')},
#  {'Age': 19.0,
#   'Fare': 8.05,
#   'Name': 'Mr. Leonard Charles Moore',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce5265ae8009a426d60')},
#  {'Age': 32.5,
#   'Fare': 30.0708,
#   'Name': 'Mr. Nicholas Nasser',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce5265ae8009a426d61')},
#  {'Age': 32.5,
#   'Fare': 13.0,
#   'Name': 'Miss. Susan Webber',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcce5265ae8009a426d62')},
#  {'Age': 54.0,
#   'Fare': 77.2875,
#   'Name': 'Mr. Percival Wayland White',
#   'Parents/Children Aboard': 1,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce5265ae8009a426d63')},
#  {'Age': 12.0,
#   'Fare': 11.2417,
#   'Name': 'Master. Elias Nicola-Yarred',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcce5265ae8009a426d64')},
#  {'Age': 19.0,
#   'Fare': 7.75,
#   'Name': 'Mr. Martin McMahon',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce5265ae8009a426d65')},
#  {'Age': 24.0,
#   'Fare': 7.1417,
#   'Name': 'Mr. Fridtjof Arne Madsen',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcce6265ae8009a426d66')},
#  {'Age': 2.0,
#   'Fare': 22.3583,
#   'Name': 'Miss. Anna Peter',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcce6265ae8009a426d67')},
#  {'Age': 45.0,
#   'Fare': 6.975,
#   'Name': 'Mr. Johan Ekstrom',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce6265ae8009a426d68')},
#  {'Age': 33.0,
#   'Fare': 7.8958,
#   'Name': 'Mr. Jozef Drazenoic',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce6265ae8009a426d69')},
#  {'Age': 20.0,
#   'Fare': 7.05,
#   'Name': 'Mr. Domingos Fernandeo Coelho',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce6265ae8009a426d6a')},
#  {'Age': 47.0,
#   'Fare': 14.5,
#   'Name': 'Mrs. Alexander A (Grace Charity Laury) Robins',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce6265ae8009a426d6b')},
#  {'Age': 29.0,
#   'Fare': 26.0,
#   'Name': 'Mrs. Leopold (Mathilde Francoise Pede) Weisz',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcce6265ae8009a426d6c')},
#  {'Age': 25.0,
#   'Fare': 13.0,
#   'Name': 'Mr. Samuel James Hayden Sobey',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce7265ae8009a426d6d')},
#  {'Age': 23.0,
#   'Fare': 15.0458,
#   'Name': 'Mr. Emile Richard',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce7265ae8009a426d6e')},
#  {'Age': 19.0,
#   'Fare': 26.2833,
#   'Name': 'Miss. Helen Monypeny Newsom',
#   'Parents/Children Aboard': 2,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcce7265ae8009a426d6f')},
#  {'Age': 37.0,
#   'Fare': 53.1,
#   'Name': 'Mr. Jacques Heath Futrelle',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce7265ae8009a426d70')},
#  {'Age': 16.0,
#   'Fare': 9.2167,
#   'Name': 'Mr. Olaf Elon Osen',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce7265ae8009a426d71')},
#  {'Age': 24.0,
#   'Fare': 79.2,
#   'Name': 'Mr. Victor Giglio',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce7265ae8009a426d72')},
#  {'Age': 40.0,
#   'Fare': 15.2458,
#   'Name': 'Mrs. Joseph (Sultana) Boulos',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce7265ae8009a426d73')},
#  {'Age': 22.0,
#   'Fare': 7.75,
#   'Name': 'Miss. Anna Sofia Nysten',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcce8265ae8009a426d74')},
#  {'Age': 24.0,
#   'Fare': 15.85,
#   'Name': 'Mrs. Pekka Pietari (Elin Matilda Dolck) Hakkarainen',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcce8265ae8009a426d75')},
#  {'Age': 19.0,
#   'Fare': 6.75,
#   'Name': 'Mr. Jeremiah Burke',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce8265ae8009a426d76')},
#  {'Age': 18.0,
#   'Fare': 11.5,
#   'Name': 'Mr. Edgardo Samuel Andrew',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce8265ae8009a426d77')},
#  {'Age': 19.0,
#   'Fare': 36.75,
#   'Name': 'Mr. Joseph Charles Nicholls',
#   'Parents/Children Aboard': 1,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce8265ae8009a426d78')},
#  {'Age': 27.0,
#   'Fare': 7.7958,
#   'Name': 'Mr. August Edvard Andersson',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcce8265ae8009a426d79')},
#  {'Age': 9.0,
#   'Fare': 34.375,
#   'Name': 'Miss. Robina Maggie Ford',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 2,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce8265ae8009a426d7a')},
#  {'Age': 36.5,
#   'Fare': 26.0,
#   'Name': 'Mr. Michel Navratil',
#   'Parents/Children Aboard': 2,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce8265ae8009a426d7b')},
#  {'Age': 42.0,
#   'Fare': 13.0,
#   'Name': 'Rev. Thomas Roussel Davids Byles',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce9265ae8009a426d7c')},
#  {'Age': 51.0,
#   'Fare': 12.525,
#   'Name': 'Rev. Robert James Bateman',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce9265ae8009a426d7d')},
#  {'Age': 22.0,
#   'Fare': 66.6,
#   'Name': 'Mrs. Thomas (Edith Wearne) Pears',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcce9265ae8009a426d7e')},
#  {'Age': 55.5,
#   'Fare': 8.05,
#   'Name': 'Mr. Alfonzo Meo',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce9265ae8009a426d7f')},
#  {'Age': 40.5,
#   'Fare': 14.5,
#   'Name': 'Mr. Austin Blyler van Billiard',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce9265ae8009a426d80')},
#  {'Age': 27.0,
#   'Fare': 7.3125,
#   'Name': 'Mr. Ole Martin Olsen',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce9265ae8009a426d81')},
#  {'Age': 51.0,
#   'Fare': 61.3792,
#   'Name': 'Mr. Charles Duane Williams',
#   'Parents/Children Aboard': 1,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcce9265ae8009a426d82')},
#  {'Age': 16.0,
#   'Fare': 7.7333,
#   'Name': 'Miss. Katherine Gilnagh',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccea265ae8009a426d83')},
#  {'Age': 30.0,
#   'Fare': 8.05,
#   'Name': 'Mr. Harry Corn',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccea265ae8009a426d84')},
#  {'Age': 37.0,
#   'Fare': 8.6625,
#   'Name': 'Mr. Mile Smiljanic',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccea265ae8009a426d85')},
#  {'Age': 5.0,
#   'Fare': 69.55,
#   'Name': 'Master. Thomas Henry Sage',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 8,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccea265ae8009a426d86')},
#  {'Age': 44.0,
#   'Fare': 16.1,
#   'Name': 'Mr. John Hatfield Cribb',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccea265ae8009a426d87')},
#  {'Age': 40.0,
#   'Fare': 15.75,
#   'Name': 'Mrs. James (Elizabeth Inglis Milne) Watt',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccea265ae8009a426d88')},
#  {'Age': 26.0,
#   'Fare': 7.775,
#   'Name': 'Mr. John Viktor Bengtsson',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccea265ae8009a426d89')},
#  {'Age': 17.0,
#   'Fare': 8.6625,
#   'Name': 'Mr. Jovo Calic',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcceb265ae8009a426d8a')},
#  {'Age': 1.0,
#   'Fare': 39.6875,
#   'Name': 'Master. Eino Viljami Panula',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 4,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcceb265ae8009a426d8b')},
#  {'Age': 9.0,
#   'Fare': 20.525,
#   'Name': 'Master. Frank John William Goldsmith',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcceb265ae8009a426d8c')},
#  {'Age': 48.0,
#   'Fare': 55.0,
#   'Name': 'Mrs. (Edith Martha Bowerman) Chibnall',
#   'Parents/Children Aboard': 1,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcceb265ae8009a426d8d')},
#  {'Age': 45.0,
#   'Fare': 27.9,
#   'Name': 'Mrs. William (Anna Bernhardina Karlsson) Skoog',
#   'Parents/Children Aboard': 4,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcceb265ae8009a426d8e')},
#  {'Age': 60.0,
#   'Fare': 25.925,
#   'Name': 'Mr. John D Baumann',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcceb265ae8009a426d8f')},
#  {'Age': 28.0,
#   'Fare': 56.4958,
#   'Name': 'Mr. Lee Ling',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcceb265ae8009a426d90')},
#  {'Age': 61.0,
#   'Fare': 33.5,
#   'Name': 'Mr. Wyckoff Van der hoef',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcceb265ae8009a426d91')},
#  {'Age': 4.0,
#   'Fare': 29.125,
#   'Name': 'Master. Arthur Rice',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 4,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccec265ae8009a426d92')},
#  {'Age': 1.0,
#   'Fare': 11.1333,
#   'Name': 'Miss. Eleanor Ileen Johnson',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccec265ae8009a426d93')},
#  {'Age': 21.0,
#   'Fare': 7.925,
#   'Name': 'Mr. Antti Wilhelm Sivola',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccec265ae8009a426d94')},
#  {'Age': 56.0,
#   'Fare': 30.6958,
#   'Name': 'Mr. James Clinch Smith',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccec265ae8009a426d95')},
#  {'Age': 18.0,
#   'Fare': 7.8542,
#   'Name': 'Mr. Klas Albin Klasen',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccec265ae8009a426d96')},
#  {'Age': 5.0,
#   'Fare': 25.4667,
#   'Name': 'Master. Henry Forbes Lefebre',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 3,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccec265ae8009a426d97')},
#  {'Age': 50.0,
#   'Fare': 28.7125,
#   'Name': 'Miss. Ann Elizabeth Isham',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccec265ae8009a426d98')},
#  {'Age': 30.0,
#   'Fare': 13.0,
#   'Name': 'Mr. Reginald Hale',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcced265ae8009a426d99')},
#  {'Age': 36.0,
#   'Fare': 0.0,
#   'Name': 'Mr. Lionel Leonard',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcced265ae8009a426d9a')},
#  {'Age': 8.0,
#   'Fare': 69.55,
#   'Name': 'Miss. Constance Gladys Sage',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 8,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcced265ae8009a426d9b')},
#  {'Age': 39.0,
#   'Fare': 15.05,
#   'Name': 'Mr. Rene Pernot',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcced265ae8009a426d9c')},
#  {'Age': 9.0,
#   'Fare': 31.3875,
#   'Name': 'Master. Clarence Gustaf Hugo Asplund',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 4,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcced265ae8009a426d9d')},
#  {'Age': 1.0,
#   'Fare': 39.0,
#   'Name': 'Master. Richard F Becker',
#   'Parents/Children Aboard': 1,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 2,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcced265ae8009a426d9e')},
#  {'Age': 4.0,
#   'Fare': 22.025,
#   'Name': 'Miss. Luise Gretchen Kink-Heilmann',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcced265ae8009a426d9f')},
#  {'Age': 39.0,
#   'Fare': 50.0,
#   'Name': 'Mr. Hugh Roscoe Rood',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccee265ae8009a426da0')},
#  {'Age': 26.0,
#   'Fare': 15.5,
#   'Name': "Mrs. Thomas (Johanna Godfrey) O'Brien",
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccee265ae8009a426da1')},
#  {'Age': 45.0,
#   'Fare': 26.55,
#   'Name': 'Mr. Charles Hallace Romaine',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccee265ae8009a426da2')},
#  {'Age': 40.0,
#   'Fare': 15.5,
#   'Name': 'Mr. John Bourke',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccee265ae8009a426da3')},
#  {'Age': 36.0,
#   'Fare': 7.8958,
#   'Name': 'Mr. Stjepan Turcin',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccee265ae8009a426da4')},
#  {'Age': 32.0,
#   'Fare': 13.0,
#   'Name': 'Mrs. (Rosa) Pinsky',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccee265ae8009a426da5')},
#  {'Age': 19.0,
#   'Fare': 13.0,
#   'Name': 'Mr. William Carbines',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccee265ae8009a426da6')},
#  {'Age': 19.0,
#   'Fare': 7.8542,
#   'Name': 'Miss. Carla Christine Nielsine Andersen-Jensen',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccee265ae8009a426da7')},
#  {'Age': 3.0,
#   'Fare': 26.0,
#   'Name': 'Master. Michel M Navratil',
#   'Parents/Children Aboard': 1,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccef265ae8009a426da8')},
#  {'Age': 44.0,
#   'Fare': 27.7208,
#   'Name': 'Mrs. James Joseph (Margaret Tobin) Brown',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccef265ae8009a426da9')},
#  {'Age': 58.0,
#   'Fare': 146.5208,
#   'Name': 'Miss. Elise Lurette',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccef265ae8009a426daa')},
#  {'Age': 28.0,
#   'Fare': 7.75,
#   'Name': 'Mr. Robert Mernagh',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccef265ae8009a426dab')},
#  {'Age': 42.0,
#   'Fare': 8.4042,
#   'Name': 'Mr. Karl Siegwart Andreas Olsen',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccef265ae8009a426dac')},
#  {'Age': 21.0,
#   'Fare': 7.75,
#   'Name': 'Miss. Margaret Madigan',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccef265ae8009a426dad')},
#  {'Age': 24.0,
#   'Fare': 13.0,
#   'Name': 'Miss. Henriette Yrois',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccef265ae8009a426dae')},
#  {'Age': 28.0,
#   'Fare': 9.5,
#   'Name': 'Mr. Nestor Cyriel Vande Walle',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccf0265ae8009a426daf')},
#  {'Age': 17.0,
#   'Fare': 69.55,
#   'Name': 'Mr. Frederick Sage',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 8,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccf0265ae8009a426db0')},
#  {'Age': 34.0,
#   'Fare': 6.4958,
#   'Name': 'Mr. Jakob Alfred Johanson',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccf0265ae8009a426db1')},
#  {'Age': 45.5,
#   'Fare': 7.225,
#   'Name': 'Mr. Gerious Youseff',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccf0265ae8009a426db2')},
#  {'Age': 18.0,
#   'Fare': 8.05,
#   'Name': 'Mr. Gurshon Cohen',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dccf0265ae8009a426db3')},
#  {'Age': 2.0,
#   'Fare': 10.4625,
#   'Name': 'Miss. Telma Matilda Strom',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dccf0265ae8009a426db4')},
#  {'Age': 32.0,
#   'Fare': 15.85,
#   'Name': 'Mr. Karl Alfred Backstrom',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
# ...
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd42265ae8009a42701a')},
#  {'Age': 27.0,
#   'Fare': 12.475,
#   'Name': 'Mrs. (Beila) Moor',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd42265ae8009a42701b')},
#  {'Age': 2.0,
#   'Fare': 39.6875,
#   'Name': 'Master. Urho Abraham Panula',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 4,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd42265ae8009a42701c')},
#  {'Age': 36.0,
#   'Fare': 6.95,
#   'Name': 'Mr. John Flynn',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd43265ae8009a42701d')},
#  {'Age': 23.0,
#   'Fare': 56.4958,
#   'Name': 'Mr. Len Lam',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd43265ae8009a42701e')},
#  {'Age': 1.0,
#   'Fare': 37.0042,
#   'Name': 'Master. Andre Mallet',
#   'Parents/Children Aboard': 2,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd43265ae8009a42701f')},
#  {'Age': 19.0,
#   'Fare': 7.75,
#   'Name': 'Mr. Thomas Joseph McCormack',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd43265ae8009a427020')},
#  {'Age': 62.0,
#   'Fare': 80.0,
#   'Name': 'Mrs. George Nelson (Martha Evelyn) Stone',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd43265ae8009a427021')},
#  {'Age': 15.0,
#   'Fare': 14.4542,
#   'Name': 'Mrs. Antoni (Selini Alexander) Yasbeck',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd43265ae8009a427022')},
#  {'Age': 0.83,
#   'Fare': 18.75,
#   'Name': 'Master. George Sibley Richards',
#   'Parents/Children Aboard': 1,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd43265ae8009a427023')},
#  {'Age': 30.0,
#   'Fare': 7.2292,
#   'Name': 'Mr. Amin Saad',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd44265ae8009a427024')},
#  {'Age': 23.0,
#   'Fare': 7.8542,
#   'Name': 'Mr. Albert Augustsson',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd44265ae8009a427025')},
#  {'Age': 18.0,
#   'Fare': 8.3,
#   'Name': 'Mr. Owen George Allum',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd44265ae8009a427026')},
#  {'Age': 39.0,
#   'Fare': 83.1583,
#   'Name': 'Miss. Sara Rebecca Compton',
#   'Parents/Children Aboard': 1,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd44265ae8009a427027')},
#  {'Age': 21.0,
#   'Fare': 8.6625,
#   'Name': 'Mr. Jakob Pasic',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd44265ae8009a427028')},
#  {'Age': 20.0,
#   'Fare': 8.05,
#   'Name': 'Mr. Maurice Sirota',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd44265ae8009a427029')},
#  {'Age': 32.0,
#   'Fare': 56.4958,
#   'Name': 'Mr. Chang Chip',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd44265ae8009a42702a')},
#  {'Age': 29.0,
#   'Fare': 29.7,
#   'Name': 'Mr. Pierre Marechal',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd44265ae8009a42702b')},
#  {'Age': 20.0,
#   'Fare': 7.925,
#   'Name': 'Mr. Ilmari Rudolf Alhomaki',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd45265ae8009a42702c')},
#  {'Age': 16.0,
#   'Fare': 10.5,
#   'Name': 'Mr. Thomas Charles Mudd',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd45265ae8009a42702d')},
#  {'Age': 30.0,
#   'Fare': 31.0,
#   'Name': 'Miss. Augusta Serepeca',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd45265ae8009a42702e')},
#  {'Age': 34.5,
#   'Fare': 6.4375,
#   'Name': 'Mr. Peter L Lemberopolous',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd45265ae8009a42702f')},
#  {'Age': 17.0,
#   'Fare': 8.6625,
#   'Name': 'Mr. Jeso Culumovic',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd45265ae8009a427030')},
#  {'Age': 42.0,
#   'Fare': 7.55,
#   'Name': 'Mr. Anthony Abbing',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd45265ae8009a427031')},
#  {'Age': 18.0,
#   'Fare': 69.55,
#   'Name': 'Mr. Douglas Bullen Sage',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 8,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd45265ae8009a427032')},
#  {'Age': 35.0,
#   'Fare': 7.8958,
#   'Name': 'Mr. Marin Markoff',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd46265ae8009a427033')},
#  {'Age': 28.0,
#   'Fare': 33.0,
#   'Name': 'Rev. John Harper',
#   'Parents/Children Aboard': 1,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd46265ae8009a427034')},
#  {'Age': 40.0,
#   'Fare': 89.1042,
#   'Name': 'Mrs. Samuel L (Edwiga Grabowska) Goldenberg',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd46265ae8009a427035')},
#  {'Age': 4.0,
#   'Fare': 31.275,
#   'Name': 'Master. Sigvard Harald Elias Andersson',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 4,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd46265ae8009a427036')},
#  {'Age': 74.0,
#   'Fare': 7.775,
#   'Name': 'Mr. Johan Svensson',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd46265ae8009a427037')},
#  {'Age': 9.0,
#   'Fare': 15.2458,
#   'Name': 'Miss. Nourelain Boulos',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd46265ae8009a427038')},
#  {'Age': 16.0,
#   'Fare': 39.4,
#   'Name': 'Miss. Mary Conover Lines',
#   'Parents/Children Aboard': 1,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd46265ae8009a427039')},
#  {'Age': 44.0,
#   'Fare': 26.0,
#   'Name': 'Mrs. Ernest Courtenay (Lilian Hughes) Carter',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd46265ae8009a42703a')},
#  {'Age': 18.0,
#   'Fare': 9.35,
#   'Name': 'Mrs. Sam (Leah Rosen) Aks',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd47265ae8009a42703b')},
#  {'Age': 45.0,
#   'Fare': 164.8667,
#   'Name': 'Mrs. George Dennick (Mary Hitchcock) Wick',
#   'Parents/Children Aboard': 1,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd47265ae8009a42703c')},
#  {'Age': 51.0,
#   'Fare': 26.55,
#   'Name': 'Mr. Peter Denis Daly',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd47265ae8009a42703d')},
#  {'Age': 24.0,
#   'Fare': 19.2583,
#   'Name': 'Mrs. Solomon (Latifa Qurban) Baclini',
#   'Parents/Children Aboard': 3,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd47265ae8009a42703e')},
#  {'Age': 30.0,
#   'Fare': 7.2292,
#   'Name': 'Mr. Raihed Razi',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd47265ae8009a42703f')},
#  {'Age': 41.0,
#   'Fare': 14.1083,
#   'Name': 'Mr. Claus Peter Hansen',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 2,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd47265ae8009a427040')},
#  {'Age': 21.0,
#   'Fare': 11.5,
#   'Name': 'Mr. Frederick Edward Giles',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd47265ae8009a427041')},
#  {'Age': 48.0,
#   'Fare': 25.9292,
#   'Name': 'Mrs. Frederick Joel (Margaret Welles Barron) Swift',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd48265ae8009a427042')},
#  {'Age': 14.0,
#   'Fare': 69.55,
#   'Name': 'Miss. Dorothy Edith Sage',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 8,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd48265ae8009a427043')},
#  {'Age': 24.0,
#   'Fare': 13.0,
#   'Name': 'Mr. John William Gill',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd48265ae8009a427044')},
#  {'Age': 42.0,
#   'Fare': 13.0,
#   'Name': 'Mrs. (Karolina) Bystrom',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd48265ae8009a427045')},
#  {'Age': 27.0,
#   'Fare': 13.8583,
#   'Name': 'Miss. Asuncion Duran y More',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd48265ae8009a427046')},
#  {'Age': 31.0,
#   'Fare': 50.4958,
#   'Name': 'Mr. Washington Augustus II Roebling',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd48265ae8009a427047')},
#  {'Age': 23.0,
#   'Fare': 9.5,
#   'Name': 'Mr. Philemon van Melkebeke',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd48265ae8009a427048')},
#  {'Age': 4.0,
#   'Fare': 11.1333,
#   'Name': 'Master. Harold Theodor Johnson',
#   'Parents/Children Aboard': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd48265ae8009a427049')},
#  {'Age': 26.0,
#   'Fare': 7.8958,
#   'Name': 'Mr. Cerin Balkic',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd49265ae8009a42704a')},
#  {'Age': 47.0,
#   'Fare': 52.5542,
#   'Name': 'Mrs. Richard Leonard (Sallie Monypeny) Beckwith',
#   'Parents/Children Aboard': 1,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd49265ae8009a42704b')},
#  {'Age': 33.0,
#   'Fare': 5.0,
#   'Name': 'Mr. Frans Olof Carlsson',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd49265ae8009a42704c')},
#  {'Age': 47.0,
#   'Fare': 9.0,
#   'Name': 'Mr. Victor Vander Cruyssen',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd49265ae8009a42704d')},
#  {'Age': 28.0,
#   'Fare': 24.0,
#   'Name': 'Mrs. Samuel (Hannah Wizosky) Abelson',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd49265ae8009a42704e')},
#  {'Age': 15.0,
#   'Fare': 7.225,
#   'Name': 'Miss. Adele Kiamie Najib',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd49265ae8009a42704f')},
#  {'Age': 20.0,
#   'Fare': 9.8458,
#   'Name': 'Mr. Alfred Ossian Gustafsson',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd49265ae8009a427050')},
#  {'Age': 19.0,
#   'Fare': 7.8958,
#   'Name': 'Mr. Nedelio Petroff',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd4a265ae8009a427051')},
#  {'Age': 23.0,
#   'Fare': 7.8958,
#   'Name': 'Mr. Kristo Laleff',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd4a265ae8009a427052')},
#  {'Age': 56.0,
#   'Fare': 83.1583,
#   'Name': 'Mrs. Thomas Jr (Lily Alexenia Wilson) Potter',
#   'Parents/Children Aboard': 1,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd4a265ae8009a427053')},
#  {'Age': 25.0,
#   'Fare': 26.0,
#   'Name': 'Mrs. William (Imanita Parrish Hall) Shelley',
#   'Parents/Children Aboard': 1,
#   'Pclass': 2,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd4a265ae8009a427054')},
#  {'Age': 33.0,
#   'Fare': 7.8958,
#   'Name': 'Mr. Johann Markun',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd4a265ae8009a427055')},
#  {'Age': 22.0,
#   'Fare': 10.5167,
#   'Name': 'Miss. Gerda Ulrika Dahlberg',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd4a265ae8009a427056')},
#  {'Age': 28.0,
#   'Fare': 10.5,
#   'Name': 'Mr. Frederick James Banfield',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd4a265ae8009a427057')},
#  {'Age': 25.0,
#   'Fare': 7.05,
#   'Name': 'Mr. Henry Jr Sutehall',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd4a265ae8009a427058')},
#  {'Age': 39.0,
#   'Fare': 29.125,
#   'Name': 'Mrs. William (Margaret Norton) Rice',
#   'Parents/Children Aboard': 5,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd4b265ae8009a427059')},
#  {'Age': 27.0,
#   'Fare': 13.0,
#   'Name': 'Rev. Juozas Montvila',
#   'Parents/Children Aboard': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd4b265ae8009a42705a')},
#  {'Age': 19.0,
#   'Fare': 30.0,
#   'Name': 'Miss. Margaret Edith Graham',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd4b265ae8009a42705b')},
#  {'Age': 7.0,
#   'Fare': 23.45,
#   'Name': 'Miss. Catherine Helen Johnston',
#   'Parents/Children Aboard': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'Siblings/Spouses Aboard': 1,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd4b265ae8009a42705c')},
#  {'Age': 26.0,
#   'Fare': 30.0,
#   'Name': 'Mr. Karl Howell Behr',
#   'Parents/Children Aboard': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 1,
#   '_id': ObjectId('5c6dcd4b265ae8009a42705d')},
#  {'Age': 32.0,
#   'Fare': 7.75,
#   'Name': 'Mr. Patrick Dooley',
#   'Parents/Children Aboard': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'Siblings/Spouses Aboard': 0,
#   'Survived': 0,
#   '_id': ObjectId('5c6dcd4b265ae8009a42705e')}]
