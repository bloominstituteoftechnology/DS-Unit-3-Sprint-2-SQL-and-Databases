# %%
import sqlite3
import pymongo

# %%
myclient = pymongo.MongoClient("mongodb+srv://dwight:u8hze1XIB74QFkyb@cluster0-3q1mp.mongodb.net/test?retryWrites=true&w=majority")

# %%
mydb = myclient['dwight']

# %%
mycol = mydb['rpg']

# %%
conn = sqlite3.connect('rpg_db.sqlite3')

# %%
cur = conn.cursor()

# %%
cur.execute("""
    SELECT * FROM armory_weapon LIMIT 10;
""")
conn.commit()

# %%
lst = []

for row in cur.execute(f"""
    SELECT * 
    FROM armory_item
    """):
    lst.append({'item_id': row[0], 'name': row[1], 'value': row[2],'weight': row[3]})
    
conn.commit()

# %%
mycol = mydb['armory_item']

# %%
items = mycol.insert_many(lst)

# %%
lst = []

for row in cur.execute(f"""
    SELECT * 
    FROM armory_weapon
    """):
    lst.append({'item_ptr_id': row[0], 'power': row[1]})
    
conn.commit()

# %%
mycol = mydb['armory_weapon']
items = mycol.insert_many(lst)

# %%
lst = []

for row in cur.execute(f"""
    SELECT * 
    FROM charactercreator_character_inventory
    """):
    lst.append({'id': row[0], 'character_id': row[1], 'item_id': row[2]})
    
conn.commit()
mycol = mydb['charactercreator_character_inventory']
items = mycol.insert_many(lst)

# %%
lst = []

for row in cur.execute(f"""
    SELECT * 
    FROM charactercreator_character
    """):
    lst.append({'character_id': row[0], 
                'name': row[1], 
                'level': row[2], 
                'exp': row[3], 
                'hp': row[4], 
                'strength': row[5], 
                'intelligence': row[6], 
                'dexterity': row[7], 
                'wisdom': row[8]})
    
conn.commit()

# %%
mycol = mydb['charactercreator_character']
items = mycol.insert_many(lst)

# %%
lst = []

for row in cur.execute(f"""
    SELECT * 
    FROM charactercreator_cleric
    """):
    lst.append({'character_ptr_id': row[0], 'using_shield': row[1], 'mana': row[2]})
    
conn.commit()
mycol = mydb['charactercreator_cleric']
items = mycol.insert_many(lst)

# %%
lst = []

for row in cur.execute(f"""
    SELECT * 
    FROM charactercreator_fighter
    """):
    lst.append({'character_ptr_id': row[0], 'using_shield': row[1], 'rage': row[2]})
    
conn.commit()
mycol = mydb['charactercreator_fighter']
items = mycol.insert_many(lst)

# %%
names = list(map(lambda x: x[0], cur.description))
names
# Out:
# ['character_id',
#  'name',
#  'level',
#  'exp',
#  'hp',
#  'strength',
#  'intelligence',
#  'dexterity',
#  'wisdom']

# %%
def insertTable(x):
    lst = []
    for row in cur.execute(f"""
        SELECT * 
        FROM {x}
        """):
        names = list(map(lambda x: x[0], cur.description))

        for name in names: 
            lst.append({names[i]: row[i]})

    #     names = list(map(lambda x: x[0], cur.description))

    #     for name in names: 
    #         lst.append({name: 'hey'})

    conn.commit()

# %%
lst
# Out:
# [{'character_id': 1},
#  {'character_id': 2},
#  {'character_id': 3},
#  {'character_id': 4},
#  {'character_id': 5},
#  {'character_id': 6},
#  {'character_id': 7},
#  {'character_id': 8},
#  {'character_id': 9},
#  {'character_id': 10},
#  {'character_id': 11},
#  {'character_id': 12},
#  {'character_id': 13},
#  {'character_id': 14},
#  {'character_id': 15},
#  {'character_id': 16},
#  {'character_id': 17},
#  {'character_id': 18},
#  {'character_id': 19},
#  {'character_id': 20},
#  {'character_id': 21},
#  {'character_id': 22},
#  {'character_id': 23},
#  {'character_id': 24},
#  {'character_id': 25},
#  {'character_id': 26},
#  {'character_id': 27},
#  {'character_id': 28},
#  {'character_id': 29},
#  {'character_id': 30},
#  {'character_id': 31},
#  {'character_id': 32},
#  {'character_id': 33},
#  {'character_id': 34},
#  {'character_id': 35},
#  {'character_id': 36},
#  {'character_id': 37},
#  {'character_id': 38},
#  {'character_id': 39},
#  {'character_id': 40},
# ...
