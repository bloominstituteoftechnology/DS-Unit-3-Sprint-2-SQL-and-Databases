# %% [markdown]
# ### DSPT1_MongoDB_Playground
#
# LSDS Unit 3 Sprint 2 Module 3

# %%
# !curl https://ipecho.net/plain
# Out:
# 35.233.249.250

# %%
# !python --version
# Out:
# Python 3.6.8

# %% [markdown]
# password: OYku4Q3YDv8ltErW

# %%
# !pip install pymongo

# %%
import pymongo

client = pymongo.MongoClient(
    "mongodb://admin:OYku4Q3YDv8ltErW@lambdatest-shard-00-00-awyah.mongodb.net:27017,lambdatest-shard-00-01-awyah.mongodb.net:27017,lambdatest-shard-00-02-awyah.mongodb.net:27017/test?ssl=true&replicaSet=LambdaTest-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.test

# %%
db
# Out:
# Database(MongoClient(host=['lambdatest-shard-00-00-awyah.mongodb.net:27017', 'lambdatest-shard-00-02-awyah.mongodb.net:27017', 'lambdatest-shard-00-01-awyah.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='LambdaTest-shard-0', authsource='admin', retrywrites=True, w='majority'), 'test')

# %%
client.nodes
# Out:
# frozenset({('lambdatest-shard-00-00-awyah.mongodb.net', 27017),
#            ('lambdatest-shard-00-01-awyah.mongodb.net', 27017),
#            ('lambdatest-shard-00-02-awyah.mongodb.net', 27017)})

# %%
db.test.insert_one({'x': 1})

# %%
list(db.test.find())
# Out:
# [{'_id': ObjectId('5d8ab26ecfd2bd6dc70cebc1'), 'x': 1}]

# %%
db.test.count_documents({'x': 1})
# Out:
# 1

# %%
bruno_doc = {
    'name': 'Bruno',
    'favorite animal': ['penguin','dogs'],
    'favorite beer': 'stella artois'
}

tina_doc = {
    'favorite animal': 'owl',
    'favorite wine': 'rose'
}

gwen_doc = {
    'favorite animal': 'dog',
    'favorite author': 'bryan jakes'
}

db.test.insert_many([bruno_doc, tina_doc, gwen_doc])

# %%
list(db.test.find())
# Out:
# [{'_id': ObjectId('5d8ab26ecfd2bd6dc70cebc1'), 'x': 1},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc2'),
#   'favorite animal': ['penguin', 'dogs'],
#   'favorite beer': 'stella artois',
#   'name': 'Bruno'},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc3'),
#   'favorite animal': 'owl',
#   'favorite wine': 'rose'},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc4'),
#   'favorite animal': 'dog',
#   'favorite author': 'bryan jakes'}]

# %%
more_docs = []
for i in range(10):
  doc = {'even': i % 2 == 0}
  doc['value'] = i
  more_docs.append(doc)
  
more_docs
# Out:
# [{'even': True, 'value': 0},
#  {'even': False, 'value': 1},
#  {'even': True, 'value': 2},
#  {'even': False, 'value': 3},
#  {'even': True, 'value': 4},
#  {'even': False, 'value': 5},
#  {'even': True, 'value': 6},
#  {'even': False, 'value': 7},
#  {'even': True, 'value': 8},
#  {'even': False, 'value': 9}]

# %%
db.test.insert_many(more_docs)

# %%
list(db.test.find())
# Out:
# [{'_id': ObjectId('5d8ab26ecfd2bd6dc70cebc1'), 'x': 1},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc2'),
#   'favorite animal': ['penguin', 'dogs'],
#   'favorite beer': 'stella artois',
#   'name': 'Bruno'},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc3'),
#   'favorite animal': 'owl',
#   'favorite wine': 'rose'},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc4'),
#   'favorite animal': 'dog',
#   'favorite author': 'bryan jakes'},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc5'), 'even': True, 'value': 0},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc6'), 'even': False, 'value': 1},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc7'), 'even': True, 'value': 2},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc8'), 'even': False, 'value': 3},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc9'), 'even': True, 'value': 4},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebca'), 'even': False, 'value': 5},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebcb'), 'even': True, 'value': 6},
# ...

# %% [markdown]
# ### CRUD: Create Read Update Delete

# %%
db.test.update_one({'value': 3},
                   {'$inc': {'value': 100}})

list(db.test.find())
# Out:
# [{'_id': ObjectId('5d8ab26ecfd2bd6dc70cebc1'), 'x': 1},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc2'),
#   'favorite animal': ['penguin', 'dogs'],
#   'favorite beer': 'stella artois',
#   'name': 'Bruno'},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc3'),
#   'favorite animal': 'owl',
#   'favorite wine': 'rose'},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc4'),
#   'favorite animal': 'dog',
#   'favorite author': 'bryan jakes'},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc5'), 'even': True, 'value': 0},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc6'), 'even': False, 'value': 1},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc7'), 'even': True, 'value': 2},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc8'), 'even': False, 'value': 103},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc9'), 'even': True, 'value': 4},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebca'), 'even': False, 'value': 5},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebcb'), 'even': True, 'value': 6},
# ...

# %%
db.test.update_many({'even': True},
                    {'$inc': {'value': 100}})

list(db.test.find())
# Out:
# [{'_id': ObjectId('5d8ab26ecfd2bd6dc70cebc1'), 'x': 1},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc2'),
#   'favorite animal': ['penguin', 'dogs'],
#   'favorite beer': 'stella artois',
#   'name': 'Bruno'},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc3'),
#   'favorite animal': 'owl',
#   'favorite wine': 'rose'},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc4'),
#   'favorite animal': 'dog',
#   'favorite author': 'bryan jakes'},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc5'), 'even': True, 'value': 100},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc6'), 'even': False, 'value': 1},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc7'), 'even': True, 'value': 102},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc8'), 'even': False, 'value': 103},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc9'), 'even': True, 'value': 104},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebca'), 'even': False, 'value': 5},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebcb'), 'even': True, 'value': 106},
# ...

# %%
db.test.delete_many({'even': False})
list(db.test.find())
# Out:
# [{'_id': ObjectId('5d8ab26ecfd2bd6dc70cebc1'), 'x': 1},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc2'),
#   'favorite animal': ['penguin', 'dogs'],
#   'favorite beer': 'stella artois',
#   'name': 'Bruno'},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc3'),
#   'favorite animal': 'owl',
#   'favorite wine': 'rose'},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc4'),
#   'favorite animal': 'dog',
#   'favorite author': 'bryan jakes'},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc5'), 'even': True, 'value': 100},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc7'), 'even': True, 'value': 102},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc9'), 'even': True, 'value': 104},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebcb'), 'even': True, 'value': 106},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebcd'), 'even': True, 'value': 108}]

# %%
db.list_collections_names
# Out:
# Collection(Database(MongoClient(host=['lambdatest-shard-00-00-awyah.mongodb.net:27017', 'lambdatest-shard-00-02-awyah.mongodb.net:27017', 'lambdatest-shard-00-01-awyah.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='LambdaTest-shard-0', authsource='admin', retrywrites=True, w='majority'), 'test'), 'list_collections_names')

# %%
db.collection_names
# Out:
# <bound method Database.collection_names of Database(MongoClient(host=['lambdatest-shard-00-00-awyah.mongodb.net:27017', 'lambdatest-shard-00-02-awyah.mongodb.net:27017', 'lambdatest-shard-00-01-awyah.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='LambdaTest-shard-0', authsource='admin', retrywrites=True, w='majority'), 'test')>

# %%
rpg_character = (1, 'King James', 0, 1, 2, 0, 1)
db.test.insert_one({'rpg_character': rpg_character})
list(db.test.find())
# Out:
# [{'_id': ObjectId('5d8ab26ecfd2bd6dc70cebc1'), 'x': 1},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc2'),
#   'favorite animal': ['penguin', 'dogs'],
#   'favorite beer': 'stella artois',
#   'name': 'Bruno'},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc3'),
#   'favorite animal': 'owl',
#   'favorite wine': 'rose'},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc4'),
#   'favorite animal': 'dog',
#   'favorite author': 'bryan jakes'},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc5'), 'even': True, 'value': 100},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc7'), 'even': True, 'value': 102},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc9'), 'even': True, 'value': 104},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebcb'), 'even': True, 'value': 106},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebcd'), 'even': True, 'value': 108},
#  {'_id': ObjectId('5d8ab2a7cfd2bd6dc70cebcf'),
#   'rpg_character': [1, 'King James', 0, 1, 2, 0, 1]}]

# %%
# !wget https://github.com/LambdaSchool/Django-RPG/raw/master/testdata.json
# Out:
# --2019-09-25 00:20:02--  https://github.com/LambdaSchool/Django-RPG/raw/master/testdata.json
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/LambdaSchool/Django-RPG/master/testdata.json [following]
# --2019-09-25 00:20:03--  https://raw.githubusercontent.com/LambdaSchool/Django-RPG/master/testdata.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 123399 (121K) [text/plain]
# Saving to: ‘testdata.json’
#
# testdata.json       100%[===================>] 120.51K  --.-KB/s    in 0.02s
#
# 2019-09-25 00:20:03 (5.62 MB/s) - ‘testdata.json’ saved [123399/123399]

# %%
import json

with open('testdata.json') as json_file:
  rpg_data = json.load(json_file)
  
rpg_data[0]
# Out:
# {'fields': {'dexterity': 1,
#   'exp': 0,
#   'hp': 10,
#   'intelligence': 1,
#   'inventory': [20, 58, 85],
#   'level': 0,
#   'name': 'Aliquid iste optio reiciendi',
#   'strength': 1,
#   'wisdom': 1},
#  'model': 'charactercreator.character',
#  'pk': 1}

# %%
db.test.insert_many(rpg_data)
list(db.test.find())
# Out:
# [{'_id': ObjectId('5d8ab26ecfd2bd6dc70cebc1'), 'x': 1},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc2'),
#   'favorite animal': ['penguin', 'dogs'],
#   'favorite beer': 'stella artois',
#   'name': 'Bruno'},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc3'),
#   'favorite animal': 'owl',
#   'favorite wine': 'rose'},
#  {'_id': ObjectId('5d8ab287cfd2bd6dc70cebc4'),
#   'favorite animal': 'dog',
#   'favorite author': 'bryan jakes'},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc5'), 'even': True, 'value': 100},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc7'), 'even': True, 'value': 102},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebc9'), 'even': True, 'value': 104},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebcb'), 'even': True, 'value': 106},
#  {'_id': ObjectId('5d8ab294cfd2bd6dc70cebcd'), 'even': True, 'value': 108},
#  {'_id': ObjectId('5d8ab2a7cfd2bd6dc70cebcf'),
#   'rpg_character': [1, 'King James', 0, 1, 2, 0, 1]},
#  {'_id': ObjectId('5d8ab2b9cfd2bd6dc70cebd0'),
# ...

# %%
list(db.test.find({'model': 'charactercreator.character'}))
# Out:
# [{'_id': ObjectId('5d8ab2b9cfd2bd6dc70cebd0'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [20, 58, 85],
#    'level': 0,
#    'name': 'Aliquid iste optio reiciendi',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 1},
#  {'_id': ObjectId('5d8ab2b9cfd2bd6dc70cebd1'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [93, 115, 133],
#    'level': 0,
#    'name': 'Optio dolorem ex a',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 2},
#  {'_id': ObjectId('5d8ab2b9cfd2bd6dc70cebd2'),
#   'fields': {'dexterity': 1,
#    'exp': 0,
#    'hp': 10,
#    'intelligence': 1,
#    'inventory': [8, 43],
#    'level': 0,
#    'name': 'Minus c',
#    'strength': 1,
#    'wisdom': 1},
#   'model': 'charactercreator.character',
#   'pk': 3},
#  {'_id': ObjectId('5d8ab2b9cfd2bd6dc70cebd3'),
# ...

# %%
db.sample_airbnb.listingsAndReviews.count_documents({'beds': 3})
# Out:
# 0

# %%
db.sample_airbnb.count_documents({'beds': 10})
# Out:
# 0
