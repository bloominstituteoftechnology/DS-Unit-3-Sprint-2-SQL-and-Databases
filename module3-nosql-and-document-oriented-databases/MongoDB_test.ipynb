# %%
# !pip install pymongo
# Out:
# ...
#     100% |████████████████████████████████| 317kB 5.2MB/s
# ...

# %%
# !curl ipecho.net/plain
# Out:
# 69.141.246.232

# %%
connection_string = 'mongodb://danielleromanoff:4Kronos4@cluster0-shard-00-00-dazcn.mongodb.net:27017,cluster0-shard-00-01-dazcn.mongodb.net:27017,cluster0-shard-00-02-dazcn.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true'

# %%
import pymongo
client = pymongo.MongoClient(connection_string)

# %%
client.nodes
# Out:
# frozenset({('cluster0-shard-00-00-dazcn.mongodb.net', 27017),
#            ('cluster0-shard-00-01-dazcn.mongodb.net', 27017),
#            ('cluster0-shard-00-02-dazcn.mongodb.net', 27017)})

# %%
client.server_info
# Out:
# <bound method MongoClient.server_info of MongoClient(host=['cluster0-shard-00-00-dazcn.mongodb.net:27017', 'cluster0-shard-00-02-dazcn.mongodb.net:27017', 'cluster0-shard-00-01-dazcn.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='Cluster0-shard-0', authsource='admin', retrywrites=True)>

# %%
db = client.test

# %%
db.test.insert
# Out:
# <bound method Collection.insert of Collection(Database(MongoClient(host=['cluster0-shard-00-00-dazcn.mongodb.net:27017', 'cluster0-shard-00-02-dazcn.mongodb.net:27017', 'cluster0-shard-00-01-dazcn.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='Cluster0-shard-0', authsource='admin', retrywrites=True), 'test'), 'test')>

# %%
valeries_doc = {'favorite animal': 'dolphin'}
if not db.test.find_one(valeries_doc):
    print('Inserting!')
    db.test.insert_one(valeries_doc)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-22-780c094a3ee0> in <module>
#       1 valeries_doc = {'favorite animal': 'dolphin'}
# ----> 2 if not db.test.find_one(valeries_doc):
#       3     print('Inserting!')
#       4     db.test.insert_one(valeries_doc)
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in find_one(self, filter, *args, **kwargs)
#    1260
#    1261         cursor = self.find(filter, *args, **kwargs)
# -> 1262         for result in cursor.limit(-1):
#    1263             return result
#    1264         return None
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in next(self)
#    1187         if self.__empty:
#    1188             raise StopIteration
# -> 1189         if len(self.__data) or self._refresh():
#    1190             if self.__manipulate:
#    1191                 _db = self.__collection.database
# ...

# %%
results.inserted_id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-c03df8d7046e> in <module>
# ----> 1 results.inserted_id
#
# NameError: name 'results' is not defined

# %%
db.test.find_one(valeries_doc)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-25-797b8991ca3b> in <module>
# ----> 1 db.test.find_one(valeries_doc)
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in find_one(self, filter, *args, **kwargs)
#    1260
#    1261         cursor = self.find(filter, *args, **kwargs)
# -> 1262         for result in cursor.limit(-1):
#    1263             return result
#    1264         return None
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in next(self)
#    1187         if self.__empty:
#    1188             raise StopIteration
# -> 1189         if len(self.__data) or self._refresh():
#    1190             if self.__manipulate:
#    1191                 _db = self.__collection.database
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in _refresh(self)
#    1102                                   self.__session,
# ...

# %%
results = db.test.find()

# %%
results

# %%
list(results)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-28-c8feace8e0a5> in <module>
# ----> 1 list(results)
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in next(self)
#    1187         if self.__empty:
#    1188             raise StopIteration
# -> 1189         if len(self.__data) or self._refresh():
#    1190             if self.__manipulate:
#    1191                 _db = self.__collection.database
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in _refresh(self)
#    1102                                   self.__session,
#    1103                                   self.__collection.database.client)
# -> 1104             self.__send_message(q)
#    1105         elif self.__id:  # Get More
#    1106             if self.__limit:
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in __send_message(self, operation)
# ...

# %%
daniels_doc = {'favorite game': 'go'}
db.test.insert_one(daniels_doc)
db.test.find_one(daniels_doc)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-29-1667a658ba43> in <module>
#       1 daniels_doc = {'favorite game': 'go'}
# ----> 2 db.test.insert_one(daniels_doc)
#       3 db.test.find_one(daniels_doc)
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session)
#     691                          write_concern=write_concern,
#     692                          bypass_doc_val=bypass_document_validation,
# --> 693                          session=session),
#     694             write_concern.acknowledged)
#     695
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     605             return self._insert_one(
# ...

# %%
list(db.test.find({}))
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-30-22206123184c> in <module>
# ----> 1 list(db.test.find({}))
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in next(self)
#    1187         if self.__empty:
#    1188             raise StopIteration
# -> 1189         if len(self.__data) or self._refresh():
#    1190             if self.__manipulate:
#    1191                 _db = self.__collection.database
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in _refresh(self)
#    1102                                   self.__session,
#    1103                                   self.__collection.database.client)
# -> 1104             self.__send_message(q)
#    1105         elif self.__id:  # Get More
#    1106             if self.__limit:
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in __send_message(self, operation)
# ...

# %%
db.test.insert_one({'1': 2, 'a': 3})

# %%
db.test.insert_one({'1': 2, 'a': 4, 'b': 17})

# %%
list(db.test.find({'1': 2}))
