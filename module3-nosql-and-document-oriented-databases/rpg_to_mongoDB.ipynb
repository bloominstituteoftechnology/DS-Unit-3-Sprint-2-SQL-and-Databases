# %% [markdown]
# # MongoDB with PyMongo
#
# LSDS Unit 3 Sprint 2 Module 3
#
# Some resources:
#
# https://docs.atlas.mongodb.com/getting-started/
#
# https://api.mongodb.com/python/current/
#
# HN Discussion on MongoDB versus PostgreSQL/SQLite: https://news.ycombinator.com/item?id=19158854

# %%
#Pull out the IP address for this collab notebook
# !curl ipecho.net/plain
# Out:
# 35.199.150.243

# %% [markdown]
# username: admin2
#
#
# password: gtjITcI8UQvmtTcY

# %%
#How do we figure out our python version?
import sys
print(sys.version)
# Out:
# 3.6.8 (default, Jan 14 2019, 11:02:34)
# [GCC 8.0.1 20180414 (experimental) [trunk revision 259383]]

# %%
# !pip install pymongo

# %%
import pymongo

# Use 3.4 connection string for clarity

client = pymongo.MongoClient("mongodb://admin:gtjITcI8UQvmtTcY@cluster0-shard-00-00-6mbpl.mongodb.net:27017,cluster0-shard-00-01-6mbpl.mongodb.net:27017,cluster0-shard-00-02-6mbpl.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.test

# %%
# database object
db
# Out:
# Database(MongoClient(host=['cluster0-shard-00-02-6mbpl.mongodb.net:27017', 'cluster0-shard-00-00-6mbpl.mongodb.net:27017', 'cluster0-shard-00-01-6mbpl.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='Cluster0-shard-0', authsource='admin', retrywrites=True, w='majority'), 'test')

# %%
# check how many machines
client.nodes
# Out:
# frozenset({('cluster0-shard-00-00-6mbpl.mongodb.net', 27017),
#            ('cluster0-shard-00-01-6mbpl.mongodb.net', 27017),
#            ('cluster0-shard-00-02-6mbpl.mongodb.net', 27017)})

# %%
# call help if necessary
help(db)

# %%
# show methods to work with 
dir(db.test)
# Out:
# ['_BaseObject__codec_options',
#  '_BaseObject__read_concern',
#  '_BaseObject__read_preference',
#  '_BaseObject__write_concern',
#  '_Collection__create',
#  '_Collection__create_index',
#  '_Collection__database',
#  '_Collection__find_and_modify',
#  '_Collection__full_name',
#  '_Collection__name',
#  '_Collection__write_response_codec_options',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_aggregate',
#  '_aggregate_one_result',
#  '_command',
#  '_count',
#  '_delete',
#  '_delete_retryable',
#  '_insert',
# ...

# %%
help(db.test.insert_one)
# Out:
# Help on method insert_one in module pymongo.collection:
#
# insert_one(document, bypass_document_validation=False, session=None) method of pymongo.collection.Collection instance
#     Insert a single document.
#
#       >>> db.test.count_documents({'x': 1})
#       0
#       >>> result = db.test.insert_one({'x': 1})
#       >>> result.inserted_id
#       ObjectId('54f112defba522406c9cc208')
#       >>> db.test.find_one({'x': 1})
#       {u'x': 1, u'_id': ObjectId('54f112defba522406c9cc208')}
#
#     :Parameters:
#       - `document`: The document to insert. Must be a mutable mapping
#         type. If the document does not have an _id field one will be
#         added automatically.
#       - `bypass_document_validation`: (optional) If ``True``, allows the
#         write to opt-out of document level validation. Default is
#         ``False``.
#       - `session` (optional): a
#         :class:`~pymongo.client_session.ClientSession`.
#
#     :Returns:
# ...

# %%
# Count how many documents
db.test.count_documents({'x':1})
# Out:
# 0

# %%
# Insert one document
db.test.insert_one({'x': 1})

# %%
# Count how many documents: 1
db.test.count_documents({'x':1})
# Out:
# 1

# %%
# Insert another document
db.test.insert_one({'x': 1})

# %%
# Count again how many documents: 2
db.test.count_documents({'x':1})

# this is because
# they live in different memory locations
# Out:
# 2

# %%
# find documents

db.test.find_one({'x': 1})
# Out:
# {'_id': ObjectId('5d7a98639fd615748e601079'), 'x': 1}

# %%
# find() returns cursor object
db.test.find({'x':1})

# %%
# hence, set it to a cursor
curs = db.test.find({'x':1})

# %%
# does it have fetch all?
dir(curs)

# %%
# cast the curs object to a list
list(curs)
# Out:
# [{'_id': ObjectId('5d7a98639fd615748e601079'), 'x': 1},
#  {'_id': ObjectId('5d7a98729fd615748e60107a'), 'x': 1}]

# %%
# add more docs

jason_doc = {
    'favorite animal': ['Shark', 'Cats']
}

matthew_doc = {
    'favorite animal': 'Platypus'
}

nick_doc = {
    'favorite animal' : 'Hippogriff'
}

# %%
# insert multiple documents with insert_many
db.test.insert_many([jason_doc, matthew_doc, nick_doc])

# %%
# now, list all documents in the db that we inserted
# using find()
list(db.test.find())
# Out:
# [{'_id': ObjectId('5d7a98639fd615748e601079'), 'x': 1},
#  {'_id': ObjectId('5d7a98729fd615748e60107a'), 'x': 1},
#  {'_id': ObjectId('5d7a9f1c9fd615748e60107b'),
#   'favorite animal': ['Shark', 'Cats']},
#  {'_id': ObjectId('5d7a9f1c9fd615748e60107c'), 'favorite animal': 'Platypus'},
#  {'_id': ObjectId('5d7a9f1c9fd615748e60107d'),
#   'favorite animal': 'Hippogriff'}]

# %%
#Now let's make more docs.

more_docs = []
for i in range(10):
  doc = {'even': i % 2 == 0}
  doc['value'] = i
  more_docs.append(doc)

more_docs
# Out:
# [{'even': True, 'value': 0},
#  {'even': False, 'value': 1},
#  {'even': True, 'value': 2},
#  {'even': False, 'value': 3},
#  {'even': True, 'value': 4},
#  {'even': False, 'value': 5},
#  {'even': True, 'value': 6},
#  {'even': False, 'value': 7},
#  {'even': True, 'value': 8},
#  {'even': False, 'value': 9}]

# %%
db.test.insert_many(more_docs)

# %%
# filter for specific ones
list(db.test.find({'even':False}))
# Out:
# [{'_id': ObjectId('5d7aa06a9fd615748e60107f'), 'even': False, 'value': 1},
#  {'_id': ObjectId('5d7aa06a9fd615748e601081'), 'even': False, 'value': 3},
#  {'_id': ObjectId('5d7aa06a9fd615748e601083'), 'even': False, 'value': 5},
#  {'_id': ObjectId('5d7aa06a9fd615748e601085'), 'even': False, 'value': 7},
#  {'_id': ObjectId('5d7aa06a9fd615748e601087'), 'even': False, 'value': 9}]

# %%
# filter
list(db.test.find({'even':True}))

# %%
# filter
list(db.test.find({'favorite animal': 'Platypus'}))
# Out:
# [{'_id': ObjectId('5d7a9f1c9fd615748e60107c'), 'favorite animal': 'Platypus'}]

# %% [markdown]
# ## CRUD - Create Read Update Delete

# %%
help(db.test.update_one)
# Out:
# Help on method update_one in module pymongo.collection:
#
# update_one(filter, update, upsert=False, bypass_document_validation=False, collation=None, array_filters=None, session=None) method of pymongo.collection.Collection instance
#     Update a single document matching the filter.
#
#       >>> for doc in db.test.find():
#       ...     print(doc)
#       ...
#       {u'x': 1, u'_id': 0}
#       {u'x': 1, u'_id': 1}
#       {u'x': 1, u'_id': 2}
#       >>> result = db.test.update_one({'x': 1}, {'$inc': {'x': 3}})
#       >>> result.matched_count
#       1
#       >>> result.modified_count
#       1
#       >>> for doc in db.test.find():
#       ...     print(doc)
#       ...
#       {u'x': 4, u'_id': 0}
#       {u'x': 1, u'_id': 1}
#       {u'x': 1, u'_id': 2}
#
#     :Parameters:
#       - `filter`: A query that matches the document to update.
#       - `update`: The modifications to apply.
#       - `upsert` (optional): If ``True``, perform an insert if no documents
# ...

# %%
help(db.test.delete_one)
# Out:
# Help on method delete_one in module pymongo.collection:
#
# delete_one(filter, collation=None, session=None) method of pymongo.collection.Collection instance
#     Delete a single document matching the filter.
#
#       >>> db.test.count_documents({'x': 1})
#       3
#       >>> result = db.test.delete_one({'x': 1})
#       >>> result.deleted_count
#       1
#       >>> db.test.count_documents({'x': 1})
#       2
#
#     :Parameters:
#       - `filter`: A query that matches the document to delete.
#       - `collation` (optional): An instance of
#         :class:`~pymongo.collation.Collation`. This option is only supported
#         on MongoDB 3.4 and above.
#       - `session` (optional): a
#         :class:`~pymongo.client_session.ClientSession`.
#
#     :Returns:
#       - An instance of :class:`~pymongo.results.DeleteResult`.
#
#     .. versionchanged:: 3.6
#        Added ``session`` parameter.
#
#     .. versionchanged:: 3.4
#       Added the `collation` option.
#
# ...

# %%
list(db.test.find({'value': 5}))
# Out:
# [{'_id': ObjectId('5d7aa06a9fd615748e601083'), 'even': False, 'value': 5}]

# %%
# update records

db.test.update_one({'value':5},
                   {'$inc': {'value': 1000}})

# %%
list(db.test.find())
# Out:
# [{'_id': ObjectId('5d7a98639fd615748e601079'), 'x': 1},
#  {'_id': ObjectId('5d7a98729fd615748e60107a'), 'x': 1},
#  {'_id': ObjectId('5d7a9f1c9fd615748e60107b'),
#   'favorite animal': ['Shark', 'Cats']},
#  {'_id': ObjectId('5d7a9f1c9fd615748e60107c'), 'favorite animal': 'Platypus'},
#  {'_id': ObjectId('5d7a9f1c9fd615748e60107d'),
#   'favorite animal': 'Hippogriff'},
#  {'_id': ObjectId('5d7aa06a9fd615748e60107e'), 'even': True, 'value': 0},
#  {'_id': ObjectId('5d7aa06a9fd615748e60107f'), 'even': False, 'value': 1},
#  {'_id': ObjectId('5d7aa06a9fd615748e601080'), 'even': True, 'value': 2},
#  {'_id': ObjectId('5d7aa06a9fd615748e601081'), 'even': False, 'value': 8},
#  {'_id': ObjectId('5d7aa06a9fd615748e601082'), 'even': True, 'value': 4},
#  {'_id': ObjectId('5d7aa06a9fd615748e601083'), 'even': False, 'value': 1005},
#  {'_id': ObjectId('5d7aa06a9fd615748e601084'), 'even': True, 'value': 6},
#  {'_id': ObjectId('5d7aa06a9fd615748e601085'), 'even': False, 'value': 7},
# ...

# %%
db.test.update_many({'even': True},
                    {'$inc': {'value':100}})

# %%
list(db.test.find({'even':True}))
# Out:
# [{'_id': ObjectId('5d7aa06a9fd615748e60107e'), 'even': True, 'value': 0},
#  {'_id': ObjectId('5d7aa06a9fd615748e601080'), 'even': True, 'value': 2},
#  {'_id': ObjectId('5d7aa06a9fd615748e601082'), 'even': True, 'value': 4},
#  {'_id': ObjectId('5d7aa06a9fd615748e601084'), 'even': True, 'value': 6},
#  {'_id': ObjectId('5d7aa06a9fd615748e601086'), 'even': True, 'value': 8}]

# %%
db.test.delete_many({'even':False})

# %%
list(db.test.find())
# Out:
# [{'_id': ObjectId('5d7a98639fd615748e601079'), 'x': 1},
#  {'_id': ObjectId('5d7a98729fd615748e60107a'), 'x': 1},
#  {'_id': ObjectId('5d7a9f1c9fd615748e60107b'),
#   'favorite animal': ['Shark', 'Cats']},
#  {'_id': ObjectId('5d7a9f1c9fd615748e60107c'), 'favorite animal': 'Platypus'},
#  {'_id': ObjectId('5d7a9f1c9fd615748e60107d'),
#   'favorite animal': 'Hippogriff'},
#  {'_id': ObjectId('5d7aa06a9fd615748e60107e'), 'even': True, 'value': 0},
#  {'_id': ObjectId('5d7aa06a9fd615748e601080'), 'even': True, 'value': 2},
#  {'_id': ObjectId('5d7aa06a9fd615748e601082'), 'even': True, 'value': 4},
#  {'_id': ObjectId('5d7aa06a9fd615748e601084'), 'even': True, 'value': 6},
#  {'_id': ObjectId('5d7aa06a9fd615748e601086'), 'even': True, 'value': 8}]

# %% [markdown]
# ## RPG to Mongo DB

# %%
rpg_character = (1, "King Bob", 10, 3, 0, 0, 0)

# %%
# This gets error because not a dictionary! it's a tuple
# db.test.insert_one(rpg_character)

# %%
# solution:
# Wrap it in a simple dictionary so that the insert_one method works
db.test.insert_one({'rpg_character' : rpg_character})

# %%
db.test.find_one({'rpg_character' : rpg_character})
# Out:
# {'_id': ObjectId('5d7aa1719fd615748e601088'),
#  'rpg_character': [1, 'King Bob', 10, 3, 0, 0, 0]}

# %%
# make a loop out of this

db.test.insert_one({
    'sql_id': rpg_character[0],
    'name': rpg_character[1],
    'hp': rpg_character[2],
    'level': rpg_character[3]

})

# %%
list(db.test.find())
# Out:
# [{'_id': ObjectId('5d7a98639fd615748e601079'), 'x': 1},
#  {'_id': ObjectId('5d7a98729fd615748e60107a'), 'x': 1},
#  {'_id': ObjectId('5d7a9f1c9fd615748e60107b'),
#   'favorite animal': ['Shark', 'Cats']},
#  {'_id': ObjectId('5d7a9f1c9fd615748e60107c'), 'favorite animal': 'Platypus'},
#  {'_id': ObjectId('5d7a9f1c9fd615748e60107d'),
#   'favorite animal': 'Hippogriff'},
#  {'_id': ObjectId('5d7aa06a9fd615748e60107e'), 'even': True, 'value': 0},
#  {'_id': ObjectId('5d7aa06a9fd615748e601080'), 'even': True, 'value': 2},
#  {'_id': ObjectId('5d7aa06a9fd615748e601082'), 'even': True, 'value': 4},
#  {'_id': ObjectId('5d7aa06a9fd615748e601084'), 'even': True, 'value': 6},
#  {'_id': ObjectId('5d7aa06a9fd615748e601086'), 'even': True, 'value': 8},
#  {'_id': ObjectId('5d7aa1719fd615748e601088'),
#   'rpg_character': [1, 'King Bob', 10, 3, 0, 0, 0]},
#  {'_id': ObjectId('5d7aa18a9fd615748e601089'),
#   'rpg_character': [1, 'King Bob', 10, 3, 0, 0, 0]},
# ...

# %% [markdown]
# ## assignment: rpg db to mongo db

# %%
# getting the rpg SQL database
# !wget https://github.com/LambdaSchool/DS-Unit-3-Sprint-2-SQL-and-Databases/raw/master/module1-introduction-to-sql/rpg_db.sqlite3
# Out:
# --2019-09-12 19:51:41--  https://github.com/LambdaSchool/DS-Unit-3-Sprint-2-SQL-and-Databases/raw/master/module1-introduction-to-sql/rpg_db.sqlite3
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/LambdaSchool/DS-Unit-3-Sprint-2-SQL-and-Databases/master/module1-introduction-to-sql/rpg_db.sqlite3 [following]
# --2019-09-12 19:51:42--  https://raw.githubusercontent.com/LambdaSchool/DS-Unit-3-Sprint-2-SQL-and-Databases/master/module1-introduction-to-sql/rpg_db.sqlite3
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 253952 (248K) [application/octet-stream]
# Saving to: ‘rpg_db.sqlite3’
# ...

# %%
# check where it is
# !ls -lah
# Out:
# total 264K
# drwxr-xr-x 1 root root 4.0K Sep 12 19:51 .
# drwxr-xr-x 1 root root 4.0K Sep 12 18:54 ..
# drwxr-xr-x 1 root root 4.0K Sep  9 16:05 .config
# -rw-r--r-- 1 root root 248K Sep 12 19:51 rpg_db.sqlite3
# drwxr-xr-x 1 root root 4.0K Aug 27 16:17 sample_data

# %%
import sqlite3

# create connection and cursor first 
conn = sqlite3.connect('rpg_db.sqlite3')
curs = sqlte_conn.cursor()

# %%
# select all columns from charactercreator_character
curs.execute('Select * FROM charactercreator_character')

# fetch all entries in cursor
entries = curs.fetchall()

# %%
entries
# Out:
# [(1, 'Aliquid iste optio reiciendi', 0, 0, 10, 1, 1, 1, 1),
#  (2, 'Optio dolorem ex a', 0, 0, 10, 1, 1, 1, 1),
#  (3, 'Minus c', 0, 0, 10, 1, 1, 1, 1),
#  (4, 'Sit ut repr', 0, 0, 10, 1, 1, 1, 1),
#  (5, 'At id recusandae expl', 0, 0, 10, 1, 1, 1, 1),
#  (6, 'Non nobis et of', 0, 0, 10, 1, 1, 1, 1),
#  (7, 'Perferendis', 0, 0, 10, 1, 1, 1, 1),
#  (8, 'Accusantium amet quidem eve', 0, 0, 10, 1, 1, 1, 1),
#  (9, 'Sed nostrum inventore error m', 0, 0, 10, 1, 1, 1, 1),
#  (10, 'Harum repellendus omnis od', 0, 0, 10, 1, 1, 1, 1),
#  (11, 'Itaque ut commodi,', 0, 0, 10, 1, 1, 1, 1),
#  (12, 'Molestiae quis', 0, 0, 10, 1, 1, 1, 1),
#  (13, 'Ali', 0, 0, 10, 1, 1, 1, 1),
#  (14, 'Tempora quod optio possimus il', 0, 0, 10, 1, 1, 1, 1),
#  (15, 'Sed itaque beatae pari', 0, 0, 10, 1, 1, 1, 1),
#  (16, 'Quam dolor', 0, 0, 10, 1, 1, 1, 1),
#  (17, 'Molestias expedita', 0, 0, 10, 1, 1, 1, 1),
#  (18, 'Lauda', 0, 0, 10, 1, 1, 1, 1),
#  (19, 'Incidunt sint perferen', 0, 0, 10, 1, 1, 1, 1),
# ...

# %%
entries[0][0]
# Out:
# 1

# %%
# create RPG db in mongodb
db = client.rpg
db
# Out:
# Database(MongoClient(host=['cluster0-shard-00-02-6mbpl.mongodb.net:27017', 'cluster0-shard-00-00-6mbpl.mongodb.net:27017', 'cluster0-shard-00-01-6mbpl.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='Cluster0-shard-0', authsource='admin', retrywrites=True, w='majority'), 'rpg')

# %%
# use the for loop, loop over each entry and create dict
for entry in entries:
  db.characters.insert_one({
      'id': entries[0],
      'name': entries[1],
      'level': entries[2],
      'exp': entries[3],
      'hp': entries[4],
      'str': entries[5],
      'int': entries[6],
      'dex': entries[7],
      'wis': entries[8],
  })

# %%
# confirm 
list(db.characters.find())
# Out:
# [{'_id': ObjectId('5d7ab1889fd615748e6011b9'),
#   'dex': [8, 'Accusantium amet quidem eve', 0, 0, 10, 1, 1, 1, 1],
#   'exp': [4, 'Sit ut repr', 0, 0, 10, 1, 1, 1, 1],
#   'hp': [5, 'At id recusandae expl', 0, 0, 10, 1, 1, 1, 1],
#   'id': [1, 'Aliquid iste optio reiciendi', 0, 0, 10, 1, 1, 1, 1],
#   'int': [7, 'Perferendis', 0, 0, 10, 1, 1, 1, 1],
#   'level': [3, 'Minus c', 0, 0, 10, 1, 1, 1, 1],
#   'name': [2, 'Optio dolorem ex a', 0, 0, 10, 1, 1, 1, 1],
#   'str': [6, 'Non nobis et of', 0, 0, 10, 1, 1, 1, 1],
#   'wis': [9, 'Sed nostrum inventore error m', 0, 0, 10, 1, 1, 1, 1]},
#  {'_id': ObjectId('5d7ab1889fd615748e6011ba'),
#   'dex': [8, 'Accusantium amet quidem eve', 0, 0, 10, 1, 1, 1, 1],
#   'exp': [4, 'Sit ut repr', 0, 0, 10, 1, 1, 1, 1],
#   'hp': [5, 'At id recusandae expl', 0, 0, 10, 1, 1, 1, 1],
#   'id': [1, 'Aliquid iste optio reiciendi', 0, 0, 10, 1, 1, 1, 1],
#   'int': [7, 'Perferendis', 0, 0, 10, 1, 1, 1, 1],
# ...
