# %%
import pymongo

# %%
password = 'KVeBf6EHBltlUpVU'
client = pymongo.MongoClient('mongodb://admin:<KVeBf6EHBltlUpVU>@cluster0-shard-00-00-c6tvi.mongodb.net:27017,cluster0-shard-00-01-c6tvi.mongodb.net:27017,cluster0-shard-00-02-c6tvi.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true&w=majority')
db = client.test

# %%
client.nodes
# Out:
# frozenset({('cluster0-shard-00-00-c6tvi.mongodb.net', 27017),
#            ('cluster0-shard-00-01-c6tvi.mongodb.net', 27017),
#            ('cluster0-shard-00-02-c6tvi.mongodb.net', 27017)})

# %%
db
# Out:
# Database(MongoClient(host=['cluster0-shard-00-00-c6tvi.mongodb.net:27017', 'cluster0-shard-00-02-c6tvi.mongodb.net:27017', 'cluster0-shard-00-01-c6tvi.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='Cluster0-shard-0', authsource='admin', retrywrites=True, w='majority'), 'test')

# %%
mikes_doc = {'favorite animal!':'narwhal'}
db.insert_one({'favorite animal!':'narwhal'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-894e2cd11d5a> in <module>
#       1 mikes_doc = {'favorite animal!':'narwhal'}
# ----> 2 db.insert_one({'favorite animal!':'narwhal'})
#
# /anaconda3/lib/python3.6/site-packages/pymongo/collection.py in __call__(self, *args, **kwargs)
#    3350                             "object it is failing because no such method "
#    3351                             "exists." %
# -> 3352                             self.__name)
#    3353         raise TypeError("'Collection' object is not callable. If you meant to "
#    3354                         "call the '%s' method on a 'Collection' object it is "
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'insert_one' method on a 'Database' object it is failing because no such method exists.

# %%
posts = db.test
posts_id = posts.insert_one(mikes_doc).inserted_id
posts_id
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-43-9cebfda2c0b1> in <module>
#       1 posts = db.test
# ----> 2 posts_id = posts.insert_one(mikes_doc).inserted_id
#       3 posts_id
#
# /anaconda3/lib/python3.6/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session)
#     698                          write_concern=write_concern,
#     699                          bypass_doc_val=bypass_document_validation,
# --> 700                          session=session),
#     701             write_concern.acknowledged)
#     702
#
# /anaconda3/lib/python3.6/site-packages/pymongo/collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     612             return self._insert_one(
#     613                 docs, ordered, check_keys, manipulate, write_concern, op_id,
# ...

# %%
shilpas_doc = {'favorite_color': ['black', 'white', 'red']}
db.test.insert_one(shilpas_doc)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-16-0010e28ad8bf> in <module>
#       1 shilpas_doc = {'favorite_color': ['black', 'white', 'red']}
# ----> 2 db.test.insert_one(shilpas_doc)
#
# /anaconda3/lib/python3.6/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session)
#     698                          write_concern=write_concern,
#     699                          bypass_doc_val=bypass_document_validation,
# --> 700                          session=session),
#     701             write_concern.acknowledged)
#     702
#
# /anaconda3/lib/python3.6/site-packages/pymongo/collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     612             return self._insert_one(
# ...
