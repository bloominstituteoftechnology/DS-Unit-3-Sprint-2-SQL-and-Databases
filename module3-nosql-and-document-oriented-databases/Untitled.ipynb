# %%
import pymongo

client = pymongo.MongoClient("mongodb://bwhitman:mF44bPifV9miFea2@cluster0-shard-00-00-0zuv8.mongodb.net:27017,cluster0-shard-00-01-0zuv8.mongodb.net:27017,cluster0-shard-00-02-0zuv8.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.test

# %%
db.test
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-02-0zuv8.mongodb.net:27017', 'cluster0-shard-00-01-0zuv8.mongodb.net:27017', 'cluster0-shard-00-00-0zuv8.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='Cluster0-shard-0', authsource='admin', retrywrites=True, w='majority'), 'test'), 'test')

# %%
db.test.insert_one({'x': 1})

# %%
db.test.count_documents({'x': 1})
# Out:
# 4

# %%
dir(db.test)
# Out:
# ['_BaseObject__codec_options',
#  '_BaseObject__read_concern',
#  '_BaseObject__read_preference',
#  '_BaseObject__write_concern',
#  '_Collection__create',
#  '_Collection__create_index',
#  '_Collection__database',
#  '_Collection__find_and_modify',
#  '_Collection__full_name',
#  '_Collection__name',
#  '_Collection__write_response_codec_options',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_aggregate',
#  '_aggregate_one_result',
#  '_command',
#  '_count',
#  '_delete',
#  '_delete_retryable',
#  '_insert',
#  '_insert_one',
#  '_legacy_write',
#  '_map_reduce',
#  '_read_preference_for',
#  '_socket_for_reads',
#  '_socket_for_writes',
#  '_update',
#  '_update_retryable',
#  '_write_concern_for',
#  '_write_concern_for_cmd',
#  'aggregate',
#  'aggregate_raw_batches',
#  'bulk_write',
#  'codec_options',
#  'count',
#  'count_documents',
#  'create_index',
#  'create_indexes',
#  'database',
#  'delete_many',
#  'delete_one',
#  'distinct',
#  'drop',
#  'drop_index',
#  'drop_indexes',
#  'ensure_index',
#  'estimated_document_count',
#  'find',
#  'find_and_modify',
#  'find_one',
#  'find_one_and_delete',
#  'find_one_and_replace',
#  'find_one_and_update',
#  'find_raw_batches',
#  'full_name',
#  'group',
#  'index_information',
#  'initialize_ordered_bulk_op',
#  'initialize_unordered_bulk_op',
#  'inline_map_reduce',
#  'insert',
#  'insert_many',
#  'insert_one',
#  'list_indexes',
#  'map_reduce',
#  'name',
#  'next',
#  'options',
#  'parallel_scan',
#  'read_concern',
#  'read_preference',
#  'reindex',
#  'remove',
#  'rename',
#  'replace_one',
#  'save',
#  'update',
#  'update_many',
#  'update_one',
#  'watch',
#  'with_options',
#  'write_concern']

# %%
db.test.find_one({'x': 1})
# Out:
# {'_id': ObjectId('5e3a2d35c98a7a56d68eb218'), 'x': 1}

# %%
curs = db.test.find({'x': 1})

# %%
dir(curs)
# Out:
# ['_Cursor__address',
#  '_Cursor__batch_size',
#  '_Cursor__check_okay_to_chain',
#  '_Cursor__codec_options',
#  '_Cursor__collation',
#  '_Cursor__collection',
#  '_Cursor__comment',
#  '_Cursor__data',
#  '_Cursor__die',
#  '_Cursor__empty',
#  '_Cursor__exhaust',
#  '_Cursor__exhaust_mgr',
#  '_Cursor__explain',
#  '_Cursor__explicit_session',
#  '_Cursor__hint',
#  '_Cursor__id',
#  '_Cursor__killed',
#  '_Cursor__limit',
#  '_Cursor__manipulate',
#  '_Cursor__max',
#  '_Cursor__max_await_time_ms',
#  '_Cursor__max_scan',
#  '_Cursor__max_time_ms',
#  '_Cursor__min',
#  '_Cursor__modifiers',
#  '_Cursor__ordering',
#  '_Cursor__projection',
#  '_Cursor__query_flags',
#  '_Cursor__query_spec',
#  '_Cursor__read_concern',
#  '_Cursor__read_preference',
#  '_Cursor__retrieved',
#  '_Cursor__return_key',
#  '_Cursor__send_message',
#  '_Cursor__session',
#  '_Cursor__set_hint',
#  '_Cursor__show_record_id',
#  '_Cursor__skip',
#  '_Cursor__snapshot',
#  '_Cursor__spec',
#  '__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_clone',
#  '_clone_base',
#  '_deepcopy',
#  '_getmore_class',
#  '_query_class',
#  '_read_preference',
#  '_refresh',
#  '_unpack_response',
#  'add_option',
#  'address',
#  'alive',
#  'batch_size',
#  'clone',
#  'close',
#  'collation',
#  'collection',
#  'comment',
#  'count',
#  'cursor_id',
#  'distinct',
#  'explain',
#  'hint',
#  'limit',
#  'max',
#  'max_await_time_ms',
#  'max_scan',
#  'max_time_ms',
#  'min',
#  'next',
#  'remove_option',
#  'retrieved',
#  'rewind',
#  'session',
#  'skip',
#  'sort',
#  'where']

# %%
list(curs)
# Out:
# [{'_id': ObjectId('5e3a2d35c98a7a56d68eb218'), 'x': 1},
#  {'_id': ObjectId('5e3a2d3ac98a7a56d68eb219'), 'x': 1},
#  {'_id': ObjectId('5e3a2d3ac98a7a56d68eb21a'), 'x': 1},
#  {'_id': ObjectId('5e3a2d3bc98a7a56d68eb21b'), 'x': 1}]

# %%
loris_doc = {
    'favorite_animal': 'peacock',
    'favorite_color': 'blue',
    'favorite_number': 7
}

my_doc = {
    'favorite_animal': 'whale',
    'favorite_color': 'blue',
    'favorite_number': 12
}

juds_doc = {
    'favorite_animal': 'liger',
    'favorite_color': 'blellow',
    'favorite_number': 42,
    'favorite_direction': 'weast'
}

all_docs = [loris_doc, my_doc, juds_doc]

# %%
db.test.insert_many(all_docs)

# %%
list(db.test.find())
# Out:
# [{'_id': ObjectId('5e3a2d35c98a7a56d68eb218'), 'x': 1},
#  {'_id': ObjectId('5e3a2d3ac98a7a56d68eb219'), 'x': 1},
#  {'_id': ObjectId('5e3a2d3ac98a7a56d68eb21a'), 'x': 1},
#  {'_id': ObjectId('5e3a2d3bc98a7a56d68eb21b'), 'x': 1},
#  {'_id': ObjectId('5e3a30e2c98a7a56d68eb21c'),
#   'favorite_animal': 'peacock',
#   'favorite_color': 'blue',
#   'favorite_number': 7},
#  {'_id': ObjectId('5e3a30e2c98a7a56d68eb21d'),
#   'favorite_animal': 'whale',
#   'favorite_color': 'blue',
#   'favorite_number': 12},
#  {'_id': ObjectId('5e3a30e2c98a7a56d68eb21e'),
#   'favorite_animal': 'liger',
#   'favorite_color': 'blellow',
#   'favorite_number': 42,
#   'favorite_direction': 'weast'}]

# %%
more_docs = []
for i in range(10):
    doc = {'even': i % 2 == 0}
    doc['value'] = i
    more_docs.append(doc)
    
more_docs
# Out:
# [{'even': True, 'value': 0},
#  {'even': False, 'value': 1},
#  {'even': True, 'value': 2},
#  {'even': False, 'value': 3},
#  {'even': True, 'value': 4},
#  {'even': False, 'value': 5},
#  {'even': True, 'value': 6},
#  {'even': False, 'value': 7},
#  {'even': True, 'value': 8},
#  {'even': False, 'value': 9}]

# %%
db.test.insert_many(more_docs)

# %%
list(db.test.find({'even': True, 'value': 0}))
# Out:
# [{'_id': ObjectId('5e3a31aac98a7a56d68eb21f'), 'even': True, 'value': 0}]

# %%
list(db.test.find({'even': True}))
# Out:
# [{'_id': ObjectId('5e3a31aac98a7a56d68eb21f'), 'even': True, 'value': 0},
#  {'_id': ObjectId('5e3a31aac98a7a56d68eb221'), 'even': True, 'value': 2},
#  {'_id': ObjectId('5e3a31aac98a7a56d68eb223'), 'even': True, 'value': 4},
#  {'_id': ObjectId('5e3a31aac98a7a56d68eb225'), 'even': True, 'value': 6},
#  {'_id': ObjectId('5e3a31aac98a7a56d68eb227'), 'even': True, 'value': 8}]

# %%
list(db.test.find({'favorite_color': 'blue'}))
# Out:
# [{'_id': ObjectId('5e3a30e2c98a7a56d68eb21c'),
#   'favorite_animal': 'peacock',
#   'favorite_color': 'blue',
#   'favorite_number': 7},
#  {'_id': ObjectId('5e3a30e2c98a7a56d68eb21d'),
#   'favorite_animal': 'whale',
#   'favorite_color': 'blue',
#   'favorite_number': 12}]

# %%
rpg_character = [1, 'King Bob', 10, 3, 0, 0, 0]

# %%
rpg_doc = {
    'sql_key': rpg_character[0],
    'name': rpg_character[1],
    'hp': rpg_character[2],
    'level': rpg_character[3]
}

# %%
db.test.insert_one(rpg_doc)

# %%
list(db.test.find(rpg_doc))
# Out:
# [{'_id': ObjectId('5e3a3402c98a7a56d68eb229'),
#   'sql_key': 1,
#   'name': 'King Bob',
#   'hp': 10,
#   'level': 3}]

# %%
import json

with open('rpg_data.json') as rpg_data:
    string = rpg_data.readlines()
    
string = string[0][1:-1]

# %%
import pandas as pd
df = pd.read_json('rpg_data.json')

# %%
json_string = df.to_json(orient='records')

# %%
json_string
# Out:
# '[{"model":"charactercreator.character","pk":1,"fields":{"name":"Aliquid iste optio reiciendi","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[20,58,85]}},{"model":"charactercreator.character","pk":2,"fields":{"name":"Optio dolorem ex a","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[93,115,133]}},{"model":"charactercreator.character","pk":3,"fields":{"name":"Minus c","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[8,43]}},{"model":"charactercreator.character","pk":4,"fields":{"name":"Sit ut repr","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[21,82,85,135]}},{"model":"charactercreator.character","pk":5,"fields":{"name":"At id recusandae expl","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[7,96,140,145]}},{"model":"charactercreator.character","pk":6,"fields":{"name":"Non nobis et of","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[93]}},{"model":"charactercreator.character","pk":7,"fields":{"name":"Perferendis","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[38,42,85,123,166]}},{"model":"charactercreator.character","pk":8,"fields":{"name":"Accusantium amet quidem eve","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[43,48,119]}},{"model":"charactercreator.character","pk":9,"fields":{"name":"Sed nostrum inventore error m","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[32,106,116,125]}},{"model":"charactercreator.character","pk":10,"fields":{"name":"Harum repellendus omnis od","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[117,129,131,135]}},{"model":"charactercreator.character","pk":11,"fields":{"name":"Itaque ut commodi,","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[54,108,158]}},{"model":"charactercreator.character","pk":12,"fields":{"name":"Molestiae quis","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[65,115,126]}},{"model":"charactercreator.character","pk":13,"fields":{"name":"Ali","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[38,44,62,125]}},{"model":"charactercreator.character","pk":14,"fields":{"name":"Tempora quod optio possimus il","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[34,41,65,68]}},{"model":"charactercreator.character","pk":15,"fields":{"name":"Sed itaque beatae pari","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[34,56,74,84]}},{"model":"charactercreator.character","pk":16,"fields":{"name":"Quam dolor","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[87]}},{"model":"charactercreator.character","pk":17,"fields":{"name":"Molestias expedita","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[64,68,116,128,136]}},{"model":"charactercreator.character","pk":18,"fields":{"name":"Lauda","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[17,60,62,64,90]}},{"model":"charactercreator.character","pk":19,"fields":{"name":"Incidunt sint perferen","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[5,52,113]}},{"model":"charactercreator.character","pk":20,"fields":{"name":"Laboriosa","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inventory":[156]}},{"model":"charactercreator.character","pk":21,"fields":{"name":"Dolore esse nesciunt fugit com","level":0,"exp":0,"hp":10,"strength":1,"intelligence":1,"dexterity":1,"wisdom":1,"inven ...

# %%
json_to_load = json.loads(json_string)

# %%
db.test.insert_many(json_to_load)

# %%
list(db.test.find())
# Out:
# [{'_id': ObjectId('5e3a2d35c98a7a56d68eb218'), 'x': 1},
#  {'_id': ObjectId('5e3a2d3ac98a7a56d68eb219'), 'x': 1},
#  {'_id': ObjectId('5e3a2d3ac98a7a56d68eb21a'), 'x': 1},
#  {'_id': ObjectId('5e3a2d3bc98a7a56d68eb21b'), 'x': 1},
#  {'_id': ObjectId('5e3a30e2c98a7a56d68eb21c'),
#   'favorite_animal': 'peacock',
#   'favorite_color': 'blue',
#   'favorite_number': 7},
#  {'_id': ObjectId('5e3a30e2c98a7a56d68eb21d'),
#   'favorite_animal': 'whale',
#   'favorite_color': 'blue',
#   'favorite_number': 12},
#  {'_id': ObjectId('5e3a30e2c98a7a56d68eb21e'),
#   'favorite_animal': 'liger',
#   'favorite_color': 'blellow',
#   'favorite_number': 42,
#   'favorite_direction': 'weast'},
#  {'_id': ObjectId('5e3a31aac98a7a56d68eb21f'), 'even': True, 'value': 0},
#  {'_id': ObjectId('5e3a31aac98a7a56d68eb220'), 'even': False, 'value': 1},
#  {'_id': ObjectId('5e3a31aac98a7a56d68eb221'), 'even': True, 'value': 2},
#  {'_id': ObjectId('5e3a31aac98a7a56d68eb222'), 'even': False, 'value': 3},
#  {'_id': ObjectId('5e3a31aac98a7a56d68eb223'), 'even': True, 'value': 4},
#  {'_id': ObjectId('5e3a31aac98a7a56d68eb224'), 'even': False, 'value': 5},
#  {'_id': ObjectId('5e3a31aac98a7a56d68eb225'), 'even': True, 'value': 6},
#  {'_id': ObjectId('5e3a31aac98a7a56d68eb226'), 'even': False, 'value': 7},
#  {'_id': ObjectId('5e3a31aac98a7a56d68eb227'), 'even': True, 'value': 8},
#  {'_id': ObjectId('5e3a31aac98a7a56d68eb228'), 'even': False, 'value': 9},
#  {'_id': ObjectId('5e3a3402c98a7a56d68eb229'),
#   'sql_key': 1,
#   'name': 'King Bob',
#   'hp': 10,
#   'level': 3},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb22a'),
#   'model': 'charactercreator.character',
#   'pk': 1,
#   'fields': {'name': 'Aliquid iste optio reiciendi',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [20, 58, 85]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb22b'),
#   'model': 'charactercreator.character',
#   'pk': 2,
#   'fields': {'name': 'Optio dolorem ex a',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [93, 115, 133]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb22c'),
#   'model': 'charactercreator.character',
#   'pk': 3,
#   'fields': {'name': 'Minus c',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [8, 43]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb22d'),
#   'model': 'charactercreator.character',
#   'pk': 4,
#   'fields': {'name': 'Sit ut repr',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [21, 82, 85, 135]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb22e'),
#   'model': 'charactercreator.character',
#   'pk': 5,
#   'fields': {'name': 'At id recusandae expl',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [7, 96, 140, 145]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb22f'),
#   'model': 'charactercreator.character',
#   'pk': 6,
#   'fields': {'name': 'Non nobis et of',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [93]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb230'),
#   'model': 'charactercreator.character',
#   'pk': 7,
#   'fields': {'name': 'Perferendis',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [38, 42, 85, 123, 166]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb231'),
#   'model': 'charactercreator.character',
#   'pk': 8,
#   'fields': {'name': 'Accusantium amet quidem eve',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [43, 48, 119]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb232'),
#   'model': 'charactercreator.character',
#   'pk': 9,
#   'fields': {'name': 'Sed nostrum inventore error m',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [32, 106, 116, 125]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb233'),
#   'model': 'charactercreator.character',
#   'pk': 10,
#   'fields': {'name': 'Harum repellendus omnis od',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [117, 129, 131, 135]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb234'),
#   'model': 'charactercreator.character',
#   'pk': 11,
#   'fields': {'name': 'Itaque ut commodi,',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [54, 108, 158]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb235'),
#   'model': 'charactercreator.character',
#   'pk': 12,
#   'fields': {'name': 'Molestiae quis',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [65, 115, 126]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb236'),
#   'model': 'charactercreator.character',
#   'pk': 13,
#   'fields': {'name': 'Ali',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [38, 44, 62, 125]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb237'),
#   'model': 'charactercreator.character',
#   'pk': 14,
#   'fields': {'name': 'Tempora quod optio possimus il',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [34, 41, 65, 68]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb238'),
#   'model': 'charactercreator.character',
#   'pk': 15,
#   'fields': {'name': 'Sed itaque beatae pari',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [34, 56, 74, 84]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb239'),
#   'model': 'charactercreator.character',
#   'pk': 16,
#   'fields': {'name': 'Quam dolor',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [87]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb23a'),
#   'model': 'charactercreator.character',
#   'pk': 17,
#   'fields': {'name': 'Molestias expedita',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [64, 68, 116, 128, 136]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb23b'),
#   'model': 'charactercreator.character',
#   'pk': 18,
#   'fields': {'name': 'Lauda',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [17, 60, 62, 64, 90]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb23c'),
#   'model': 'charactercreator.character',
#   'pk': 19,
#   'fields': {'name': 'Incidunt sint perferen',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [5, 52, 113]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb23d'),
#   'model': 'charactercreator.character',
#   'pk': 20,
#   'fields': {'name': 'Laboriosa',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [156]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb23e'),
#   'model': 'charactercreator.character',
#   'pk': 21,
#   'fields': {'name': 'Dolore esse nesciunt fugit com',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [33, 34, 51, 117]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb23f'),
#   'model': 'charactercreator.character',
#   'pk': 22,
#   'fields': {'name': 'Dolorum nam reic',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [41, 43, 164]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb240'),
#   'model': 'charactercreator.character',
#   'pk': 23,
#   'fields': {'name': 'Repellat ad numquam volu',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [33, 61, 160]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb241'),
#   'model': 'charactercreator.character',
#   'pk': 24,
#   'fields': {'name': 'Facere enim velit eligend',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [8]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb242'),
#   'model': 'charactercreator.character',
#   'pk': 25,
#   'fields': {'name': 'Sed ratione quis rep',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [50, 122]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb243'),
#   'model': 'charactercreator.character',
#   'pk': 26,
#   'fields': {'name': 'Doloribus neque',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [112, 149]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb244'),
#   'model': 'charactercreator.character',
#   'pk': 27,
#   'fields': {'name': 'Ab voluptas se',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [10, 104, 148, 157, 172]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb245'),
#   'model': 'charactercreator.character',
#   'pk': 28,
#   'fields': {'name': 'Molestias m',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [51]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb246'),
#   'model': 'charactercreator.character',
#   'pk': 29,
#   'fields': {'name': 'In pariatur corpori',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [107, 120, 157, 170]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb247'),
#   'model': 'charactercreator.character',
#   'pk': 30,
#   'fields': {'name': 'Possimus ad dignissimos vel, a',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [69, 109, 114, 138]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb248'),
#   'model': 'charactercreator.character',
#   'pk': 31,
#   'fields': {'name': 'At minus accusa',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [9, 45, 61]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb249'),
#   'model': 'charactercreator.character',
#   'pk': 32,
#   'fields': {'name': 'Ad necess',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [111, 142]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb24a'),
#   'model': 'charactercreator.character',
#   'pk': 33,
#   'fields': {'name': 'Expedita c',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [64, 110]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb24b'),
#   'model': 'charactercreator.character',
#   'pk': 34,
#   'fields': {'name': 'Voluptates sunt voluptas volu',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [5, 90, 132, 160]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb24c'),
#   'model': 'charactercreator.character',
#   'pk': 35,
#   'fields': {'name': 'Autem mollitia fuga lauda',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [3, 62, 101, 165, 166]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb24d'),
#   'model': 'charactercreator.character',
#   'pk': 36,
#   'fields': {'name': 'Sint quibusdam ob',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [29, 34, 141, 153, 155]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb24e'),
#   'model': 'charactercreator.character',
#   'pk': 37,
#   'fields': {'name': 'Rerum et o',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [20, 42, 54, 169, 174]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb24f'),
#   'model': 'charactercreator.character',
#   'pk': 38,
#   'fields': {'name': 'Doloribus dolore r',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [80, 115, 124, 146, 165]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb250'),
#   'model': 'charactercreator.character',
#   'pk': 39,
#   'fields': {'name': 'Eaque su',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [58, 150, 168]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb251'),
#   'model': 'charactercreator.character',
#   'pk': 40,
#   'fields': {'name': 'Vel molestias numqua',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [26, 32, 147]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb252'),
#   'model': 'charactercreator.character',
#   'pk': 41,
#   'fields': {'name': 'Iste assumenda repellat q',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [112, 168]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb253'),
#   'model': 'charactercreator.character',
#   'pk': 42,
#   'fields': {'name': 'Animi labo',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [65, 92, 131]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb254'),
#   'model': 'charactercreator.character',
#   'pk': 43,
#   'fields': {'name': 'Eum culpa eaque ea omn',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [131]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb255'),
#   'model': 'charactercreator.character',
#   'pk': 44,
#   'fields': {'name': 'Harum provident vel quam',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [38]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb256'),
#   'model': 'charactercreator.character',
#   'pk': 45,
#   'fields': {'name': 'Aspe',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [12, 16, 66, 76]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb257'),
#   'model': 'charactercreator.character',
#   'pk': 46,
#   'fields': {'name': 'Nisi nequ',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [84]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb258'),
#   'model': 'charactercreator.character',
#   'pk': 47,
#   'fields': {'name': 'Quod tempora',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [35, 94, 136, 161]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb259'),
#   'model': 'charactercreator.character',
#   'pk': 48,
#   'fields': {'name': 'Porro aliq',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [45, 47, 126, 137]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb25a'),
#   'model': 'charactercreator.character',
#   'pk': 49,
#   'fields': {'name': 'Quas',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [2, 41, 86, 113]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb25b'),
#   'model': 'charactercreator.character',
#   'pk': 50,
#   'fields': {'name': 'Magnam eligendi quia animi',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [29]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb25c'),
#   'model': 'charactercreator.character',
#   'pk': 51,
#   'fields': {'name': 'Officiis se',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [73, 79, 153]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb25d'),
#   'model': 'charactercreator.character',
#   'pk': 52,
#   'fields': {'name': 'Id assumend',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [115, 131]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb25e'),
#   'model': 'charactercreator.character',
#   'pk': 53,
#   'fields': {'name': 'Voluptatibus fu',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [3, 26, 54, 119, 170]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb25f'),
#   'model': 'charactercreator.character',
#   'pk': 54,
#   'fields': {'name': 'Odit rat',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [55]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb260'),
#   'model': 'charactercreator.character',
#   'pk': 55,
#   'fields': {'name': 'Debit',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [49, 81, 141, 160]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb261'),
#   'model': 'charactercreator.character',
#   'pk': 56,
#   'fields': {'name': 'Cum aut quas repudia',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [156]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb262'),
#   'model': 'charactercreator.character',
#   'pk': 57,
#   'fields': {'name': 'Deleniti qui quae quidem',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [36, 156, 168]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb263'),
#   'model': 'charactercreator.character',
#   'pk': 58,
#   'fields': {'name': 'Adipisci voluptas',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [5, 46, 62, 159]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb264'),
#   'model': 'charactercreator.character',
#   'pk': 59,
#   'fields': {'name': 'Debitis sit ratione eos nam',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [87, 89, 166, 174]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb265'),
#   'model': 'charactercreator.character',
#   'pk': 60,
#   'fields': {'name': 'Esse illo molestias archi',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [87, 129, 130, 141]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb266'),
#   'model': 'charactercreator.character',
#   'pk': 61,
#   'fields': {'name': 'Sunt at itaque voluptatum d',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [95, 116]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb267'),
#   'model': 'charactercreator.character',
#   'pk': 62,
#   'fields': {'name': 'Est totam',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [115]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb268'),
#   'model': 'charactercreator.character',
#   'pk': 63,
#   'fields': {'name': 'Reprehenderit commodi eius',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [5, 19, 151, 158, 163]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb269'),
#   'model': 'charactercreator.character',
#   'pk': 64,
#   'fields': {'name': 'Debit',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [66, 134, 160]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb26a'),
#   'model': 'charactercreator.character',
#   'pk': 65,
#   'fields': {'name': 'Soluta dol',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [8, 18, 116, 136, 157]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb26b'),
#   'model': 'charactercreator.character',
#   'pk': 66,
#   'fields': {'name': 'Vel nesc',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [3, 83, 113, 123, 145]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb26c'),
#   'model': 'charactercreator.character',
#   'pk': 67,
#   'fields': {'name': 'Ratione quia ali',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [89]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb26d'),
#   'model': 'charactercreator.character',
#   'pk': 68,
#   'fields': {'name': 'Rerum recusandae minima',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [54, 93, 114, 147]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb26e'),
#   'model': 'charactercreator.character',
#   'pk': 69,
#   'fields': {'name': 'Totam natus eius fugiat volu',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [43, 90, 146]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb26f'),
#   'model': 'charactercreator.character',
#   'pk': 70,
#   'fields': {'name': 'Perferendis commodi null',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [139, 151, 172]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb270'),
#   'model': 'charactercreator.character',
#   'pk': 71,
#   'fields': {'name': 'Laudantiu',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [11, 83, 167]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb271'),
#   'model': 'charactercreator.character',
#   'pk': 72,
#   'fields': {'name': 'Voluptat',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [128]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb272'),
#   'model': 'charactercreator.character',
#   'pk': 73,
#   'fields': {'name': 'Incidunt nesciun',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [19]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb273'),
#   'model': 'charactercreator.character',
#   'pk': 74,
#   'fields': {'name': 'Illum amet vero',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [106, 139]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb274'),
#   'model': 'charactercreator.character',
#   'pk': 75,
#   'fields': {'name': 'Suscipit exercitationem re',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [99]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb275'),
#   'model': 'charactercreator.character',
#   'pk': 76,
#   'fields': {'name': 'Quas enim error maxime nisi m',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [24]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb276'),
#   'model': 'charactercreator.character',
#   'pk': 77,
#   'fields': {'name': 'Labore qu',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [2, 22, 68, 133]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb277'),
#   'model': 'charactercreator.character',
#   'pk': 78,
#   'fields': {'name': 'Repudiandae deleniti unde',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [21, 25, 141]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb278'),
#   'model': 'charactercreator.character',
#   'pk': 79,
#   'fields': {'name': 'Ut do',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [106]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb279'),
#   'model': 'charactercreator.character',
#   'pk': 80,
#   'fields': {'name': 'Quaerat esse labore q',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [8, 102, 149]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb27a'),
#   'model': 'charactercreator.character',
#   'pk': 81,
#   'fields': {'name': 'Quidem aliq',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [4, 24, 101, 155, 158]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb27b'),
#   'model': 'charactercreator.character',
#   'pk': 82,
#   'fields': {'name': 'Aperiam vitae eos dolor sed',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [12, 30, 93, 136]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb27c'),
#   'model': 'charactercreator.character',
#   'pk': 83,
#   'fields': {'name': 'Minus nobis porro',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [9, 101, 115]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb27d'),
#   'model': 'charactercreator.character',
#   'pk': 84,
#   'fields': {'name': 'In similique',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [3, 97, 143, 162]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb27e'),
#   'model': 'charactercreator.character',
#   'pk': 85,
#   'fields': {'name': 'Culpa repellat unde',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [65, 72, 116, 153, 165]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb27f'),
#   'model': 'charactercreator.character',
#   'pk': 86,
#   'fields': {'name': 'Architecto i',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [15, 20, 24, 46, 148]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb280'),
#   'model': 'charactercreator.character',
#   'pk': 87,
#   'fields': {'name': 'A sed pariatur qua',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [40]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb281'),
#   'model': 'charactercreator.character',
#   'pk': 88,
#   'fields': {'name': 'Tempore assumenda aperiam',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [97, 108, 137, 170]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb282'),
#   'model': 'charactercreator.character',
#   'pk': 89,
#   'fields': {'name': 'Sed ullam tempora iusto co',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [38, 91]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb283'),
#   'model': 'charactercreator.character',
#   'pk': 90,
#   'fields': {'name': 'Ipsa',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [4, 166]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb284'),
#   'model': 'charactercreator.character',
#   'pk': 91,
#   'fields': {'name': 'Fugiat incidun',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [5, 41, 51, 128, 135]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb285'),
#   'model': 'charactercreator.character',
#   'pk': 92,
#   'fields': {'name': 'Molestiae of',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [16, 59, 77, 95, 151]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb286'),
#   'model': 'charactercreator.character',
#   'pk': 93,
#   'fields': {'name': 'Quae quisquam cons',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [5, 12, 60, 131]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb287'),
#   'model': 'charactercreator.character',
#   'pk': 94,
#   'fields': {'name': 'Repellendus ea non facil',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [58, 73, 100, 139]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb288'),
#   'model': 'charactercreator.character',
#   'pk': 95,
#   'fields': {'name': 'Quod non quibu',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [14, 58, 67, 99, 112]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb289'),
#   'model': 'charactercreator.character',
#   'pk': 96,
#   'fields': {'name': 'Numquam velit distinctio',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [77, 130, 135, 142, 170]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb28a'),
#   'model': 'charactercreator.character',
#   'pk': 97,
#   'fields': {'name': 'Necessitatibus nihil ex debi',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [17, 72, 101]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb28b'),
#   'model': 'charactercreator.character',
#   'pk': 98,
#   'fields': {'name': 'Velit tempore nemo, na',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [10, 87]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb28c'),
#   'model': 'charactercreator.character',
#   'pk': 99,
#   'fields': {'name': 'Nesciunt v',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [158]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb28d'),
#   'model': 'charactercreator.character',
#   'pk': 100,
#   'fields': {'name': 'Dicta enim debitis accusantiu',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [40, 57, 85, 107, 146]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb28e'),
#   'model': 'charactercreator.character',
#   'pk': 101,
#   'fields': {'name': 'Vitae a',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [22, 30, 39, 40, 170]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb28f'),
#   'model': 'charactercreator.character',
#   'pk': 102,
#   'fields': {'name': 'Praesentium voluptas u',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [26, 52, 84]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb290'),
#   'model': 'charactercreator.character',
#   'pk': 103,
#   'fields': {'name': 'Unde ullam mollitia? Nu',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [45, 111, 113, 120, 158]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb291'),
#   'model': 'charactercreator.character',
#   'pk': 104,
#   'fields': {'name': 'Neque molestias qu',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [40, 64, 71, 122, 129]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb292'),
#   'model': 'charactercreator.character',
#   'pk': 105,
#   'fields': {'name': 'Officiis es',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [43, 137, 146]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb293'),
#   'model': 'charactercreator.character',
#   'pk': 106,
#   'fields': {'name': 'Beatae mi',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [84, 112, 126, 148]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb294'),
#   'model': 'charactercreator.character',
#   'pk': 107,
#   'fields': {'name': 'Mollitia nam corporis temp',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [116]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb295'),
#   'model': 'charactercreator.character',
#   'pk': 108,
#   'fields': {'name': 'Repudiandae repellat i',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [47, 75, 160, 166]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb296'),
#   'model': 'charactercreator.character',
#   'pk': 109,
#   'fields': {'name': 'Laboriosam',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [92]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb297'),
#   'model': 'charactercreator.character',
#   'pk': 110,
#   'fields': {'name': 'Nam minus amet',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [90]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb298'),
#   'model': 'charactercreator.character',
#   'pk': 111,
#   'fields': {'name': 'Harum quae volup',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [122]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb299'),
#   'model': 'charactercreator.character',
#   'pk': 112,
#   'fields': {'name': 'Impedit facere ulla',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [127, 157]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb29a'),
#   'model': 'charactercreator.character',
#   'pk': 113,
#   'fields': {'name': 'Enim',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [142, 166]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb29b'),
#   'model': 'charactercreator.character',
#   'pk': 114,
#   'fields': {'name': 'Dolore magni',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [10, 50, 61, 91, 153]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb29c'),
#   'model': 'charactercreator.character',
#   'pk': 115,
#   'fields': {'name': 'Eaque at corpori',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [10, 18, 68, 101, 144]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb29d'),
#   'model': 'charactercreator.character',
#   'pk': 116,
#   'fields': {'name': 'Fug',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [20]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb29e'),
#   'model': 'charactercreator.character',
#   'pk': 117,
#   'fields': {'name': 'Dolorum laudanti',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [15, 21, 116, 160]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb29f'),
#   'model': 'charactercreator.character',
#   'pk': 118,
#   'fields': {'name': 'Perferendis nat',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [9, 71, 128, 133, 174]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2a0'),
#   'model': 'charactercreator.character',
#   'pk': 119,
#   'fields': {'name': 'Cupidi',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [1, 15, 31, 54, 95]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2a1'),
#   'model': 'charactercreator.character',
#   'pk': 120,
#   'fields': {'name': 'Commodi eius dicta digniss',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [50, 91, 94]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2a2'),
#   'model': 'charactercreator.character',
#   'pk': 121,
#   'fields': {'name': 'Debitis eu',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [59, 63, 100]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2a3'),
#   'model': 'charactercreator.character',
#   'pk': 122,
#   'fields': {'name': 'Nihil repella',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [87, 162]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2a4'),
#   'model': 'charactercreator.character',
#   'pk': 123,
#   'fields': {'name': 'Rem quasi minima hic sed anim',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [46, 56, 90]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2a5'),
#   'model': 'charactercreator.character',
#   'pk': 124,
#   'fields': {'name': 'Sed ali',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [98]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2a6'),
#   'model': 'charactercreator.character',
#   'pk': 125,
#   'fields': {'name': 'Earum vol',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [8, 110, 131]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2a7'),
#   'model': 'charactercreator.character',
#   'pk': 126,
#   'fields': {'name': 'Inventore tempore com',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [162]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2a8'),
#   'model': 'charactercreator.character',
#   'pk': 127,
#   'fields': {'name': 'Repell',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [133, 154, 171]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2a9'),
#   'model': 'charactercreator.character',
#   'pk': 128,
#   'fields': {'name': 'Consequatur quis recusandae qu',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [111, 138, 171]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2aa'),
#   'model': 'charactercreator.character',
#   'pk': 129,
#   'fields': {'name': 'Dolores ea velit mi',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [4, 51, 108, 138, 149]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2ab'),
#   'model': 'charactercreator.character',
#   'pk': 130,
#   'fields': {'name': 'Atque blanditiis a aperiam',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [63]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2ac'),
#   'model': 'charactercreator.character',
#   'pk': 131,
#   'fields': {'name': 'Reprehenderit sequi iu',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [4, 17, 147]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2ad'),
#   'model': 'charactercreator.character',
#   'pk': 132,
#   'fields': {'name': 'Natus architecto eos, hic blan',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [15, 16, 89, 133]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2ae'),
#   'model': 'charactercreator.character',
#   'pk': 133,
#   'fields': {'name': 'Ipsa illo quas',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [8, 19, 28]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2af'),
#   'model': 'charactercreator.character',
#   'pk': 134,
#   'fields': {'name': 'Voluptas ali',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [127, 132, 144, 173]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2b0'),
#   'model': 'charactercreator.character',
#   'pk': 135,
#   'fields': {'name': 'Voluptates obcaecati quod e',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [13, 20, 40, 43, 72]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2b1'),
#   'model': 'charactercreator.character',
#   'pk': 136,
#   'fields': {'name': 'Dolor adipisci a voluptate',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [18, 53, 87, 166]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2b2'),
#   'model': 'charactercreator.character',
#   'pk': 137,
#   'fields': {'name': 'Repellendus natus quae, n',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [53, 55, 101]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2b3'),
#   'model': 'charactercreator.character',
#   'pk': 138,
#   'fields': {'name': 'Laudantium earum nam in dol',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [65, 69, 133]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2b4'),
#   'model': 'charactercreator.character',
#   'pk': 139,
#   'fields': {'name': 'Molestias face',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [23, 54, 109, 116, 174]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2b5'),
#   'model': 'charactercreator.character',
#   'pk': 140,
#   'fields': {'name': 'Maiores suscipit exc',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [7, 42, 103]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2b6'),
#   'model': 'charactercreator.character',
#   'pk': 141,
#   'fields': {'name': 'Illum dolore perferen',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [171]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2b7'),
#   'model': 'charactercreator.character',
#   'pk': 142,
#   'fields': {'name': 'Explicabo recusandae ma',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [50, 51, 155, 173, 174]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2b8'),
#   'model': 'charactercreator.character',
#   'pk': 143,
#   'fields': {'name': 'Odio obcaecati hic nostrum n',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [55, 152]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2b9'),
#   'model': 'charactercreator.character',
#   'pk': 144,
#   'fields': {'name': 'Voluptate ali',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [117]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2ba'),
#   'model': 'charactercreator.character',
#   'pk': 145,
#   'fields': {'name': 'Repudiandae vitae sapiente mol',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [25, 26, 116, 163]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2bb'),
#   'model': 'charactercreator.character',
#   'pk': 146,
#   'fields': {'name': 'Ipsam cumque',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [18, 26, 56, 106]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2bc'),
#   'model': 'charactercreator.character',
#   'pk': 147,
#   'fields': {'name': 'Fugiat quos alias eos dese',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [163]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2bd'),
#   'model': 'charactercreator.character',
#   'pk': 148,
#   'fields': {'name': 'Eaque impe',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [26, 62, 130, 147]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2be'),
#   'model': 'charactercreator.character',
#   'pk': 149,
#   'fields': {'name': 'Elige',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [121, 128, 142]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2bf'),
#   'model': 'charactercreator.character',
#   'pk': 150,
#   'fields': {'name': 'Adip',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [31, 97, 134]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2c0'),
#   'model': 'charactercreator.character',
#   'pk': 151,
#   'fields': {'name': 'Fuga nemo vel mo',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [57, 87, 153]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2c1'),
#   'model': 'charactercreator.character',
#   'pk': 152,
#   'fields': {'name': 'Libero cumque impedit eveniet',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [5, 106, 158]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2c2'),
#   'model': 'charactercreator.character',
#   'pk': 153,
#   'fields': {'name': 'Odio soluta',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [20, 54, 122, 160]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2c3'),
#   'model': 'charactercreator.character',
#   'pk': 154,
#   'fields': {'name': 'Vero nostrum duc',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [1, 27, 69]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2c4'),
#   'model': 'charactercreator.character',
#   'pk': 155,
#   'fields': {'name': 'Repellend',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [15, 79, 90, 122]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2c5'),
#   'model': 'charactercreator.character',
#   'pk': 156,
#   'fields': {'name': 'Quod',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [29, 102, 120, 130, 162]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2c6'),
#   'model': 'charactercreator.character',
#   'pk': 157,
#   'fields': {'name': 'Suscipit reiciend',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [110]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2c7'),
#   'model': 'charactercreator.character',
#   'pk': 158,
#   'fields': {'name': 'Voluptat',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [71]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2c8'),
#   'model': 'charactercreator.character',
#   'pk': 159,
#   'fields': {'name': 'Porro dolor fuga quam',
#    'level': 0,
#    'exp': 0,
#    'hp': 10,
#    'strength': 1,
#    'intelligence': 1,
#    'dexterity': 1,
#    'wisdom': 1,
#    'inventory': [40, 86, 115]}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb2c9'),
# ...
#   'model': 'armory.item',
#   'pk': 100,
#   'fields': {'name': 'Incidunt libero assumen', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb4f5'),
#   'model': 'armory.item',
#   'pk': 101,
#   'fields': {'name': 'Earum suscipit ea voluptates i',
#    'value': 0,
#    'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb4f6'),
#   'model': 'armory.item',
#   'pk': 102,
#   'fields': {'name': 'Sint dolorum', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb4f7'),
#   'model': 'armory.item',
#   'pk': 103,
#   'fields': {'name': 'Incidunt fugiat ea, ea', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb4f8'),
#   'model': 'armory.item',
#   'pk': 104,
#   'fields': {'name': 'Molestiae r', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb4f9'),
#   'model': 'armory.item',
#   'pk': 105,
#   'fields': {'name': 'Voluptatem labore laboriosa', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb4fa'),
#   'model': 'armory.item',
#   'pk': 106,
#   'fields': {'name': 'Et ducimus cumque aut perspic',
#    'value': 0,
#    'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb4fb'),
#   'model': 'armory.item',
#   'pk': 107,
#   'fields': {'name': 'Corrupti ap', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb4fc'),
#   'model': 'armory.item',
#   'pk': 108,
#   'fields': {'name': 'Perferendis nesciunt quae dolo',
#    'value': 0,
#    'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb4fd'),
#   'model': 'armory.item',
#   'pk': 109,
#   'fields': {'name': 'Sunt doloremque recusanda', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb4fe'),
#   'model': 'armory.item',
#   'pk': 110,
#   'fields': {'name': 'Deleniti similique obc', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb4ff'),
#   'model': 'armory.item',
#   'pk': 111,
#   'fields': {'name': 'Numquam tempor', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb500'),
#   'model': 'armory.item',
#   'pk': 112,
#   'fields': {'name': 'Quibusdam deleniti quasi provi',
#    'value': 0,
#    'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb501'),
#   'model': 'armory.item',
#   'pk': 113,
#   'fields': {'name': 'Accusamus exercitat', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb502'),
#   'model': 'armory.item',
#   'pk': 114,
#   'fields': {'name': 'Error eveniet ipsum, expedi', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb503'),
#   'model': 'armory.item',
#   'pk': 115,
#   'fields': {'name': 'Sapiente do', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb504'),
#   'model': 'armory.item',
#   'pk': 116,
#   'fields': {'name': 'Fuga necessitatibus', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb505'),
#   'model': 'armory.item',
#   'pk': 117,
#   'fields': {'name': 'Nam excepturi placeat asperna',
#    'value': 0,
#    'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb506'),
#   'model': 'armory.item',
#   'pk': 118,
#   'fields': {'name': 'Dolore fugit itaq', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb507'),
#   'model': 'armory.item',
#   'pk': 119,
#   'fields': {'name': 'Beatae ve', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb508'),
#   'model': 'armory.item',
#   'pk': 120,
#   'fields': {'name': 'Blanditiis corporis exerci', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb509'),
#   'model': 'armory.item',
#   'pk': 121,
#   'fields': {'name': 'Nesciunt quia nobi', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb50a'),
#   'model': 'armory.item',
#   'pk': 122,
#   'fields': {'name': 'Quisquam e', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb50b'),
#   'model': 'armory.item',
#   'pk': 123,
#   'fields': {'name': 'Illo q', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb50c'),
#   'model': 'armory.item',
#   'pk': 124,
#   'fields': {'name': 'Repellat voluptates ea,', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb50d'),
#   'model': 'armory.item',
#   'pk': 125,
#   'fields': {'name': 'Labore architecto tempora d', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb50e'),
#   'model': 'armory.item',
#   'pk': 126,
#   'fields': {'name': 'Porro impedit enim earum nam n',
#    'value': 0,
#    'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb50f'),
#   'model': 'armory.item',
#   'pk': 127,
#   'fields': {'name': 'Evenie', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb510'),
#   'model': 'armory.item',
#   'pk': 128,
#   'fields': {'name': 'Similique do', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb511'),
#   'model': 'armory.item',
#   'pk': 129,
#   'fields': {'name': 'Quos voluptates at n', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb512'),
#   'model': 'armory.item',
#   'pk': 130,
#   'fields': {'name': 'Neq', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb513'),
#   'model': 'armory.item',
#   'pk': 131,
#   'fields': {'name': 'Neq', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb514'),
#   'model': 'armory.item',
#   'pk': 132,
#   'fields': {'name': 'Optio dolore itaque', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb515'),
#   'model': 'armory.item',
#   'pk': 133,
#   'fields': {'name': 'Libero saepe accusantium', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb516'),
#   'model': 'armory.item',
#   'pk': 134,
#   'fields': {'name': 'Illum nequ', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb517'),
#   'model': 'armory.item',
#   'pk': 135,
#   'fields': {'name': 'Culpa accusantium fugit id', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb518'),
#   'model': 'armory.item',
#   'pk': 136,
#   'fields': {'name': 'Fugit pariatur vero nesciu', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb519'),
#   'model': 'armory.item',
#   'pk': 137,
#   'fields': {'name': 'Numqu', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb51a'),
#   'model': 'armory.item',
#   'pk': 138,
#   'fields': {'name': 'Corrupti sit at cum', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb51b'),
#   'model': 'armory.item',
#   'pk': 139,
#   'fields': {'name': 'Est fugit incidunt co', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb51c'),
#   'model': 'armory.item',
#   'pk': 140,
#   'fields': {'name': 'Quos nihil quibusdam', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb51d'),
#   'model': 'armory.item',
#   'pk': 141,
#   'fields': {'name': 'Sit quidem tempora doloribus r',
#    'value': 0,
#    'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb51e'),
#   'model': 'armory.item',
#   'pk': 142,
#   'fields': {'name': 'Amet vel distinctio mo', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb51f'),
#   'model': 'armory.item',
#   'pk': 143,
#   'fields': {'name': 'Illum eaque atque recusand', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb520'),
#   'model': 'armory.item',
#   'pk': 144,
#   'fields': {'name': 'Dignissi', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb521'),
#   'model': 'armory.item',
#   'pk': 145,
#   'fields': {'name': 'Corporis fug', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb522'),
#   'model': 'armory.item',
#   'pk': 146,
#   'fields': {'name': 'Sequi nesciunt', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb523'),
#   'model': 'armory.item',
#   'pk': 147,
#   'fields': {'name': 'Facere neque qu', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb524'),
#   'model': 'armory.item',
#   'pk': 148,
#   'fields': {'name': 'Corporis voluptas provi', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb525'),
#   'model': 'armory.item',
#   'pk': 149,
#   'fields': {'name': 'Repella', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb526'),
#   'model': 'armory.item',
#   'pk': 150,
#   'fields': {'name': 'Culpa cumque quo vel', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb527'),
#   'model': 'armory.item',
#   'pk': 151,
#   'fields': {'name': 'Magni totam q', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb528'),
#   'model': 'armory.item',
#   'pk': 152,
#   'fields': {'name': 'Illu', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb529'),
#   'model': 'armory.item',
#   'pk': 153,
#   'fields': {'name': 'Sit quibusdam ab, enim in ex', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb52a'),
#   'model': 'armory.item',
#   'pk': 154,
#   'fields': {'name': 'Consequuntur at earum d', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb52b'),
#   'model': 'armory.item',
#   'pk': 155,
#   'fields': {'name': 'Voluptatum doloremque to', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb52c'),
#   'model': 'armory.item',
#   'pk': 156,
#   'fields': {'name': 'Expedita nam est in l', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb52d'),
#   'model': 'armory.item',
#   'pk': 157,
#   'fields': {'name': 'Repelle', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb52e'),
#   'model': 'armory.item',
#   'pk': 158,
#   'fields': {'name': 'Sit numqu', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb52f'),
#   'model': 'armory.item',
#   'pk': 159,
#   'fields': {'name': 'Ipsum sit praesentium cum ame',
#    'value': 0,
#    'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb530'),
#   'model': 'armory.item',
#   'pk': 160,
#   'fields': {'name': 'Totam delectus sed fugiat o', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb531'),
#   'model': 'armory.item',
#   'pk': 161,
#   'fields': {'name': 'Doloremq', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb532'),
#   'model': 'armory.item',
#   'pk': 162,
#   'fields': {'name': 'Id reprehenderit ullam rat', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb533'),
#   'model': 'armory.item',
#   'pk': 163,
#   'fields': {'name': 'Dignissimos dolo', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb534'),
#   'model': 'armory.item',
#   'pk': 164,
#   'fields': {'name': 'Inventore re', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb535'),
#   'model': 'armory.item',
#   'pk': 165,
#   'fields': {'name': 'Nemo expl', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb536'),
#   'model': 'armory.item',
#   'pk': 166,
#   'fields': {'name': 'Distinctio tene', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb537'),
#   'model': 'armory.item',
#   'pk': 167,
#   'fields': {'name': 'Recusandae fug', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb538'),
#   'model': 'armory.item',
#   'pk': 168,
#   'fields': {'name': 'Officiis illo cum acc', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb539'),
#   'model': 'armory.item',
#   'pk': 169,
#   'fields': {'name': 'Repudiandae molestias be', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb53a'),
#   'model': 'armory.item',
#   'pk': 170,
#   'fields': {'name': 'Iure nob', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb53b'),
#   'model': 'armory.item',
#   'pk': 171,
#   'fields': {'name': 'Ea dolor exercitation', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb53c'),
#   'model': 'armory.item',
#   'pk': 172,
#   'fields': {'name': 'Omnis maxime deserunt', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb53d'),
#   'model': 'armory.item',
#   'pk': 173,
#   'fields': {'name': 'Eum error eveni', 'value': 0, 'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb53e'),
#   'model': 'armory.item',
#   'pk': 174,
#   'fields': {'name': 'Atque repudiandae molestiae v',
#    'value': 0,
#    'weight': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb53f'),
#   'model': 'armory.weapon',
#   'pk': 138,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb540'),
#   'model': 'armory.weapon',
#   'pk': 139,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb541'),
#   'model': 'armory.weapon',
#   'pk': 140,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb542'),
#   'model': 'armory.weapon',
#   'pk': 141,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb543'),
#   'model': 'armory.weapon',
#   'pk': 142,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb544'),
#   'model': 'armory.weapon',
#   'pk': 143,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb545'),
#   'model': 'armory.weapon',
#   'pk': 144,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb546'),
#   'model': 'armory.weapon',
#   'pk': 145,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb547'),
#   'model': 'armory.weapon',
#   'pk': 146,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb548'),
#   'model': 'armory.weapon',
#   'pk': 147,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb549'),
#   'model': 'armory.weapon',
#   'pk': 148,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb54a'),
#   'model': 'armory.weapon',
#   'pk': 149,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb54b'),
#   'model': 'armory.weapon',
#   'pk': 150,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb54c'),
#   'model': 'armory.weapon',
#   'pk': 151,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb54d'),
#   'model': 'armory.weapon',
#   'pk': 152,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb54e'),
#   'model': 'armory.weapon',
#   'pk': 153,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb54f'),
#   'model': 'armory.weapon',
#   'pk': 154,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb550'),
#   'model': 'armory.weapon',
#   'pk': 155,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb551'),
#   'model': 'armory.weapon',
#   'pk': 156,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb552'),
#   'model': 'armory.weapon',
#   'pk': 157,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb553'),
#   'model': 'armory.weapon',
#   'pk': 158,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb554'),
#   'model': 'armory.weapon',
#   'pk': 159,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb555'),
#   'model': 'armory.weapon',
#   'pk': 160,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb556'),
#   'model': 'armory.weapon',
#   'pk': 161,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb557'),
#   'model': 'armory.weapon',
#   'pk': 162,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb558'),
#   'model': 'armory.weapon',
#   'pk': 163,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb559'),
#   'model': 'armory.weapon',
#   'pk': 164,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb55a'),
#   'model': 'armory.weapon',
#   'pk': 165,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb55b'),
#   'model': 'armory.weapon',
#   'pk': 166,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb55c'),
#   'model': 'armory.weapon',
#   'pk': 167,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb55d'),
#   'model': 'armory.weapon',
#   'pk': 168,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb55e'),
#   'model': 'armory.weapon',
#   'pk': 169,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb55f'),
#   'model': 'armory.weapon',
#   'pk': 170,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb560'),
#   'model': 'armory.weapon',
#   'pk': 171,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb561'),
#   'model': 'armory.weapon',
#   'pk': 172,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb562'),
#   'model': 'armory.weapon',
#   'pk': 173,
#   'fields': {'power': 0}},
#  {'_id': ObjectId('5e3a4c29c98a7a56d68eb563'),
#   'model': 'armory.weapon',
#   'pk': 174,
#   'fields': {'power': 0}}]
