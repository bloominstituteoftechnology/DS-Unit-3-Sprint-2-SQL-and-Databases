# %%
# !curl ipecho.net/plain
# Out:
# 75.39.26.83

# %%
import pymongo

# %%
dir(pymongo)
# Out:
# ['ALL',
#  'ASCENDING',
#  'CursorType',
#  'DESCENDING',
#  'DeleteMany',
#  'DeleteOne',
#  'GEO2D',
#  'GEOHAYSTACK',
#  'GEOSPHERE',
#  'HASHED',
#  'IndexModel',
#  'InsertOne',
#  'MAX_SUPPORTED_WIRE_VERSION',
#  'MIN_SUPPORTED_WIRE_VERSION',
#  'MongoClient',
#  'MongoReplicaSetClient',
#  'OFF',
#  'ReadPreference',
#  'ReplaceOne',
#  'ReturnDocument',
#  'SLOW_ONLY',
#  'TEXT',
#  'UpdateMany',
#  'UpdateOne',
#  'WriteConcern',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_cmessage',
#  'auth',
#  'bulk',
#  'change_stream',
#  'client_options',
#  'client_session',
#  'collation',
#  'collection',
#  'command_cursor',
#  'common',
#  'compression_support',
#  'cursor',
#  'cursor_manager',
#  'database',
#  'driver_info',
#  'errors',
#  'get_version_string',
#  'has_c',
#  'helpers',
#  'ismaster',
#  'max_staleness_selectors',
#  'message',
# ...

# %%
client = pymongo.MongoClient("mongodb://jayson:happy@cluster0-shard-00-00-3bwmt.mongodb.net:27017,cluster0-shard-00-01-3bwmt.mongodb.net:27017,cluster0-shard-00-02-3bwmt.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.test

# %%
db
# Out:
# Database(MongoClient(host=['cluster0-shard-00-02-3bwmt.mongodb.net:27017', 'cluster0-shard-00-01-3bwmt.mongodb.net:27017', 'cluster0-shard-00-00-3bwmt.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='Cluster0-shard-0', authsource='admin', retrywrites=True, w='majority'), 'test')

# %%
client.nodes
# Out:
# frozenset({('cluster0-shard-00-00-3bwmt.mongodb.net', 27017),
#            ('cluster0-shard-00-01-3bwmt.mongodb.net', 27017),
#            ('cluster0-shard-00-02-3bwmt.mongodb.net', 27017)})

# %%
dir(db.test)
# Out:
# ['_BaseObject__codec_options',
#  '_BaseObject__read_concern',
#  '_BaseObject__read_preference',
#  '_BaseObject__write_concern',
#  '_Collection__create',
#  '_Collection__create_index',
#  '_Collection__database',
#  '_Collection__find_and_modify',
#  '_Collection__full_name',
#  '_Collection__name',
#  '_Collection__write_response_codec_options',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_aggregate',
#  '_aggregate_one_result',
#  '_command',
#  '_count',
#  '_delete',
#  '_delete_retryable',
#  '_insert',
# ...

# %%
db.test.count_documents({'x':1})
# Out:
# 0

# %%
db.test.insert_one({'x':1})

# %%
db.test.count_documents({'x':1})
# Out:
# 1

# %%
jason_doc = {
    'fav animal': ['Sharks', 'Cats']
}

matthew_doc = {
    'fav animal': 'Platypus'
}

nick_doc = {
    'fav animal': 'Hippogriggs'
}

# %%
db.test.insert_many([jason_doc, matthew_doc, nick_doc])

# %%
list(db.test.find())
# Out:
# [{'_id': ObjectId('5d792f31cac3c1c030885f7e'), 'x': 1},
#  {'_id': ObjectId('5d79304bcac3c1c030885f7f'),
#   'fav animal': ['Sharks', 'Cats']},
#  {'_id': ObjectId('5d79304bcac3c1c030885f80'), 'fav animal': 'Platypus'},
#  {'_id': ObjectId('5d79304bcac3c1c030885f81'), 'fav animal': 'Hippogriggs'}]

# %%
more_docs = []
for i in range(10):
    doc = {'even': i % 2 == 0}
    doc['value'] = i
    more_docs.append(doc)

# %%
more_docs
# Out:
# [{'even': True, 'value': 0},
#  {'even': False, 'value': 1},
#  {'even': True, 'value': 2},
#  {'even': False, 'value': 3},
#  {'even': True, 'value': 4},
#  {'even': False, 'value': 5},
#  {'even': True, 'value': 6},
#  {'even': False, 'value': 7},
#  {'even': True, 'value': 8},
#  {'even': False, 'value': 9}]

# %%
db.test.insert_many(more_docs)

# %%
list(db.test.find())
# Out:
# [{'_id': ObjectId('5d792f31cac3c1c030885f7e'), 'x': 1},
#  {'_id': ObjectId('5d79304bcac3c1c030885f7f'),
#   'fav animal': ['Sharks', 'Cats']},
#  {'_id': ObjectId('5d79304bcac3c1c030885f80'), 'fav animal': 'Platypus'},
#  {'_id': ObjectId('5d79304bcac3c1c030885f81'), 'fav animal': 'Hippogriggs'},
#  {'_id': ObjectId('5d7930f1cac3c1c030885f82'), 'even': True, 'value': 0},
#  {'_id': ObjectId('5d7930f1cac3c1c030885f83'), 'even': False, 'value': 1},
#  {'_id': ObjectId('5d7930f1cac3c1c030885f84'), 'even': True, 'value': 2},
#  {'_id': ObjectId('5d7930f1cac3c1c030885f85'), 'even': False, 'value': 3},
#  {'_id': ObjectId('5d7930f1cac3c1c030885f86'), 'even': True, 'value': 4},
#  {'_id': ObjectId('5d7930f1cac3c1c030885f87'), 'even': False, 'value': 5},
#  {'_id': ObjectId('5d7930f1cac3c1c030885f88'), 'even': True, 'value': 6},
#  {'_id': ObjectId('5d7930f1cac3c1c030885f89'), 'even': False, 'value': 7},
#  {'_id': ObjectId('5d7930f1cac3c1c030885f8a'), 'even': True, 'value': 8},
# ...

# %%
list(db.test.find({'even': False}))
# Out:
# [{'_id': ObjectId('5d7930f1cac3c1c030885f83'), 'even': False, 'value': 1},
#  {'_id': ObjectId('5d7930f1cac3c1c030885f85'), 'even': False, 'value': 3},
#  {'_id': ObjectId('5d7930f1cac3c1c030885f87'), 'even': False, 'value': 5},
#  {'_id': ObjectId('5d7930f1cac3c1c030885f89'), 'even': False, 'value': 7},
#  {'_id': ObjectId('5d7930f1cac3c1c030885f8b'), 'even': False, 'value': 9}]

# %%
list(db.test.find({'fav animal': 'Platypus'}))
# Out:
# [{'_id': ObjectId('5d79304bcac3c1c030885f80'), 'fav animal': 'Platypus'}]

# %%
help(db.test.update_one)
# Out:
# Help on method update_one in module pymongo.collection:
#
# update_one(filter, update, upsert=False, bypass_document_validation=False, collation=None, array_filters=None, session=None) method of pymongo.collection.Collection instance
#     Update a single document matching the filter.
#
#       >>> for doc in db.test.find():
#       ...     print(doc)
#       ...
#       {u'x': 1, u'_id': 0}
#       {u'x': 1, u'_id': 1}
#       {u'x': 1, u'_id': 2}
#       >>> result = db.test.update_one({'x': 1}, {'$inc': {'x': 3}})
#       >>> result.matched_count
#       1
#       >>> result.modified_count
#       1
#       >>> for doc in db.test.find():
#       ...     print(doc)
#       ...
#       {u'x': 4, u'_id': 0}
#       {u'x': 1, u'_id': 1}
#       {u'x': 1, u'_id': 2}
#
#     :Parameters:
#       - `filter`: A query that matches the document to update.
#       - `update`: The modifications to apply.
#       - `upsert` (optional): If ``True``, perform an insert if no documents
# ...

# %%
help(db)
# Out:
# Help on Database in module pymongo.database object:
#
# class Database(pymongo.common.BaseObject)
#  |  Database(client, name, codec_options=None, read_preference=None, write_concern=None, read_concern=None)
#  |
#  |  A Mongo database.
#  |
#  |  Method resolution order:
#  |      Database
#  |      pymongo.common.BaseObject
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __call__(self, *args, **kwargs)
#  |      This is only here so that some API misusages are easier to debug.
#  |
#  |  __eq__(self, other)
#  |      Return self==value.
#  |
#  |  __getattr__(self, name)
#  |      Get a collection of this database by name.
#  |
#  |      Raises InvalidName if an invalid collection name is used.
#  |
#  |      :Parameters:
#  |        - `name`: the name of the collection to get
#  |
#  |  __getitem__(self, name)
#  |      Get a collection of this database by name.
#  |
#  |      Raises InvalidName if an invalid collection name is used.
#  |
# ...

# %%
import sqlite3

# %%
sl_conn = sqlite3.connect('')
