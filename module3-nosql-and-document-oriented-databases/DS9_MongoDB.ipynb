# %%
# !curl ipecho.net/plain
# Out:
# 35.190.145.151

# %% [markdown]
# username: admin
#
# password: kIiLjnHdxnppUmuY

# %%
# !pip install pymongo
import pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (3.9.0)

# %%
client = pymongo.MongoClient("mongodb://admin:kIiLjnHdxnppUmuY@cluster0-shard-00-00-qlfha.mongodb.net:27017,cluster0-shard-00-01-qlfha.mongodb.net:27017,cluster0-shard-00-02-qlfha.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.test

# %%
help(db)

# %%
client.nodes
# Out:
# frozenset({('cluster0-shard-00-00-qlfha.mongodb.net', 27017),
#            ('cluster0-shard-00-01-qlfha.mongodb.net', 27017),
#            ('cluster0-shard-00-02-qlfha.mongodb.net', 27017)})

# %%
dir(db.test)

# %%
help(db.test.insert_one)

# %%
#insert a document
db.test.insert_one({'x':1})

# %%
#count how many documents
db.test.count_documents({'x':1})
# Out:
# 2

# %%
#looking for a document
db.test.find({'x':1})

# %%
curs = db.test.find({'x':1})

# %%
dir(curs)

# %%
list(curs)
# Out:
# [{'_id': ObjectId('5df133a1f30efdd699b2d3ee'), 'x': 1},
#  {'_id': ObjectId('5df133d2f30efdd699b2d3ef'), 'x': 1}]

# %%
stephanie_doc = {
    'favorite animal': 'alpaca',
    'favorite color': 'blue'
}

zoli_michelle_doc = {
    'favorite animal': ['Black Panther', 'Unicorn']
}

dorothy_doc = {
    'favorite animal': 'dog'
}

# %%
db.test.insert_many([stephanie_doc, zoli_michelle_doc, dorothy_doc])

# %%
#LOOK AT ALL DOCUMENTS
list(db.test.find())
# Out:
# [{'_id': ObjectId('5df133a1f30efdd699b2d3ee'), 'x': 1},
#  {'_id': ObjectId('5df133d2f30efdd699b2d3ef'), 'x': 1},
#  {'_id': ObjectId('5df13576f30efdd699b2d3f0'),
#   'favorite animal': 'alpaca',
#   'favorite color': 'blue'},
#  {'_id': ObjectId('5df13576f30efdd699b2d3f1'),
#   'favorite animal': ['Black Panther', 'Unicorn']},
#  {'_id': ObjectId('5df13576f30efdd699b2d3f2'), 'favorite animal': 'dog'}]

# %%
#make more docs
more_docs = []
for i in range(10):
  doc = {'even': i % 2 == 0}
  doc['value'] = i 
  more_docs.append(doc)

more_docs
# Out:
# [{'even': True, 'value': 0},
#  {'even': False, 'value': 1},
#  {'even': True, 'value': 2},
#  {'even': False, 'value': 3},
#  {'even': True, 'value': 4},
#  {'even': False, 'value': 5},
#  {'even': True, 'value': 6},
#  {'even': False, 'value': 7},
#  {'even': True, 'value': 8},
#  {'even': False, 'value': 9}]

# %%
db.test.insert_many(more_docs)

# %%
list(db.test.find({'even':False}))
# Out:
# [{'_id': ObjectId('5df1374ff30efdd699b2d3f4'), 'even': False, 'value': 1},
#  {'_id': ObjectId('5df1374ff30efdd699b2d3f6'), 'even': False, 'value': 3},
#  {'_id': ObjectId('5df1374ff30efdd699b2d3f8'), 'even': False, 'value': 5},
#  {'_id': ObjectId('5df1374ff30efdd699b2d3fa'), 'even': False, 'value': 7},
#  {'_id': ObjectId('5df1374ff30efdd699b2d3fc'), 'even': False, 'value': 9}]

# %%
db.test.update_one({'value':3},
                   {'$inc': {'value':5}})

# %%
list(db.test.find())

# %%
db.test.update_many({'even':True},
                    {'$inc': {'value':100}})

# %%
list(db.test.find())

# %%
db.test.delete_many({'even':False})

# %%
list(db.test.find())
# Out:
# [{'_id': ObjectId('5df133a1f30efdd699b2d3ee'), 'x': 1},
#  {'_id': ObjectId('5df133d2f30efdd699b2d3ef'), 'x': 1},
#  {'_id': ObjectId('5df13576f30efdd699b2d3f0'),
#   'favorite animal': 'alpaca',
#   'favorite color': 'blue'},
#  {'_id': ObjectId('5df13576f30efdd699b2d3f1'),
#   'favorite animal': ['Black Panther', 'Unicorn']},
#  {'_id': ObjectId('5df13576f30efdd699b2d3f2'), 'favorite animal': 'dog'},
#  {'_id': ObjectId('5df1374ff30efdd699b2d3f3'), 'even': True, 'value': 100},
#  {'_id': ObjectId('5df1374ff30efdd699b2d3f5'), 'even': True, 'value': 102},
#  {'_id': ObjectId('5df1374ff30efdd699b2d3f7'), 'even': True, 'value': 104},
#  {'_id': ObjectId('5df1374ff30efdd699b2d3f9'), 'even': True, 'value': 106},
#  {'_id': ObjectId('5df1374ff30efdd699b2d3fb'), 'even': True, 'value': 108}]

# %%
rpg_character = (1, "King Bob", 10, 3, 0, 0, 0)
#you would get error if you did db.test.insert_one(rpg_character)

# %%
#here is how to cast to dictionary
db.test.insert_one({'rpg_character': rpg_character})

# %%
db.test.insert_one({
    'sql_id': rpg_character[0],
    'name': rpg_character[1],
    'hp': rpg_character[2],
    'level': rpg_character[3]
})

# %%
list(db.test.find())
# Out:
# [{'_id': ObjectId('5df133a1f30efdd699b2d3ee'), 'x': 1},
#  {'_id': ObjectId('5df133d2f30efdd699b2d3ef'), 'x': 1},
#  {'_id': ObjectId('5df13576f30efdd699b2d3f0'),
#   'favorite animal': 'alpaca',
#   'favorite color': 'blue'},
#  {'_id': ObjectId('5df13576f30efdd699b2d3f1'),
#   'favorite animal': ['Black Panther', 'Unicorn']},
#  {'_id': ObjectId('5df13576f30efdd699b2d3f2'), 'favorite animal': 'dog'},
#  {'_id': ObjectId('5df1374ff30efdd699b2d3f3'), 'even': True, 'value': 100},
#  {'_id': ObjectId('5df1374ff30efdd699b2d3f5'), 'even': True, 'value': 102},
#  {'_id': ObjectId('5df1374ff30efdd699b2d3f7'), 'even': True, 'value': 104},
#  {'_id': ObjectId('5df1374ff30efdd699b2d3f9'), 'even': True, 'value': 106},
#  {'_id': ObjectId('5df1374ff30efdd699b2d3fb'), 'even': True, 'value': 108},
#  {'_id': ObjectId('5df13894f30efdd699b2d3fd'),
#   'rpg_character': [1, 'King Bob', 10, 3, 0, 0, 0]},
#  {'_id': ObjectId('5df138d5f30efdd699b2d3fe'),
#   'hp': 10,
#   'level': 3,
#   'name': 'King Bob',
#   'sql_id': 1}]
