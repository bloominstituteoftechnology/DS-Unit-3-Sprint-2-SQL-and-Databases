# %% [markdown]
# # ElephantSQL with PostgresSQL2
#
# This notebook is some cursory notes on setting up Databases and creating tables. It is using an environment where the pymongo and psycopg2 are installed.

# %% [markdown]
# ## Connecting

# %%
# First I'll be working with a relational database. 
# It is hosted by ElephantSQL
## I'll be using PostgreSQL2
## http://initd.org/psycopg/

import psycopg2

# %%
dir(psycopg2)
# Out:
# ['BINARY',
#  'Binary',
#  'DATETIME',
#  'DataError',
#  'DatabaseError',
#  'Date',
#  'DateFromTicks',
#  'Error',
#  'IntegrityError',
#  'InterfaceError',
#  'InternalError',
#  'NUMBER',
#  'NotSupportedError',
#  'OperationalError',
#  'ProgrammingError',
#  'ROWID',
#  'STRING',
#  'Time',
#  'TimeFromTicks',
#  'Timestamp',
#  'TimestampFromTicks',
#  'Warning',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__libpq_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_connect',
#  '_ext',
#  '_json',
#  '_psycopg',
#  '_range',
#  'apilevel',
#  'connect',
#  'extensions',
#  'paramstyle',
#  'threadsafety',
#  'tz']

# %% [markdown]
# The method I am looking for is "connect".

# %%
help(psycopg2.connect)
# Out:
# Help on function connect in module psycopg2:
#
# connect(dsn=None, connection_factory=None, cursor_factory=None, **kwargs)
#     Create a new database connection.
#
#     The connection parameters can be specified as a string:
#
#         conn = psycopg2.connect("dbname=test user=postgres password=secret")
#
#     or using a set of keyword arguments:
#
#         conn = psycopg2.connect(database="test", user="postgres", password="secret")
#
#     Or as a mix of both. The basic connection parameters are:
#
#     - *dbname*: the database name
#     - *database*: the database name (only as keyword argument)
#     - *user*: user name used to authenticate
#     - *password*: password used to authenticate
#     - *host*: database host address (defaults to UNIX socket if not provided)
#     - *port*: connection port number (defaults to 5432 if not provided)
#
#     Using the *connection_factory* parameter a different class or connections
#     factory can be specified. It should be a callable object taking a dsn
#     argument.
#
#     Using the *cursor_factory* parameter, a new default cursor factory will be
#     used by cursor().
#
#     Using *async*=True an asynchronous connection will be created. *async_* is
#     a valid alias (for Python versions where ``async`` is a keyword).
#
#     Any other keyword parameter will be passed to the underlying client
#     library: the list of supported parameters depends on the library version.

# %% [markdown]
# This is great info. The specific information I need is :
#
#      The connection parameters can be specified as a string:
#      conn = psycopg2.connect("dbname=test user=postgres password=secret")
#
#  Where the parameters are:
#
#     - *dbname*: the database name
#     - *database*: the database name (only as keyword argument)
#     - *user*: user name used to authenticate
#     - *password*: password used to authenticate
#     - *host*: database host address (defaults to UNIX socket if not provided)
#     - *port*: connection port number (defaults to 5432 if not provided)
#
# For the current playground database, I don;t need *database* and *port*

# %%
# Establishing Parameters
dbname = 'ckdaorek'
user = 'ckdaorek'
password = '******'   # Changed so you can't see my password. 
host = 'raja.db.elephantsql.com'

# %%
# Creating a connection to my database
pg_conn = psycopg2.connect(dbname=dbname, user=user,
                           password=password, host=host)

# %%
# Connection cretes a connection object containing my paremeters
pg_conn
# Out:
# <connection object at 0x10eac17f8; dsn: 'user=ckdaorek password=xxx dbname=ckdaorek host=raja.db.elephantsql.com', closed: 0>

# %%
# Creating my cursor
pg_curs = pg_conn.cursor()

# %% [markdown]
# ## Create a Table on ElephantSQL from rpg_db
# Now I am going to use **sqlite** to import the **rpg_db** and upload it to the connected database.

# %%
import sqlite3

# I'm using a s1 connection and cursor so I don't overlap databases and libraries. 
sl_conn = sqlite3.connect('/Users/azel/Documents/GitHub/DS-Unit-3-Sprint-2-SQL-and-Databases/module1-introduction-to-sql/rpg_db.sqlite3')
sl_curs = sl_conn.cursor()

# %%
# Quick test to make sure its working and the database is populated. 
sl_curs.execute('SELECT COUNT(*) FROM charactercreator_character;').fetchall()
# Out:
# [(302,)]

# %%
# Each row is represented as a tuple. Those tuples can be accessed by an integer index. 
characters = sl_curs.execute('SELECT * FROM charactercreator_character;').fetchall()
characters [0]
# Out:
# (1, 'Aliquid iste optio reiciendi', 0, 0, 10, 1, 1, 1, 1)

# %%
# Each part of the tuple can be indexed as well. 
characters [0][1]
# Out:
# 'Aliquid iste optio reiciendi'

# %% [markdown]
# So to create a table on my Relational database, I need to provide the columns and their datatypes. This metadata will match up with the indices of each row-tuple. This is the information provided with the rpg_db:
#
# ```python
# class Character(models.Model):
#     """Base representation of RPG characters."""
#     character_id = models.AutoField(primary_key=True)
#     name = models.CharField("Character's name", max_length=30)
#     level = models.IntegerField(default=0)
#     exp = models.IntegerField(default=0)
#     hp = models.IntegerField(default=10)
#     strength = models.IntegerField(default=1)
#     intelligence = models.IntegerField(default=1)
#     dexterity = models.IntegerField(default=1)
#     wisdom = models.IntegerField(default=1)
# ```
#
# With this, I can create a table in the database with these columns and the required datatype.

# %%
create_character_table = """
CREATE TABLE charactercreator_character (
  character_id SERIAL PRIMARY KEY,
  name VARCHAR(30),
  level INT,
  exp INT,
  hp INT,
  strength INT,
  intelligence INT,
  dexterity INT,
  wisdom INT
)
"""

# %%
pg_conn.commit()

# %%
pg_curs.execute(create_character_table)

# %%
attempted_insert = """
  INSERT INTO charactercreator_character
  VALUES """ + str(characters[0])
attempted_insert
# Out:
# "\n  INSERT INTO charactercreator_character\n  VALUES (1, 'Aliquid iste optio reiciendi', 0, 0, 10, 1, 1, 1, 1)"

# %%
pg_curs.execute(attempted_insert)

# %%
pg_conn.commit()  # We need to "save" our work for the new table/data to show up

# %%
pg_curs = pg_conn.cursor()
pg_curs.execute('SELECT * FROM charactercreator_character;')
pg_characters = pg_curs.fetchall()
pg_characters[0]
# Out:
# (1, 'Aliquid iste optio reiciendi', 0, 0, 10, 1, 1, 1, 1)

# %% [markdown]
# Ok, that works! I am going to insert the remaining characters into the database.

# %%
# Let's insert the rest of the characters!
for character in characters[1:]:
  insert_character = """
  INSERT INTO charactercreator_character
  VALUES """ + str(character)
  pg_curs.execute(insert_character)
pg_conn.commit()

# %%
pg_curs = pg_conn.cursor()
pg_curs.execute('SELECT * FROM charactercreator_character;')
pg_characters = pg_curs.fetchall()

# %%
len(pg_characters)
# Out:
# 302

# %%
pg_characters[0]
# Out:
# (1, 'Aliquid iste optio reiciendi', 0, 0, 10, 1, 1, 1, 1)

# %%
for character, pg_character in zip(characters, pg_characters):
  assert character == pg_character

# %% [markdown]
# Nothing happened! That's a good thing since the `assert` function will return an error if the statement is not `True`.
#
# This is how to push a create a relational database in the cloud. The next step is to take a csv and move it up as well.

# %% [markdown]
# ## Titanic Dataset to ElephantSQL

# %%
import pandas as pd
df = pd.read_csv('/Users/azel/Documents/GitHub/DS-Unit-3-Sprint-2-SQL-and-Databases/module2-sql-for-analysis/titanic.csv')

# %% [markdown]
# # MongoDB with PyMongo
#
# LSDS Unit 3 Sprint 2 Module 3
#
# Some resources:
#
# https://docs.atlas.mongodb.com/getting-started/
#
# https://api.mongodb.com/python/current/
#
# HN Discussion on MongoDB versus PostgreSQL/SQLite: https://news.ycombinator.com/item?id=19158854

# %% [markdown]
# ## Connecting

# %%
import pymongo

# %% [markdown]
# For some reason, pymongo was throwing an error when I used the link designed for Python 3.6. It seems the link designed for Python 3.4 works better.

# %%
# Password removed before committing. 
client = pymongo.MongoClient("mongodb://admin:<password>@cluster0-shard-00-00-l0vzq.mongodb.net:27017,cluster0-shard-00-01-l0vzq.mongodb.net:27017,cluster0-shard-00-02-l0vzq.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.test

# %%
print('DB info: \n',db, '\n\n')
print('My nodes: \n', client.nodes)
# Out:
# DB info:
#  Database(MongoClient(host=['cluster0-shard-00-01-l0vzq.mongodb.net:27017', 'cluster0-shard-00-02-l0vzq.mongodb.net:27017', 'cluster0-shard-00-00-l0vzq.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='Cluster0-shard-0', authsource='admin', retrywrites=True, w='majority'), 'test')
#
#
# My nodes:
#  frozenset({('cluster0-shard-00-01-l0vzq.mongodb.net', 27017), ('cluster0-shard-00-02-l0vzq.mongodb.net', 27017), ('cluster0-shard-00-00-l0vzq.mongodb.net', 27017)})

# %% [markdown]
# I'm connected and have 3 nodes available. Time to start adding data.

# %% [markdown]
# ## Add Data to a MongoDB Database

# %%
# I want to see what I can do. 
help(db)
# Out:
# Help on Database in module pymongo.database object:
#
# class Database(pymongo.common.BaseObject)
#  |  Database(client, name, codec_options=None, read_preference=None, write_concern=None, read_concern=None)
#  |
#  |  A Mongo database.
#  |
#  |  Method resolution order:
#  |      Database
#  |      pymongo.common.BaseObject
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __call__(self, *args, **kwargs)
#  |      This is only here so that some API misusages are easier to debug.
#  |
#  |  __eq__(self, other)
#  |      Return self==value.
#  |
#  |  __getattr__(self, name)
#  |      Get a collection of this database by name.
#  |
#  |      Raises InvalidName if an invalid collection name is used.
#  |
#  |      :Parameters:
#  |        - `name`: the name of the collection to get
#  |
#  |  __getitem__(self, name)
#  |      Get a collection of this database by name.
#  |
#  |      Raises InvalidName if an invalid collection name is used.
#  |
#  |      :Parameters:
#  |        - `name`: the name of the collection to get
#  |
#  |  __init__(self, client, name, codec_options=None, read_preference=None, write_concern=None, read_concern=None)
#  |      Get a database by client and name.
#  |
#  |      Raises :class:`TypeError` if `name` is not an instance of
#  |      :class:`basestring` (:class:`str` in python 3). Raises
#  |      :class:`~pymongo.errors.InvalidName` if `name` is not a valid
#  |      database name.
#  |
#  |      :Parameters:
#  |        - `client`: A :class:`~pymongo.mongo_client.MongoClient` instance.
#  |        - `name`: The database name.
#  |        - `codec_options` (optional): An instance of
#  |          :class:`~bson.codec_options.CodecOptions`. If ``None`` (the
#  |          default) client.codec_options is used.
#  |        - `read_preference` (optional): The read preference to use. If
#  |          ``None`` (the default) client.read_preference is used.
#  |        - `write_concern` (optional): An instance of
#  |          :class:`~pymongo.write_concern.WriteConcern`. If ``None`` (the
#  |          default) client.write_concern is used.
#  |        - `read_concern` (optional): An instance of
#  |          :class:`~pymongo.read_concern.ReadConcern`. If ``None`` (the
#  |          default) client.read_concern is used.
#  |
#  |      .. mongodoc:: databases
#  |
#  |      .. versionchanged:: 3.2
#  |         Added the read_concern option.
#  |
#  |      .. versionchanged:: 3.0
#  |         Added the codec_options, read_preference, and write_concern options.
#  |         :class:`~pymongo.database.Database` no longer returns an instance
#  |         of :class:`~pymongo.collection.Collection` for attribute names
#  |         with leading underscores. You must use dict-style lookups instead::
#  |
#  |             db['__my_collection__']
#  |
#  |         Not:
#  |
#  |             db.__my_collection__
#  |
#  |  __iter__(self)
#  |
#  |  __ne__(self, other)
#  |      Return self!=value.
#  |
#  |  __next__(self)
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  add_son_manipulator(self, manipulator)
#  |      Add a new son manipulator to this database.
#  |
#  |      **DEPRECATED** - `add_son_manipulator` is deprecated.
#  |
#  |      .. versionchanged:: 3.0
#  |        Deprecated add_son_manipulator.
#  |
#  |  add_user(self, name, password=None, read_only=None, session=None, **kwargs)
#  |      **DEPRECATED**: Create user `name` with password `password`.
#  |
#  |      Add a new user with permissions for this :class:`Database`.
#  |
#  |      .. note:: Will change the password if user `name` already exists.
#  |
#  |      .. note:: add_user is deprecated and will be removed in PyMongo
#  |        4.0. Starting with MongoDB 2.6 user management is handled with four
#  |        database commands, createUser_, usersInfo_, updateUser_, and
#  |        dropUser_.
#  |
#  |        To create a user::
#  |
#  |          db.command("createUser", "admin", pwd="password", roles=["root"])
#  |
#  |        To create a read-only user::
#  |
#  |          db.command("createUser", "user", pwd="password", roles=["read"])
#  |
#  |        To change a password::
#  |
#  |          db.command("updateUser", "user", pwd="newpassword")
#  |
#  |        Or change roles::
#  |
#  |          db.command("updateUser", "user", roles=["readWrite"])
#  |
#  |      .. _createUser: https://docs.mongodb.com/manual/reference/command/createUser/
#  |      .. _usersInfo: https://docs.mongodb.com/manual/reference/command/usersInfo/
#  |      .. _updateUser: https://docs.mongodb.com/manual/reference/command/updateUser/
#  |      .. _dropUser: https://docs.mongodb.com/manual/reference/command/createUser/
#  |
#  |      .. warning:: Never create or modify users over an insecure network without
#  |        the use of TLS. See :doc:`/examples/tls` for more information.
#  |
#  |      :Parameters:
#  |        - `name`: the name of the user to create
#  |        - `password` (optional): the password of the user to create. Can not
#  |          be used with the ``userSource`` argument.
#  |        - `read_only` (optional): if ``True`` the user will be read only
#  |        - `**kwargs` (optional): optional fields for the user document
#  |          (e.g. ``userSource``, ``otherDBRoles``, or ``roles``). See
#  |          `<http://docs.mongodb.org/manual/reference/privilege-documents>`_
#  |          for more information.
#  |        - `session` (optional): a
#  |          :class:`~pymongo.client_session.ClientSession`.
#  |
#  |      .. versionchanged:: 3.7
#  |         Added support for SCRAM-SHA-256 users with MongoDB 4.0 and later.
#  |
#  |      .. versionchanged:: 3.6
#  |         Added ``session`` parameter. Deprecated add_user.
#  |
#  |      .. versionchanged:: 2.5
#  |         Added kwargs support for optional fields introduced in MongoDB 2.4
#  |
#  |      .. versionchanged:: 2.2
#  |         Added support for read only users
#  |
#  |  authenticate(self, name=None, password=None, source=None, mechanism='DEFAULT', **kwargs)
#  |      **DEPRECATED**: Authenticate to use this database.
#  |
#  |      .. warning:: Starting in MongoDB 3.6, calling :meth:`authenticate`
#  |        invalidates all existing cursors. It may also leave logical sessions
#  |        open on the server for up to 30 minutes until they time out.
#  |
#  |      Authentication lasts for the life of the underlying client
#  |      instance, or until :meth:`logout` is called.
#  |
#  |      Raises :class:`TypeError` if (required) `name`, (optional) `password`,
#  |      or (optional) `source` is not an instance of :class:`basestring`
#  |      (:class:`str` in python 3).
#  |
#  |      .. note::
#  |        - This method authenticates the current connection, and
#  |          will also cause all new :class:`~socket.socket` connections
#  |          in the underlying client instance to be authenticated automatically.
#  |
#  |        - Authenticating more than once on the same database with different
#  |          credentials is not supported. You must call :meth:`logout` before
#  |          authenticating with new credentials.
#  |
#  |        - When sharing a client instance between multiple threads, all
#  |          threads will share the authentication. If you need different
#  |          authentication profiles for different purposes you must use
#  |          distinct client instances.
#  |
#  |      :Parameters:
#  |        - `name`: the name of the user to authenticate. Optional when
#  |          `mechanism` is MONGODB-X509 and the MongoDB server version is
#  |          >= 3.4.
#  |        - `password` (optional): the password of the user to authenticate.
#  |          Not used with GSSAPI or MONGODB-X509 authentication.
#  |        - `source` (optional): the database to authenticate on. If not
#  |          specified the current database is used.
#  |        - `mechanism` (optional): See :data:`~pymongo.auth.MECHANISMS` for
#  |          options. If no mechanism is specified, PyMongo automatically uses
#  |          MONGODB-CR when connected to a pre-3.0 version of MongoDB,
#  |          SCRAM-SHA-1 when connected to MongoDB 3.0 through 3.6, and
#  |          negotiates the mechanism to use (SCRAM-SHA-1 or SCRAM-SHA-256) when
#  |          connected to MongoDB 4.0+.
#  |        - `authMechanismProperties` (optional): Used to specify
#  |          authentication mechanism specific options. To specify the service
#  |          name for GSSAPI authentication pass
#  |          authMechanismProperties='SERVICE_NAME:<service name>'
#  |
#  |      .. versionchanged:: 3.7
#  |         Added support for SCRAM-SHA-256 with MongoDB 4.0 and later.
#  |
#  |      .. versionchanged:: 3.5
#  |         Deprecated. Authenticating multiple users conflicts with support for
#  |         logical sessions in MongoDB 3.6. To authenticate as multiple users,
#  |         create multiple instances of MongoClient.
#  |
#  |      .. versionadded:: 2.8
#  |         Use SCRAM-SHA-1 with MongoDB 3.0 and later.
#  |
#  |      .. versionchanged:: 2.5
#  |         Added the `source` and `mechanism` parameters. :meth:`authenticate`
#  |         now raises a subclass of :class:`~pymongo.errors.PyMongoError` if
#  |         authentication fails due to invalid credentials or configuration
#  |         issues.
#  |
#  |      .. mongodoc:: authenticate
#  |
#  |  collection_names(self, include_system_collections=True, session=None)
#  |      **DEPRECATED**: Get a list of all the collection names in this
#  |      database.
#  |
#  |      :Parameters:
#  |        - `include_system_collections` (optional): if ``False`` list
#  |          will not include system collections (e.g ``system.indexes``)
#  |        - `session` (optional): a
#  |          :class:`~pymongo.client_session.ClientSession`.
#  |
#  |      .. versionchanged:: 3.7
#  |         Deprecated. Use :meth:`list_collection_names` instead.
#  |
#  |      .. versionchanged:: 3.6
#  |         Added ``session`` parameter.
#  |
#  |  command(self, command, value=1, check=True, allowable_errors=None, read_preference=None, codec_options=CodecOptions(document_class=dict, tz_aware=False, uuid_representation=PYTHON_LEGACY, unicode_decode_error_handler='strict', tzinfo=None), session=None, **kwargs)
#  |      Issue a MongoDB command.
#  |
#  |      Send command `command` to the database and return the
#  |      response. If `command` is an instance of :class:`basestring`
#  |      (:class:`str` in python 3) then the command {`command`: `value`}
#  |      will be sent. Otherwise, `command` must be an instance of
#  |      :class:`dict` and will be sent as is.
#  |
#  |      Any additional keyword arguments will be added to the final
#  |      command document before it is sent.
#  |
#  |      For example, a command like ``{buildinfo: 1}`` can be sent
#  |      using:
#  |
#  |      >>> db.command("buildinfo")
#  |
#  |      For a command where the value matters, like ``{collstats:
#  |      collection_name}`` we can do:
#  |
#  |      >>> db.command("collstats", collection_name)
#  |
#  |      For commands that take additional arguments we can use
#  |      kwargs. So ``{filemd5: object_id, root: file_root}`` becomes:
#  |
#  |      >>> db.command("filemd5", object_id, root=file_root)
#  |
#  |      :Parameters:
#  |        - `command`: document representing the command to be issued,
#  |          or the name of the command (for simple commands only).
#  |
#  |          .. note:: the order of keys in the `command` document is
#  |             significant (the "verb" must come first), so commands
#  |             which require multiple keys (e.g. `findandmodify`)
#  |             should use an instance of :class:`~bson.son.SON` or
#  |             a string and kwargs instead of a Python `dict`.
#  |
#  |        - `value` (optional): value to use for the command verb when
#  |          `command` is passed as a string
#  |        - `check` (optional): check the response for errors, raising
#  |          :class:`~pymongo.errors.OperationFailure` if there are any
#  |        - `allowable_errors`: if `check` is ``True``, error messages
#  |          in this list will be ignored by error-checking
#  |        - `read_preference` (optional): The read preference for this
#  |          operation. See :mod:`~pymongo.read_preferences` for options.
#  |          If the provided `session` is in a transaction, defaults to the
#  |          read preference configured for the transaction.
#  |          Otherwise, defaults to
#  |          :attr:`~pymongo.read_preferences.ReadPreference.PRIMARY`.
#  |        - `codec_options`: A :class:`~bson.codec_options.CodecOptions`
#  |          instance.
#  |        - `session` (optional): A
#  |          :class:`~pymongo.client_session.ClientSession`.
#  |        - `**kwargs` (optional): additional keyword arguments will
#  |          be added to the command document before it is sent
#  |
#  |      .. note:: :meth:`command` does **not** obey this Database's
#  |         :attr:`read_preference` or :attr:`codec_options`. You must use the
#  |         `read_preference` and `codec_options` parameters instead.
#  |
#  |      .. versionchanged:: 3.6
#  |         Added ``session`` parameter.
#  |
#  |      .. versionchanged:: 3.0
#  |         Removed the `as_class`, `fields`, `uuid_subtype`, `tag_sets`,
#  |         and `secondary_acceptable_latency_ms` option.
#  |         Removed `compile_re` option: PyMongo now always represents BSON
#  |         regular expressions as :class:`~bson.regex.Regex` objects. Use
#  |         :meth:`~bson.regex.Regex.try_compile` to attempt to convert from a
#  |         BSON regular expression to a Python regular expression object.
#  |         Added the `codec_options` parameter.
#  |
#  |      .. versionchanged:: 2.7
#  |         Added `compile_re` option. If set to False, PyMongo represented BSON
#  |         regular expressions as :class:`~bson.regex.Regex` objects instead of
#  |         attempting to compile BSON regular expressions as Python native
#  |         regular expressions, thus preventing errors for some incompatible
#  |         patterns, see `PYTHON-500`_.
#  |
#  |      .. versionchanged:: 2.3
#  |         Added `tag_sets` and `secondary_acceptable_latency_ms` options.
#  |      .. versionchanged:: 2.2
#  |         Added support for `as_class` - the class you want to use for
#  |         the resulting documents
#  |
#  |      .. _PYTHON-500: https://jira.mongodb.org/browse/PYTHON-500
#  |
#  |      .. mongodoc:: commands
#  |
#  |  create_collection(self, name, codec_options=None, read_preference=None, write_concern=None, read_concern=None, session=None, **kwargs)
#  |      Create a new :class:`~pymongo.collection.Collection` in this
#  |      database.
#  |
#  |      Normally collection creation is automatic. This method should
#  |      only be used to specify options on
#  |      creation. :class:`~pymongo.errors.CollectionInvalid` will be
#  |      raised if the collection already exists.
#  |
#  |      Options should be passed as keyword arguments to this method. Supported
#  |      options vary with MongoDB release. Some examples include:
#  |
#  |        - "size": desired initial size for the collection (in
#  |          bytes). For capped collections this size is the max
#  |          size of the collection.
#  |        - "capped": if True, this is a capped collection
#  |        - "max": maximum number of objects if capped (optional)
#  |
#  |      See the MongoDB documentation for a full list of supported options by
#  |      server version.
#  |
#  |      :Parameters:
#  |        - `name`: the name of the collection to create
#  |        - `codec_options` (optional): An instance of
#  |          :class:`~bson.codec_options.CodecOptions`. If ``None`` (the
#  |          default) the :attr:`codec_options` of this :class:`Database` is
#  |          used.
#  |        - `read_preference` (optional): The read preference to use. If
#  |          ``None`` (the default) the :attr:`read_preference` of this
#  |          :class:`Database` is used.
#  |        - `write_concern` (optional): An instance of
#  |          :class:`~pymongo.write_concern.WriteConcern`. If ``None`` (the
#  |          default) the :attr:`write_concern` of this :class:`Database` is
#  |          used.
#  |        - `read_concern` (optional): An instance of
#  |          :class:`~pymongo.read_concern.ReadConcern`. If ``None`` (the
#  |          default) the :attr:`read_concern` of this :class:`Database` is
#  |          used.
#  |        - `collation` (optional): An instance of
#  |          :class:`~pymongo.collation.Collation`.
#  |        - `session` (optional): a
#  |          :class:`~pymongo.client_session.ClientSession`.
#  |        - `**kwargs` (optional): additional keyword arguments will
#  |          be passed as options for the create collection command
#  |
#  |      .. versionchanged:: 3.6
#  |         Added ``session`` parameter.
#  |
#  |      .. versionchanged:: 3.4
#  |         Added the collation option.
#  |
#  |      .. versionchanged:: 3.0
#  |         Added the codec_options, read_preference, and write_concern options.
#  |
#  |      .. versionchanged:: 2.2
#  |         Removed deprecated argument: options
#  |
#  |  current_op(self, include_all=False, session=None)
#  |      Get information on operations currently running.
#  |
#  |      :Parameters:
#  |        - `include_all` (optional): if ``True`` also list currently
#  |          idle operations in the result
#  |        - `session` (optional): a
#  |          :class:`~pymongo.client_session.ClientSession`.
#  |
#  |      .. versionchanged:: 3.6
#  |         Added ``session`` parameter.
#  |
#  |  dereference(self, dbref, session=None, **kwargs)
#  |      Dereference a :class:`~bson.dbref.DBRef`, getting the
#  |      document it points to.
#  |
#  |      Raises :class:`TypeError` if `dbref` is not an instance of
#  |      :class:`~bson.dbref.DBRef`. Returns a document, or ``None`` if
#  |      the reference does not point to a valid document.  Raises
#  |      :class:`ValueError` if `dbref` has a database specified that
#  |      is different from the current database.
#  |
#  |      :Parameters:
#  |        - `dbref`: the reference
#  |        - `session` (optional): a
#  |          :class:`~pymongo.client_session.ClientSession`.
#  |        - `**kwargs` (optional): any additional keyword arguments
#  |          are the same as the arguments to
#  |          :meth:`~pymongo.collection.Collection.find`.
#  |
#  |      .. versionchanged:: 3.6
#  |         Added ``session`` parameter.
#  |
#  |  drop_collection(self, name_or_collection, session=None)
#  |      Drop a collection.
#  |
#  |      :Parameters:
#  |        - `name_or_collection`: the name of a collection to drop or the
#  |          collection object itself
#  |        - `session` (optional): a
#  |          :class:`~pymongo.client_session.ClientSession`.
#  |
#  |      .. note:: The :attr:`~pymongo.database.Database.write_concern` of
#  |         this database is automatically applied to this operation when using
#  |         MongoDB >= 3.4.
#  |
#  |      .. versionchanged:: 3.6
#  |         Added ``session`` parameter.
#  |
#  |      .. versionchanged:: 3.4
#  |         Apply this database's write concern automatically to this operation
#  |         when connected to MongoDB >= 3.4.
#  |
#  |  error(self)
#  |      **DEPRECATED**: Get the error if one occurred on the last operation.
#  |
#  |      This method is obsolete: all MongoDB write operations (insert, update,
#  |      remove, and so on) use the write concern ``w=1`` and report their
#  |      errors by default.
#  |
#  |      .. versionchanged:: 2.8
#  |         Deprecated.
#  |
#  |  eval(self, code, *args)
#  |      **DEPRECATED**: Evaluate a JavaScript expression in MongoDB.
#  |
#  |      :Parameters:
#  |        - `code`: string representation of JavaScript code to be
#  |          evaluated
#  |        - `args` (optional): additional positional arguments are
#  |          passed to the `code` being evaluated
#  |
#  |      .. warning:: the eval command is deprecated in MongoDB 3.0 and
#  |        will be removed in a future server version.
#  |
#  |  get_collection(self, name, codec_options=None, read_preference=None, write_concern=None, read_concern=None)
#  |      Get a :class:`~pymongo.collection.Collection` with the given name
#  |      and options.
#  |
#  |      Useful for creating a :class:`~pymongo.collection.Collection` with
#  |      different codec options, read preference, and/or write concern from
#  |      this :class:`Database`.
#  |
#  |        >>> db.read_preference
#  |        Primary()
#  |        >>> coll1 = db.test
#  |        >>> coll1.read_preference
#  |        Primary()
#  |        >>> from pymongo import ReadPreference
#  |        >>> coll2 = db.get_collection(
#  |        ...     'test', read_preference=ReadPreference.SECONDARY)
#  |        >>> coll2.read_preference
#  |        Secondary(tag_sets=None)
#  |
#  |      :Parameters:
#  |        - `name`: The name of the collection - a string.
#  |        - `codec_options` (optional): An instance of
#  |          :class:`~bson.codec_options.CodecOptions`. If ``None`` (the
#  |          default) the :attr:`codec_options` of this :class:`Database` is
#  |          used.
#  |        - `read_preference` (optional): The read preference to use. If
#  |          ``None`` (the default) the :attr:`read_preference` of this
#  |          :class:`Database` is used. See :mod:`~pymongo.read_preferences`
#  |          for options.
#  |        - `write_concern` (optional): An instance of
#  |          :class:`~pymongo.write_concern.WriteConcern`. If ``None`` (the
#  |          default) the :attr:`write_concern` of this :class:`Database` is
#  |          used.
#  |        - `read_concern` (optional): An instance of
#  |          :class:`~pymongo.read_concern.ReadConcern`. If ``None`` (the
#  |          default) the :attr:`read_concern` of this :class:`Database` is
#  |          used.
#  |
#  |  last_status(self)
#  |      **DEPRECATED**: Get status information from the last operation.
#  |
#  |      This method is obsolete: all MongoDB write operations (insert, update,
#  |      remove, and so on) use the write concern ``w=1`` and report their
#  |      errors by default.
#  |
#  |      Returns a SON object with status information.
#  |
#  |      .. versionchanged:: 2.8
#  |         Deprecated.
#  |
#  |  list_collection_names(self, session=None)
#  |      Get a list of all the collection names in this database.
#  |
#  |      :Parameters:
#  |        - `session` (optional): a
#  |          :class:`~pymongo.client_session.ClientSession`.
#  |
#  |      .. versionadded:: 3.6
#  |
#  |  list_collections(self, session=None, **kwargs)
#  |      Get a cursor over the collectons of this database.
#  |
#  |      :Parameters:
#  |        - `session` (optional): a
#  |          :class:`~pymongo.client_session.ClientSession`.
#  |        - `**kwargs` (optional): Optional parameters of the
#  |          `listCollections command
#  |          <https://docs.mongodb.com/manual/reference/command/listCollections/>`_
#  |          can be passed as keyword arguments to this method. The supported
#  |          options differ by server version.
#  |
#  |      :Returns:
#  |        An instance of :class:`~pymongo.command_cursor.CommandCursor`.
#  |
#  |      .. versionadded:: 3.6
#  |
#  |  logout(self)
#  |      **DEPRECATED**: Deauthorize use of this database.
#  |
#  |      .. warning:: Starting in MongoDB 3.6, calling :meth:`logout`
#  |        invalidates all existing cursors. It may also leave logical sessions
#  |        open on the server for up to 30 minutes until they time out.
#  |
#  |  next = __next__(self)
#  |
#  |  previous_error(self)
#  |      **DEPRECATED**: Get the most recent error on this database.
#  |
#  |      This method is obsolete: all MongoDB write operations (insert, update,
#  |      remove, and so on) use the write concern ``w=1`` and report their
#  |      errors by default.
#  |
#  |      Only returns errors that have occurred since the last call to
#  |      :meth:`reset_error_history`. Returns None if no such errors have
#  |      occurred.
#  |
#  |      .. versionchanged:: 2.8
#  |         Deprecated.
#  |
#  |  profiling_info(self, session=None)
#  |      Returns a list containing current profiling information.
#  |
#  |      :Parameters:
#  |        - `session` (optional): a
#  |          :class:`~pymongo.client_session.ClientSession`.
#  |
#  |      .. versionchanged:: 3.6
#  |         Added ``session`` parameter.
#  |
#  |      .. mongodoc:: profiling
#  |
#  |  profiling_level(self, session=None)
#  |      Get the database's current profiling level.
#  |
#  |      Returns one of (:data:`~pymongo.OFF`,
#  |      :data:`~pymongo.SLOW_ONLY`, :data:`~pymongo.ALL`).
#  |
#  |      :Parameters:
#  |        - `session` (optional): a
#  |          :class:`~pymongo.client_session.ClientSession`.
#  |
#  |      .. versionchanged:: 3.6
#  |         Added ``session`` parameter.
#  |
#  |      .. mongodoc:: profiling
#  |
#  |  remove_user(self, name, session=None)
#  |      **DEPRECATED**: Remove user `name` from this :class:`Database`.
#  |
#  |      User `name` will no longer have permissions to access this
#  |      :class:`Database`.
#  |
#  |      .. note:: remove_user is deprecated and will be removed in PyMongo
#  |        4.0. Use the dropUser command instead::
#  |
#  |          db.command("dropUser", "user")
#  |
#  |      :Parameters:
#  |        - `name`: the name of the user to remove
#  |        - `session` (optional): a
#  |          :class:`~pymongo.client_session.ClientSession`.
#  |
#  |      .. versionchanged:: 3.6
#  |         Added ``session`` parameter. Deprecated remove_user.
#  |
#  |  reset_error_history(self)
#  |      **DEPRECATED**: Reset the error history of this database.
#  |
#  |      This method is obsolete: all MongoDB write operations (insert, update,
#  |      remove, and so on) use the write concern ``w=1`` and report their
#  |      errors by default.
#  |
#  |      Calls to :meth:`previous_error` will only return errors that have
#  |      occurred since the most recent call to this method.
#  |
#  |      .. versionchanged:: 2.8
#  |         Deprecated.
#  |
#  |  set_profiling_level(self, level, slow_ms=None, session=None)
#  |      Set the database's profiling level.
#  |
#  |      :Parameters:
#  |        - `level`: Specifies a profiling level, see list of possible values
#  |          below.
#  |        - `slow_ms`: Optionally modify the threshold for the profile to
#  |          consider a query or operation.  Even if the profiler is off queries
#  |          slower than the `slow_ms` level will get written to the logs.
#  |        - `session` (optional): a
#  |          :class:`~pymongo.client_session.ClientSession`.
#  |
#  |      Possible `level` values:
#  |
#  |      +----------------------------+------------------------------------+
#  |      | Level                      | Setting                            |
#  |      +============================+====================================+
#  |      | :data:`~pymongo.OFF`       | Off. No profiling.                 |
#  |      +----------------------------+------------------------------------+
#  |      | :data:`~pymongo.SLOW_ONLY` | On. Only includes slow operations. |
#  |      +----------------------------+------------------------------------+
#  |      | :data:`~pymongo.ALL`       | On. Includes all operations.       |
#  |      +----------------------------+------------------------------------+
#  |
#  |      Raises :class:`ValueError` if level is not one of
#  |      (:data:`~pymongo.OFF`, :data:`~pymongo.SLOW_ONLY`,
#  |      :data:`~pymongo.ALL`).
#  |
#  |      .. versionchanged:: 3.6
#  |         Added ``session`` parameter.
#  |
#  |      .. mongodoc:: profiling
#  |
#  |  validate_collection(self, name_or_collection, scandata=False, full=False, session=None)
#  |      Validate a collection.
#  |
#  |      Returns a dict of validation info. Raises CollectionInvalid if
#  |      validation fails.
#  |
#  |      :Parameters:
#  |        - `name_or_collection`: A Collection object or the name of a
#  |          collection to validate.
#  |        - `scandata`: Do extra checks beyond checking the overall
#  |          structure of the collection.
#  |        - `full`: Have the server do a more thorough scan of the
#  |          collection. Use with `scandata` for a thorough scan
#  |          of the structure of the collection and the individual
#  |          documents.
#  |        - `session` (optional): a
#  |          :class:`~pymongo.client_session.ClientSession`.
#  |
#  |      .. versionchanged:: 3.6
#  |         Added ``session`` parameter.
#  |
#  |  watch(self, pipeline=None, full_document='default', resume_after=None, max_await_time_ms=None, batch_size=None, collation=None, start_at_operation_time=None, session=None)
#  |      Watch changes on this database.
#  |
#  |      Performs an aggregation with an implicit initial ``$changeStream``
#  |      stage and returns a
#  |      :class:`~pymongo.change_stream.DatabaseChangeStream` cursor which
#  |      iterates over changes on all collections in this database.
#  |
#  |      Introduced in MongoDB 4.0.
#  |
#  |      .. code-block:: python
#  |
#  |         with db.watch() as stream:
#  |             for change in stream:
#  |                 print(change)
#  |
#  |      The :class:`~pymongo.change_stream.DatabaseChangeStream` iterable
#  |      blocks until the next change document is returned or an error is
#  |      raised. If the
#  |      :meth:`~pymongo.change_stream.DatabaseChangeStream.next` method
#  |      encounters a network error when retrieving a batch from the server,
#  |      it will automatically attempt to recreate the cursor such that no
#  |      change events are missed. Any error encountered during the resume
#  |      attempt indicates there may be an outage and will be raised.
#  |
#  |      .. code-block:: python
#  |
#  |          try:
#  |              with db.watch(
#  |                      [{'$match': {'operationType': 'insert'}}]) as stream:
#  |                  for insert_change in stream:
#  |                      print(insert_change)
#  |          except pymongo.errors.PyMongoError:
#  |              # The ChangeStream encountered an unrecoverable error or the
#  |              # resume attempt failed to recreate the cursor.
#  |              logging.error('...')
#  |
#  |      For a precise description of the resume process see the
#  |      `change streams specification`_.
#  |
#  |      :Parameters:
#  |        - `pipeline` (optional): A list of aggregation pipeline stages to
#  |          append to an initial ``$changeStream`` stage. Not all
#  |          pipeline stages are valid after a ``$changeStream`` stage, see the
#  |          MongoDB documentation on change streams for the supported stages.
#  |        - `full_document` (optional): The fullDocument to pass as an option
#  |          to the ``$changeStream`` stage. Allowed values: 'default',
#  |          'updateLookup'.  Defaults to 'default'.
#  |          When set to 'updateLookup', the change notification for partial
#  |          updates will include both a delta describing the changes to the
#  |          document, as well as a copy of the entire document that was
#  |          changed from some time after the change occurred.
#  |        - `resume_after` (optional): The logical starting point for this
#  |          change stream.
#  |        - `max_await_time_ms` (optional): The maximum time in milliseconds
#  |          for the server to wait for changes before responding to a getMore
#  |          operation.
#  |        - `batch_size` (optional): The maximum number of documents to return
#  |          per batch.
#  |        - `collation` (optional): The :class:`~pymongo.collation.Collation`
#  |          to use for the aggregation.
#  |        - `start_at_operation_time` (optional): If provided, the resulting
#  |          change stream will only return changes that occurred at or after
#  |          the specified :class:`~bson.timestamp.Timestamp`. Requires
#  |          MongoDB >= 4.0.
#  |        - `session` (optional): a
#  |          :class:`~pymongo.client_session.ClientSession`.
#  |
#  |      :Returns:
#  |        A :class:`~pymongo.change_stream.DatabaseChangeStream` cursor.
#  |
#  |      .. versionadded:: 3.7
#  |
#  |      .. mongodoc:: changeStreams
#  |
#  |      .. _change streams specification:
#  |          https://github.com/mongodb/specifications/blob/master/source/change-streams/change-streams.rst
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  client
#  |      The client instance for this :class:`Database`.
#  |
#  |  incoming_copying_manipulators
#  |      **DEPRECATED**: All incoming SON copying manipulators.
#  |
#  |      .. versionchanged:: 3.5
#  |        Deprecated.
#  |
#  |      .. versionadded:: 2.0
#  |
#  |  incoming_manipulators
#  |      **DEPRECATED**: All incoming SON manipulators.
#  |
#  |      .. versionchanged:: 3.5
#  |        Deprecated.
#  |
#  |      .. versionadded:: 2.0
#  |
#  |  name
#  |      The name of this :class:`Database`.
#  |
#  |  outgoing_copying_manipulators
#  |      **DEPRECATED**: All outgoing SON copying manipulators.
#  |
#  |      .. versionchanged:: 3.5
#  |        Deprecated.
#  |
#  |      .. versionadded:: 2.0
#  |
#  |  outgoing_manipulators
#  |      **DEPRECATED**: All outgoing SON manipulators.
#  |
#  |      .. versionchanged:: 3.5
#  |        Deprecated.
#  |
#  |      .. versionadded:: 2.0
#  |
#  |  system_js
#  |      **DEPRECATED**: :class:`SystemJS` helper for this :class:`Database`.
#  |
#  |      See the documentation for :class:`SystemJS` for more details.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from pymongo.common.BaseObject:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  codec_options
#  |      Read only access to the :class:`~bson.codec_options.CodecOptions`
#  |      of this instance.
#  |
#  |  read_concern
#  |      Read only access to the :class:`~pymongo.read_concern.ReadConcern`
#  |      of this instance.
#  |
#  |      .. versionadded:: 3.2
#  |
#  |  read_preference
#  |      Read only access to the read preference of this instance.
#  |
#  |      .. versionchanged:: 3.0
#  |        The :attr:`read_preference` attribute is now read only.
#  |
#  |  write_concern
#  |      Read only access to the :class:`~pymongo.write_concern.WriteConcern`
#  |      of this instance.
#  |
#  |      .. versionchanged:: 3.0
#  |        The :attr:`write_concern` attribute is now read only.

# %%
# This command refers to "test" collection on my cluster.
dir(db.test)
# Out:
# ['_BaseObject__codec_options',
#  '_BaseObject__read_concern',
#  '_BaseObject__read_preference',
#  '_BaseObject__write_concern',
#  '_Collection__create',
#  '_Collection__create_index',
#  '_Collection__database',
#  '_Collection__find_and_modify',
#  '_Collection__full_name',
#  '_Collection__name',
#  '_Collection__write_response_codec_options',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_aggregate',
#  '_aggregate_one_result',
#  '_command',
#  '_count',
#  '_delete',
#  '_delete_retryable',
#  '_insert',
#  '_insert_one',
#  '_legacy_write',
#  '_read_preference_for',
#  '_socket_for_primary_reads',
#  '_socket_for_reads',
#  '_socket_for_writes',
#  '_update',
#  '_update_retryable',
#  '_write_concern_for',
#  '_write_concern_for_cmd',
#  'aggregate',
#  'aggregate_raw_batches',
#  'bulk_write',
#  'codec_options',
#  'count',
#  'count_documents',
#  'create_index',
#  'create_indexes',
#  'database',
#  'delete_many',
#  'delete_one',
#  'distinct',
#  'drop',
#  'drop_index',
#  'drop_indexes',
#  'ensure_index',
#  'estimated_document_count',
#  'find',
#  'find_and_modify',
#  'find_one',
#  'find_one_and_delete',
#  'find_one_and_replace',
#  'find_one_and_update',
#  'find_raw_batches',
#  'full_name',
#  'group',
#  'index_information',
#  'initialize_ordered_bulk_op',
#  'initialize_unordered_bulk_op',
#  'inline_map_reduce',
#  'insert',
#  'insert_many',
#  'insert_one',
#  'list_indexes',
#  'map_reduce',
#  'name',
#  'next',
#  'options',
#  'parallel_scan',
#  'read_concern',
#  'read_preference',
#  'reindex',
#  'remove',
#  'rename',
#  'replace_one',
#  'save',
#  'update',
#  'update_many',
#  'update_one',
#  'watch',
#  'with_options',
#  'write_concern']

# %% [markdown]
# So I have the `db object` as `db` and the specefic collection (table-like) as `test` for my method. I could call `rpg_db` as the method if I want to modify that collection. I'll be doing that later.

# %%
# Lets get information on the insert_one method. 
help(db.test.insert_one)
# Out:
# Help on method insert_one in module pymongo.collection:
#
# insert_one(document, bypass_document_validation=False, session=None) method of pymongo.collection.Collection instance
#     Insert a single document.
#
#       >>> db.test.count_documents({'x': 1})
#       0
#       >>> result = db.test.insert_one({'x': 1})
#       >>> result.inserted_id
#       ObjectId('54f112defba522406c9cc208')
#       >>> db.test.find_one({'x': 1})
#       {u'x': 1, u'_id': ObjectId('54f112defba522406c9cc208')}
#
#     :Parameters:
#       - `document`: The document to insert. Must be a mutable mapping
#         type. If the document does not have an _id field one will be
#         added automatically.
#       - `bypass_document_validation`: (optional) If ``True``, allows the
#         write to opt-out of document level validation. Default is
#         ``False``.
#       - `session` (optional): a
#         :class:`~pymongo.client_session.ClientSession`.
#
#     :Returns:
#       - An instance of :class:`~pymongo.results.InsertOneResult`.
#
#     .. seealso:: :ref:`writes-and-ids`
#
#     .. note:: `bypass_document_validation` requires server version
#       **>= 3.2**
#
#     .. versionchanged:: 3.6
#        Added ``session`` parameter.
#
#     .. versionchanged:: 3.2
#       Added bypass_document_validation support
#
#     .. versionadded:: 3.0

# %% [markdown]
# The info provides a nice example as well as important parameters:
#
#      :Parameters:
#       - `document`: The document to insert. Must be a mutable mapping
#         type. If the document does not have an _id field one will be
#         added automatically.
#       - `bypass_document_validation`: (optional) If ``True``, allows the
#         write to opt-out of document level validation. Default is
#         ``False``.
#       - `session` (optional): a
#         :class:`~pymongo.client_session.ClientSession`.
#
# **Mutable mapping type** can be defined as:
#
# >A mapping object maps immutable values to arbitrary objects. Mappings are mutable objects. There is currently only one standard mapping type, the dictionary. A dictionary's keys are almost arbitrary values. Only values containing lists, dictionaries or other mutable types (that are compared by value rather than by object identity) may not be used as keys. Numeric types used for keys obey the normal rules for numeric comparison: if two numbers compare equal (such as 1 and 1.0) then they can be used interchangeably to index the same dictionary entry.
#
# In summary, I should use a dictionary. However, that dictionary's key must be arbitrary and thus, immuatable. In this case, I could use a tuple, but the tuple **cannot contain numeric datatypes**.
#
# I'm going to test out some isnertions to the `test` collection on my database.

# %%
db.test.insert_one({'x': 1})

# %%
#That looks like it worked, but I want to see if I can prove that it did
help(db.test.find_one)
# Out:
# Help on method find_one in module pymongo.collection:
#
# find_one(filter=None, *args, **kwargs) method of pymongo.collection.Collection instance
#     Get a single document from the database.
#
#     All arguments to :meth:`find` are also valid arguments for
#     :meth:`find_one`, although any `limit` argument will be
#     ignored. Returns a single document, or ``None`` if no matching
#     document is found.
#
#     The :meth:`find_one` method obeys the :attr:`read_preference` of
#     this :class:`Collection`.
#
#     :Parameters:
#
#       - `filter` (optional): a dictionary specifying
#         the query to be performed OR any other type to be used as
#         the value for a query for ``"_id"``.
#
#       - `*args` (optional): any additional positional arguments
#         are the same as the arguments to :meth:`find`.
#
#       - `**kwargs` (optional): any additional keyword arguments
#         are the same as the arguments to :meth:`find`.
#
#           >>> collection.find_one(max_time_ms=100)

# %%
# Finds one instance where the document matches the parameter dictionary
db.test.find_one({'x': 1})
# Out:
# {'_id': ObjectId('5cf7faecb0e0522fb5285830'), 'x': 1}

# %%
# Lets see what kind of methods are available to an object with find attached. 
results = db.test.find({'x': 1})
dir(results)
# Out:
# ['_Cursor__address',
#  '_Cursor__batch_size',
#  '_Cursor__check_okay_to_chain',
#  '_Cursor__codec_options',
#  '_Cursor__collation',
#  '_Cursor__collection',
#  '_Cursor__comment',
#  '_Cursor__data',
#  '_Cursor__die',
#  '_Cursor__empty',
#  '_Cursor__exhaust',
#  '_Cursor__exhaust_mgr',
#  '_Cursor__explain',
#  '_Cursor__explicit_session',
#  '_Cursor__hint',
#  '_Cursor__id',
#  '_Cursor__killed',
#  '_Cursor__limit',
#  '_Cursor__manipulate',
#  '_Cursor__max',
#  '_Cursor__max_await_time_ms',
#  '_Cursor__max_scan',
#  '_Cursor__max_time_ms',
#  '_Cursor__min',
#  '_Cursor__modifiers',
#  '_Cursor__ordering',
#  '_Cursor__projection',
#  '_Cursor__query_flags',
#  '_Cursor__query_spec',
#  '_Cursor__read_concern',
#  '_Cursor__read_preference',
#  '_Cursor__retrieved',
#  '_Cursor__return_key',
#  '_Cursor__send_message',
#  '_Cursor__session',
#  '_Cursor__set_hint',
#  '_Cursor__show_record_id',
#  '_Cursor__skip',
#  '_Cursor__snapshot',
#  '_Cursor__spec',
#  '__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_clone',
#  '_clone_base',
#  '_deepcopy',
#  '_getmore_class',
#  '_query_class',
#  '_read_preference',
#  '_refresh',
#  '_unpack_response',
#  'add_option',
#  'address',
#  'alive',
#  'batch_size',
#  'clone',
#  'close',
#  'collation',
#  'collection',
#  'comment',
#  'count',
#  'cursor_id',
#  'distinct',
#  'explain',
#  'hint',
#  'limit',
#  'max',
#  'max_await_time_ms',
#  'max_scan',
#  'max_time_ms',
#  'min',
#  'next',
#  'remove_option',
#  'retrieved',
#  'rewind',
#  'session',
#  'skip',
#  'sort',
#  'where']

# %%
# view the results tied up in the find object 
list(results)
# Out:
# [{'_id': ObjectId('5cf7faecb0e0522fb5285830'), 'x': 1},
#  {'_id': ObjectId('5cf842ebb0e0523ab9fdcb76'), 'x': 1}]

# %% [markdown]
# So the documents can be pulled from the `find` object by turning it into a list. The information can be viewed this way.

# %%
# Let's throw in a few more docmuents. 
artins_doc = {'favorite animal': 'silver panther'}
artins_doc
# Out:
# {'favorite animal': 'silver panther'}

# %%
# Insert to the Database. 
db.test.insert_one(artins_doc)

# %%
# Does not affect the previously saved variable. 
list(results)
# Out:
# [{'_id': ObjectId('5cf7faecb0e0522fb5285830'), 'x': 1},
#  {'_id': ObjectId('5cf842ebb0e0523ab9fdcb76'), 'x': 1}]

# %%
# Proof that the new document is there. 
list(db.test.find())
# Out:
# [{'_id': ObjectId('5cf7faecb0e0522fb5285830'), 'x': 1},
#  {'_id': ObjectId('5cf842ebb0e0523ab9fdcb76'), 'x': 1},
#  {'_id': ObjectId('5cf8431fb0e0523ab9fdcb77'),
#   'favorite animal': 'silver panther'}]

# %%
# Add a couple more
alexanders_doc = {'favorite animal': 'parrot'}
wills_favorite = {'favorite animal': 'goose'}

# %%
help(db.test.insert_many)
# Out:
# Help on method insert_many in module pymongo.collection:
#
# insert_many(documents, ordered=True, bypass_document_validation=False, session=None) method of pymongo.collection.Collection instance
#     Insert an iterable of documents.
#
#       >>> db.test.count_documents({})
#       0
#       >>> result = db.test.insert_many([{'x': i} for i in range(2)])
#       >>> result.inserted_ids
#       [ObjectId('54f113fffba522406c9cc20e'), ObjectId('54f113fffba522406c9cc20f')]
#       >>> db.test.count_documents({})
#       2
#
#     :Parameters:
#       - `documents`: A iterable of documents to insert.
#       - `ordered` (optional): If ``True`` (the default) documents will be
#         inserted on the server serially, in the order provided. If an error
#         occurs all remaining inserts are aborted. If ``False``, documents
#         will be inserted on the server in arbitrary order, possibly in
#         parallel, and all document inserts will be attempted.
#       - `bypass_document_validation`: (optional) If ``True``, allows the
#         write to opt-out of document level validation. Default is
#         ``False``.
#       - `session` (optional): a
#         :class:`~pymongo.client_session.ClientSession`.
#
#     :Returns:
#       An instance of :class:`~pymongo.results.InsertManyResult`.
#
#     .. seealso:: :ref:`writes-and-ids`
#
#     .. note:: `bypass_document_validation` requires server version
#       **>= 3.2**
#
#     .. versionchanged:: 3.6
#        Added ``session`` parameter.
#
#     .. versionchanged:: 3.2
#       Added bypass_document_validation support
#
#     .. versionadded:: 3.0

# %%
db.test.insert_many([alexanders_doc, wills_favorite])

# %% [markdown]
# The insert many method can be used to batch insert documents generated by programs.

# %%
docs = []
for i in range(10):
  doc = {'even': i % 2 == 0}
  doc['value'] = i
  docs.append(doc)

docs
# Out:
# [{'even': True, 'value': 0},
#  {'even': False, 'value': 1},
#  {'even': True, 'value': 2},
#  {'even': False, 'value': 3},
#  {'even': True, 'value': 4},
#  {'even': False, 'value': 5},
#  {'even': True, 'value': 6},
#  {'even': False, 'value': 7},
#  {'even': True, 'value': 8},
#  {'even': False, 'value': 9}]

# %%
db.test.insert_many(docs)

# %% [markdown]
# However, it is sensitive to improper datatypes. For example, the dictionary below will return an error. Although a tuple is immutable, it wont allow the values in that tuple to be numeric datatypes.

# %%
cool_dict = {
    'awesome': True,
    'even': False,
    'some numbers': [1, 2, 3],
    (3, 4): (5, 6)
}

# %%
db.test.insert_one(cool_dict)
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# <ipython-input-86-1f208c056381> in <module>
# ----> 1 db.test.insert_one(cool_dict)
#
# /anaconda3/envs/db_builder/lib/python3.7/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session)
#     691                          write_concern=write_concern,
#     692                          bypass_doc_val=bypass_document_validation,
# --> 693                          session=session),
#     694             write_concern.acknowledged)
#     695
#
# /anaconda3/envs/db_builder/lib/python3.7/site-packages/pymongo/collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     605             return self._insert_one(
#     606                 docs, ordered, check_keys, manipulate, write_concern, op_id,
# --> 607                 bypass_doc_val, session)
#     608
#     609         ids = []
#
# /anaconda3/envs/db_builder/lib/python3.7/site-packages/pymongo/collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     593
#     594         self.__database.client._retryable_write(
# --> 595             acknowledged, _insert_command, session)
#     596
#     597         if not isinstance(doc, RawBSONDocument):
#
# /anaconda3/envs/db_builder/lib/python3.7/site-packages/pymongo/mongo_client.py in _retryable_write(self, retryable, func, session)
#    1246         """Internal retryable write helper."""
#    1247         with self._tmp_session(session) as s:
# -> 1248             return self._retry_with_session(retryable, func, s, None)
#    1249
#    1250     def __reset_server(self, address):
#
# /anaconda3/envs/db_builder/lib/python3.7/site-packages/pymongo/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1199                             raise last_error
#    1200                         retryable = False
# -> 1201                     return func(session, sock_info, retryable)
#    1202             except ServerSelectionTimeoutError:
#    1203                 if is_retrying():
#
# /anaconda3/envs/db_builder/lib/python3.7/site-packages/pymongo/collection.py in _insert_command(session, sock_info, retryable_write)
#     588                 session=session,
#     589                 client=self.__database.client,
# --> 590                 retryable_write=retryable_write)
#     591
#     592             _check_write_command_response(result)
#
# /anaconda3/envs/db_builder/lib/python3.7/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events)
#     582         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     583         except BaseException as error:
# --> 584             self._raise_connection_failure(error)
#     585
#     586     def send_message(self, message, max_doc_size):
#
# /anaconda3/envs/db_builder/lib/python3.7/site-packages/pymongo/pool.py in _raise_connection_failure(self, error)
#     743             _raise_connection_failure(self.address, error)
#     744         else:
# --> 745             raise error
#     746
#     747     def __eq__(self, other):
#
# /anaconda3/envs/db_builder/lib/python3.7/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events)
#     577                            compression_ctx=self.compression_context,
#     578                            use_op_msg=self.op_msg_enabled,
# --> 579                            unacknowledged=unacknowledged)
#     580         except OperationFailure:
#     581             raise
#
# /anaconda3/envs/db_builder/lib/python3.7/site-packages/pymongo/network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged)
#     112         request_id, msg, size, max_doc_size = message._op_msg(
#     113             flags, spec, dbname, read_preference, slave_ok, check_keys,
# --> 114             codec_options, ctx=compression_ctx)
#     115         # If this is an unacknowledged write then make sure the encoded doc(s)
#     116         # are small enough, otherwise rely on the server to return an error.
#
# /anaconda3/envs/db_builder/lib/python3.7/site-packages/pymongo/message.py in _op_msg(flags, command, dbname, read_preference, slave_ok, check_keys, opts, ctx)
#     677                 flags, command, identifier, docs, check_keys, opts, ctx)
#     678         return _op_msg_uncompressed(
# --> 679             flags, command, identifier, docs, check_keys, opts)
#     680     finally:
#     681         # Add the field back to the command.
#
# InvalidDocument: documents must have only string keys, key was (3, 4)

# %%
# Turn those tuples into strings
fixed_dict = {str(key): value for key, value in cool_dict.items()}
fixed_dict
# Out:
# {'awesome': True,
#  'even': False,
#  'some numbers': [1, 2, 3],
#  '(3, 4)': (5, 6),
#  '_id': ObjectId('5cf84641b0e0523ab9fdcb84')}

# %%
db.test.insert_one(fixed_dict)

# %% [markdown]
# Can I insert data in a tuple like with PostgreSQL?

# %%
rpg_character = (1, "King Bob", 10, 3, 0, 0, 0)

# %%
db.test.insert_one(rpg_character)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-501da510ae65> in <module>
# ----> 1 db.test.insert_one(rpg_character)
#
# /anaconda3/envs/db_builder/lib/python3.7/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session)
#     682         .. versionadded:: 3.0
#     683         """
# --> 684         common.validate_is_document_type("document", document)
#     685         if not (isinstance(document, RawBSONDocument) or "_id" in document):
#     686             document["_id"] = ObjectId()
#
# /anaconda3/envs/db_builder/lib/python3.7/site-packages/pymongo/common.py in validate_is_document_type(option, value)
#     451                         "bson.raw_bson.RawBSONDocument, or "
#     452                         "a type that inherits from "
# --> 453                         "collections.MutableMapping" % (option,))
#     454
#     455
#
# TypeError: document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping

# %% [markdown]
# Turns out you can't insert information with pymongo like with psycopg2. Therefore, when inserting data, best practice might be to code the feature information into the key of the dictionary. Below are a couple methods on inserting document, one without specific descriptors for the keys, and one with.

# %%
# The key as the identifier. Assumes the user would know the feature information. Could be identified in the first document. 
db.test.insert_one({'rpg_character': rpg_character})

# %%
# End result: with unique objectId, rpg_character identifier key and list containing the information associated with the character. 
db.test.find_one({'rpg_character': rpg_character})
# Out:
# {'_id': ObjectId('5cf846c7b0e0523ab9fdcb85'),
#  'rpg_character': [1, 'King Bob', 10, 3, 0, 0, 0]}

# %%
# Let's insert a new document with more robust keys referring the names of the stats. 
db.test.insert_one({
    'sql_id': 1,
    'name': rpg_character[1],
    'hp': rpg_character[2],
    'level': rpg_character[3]
})

# %%
# Lets see the documents. 
list(db.test.find())
# Out:
# [{'_id': ObjectId('5cf7faecb0e0522fb5285830'), 'x': 1},
#  {'_id': ObjectId('5cf842ebb0e0523ab9fdcb76'), 'x': 1},
#  {'_id': ObjectId('5cf8431fb0e0523ab9fdcb77'),
#   'favorite animal': 'silver panther'},
#  {'_id': ObjectId('5cf84530b0e0523ab9fdcb78'), 'favorite animal': 'parrot'},
#  {'_id': ObjectId('5cf84530b0e0523ab9fdcb79'), 'favorite animal': 'goose'},
#  {'_id': ObjectId('5cf84542b0e0523ab9fdcb7a'), 'even': True, 'value': 0},
#  {'_id': ObjectId('5cf84542b0e0523ab9fdcb7b'), 'even': False, 'value': 1},
#  {'_id': ObjectId('5cf84542b0e0523ab9fdcb7c'), 'even': True, 'value': 2},
#  {'_id': ObjectId('5cf84542b0e0523ab9fdcb7d'), 'even': False, 'value': 3},
#  {'_id': ObjectId('5cf84542b0e0523ab9fdcb7e'), 'even': True, 'value': 4},
#  {'_id': ObjectId('5cf84542b0e0523ab9fdcb7f'), 'even': False, 'value': 5},
#  {'_id': ObjectId('5cf84542b0e0523ab9fdcb80'), 'even': True, 'value': 6},
#  {'_id': ObjectId('5cf84542b0e0523ab9fdcb81'), 'even': False, 'value': 7},
#  {'_id': ObjectId('5cf84542b0e0523ab9fdcb82'), 'even': True, 'value': 8},
#  {'_id': ObjectId('5cf84542b0e0523ab9fdcb83'), 'even': False, 'value': 9},
#  {'_id': ObjectId('5cf84641b0e0523ab9fdcb84'),
#   'awesome': True,
#   'even': False,
#   'some numbers': [1, 2, 3],
#   '(3, 4)': [5, 6]},
#  {'_id': ObjectId('5cf846c7b0e0523ab9fdcb85'),
#   'rpg_character': [1, 'King Bob', 10, 3, 0, 0, 0]},
#  {'_id': ObjectId('5cf84771b0e0523ab9fdcb86'),
#   'sql_id': 1,
#   'name': 'King Bob',
#   'hp': 10,
#   'level': 3}]

# %%
# Add another character
another_character = (2, "Queen Jane", 10, 4, 0, 0, 0)
db.test.insert_one({
    'sql_id': 1,
    'name': another_character[1],
    'hp': another_character[2],
    'level': another_character[3]
})

# %%
# Use the find method with specific parameters to pull any documents that match the parameters from the database. 
list(db.test.find({'hp': 10, 'level': 4}))
# Out:
# [{'_id': ObjectId('5cf847f0b0e0523ab9fdcb87'),
#   'sql_id': 1,
#   'name': 'Queen Jane',
#   'hp': 10,
#   'level': 4}]

# %% [markdown]
# ## Adding the rpg_db info to the MongoDB cloud

# %%
# Let's set the client to the rpg database. I'll be submitting data from the charactercreator_character table from rpg_db.sqlite3
db = client.rpg

# %%
# To make sure this works, I'm going to connect to the charactercreator_character collection within the rpg database. 
list(db.charactercreator_character.find())
# Out:
# []

# %% [markdown]
# It works! So I'm going to pull the information from the `rpg_db.sqlite3` file. Specifically, the `charactercreator_character` table.

# %%
# I'm going to pull all the information from the charactercreator_character table.
characters = sl_curs.execute('SELECT * FROM charactercreator_character;').fetchall()
# for testing purposes, I'm also going to select a single row. 
single_character = characters[0]
# Now to look at the data
characters
# Out:
# [(1, 'Aliquid iste optio reiciendi', 0, 0, 10, 1, 1, 1, 1),
#  (2, 'Optio dolorem ex a', 0, 0, 10, 1, 1, 1, 1),
#  (3, 'Minus c', 0, 0, 10, 1, 1, 1, 1),
#  (4, 'Sit ut repr', 0, 0, 10, 1, 1, 1, 1),
#  (5, 'At id recusandae expl', 0, 0, 10, 1, 1, 1, 1),
#  (6, 'Non nobis et of', 0, 0, 10, 1, 1, 1, 1),
#  (7, 'Perferendis', 0, 0, 10, 1, 1, 1, 1),
#  (8, 'Accusantium amet quidem eve', 0, 0, 10, 1, 1, 1, 1),
#  (9, 'Sed nostrum inventore error m', 0, 0, 10, 1, 1, 1, 1),
#  (10, 'Harum repellendus omnis od', 0, 0, 10, 1, 1, 1, 1),
#  (11, 'Itaque ut commodi,', 0, 0, 10, 1, 1, 1, 1),
#  (12, 'Molestiae quis', 0, 0, 10, 1, 1, 1, 1),
#  (13, 'Ali', 0, 0, 10, 1, 1, 1, 1),
#  (14, 'Tempora quod optio possimus il', 0, 0, 10, 1, 1, 1, 1),
#  (15, 'Sed itaque beatae pari', 0, 0, 10, 1, 1, 1, 1),
#  (16, 'Quam dolor', 0, 0, 10, 1, 1, 1, 1),
#  (17, 'Molestias expedita', 0, 0, 10, 1, 1, 1, 1),
#  (18, 'Lauda', 0, 0, 10, 1, 1, 1, 1),
#  (19, 'Incidunt sint perferen', 0, 0, 10, 1, 1, 1, 1),
#  (20, 'Laboriosa', 0, 0, 10, 1, 1, 1, 1),
#  (21, 'Dolore esse nesciunt fugit com', 0, 0, 10, 1, 1, 1, 1),
#  (22, 'Dolorum nam reic', 0, 0, 10, 1, 1, 1, 1),
#  (23, 'Repellat ad numquam volu', 0, 0, 10, 1, 1, 1, 1),
#  (24, 'Facere enim velit eligend', 0, 0, 10, 1, 1, 1, 1),
#  (25, 'Sed ratione quis rep', 0, 0, 10, 1, 1, 1, 1),
#  (26, 'Doloribus neque', 0, 0, 10, 1, 1, 1, 1),
#  (27, 'Ab voluptas se', 0, 0, 10, 1, 1, 1, 1),
#  (28, 'Molestias m', 0, 0, 10, 1, 1, 1, 1),
#  (29, 'In pariatur corpori', 0, 0, 10, 1, 1, 1, 1),
#  (30, 'Possimus ad dignissimos vel, a', 0, 0, 10, 1, 1, 1, 1),
#  (31, 'At minus accusa', 0, 0, 10, 1, 1, 1, 1),
#  (32, 'Ad necess', 0, 0, 10, 1, 1, 1, 1),
#  (33, 'Expedita c', 0, 0, 10, 1, 1, 1, 1),
#  (34, 'Voluptates sunt voluptas volu', 0, 0, 10, 1, 1, 1, 1),
#  (35, 'Autem mollitia fuga lauda', 0, 0, 10, 1, 1, 1, 1),
#  (36, 'Sint quibusdam ob', 0, 0, 10, 1, 1, 1, 1),
#  (37, 'Rerum et o', 0, 0, 10, 1, 1, 1, 1),
#  (38, 'Doloribus dolore r', 0, 0, 10, 1, 1, 1, 1),
#  (39, 'Eaque su', 0, 0, 10, 1, 1, 1, 1),
#  (40, 'Vel molestias numqua', 0, 0, 10, 1, 1, 1, 1),
#  (41, 'Iste assumenda repellat q', 0, 0, 10, 1, 1, 1, 1),
#  (42, 'Animi labo', 0, 0, 10, 1, 1, 1, 1),
#  (43, 'Eum culpa eaque ea omn', 0, 0, 10, 1, 1, 1, 1),
#  (44, 'Harum provident vel quam', 0, 0, 10, 1, 1, 1, 1),
#  (45, 'Aspe', 0, 0, 10, 1, 1, 1, 1),
#  (46, 'Nisi nequ', 0, 0, 10, 1, 1, 1, 1),
#  (47, 'Quod tempora', 0, 0, 10, 1, 1, 1, 1),
#  (48, 'Porro aliq', 0, 0, 10, 1, 1, 1, 1),
#  (49, 'Quas', 0, 0, 10, 1, 1, 1, 1),
#  (50, 'Magnam eligendi quia animi', 0, 0, 10, 1, 1, 1, 1),
#  (51, 'Officiis se', 0, 0, 10, 1, 1, 1, 1),
#  (52, 'Id assumend', 0, 0, 10, 1, 1, 1, 1),
#  (53, 'Voluptatibus fu', 0, 0, 10, 1, 1, 1, 1),
#  (54, 'Odit rat', 0, 0, 10, 1, 1, 1, 1),
#  (55, 'Debit', 0, 0, 10, 1, 1, 1, 1),
#  (56, 'Cum aut quas repudia', 0, 0, 10, 1, 1, 1, 1),
#  (57, 'Deleniti qui quae quidem', 0, 0, 10, 1, 1, 1, 1),
#  (58, 'Adipisci voluptas', 0, 0, 10, 1, 1, 1, 1),
#  (59, 'Debitis sit ratione eos nam', 0, 0, 10, 1, 1, 1, 1),
#  (60, 'Esse illo molestias archi', 0, 0, 10, 1, 1, 1, 1),
#  (61, 'Sunt at itaque voluptatum d', 0, 0, 10, 1, 1, 1, 1),
#  (62, 'Est totam', 0, 0, 10, 1, 1, 1, 1),
#  (63, 'Reprehenderit commodi eius', 0, 0, 10, 1, 1, 1, 1),
#  (64, 'Debit', 0, 0, 10, 1, 1, 1, 1),
#  (65, 'Soluta dol', 0, 0, 10, 1, 1, 1, 1),
#  (66, 'Vel nesc', 0, 0, 10, 1, 1, 1, 1),
#  (67, 'Ratione quia ali', 0, 0, 10, 1, 1, 1, 1),
#  (68, 'Rerum recusandae minima', 0, 0, 10, 1, 1, 1, 1),
#  (69, 'Totam natus eius fugiat volu', 0, 0, 10, 1, 1, 1, 1),
#  (70, 'Perferendis commodi null', 0, 0, 10, 1, 1, 1, 1),
#  (71, 'Laudantiu', 0, 0, 10, 1, 1, 1, 1),
#  (72, 'Voluptat', 0, 0, 10, 1, 1, 1, 1),
#  (73, 'Incidunt nesciun', 0, 0, 10, 1, 1, 1, 1),
#  (74, 'Illum amet vero', 0, 0, 10, 1, 1, 1, 1),
#  (75, 'Suscipit exercitationem re', 0, 0, 10, 1, 1, 1, 1),
#  (76, 'Quas enim error maxime nisi m', 0, 0, 10, 1, 1, 1, 1),
#  (77, 'Labore qu', 0, 0, 10, 1, 1, 1, 1),
#  (78, 'Repudiandae deleniti unde', 0, 0, 10, 1, 1, 1, 1),
#  (79, 'Ut do', 0, 0, 10, 1, 1, 1, 1),
#  (80, 'Quaerat esse labore q', 0, 0, 10, 1, 1, 1, 1),
#  (81, 'Quidem aliq', 0, 0, 10, 1, 1, 1, 1),
#  (82, 'Aperiam vitae eos dolor sed', 0, 0, 10, 1, 1, 1, 1),
#  (83, 'Minus nobis porro', 0, 0, 10, 1, 1, 1, 1),
#  (84, 'In similique', 0, 0, 10, 1, 1, 1, 1),
#  (85, 'Culpa repellat unde', 0, 0, 10, 1, 1, 1, 1),
#  (86, 'Architecto i', 0, 0, 10, 1, 1, 1, 1),
#  (87, 'A sed pariatur qua', 0, 0, 10, 1, 1, 1, 1),
#  (88, 'Tempore assumenda aperiam', 0, 0, 10, 1, 1, 1, 1),
#  (89, 'Sed ullam tempora iusto co', 0, 0, 10, 1, 1, 1, 1),
#  (90, 'Ipsa', 0, 0, 10, 1, 1, 1, 1),
#  (91, 'Fugiat incidun', 0, 0, 10, 1, 1, 1, 1),
#  (92, 'Molestiae of', 0, 0, 10, 1, 1, 1, 1),
#  (93, 'Quae quisquam cons', 0, 0, 10, 1, 1, 1, 1),
#  (94, 'Repellendus ea non facil', 0, 0, 10, 1, 1, 1, 1),
#  (95, 'Quod non quibu', 0, 0, 10, 1, 1, 1, 1),
#  (96, 'Numquam velit distinctio', 0, 0, 10, 1, 1, 1, 1),
#  (97, 'Necessitatibus nihil ex debi', 0, 0, 10, 1, 1, 1, 1),
#  (98, 'Velit tempore nemo, na', 0, 0, 10, 1, 1, 1, 1),
#  (99, 'Nesciunt v', 0, 0, 10, 1, 1, 1, 1),
#  (100, 'Dicta enim debitis accusantiu', 0, 0, 10, 1, 1, 1, 1),
#  (101, 'Vitae a', 0, 0, 10, 1, 1, 1, 1),
#  (102, 'Praesentium voluptas u', 0, 0, 10, 1, 1, 1, 1),
#  (103, 'Unde ullam mollitia? Nu', 0, 0, 10, 1, 1, 1, 1),
#  (104, 'Neque molestias qu', 0, 0, 10, 1, 1, 1, 1),
#  (105, 'Officiis es', 0, 0, 10, 1, 1, 1, 1),
#  (106, 'Beatae mi', 0, 0, 10, 1, 1, 1, 1),
#  (107, 'Mollitia nam corporis temp', 0, 0, 10, 1, 1, 1, 1),
#  (108, 'Repudiandae repellat i', 0, 0, 10, 1, 1, 1, 1),
#  (109, 'Laboriosam', 0, 0, 10, 1, 1, 1, 1),
#  (110, 'Nam minus amet', 0, 0, 10, 1, 1, 1, 1),
#  (111, 'Harum quae volup', 0, 0, 10, 1, 1, 1, 1),
#  (112, 'Impedit facere ulla', 0, 0, 10, 1, 1, 1, 1),
#  (113, 'Enim', 0, 0, 10, 1, 1, 1, 1),
#  (114, 'Dolore magni', 0, 0, 10, 1, 1, 1, 1),
#  (115, 'Eaque at corpori', 0, 0, 10, 1, 1, 1, 1),
#  (116, 'Fug', 0, 0, 10, 1, 1, 1, 1),
#  (117, 'Dolorum laudanti', 0, 0, 10, 1, 1, 1, 1),
#  (118, 'Perferendis nat', 0, 0, 10, 1, 1, 1, 1),
#  (119, 'Cupidi', 0, 0, 10, 1, 1, 1, 1),
#  (120, 'Commodi eius dicta digniss', 0, 0, 10, 1, 1, 1, 1),
#  (121, 'Debitis eu', 0, 0, 10, 1, 1, 1, 1),
#  (122, 'Nihil repella', 0, 0, 10, 1, 1, 1, 1),
#  (123, 'Rem quasi minima hic sed anim', 0, 0, 10, 1, 1, 1, 1),
#  (124, 'Sed ali', 0, 0, 10, 1, 1, 1, 1),
#  (125, 'Earum vol', 0, 0, 10, 1, 1, 1, 1),
#  (126, 'Inventore tempore com', 0, 0, 10, 1, 1, 1, 1),
#  (127, 'Repell', 0, 0, 10, 1, 1, 1, 1),
#  (128, 'Consequatur quis recusandae qu', 0, 0, 10, 1, 1, 1, 1),
#  (129, 'Dolores ea velit mi', 0, 0, 10, 1, 1, 1, 1),
#  (130, 'Atque blanditiis a aperiam', 0, 0, 10, 1, 1, 1, 1),
#  (131, 'Reprehenderit sequi iu', 0, 0, 10, 1, 1, 1, 1),
#  (132, 'Natus architecto eos, hic blan', 0, 0, 10, 1, 1, 1, 1),
#  (133, 'Ipsa illo quas', 0, 0, 10, 1, 1, 1, 1),
#  (134, 'Voluptas ali', 0, 0, 10, 1, 1, 1, 1),
#  (135, 'Voluptates obcaecati quod e', 0, 0, 10, 1, 1, 1, 1),
#  (136, 'Dolor adipisci a voluptate', 0, 0, 10, 1, 1, 1, 1),
#  (137, 'Repellendus natus quae, n', 0, 0, 10, 1, 1, 1, 1),
#  (138, 'Laudantium earum nam in dol', 0, 0, 10, 1, 1, 1, 1),
#  (139, 'Molestias face', 0, 0, 10, 1, 1, 1, 1),
#  (140, 'Maiores suscipit exc', 0, 0, 10, 1, 1, 1, 1),
#  (141, 'Illum dolore perferen', 0, 0, 10, 1, 1, 1, 1),
#  (142, 'Explicabo recusandae ma', 0, 0, 10, 1, 1, 1, 1),
#  (143, 'Odio obcaecati hic nostrum n', 0, 0, 10, 1, 1, 1, 1),
#  (144, 'Voluptate ali', 0, 0, 10, 1, 1, 1, 1),
#  (145, 'Repudiandae vitae sapiente mol', 0, 0, 10, 1, 1, 1, 1),
#  (146, 'Ipsam cumque', 0, 0, 10, 1, 1, 1, 1),
#  (147, 'Fugiat quos alias eos dese', 0, 0, 10, 1, 1, 1, 1),
#  (148, 'Eaque impe', 0, 0, 10, 1, 1, 1, 1),
#  (149, 'Elige', 0, 0, 10, 1, 1, 1, 1),
#  (150, 'Adip', 0, 0, 10, 1, 1, 1, 1),
#  (151, 'Fuga nemo vel mo', 0, 0, 10, 1, 1, 1, 1),
#  (152, 'Libero cumque impedit eveniet', 0, 0, 10, 1, 1, 1, 1),
#  (153, 'Odio soluta', 0, 0, 10, 1, 1, 1, 1),
#  (154, 'Vero nostrum duc', 0, 0, 10, 1, 1, 1, 1),
#  (155, 'Repellend', 0, 0, 10, 1, 1, 1, 1),
#  (156, 'Quod', 0, 0, 10, 1, 1, 1, 1),
#  (157, 'Suscipit reiciend', 0, 0, 10, 1, 1, 1, 1),
#  (158, 'Voluptat', 0, 0, 10, 1, 1, 1, 1),
#  (159, 'Porro dolor fuga quam', 0, 0, 10, 1, 1, 1, 1),
#  (160, 'Amet quo fugit aliquam sequi', 0, 0, 10, 1, 1, 1, 1),
#  (161, 'Magni adipisci veritatis sit q', 0, 0, 10, 1, 1, 1, 1),
#  (162, 'Debitis enim cumque cum qu', 0, 0, 10, 1, 1, 1, 1),
#  (163, 'Dolorem eligend', 0, 0, 10, 1, 1, 1, 1),
#  (164, 'Autem lib', 0, 0, 10, 1, 1, 1, 1),
#  (165, 'Saepe assumenda perferendis f', 0, 0, 10, 1, 1, 1, 1),
#  (166, 'Deserunt', 0, 0, 10, 1, 1, 1, 1),
#  (167, 'Provident soluta simil', 0, 0, 10, 1, 1, 1, 1),
#  (168, 'In accu', 0, 0, 10, 1, 1, 1, 1),
#  (169, 'Inve', 0, 0, 10, 1, 1, 1, 1),
#  (170, 'Placeat sapiente', 0, 0, 10, 1, 1, 1, 1),
#  (171, 'Ducimus architecto ullam', 0, 0, 10, 1, 1, 1, 1),
#  (172, 'Voluptate tempora rerum', 0, 0, 10, 1, 1, 1, 1),
#  (173, 'Totam incidunt earum perspicia', 0, 0, 10, 1, 1, 1, 1),
#  (174, 'Optio quas e', 0, 0, 10, 1, 1, 1, 1),
#  (175, 'Ab illum invento', 0, 0, 10, 1, 1, 1, 1),
#  (176, 'Repellat quis natus totam, s', 0, 0, 10, 1, 1, 1, 1),
#  (177, 'Est voluptate accusantium tem', 0, 0, 10, 1, 1, 1, 1),
#  (178, 'Beatae q', 0, 0, 10, 1, 1, 1, 1),
#  (179, 'Velit', 0, 0, 10, 1, 1, 1, 1),
#  (180, 'Minus nequ', 0, 0, 10, 1, 1, 1, 1),
#  (181, 'Autem eos voluptates off', 0, 0, 10, 1, 1, 1, 1),
#  (182, 'Vel fug', 0, 0, 10, 1, 1, 1, 1),
#  (183, 'Architecto repudian', 0, 0, 10, 1, 1, 1, 1),
#  (184, 'Opti', 0, 0, 10, 1, 1, 1, 1),
#  (185, 'Iust', 0, 0, 10, 1, 1, 1, 1),
#  (186, 'Sapiente', 0, 0, 10, 1, 1, 1, 1),
#  (187, 'Officiis repellat corrupti su', 0, 0, 10, 1, 1, 1, 1),
#  (188, 'Dicta et natus e', 0, 0, 10, 1, 1, 1, 1),
#  (189, 'At quos', 0, 0, 10, 1, 1, 1, 1),
#  (190, 'Laborum ven', 0, 0, 10, 1, 1, 1, 1),
#  (191, 'Exceptur', 0, 0, 10, 1, 1, 1, 1),
#  (192, 'Reiciendis assumenda dolo', 0, 0, 10, 1, 1, 1, 1),
#  (193, 'Poss', 0, 0, 10, 1, 1, 1, 1),
#  (194, 'Acc', 0, 0, 10, 1, 1, 1, 1),
#  (195, 'Placeat esse archit', 0, 0, 10, 1, 1, 1, 1),
#  (196, 'Enim repellendus nihil est te', 0, 0, 10, 1, 1, 1, 1),
#  (197, 'Ipsam incidunt t', 0, 0, 10, 1, 1, 1, 1),
#  (198, 'Iure', 0, 0, 10, 1, 1, 1, 1),
#  (199, 'Illo en', 0, 0, 10, 1, 1, 1, 1),
#  (200, 'A rem ex', 0, 0, 10, 1, 1, 1, 1),
#  (201, 'Officiis su', 0, 0, 10, 1, 1, 1, 1),
#  (202, 'Numquam molestias', 0, 0, 10, 1, 1, 1, 1),
#  (203, 'Voluptates unde', 0, 0, 10, 1, 1, 1, 1),
#  (204, 'Quae praesentium vel', 0, 0, 10, 1, 1, 1, 1),
#  (205, 'Quas', 0, 0, 10, 1, 1, 1, 1),
#  (206, 'Dolores aliquid inv', 0, 0, 10, 1, 1, 1, 1),
#  (207, 'Mollitia tempore laborum eaqu', 0, 0, 10, 1, 1, 1, 1),
#  (208, 'Nobis voluptates fugiat quia', 0, 0, 10, 1, 1, 1, 1),
#  (209, 'Similique dolorem dolore maio', 0, 0, 10, 1, 1, 1, 1),
#  (210, 'Sapiente', 0, 0, 10, 1, 1, 1, 1),
#  (211, 'Officia nisi dolore', 0, 0, 10, 1, 1, 1, 1),
#  (212, 'Distinctio', 0, 0, 10, 1, 1, 1, 1),
#  (213, 'Eos quia dignissimos saepe vel', 0, 0, 10, 1, 1, 1, 1),
#  (214, 'Ullam neque sint eligendi', 0, 0, 10, 1, 1, 1, 1),
#  (215, 'Excepturi deleniti ab a', 0, 0, 10, 1, 1, 1, 1),
#  (216, 'Accusa', 0, 0, 10, 1, 1, 1, 1),
#  (217, 'Reiciendis laboriosam di', 0, 0, 10, 1, 1, 1, 1),
#  (218, 'Delectus ex', 0, 0, 10, 1, 1, 1, 1),
#  (219, 'Pari', 0, 0, 10, 1, 1, 1, 1),
#  (220, 'Veritatis velit facilis iste', 0, 0, 10, 1, 1, 1, 1),
#  (221, 'Dol', 0, 0, 10, 1, 1, 1, 1),
#  (222, 'Qui iste pr', 0, 0, 10, 1, 1, 1, 1),
#  (223, 'Deleni', 0, 0, 10, 1, 1, 1, 1),
#  (224, 'Reprehenderit volu', 0, 0, 10, 1, 1, 1, 1),
#  (225, 'Accusantium vitae n', 0, 0, 10, 1, 1, 1, 1),
#  (226, 'Natus consequatur incidun', 0, 0, 10, 1, 1, 1, 1),
#  (227, 'Dignissimos a', 0, 0, 10, 1, 1, 1, 1),
#  (228, 'Vitae modi', 0, 0, 10, 1, 1, 1, 1),
#  (229, 'Accusantium qu', 0, 0, 10, 1, 1, 1, 1),
#  (230, 'Reiciendis dignissimos ratio', 0, 0, 10, 1, 1, 1, 1),
#  (231, 'Expedita provident natus volup', 0, 0, 10, 1, 1, 1, 1),
#  (232, 'Rerum repellat voluptas c', 0, 0, 10, 1, 1, 1, 1),
#  (233, 'Maiores quos incidunt dolor', 0, 0, 10, 1, 1, 1, 1),
#  (234, 'Aper', 0, 0, 10, 1, 1, 1, 1),
#  (235, 'Nulla', 0, 0, 10, 1, 1, 1, 1),
#  (236, 'Laudantium tempora itaque', 0, 0, 10, 1, 1, 1, 1),
#  (237, 'Reprehenderit', 0, 0, 10, 1, 1, 1, 1),
#  (238, 'Aliqu', 0, 0, 10, 1, 1, 1, 1),
#  (239, 'Odio harum nam mole', 0, 0, 10, 1, 1, 1, 1),
#  (240, 'Arc', 0, 0, 10, 1, 1, 1, 1),
#  (241, 'Reprehenderit li', 0, 0, 10, 1, 1, 1, 1),
#  (242, 'Repr', 0, 0, 10, 1, 1, 1, 1),
#  (243, 'Optio m', 0, 0, 10, 1, 1, 1, 1),
#  (244, 'Esse odit amet rep', 0, 0, 10, 1, 1, 1, 1),
#  (245, 'Provident nostrum minima', 0, 0, 10, 1, 1, 1, 1),
#  (246, 'Ex nihil quae facilis a omni', 0, 0, 10, 1, 1, 1, 1),
#  (247, 'Dolorem quaerat sunt', 0, 0, 10, 1, 1, 1, 1),
#  (248, 'Distinctio', 0, 0, 10, 1, 1, 1, 1),
#  (249, 'Repudiandae ip', 0, 0, 10, 1, 1, 1, 1),
#  (250, 'Iste debitis dolorum amet m', 0, 0, 10, 1, 1, 1, 1),
#  (251, 'Non qui vo', 0, 0, 10, 1, 1, 1, 1),
#  (252, 'Dolorem ma', 0, 0, 10, 1, 1, 1, 1),
#  (253, 'Molestias labore tempore ita', 0, 0, 10, 1, 1, 1, 1),
#  (254, 'Vol', 0, 0, 10, 1, 1, 1, 1),
#  (255, 'Adipisci molest', 0, 0, 10, 1, 1, 1, 1),
#  (256, 'Omni', 0, 0, 10, 1, 1, 1, 1),
#  (257, 'Voluptatibus dolor', 0, 0, 10, 1, 1, 1, 1),
#  (258, 'Quo', 0, 0, 10, 1, 1, 1, 1),
#  (259, 'Atque aspernatur possi', 0, 0, 10, 1, 1, 1, 1),
#  (260, 'Ullam c', 0, 0, 10, 1, 1, 1, 1),
#  (261, 'Iusto quas voluptatibu', 0, 0, 10, 1, 1, 1, 1),
#  (262, 'Optio qui sunt dolores, ab', 0, 0, 10, 1, 1, 1, 1),
#  (263, 'Illum recusandae nulla re', 0, 0, 10, 1, 1, 1, 1),
#  (264, 'Verita', 0, 0, 10, 1, 1, 1, 1),
#  (265, 'Expedita quod blanditiis', 0, 0, 10, 1, 1, 1, 1),
#  (266, 'Mag', 0, 0, 10, 1, 1, 1, 1),
#  (267, 'Omnis quos aspernatur d', 0, 0, 10, 1, 1, 1, 1),
#  (268, 'Sunt impedit co', 0, 0, 10, 1, 1, 1, 1),
#  (269, 'Minima quam ea ad', 0, 0, 10, 1, 1, 1, 1),
#  (270, 'Suscipit quidem e', 0, 0, 10, 1, 1, 1, 1),
#  (271, 'Harum', 0, 0, 10, 1, 1, 1, 1),
#  (272, 'Dolore laborum ips', 0, 0, 10, 1, 1, 1, 1),
#  (273, 'Magni veniam earum corporis', 0, 0, 10, 1, 1, 1, 1),
#  (274, 'Optio', 0, 0, 10, 1, 1, 1, 1),
#  (275, 'Nam fugit vel.', 0, 0, 10, 1, 1, 1, 1),
#  (276, 'Ut numquam quam eum, alias ius', 0, 0, 10, 1, 1, 1, 1),
#  (277, 'Error amet tempore nulla', 0, 0, 10, 1, 1, 1, 1),
#  (278, 'Deserunt a', 0, 0, 10, 1, 1, 1, 1),
#  (279, 'Aperiam sit', 0, 0, 10, 1, 1, 1, 1),
#  (280, 'Asperi', 0, 0, 10, 1, 1, 1, 1),
#  (281, 'Similique aperiam earum expli', 0, 0, 10, 1, 1, 1, 1),
#  (282, 'Iure h', 0, 0, 10, 1, 1, 1, 1),
#  (283, 'At sint ducimus nostrum i', 0, 0, 10, 1, 1, 1, 1),
#  (284, 'Reprehenderit temporib', 0, 0, 10, 1, 1, 1, 1),
#  (285, 'Molestiae quaerat maxim', 0, 0, 10, 1, 1, 1, 1),
#  (286, 'Maior', 0, 0, 10, 1, 1, 1, 1),
#  (287, 'Unde natus ut ipsa cupi', 0, 0, 10, 1, 1, 1, 1),
#  (288, 'Praesentium atque ear', 0, 0, 10, 1, 1, 1, 1),
#  (289, 'Rem minima', 0, 0, 10, 1, 1, 1, 1),
#  (290, 'Provident sed soluta, sed si', 0, 0, 10, 1, 1, 1, 1),
#  (291, 'Natus quia veritatis', 0, 0, 10, 1, 1, 1, 1),
#  (292, 'Vero a', 0, 0, 10, 1, 1, 1, 1),
#  (293, 'Optio harum labori', 0, 0, 10, 1, 1, 1, 1),
#  (294, 'Duci', 0, 0, 10, 1, 1, 1, 1),
#  (295, 'Ipsa elige', 0, 0, 10, 1, 1, 1, 1),
#  (296, 'Sunt blanditiis i', 0, 0, 10, 1, 1, 1, 1),
#  (297, 'Doloremque', 0, 0, 10, 1, 1, 1, 1),
#  (298, 'Autem ratione vitae quos, do', 0, 0, 10, 1, 1, 1, 1),
#  (299, 'Voluptatibus aliquid', 0, 0, 10, 1, 1, 1, 1),
#  (300, 'Quaerat sequi sit eius corpori', 0, 0, 10, 1, 1, 1, 1),
#  (301, 'Libe', 0, 0, 10, 1, 1, 1, 1),
#  (302, 'Aliquam n', 0, 0, 10, 1, 1, 1, 1)]

# %%
single_character
# Out:
# (1, 'Aliquid iste optio reiciendi', 0, 0, 10, 1, 1, 1, 1)

# %% [markdown]
# So the data is here. Just to look at the key information one more time:
#
# ```python
# class Character(models.Model):
#     """Base representation of RPG characters."""
#     character_id = models.AutoField(primary_key=True)
#     name = models.CharField("Character's name", max_length=30)
#     level = models.IntegerField(default=0)
#     exp = models.IntegerField(default=0)
#     hp = models.IntegerField(default=10)
#     strength = models.IntegerField(default=1)
#     intelligence = models.IntegerField(default=1)
#     dexterity = models.IntegerField(default=1)
#     wisdom = models.IntegerField(default=1)
# ```

# %%
doc = {
    'sql_id' : single_character[0],
    'name' : single_character[1],
    'level' : single_character[2],
    'exp' : single_character[3],
    'hp' : single_character[4],
    'strength' : single_character[5],
    'intelligence' : single_character[6],
    'dexterity' : single_character[7],
    'wisdom' : single_character[8]
}

# %%
doc
# Out:
# {'sql_id': 1,
#  'name': 'Aliquid iste optio reiciendi',
#  'level': 0,
#  'exp': 0,
#  'hp': 10,
#  'strength': 1,
#  'intelligence': 1,
#  'dexterity': 1,
#  'wisdom': 1}

# %%
# Now I can use this template to loop through the character database. 
# I will use a list comprehension, then the insert_many method. 

documents = []
for i in list(range(len(characters))):
    document = {'sql_id' : characters[i][0],
                        'name' : characters[i][1],
                        'level' : characters[i][2],
                        'exp' : characters[i][3],
                        'hp' : characters[i][4],
                        'strength' : characters[i][5],
                        'intelligence' : characters[i][6],
                        'dexterity' : characters[i][7],
                        'wisdom' : characters[i][8]}
    documents.append(document)
    
documents
# Out:
# [{'sql_id': 1,
#   'name': 'Aliquid iste optio reiciendi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 2,
#   'name': 'Optio dolorem ex a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 3,
#   'name': 'Minus c',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 4,
#   'name': 'Sit ut repr',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 5,
#   'name': 'At id recusandae expl',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 6,
#   'name': 'Non nobis et of',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 7,
#   'name': 'Perferendis',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 8,
#   'name': 'Accusantium amet quidem eve',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 9,
#   'name': 'Sed nostrum inventore error m',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 10,
#   'name': 'Harum repellendus omnis od',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 11,
#   'name': 'Itaque ut commodi,',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 12,
#   'name': 'Molestiae quis',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 13,
#   'name': 'Ali',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 14,
#   'name': 'Tempora quod optio possimus il',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 15,
#   'name': 'Sed itaque beatae pari',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 16,
#   'name': 'Quam dolor',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 17,
#   'name': 'Molestias expedita',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 18,
#   'name': 'Lauda',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 19,
#   'name': 'Incidunt sint perferen',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 20,
#   'name': 'Laboriosa',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 21,
#   'name': 'Dolore esse nesciunt fugit com',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 22,
#   'name': 'Dolorum nam reic',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 23,
#   'name': 'Repellat ad numquam volu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 24,
#   'name': 'Facere enim velit eligend',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 25,
#   'name': 'Sed ratione quis rep',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 26,
#   'name': 'Doloribus neque',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 27,
#   'name': 'Ab voluptas se',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 28,
#   'name': 'Molestias m',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 29,
#   'name': 'In pariatur corpori',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 30,
#   'name': 'Possimus ad dignissimos vel, a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 31,
#   'name': 'At minus accusa',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 32,
#   'name': 'Ad necess',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 33,
#   'name': 'Expedita c',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 34,
#   'name': 'Voluptates sunt voluptas volu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 35,
#   'name': 'Autem mollitia fuga lauda',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 36,
#   'name': 'Sint quibusdam ob',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 37,
#   'name': 'Rerum et o',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 38,
#   'name': 'Doloribus dolore r',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 39,
#   'name': 'Eaque su',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 40,
#   'name': 'Vel molestias numqua',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 41,
#   'name': 'Iste assumenda repellat q',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 42,
#   'name': 'Animi labo',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 43,
#   'name': 'Eum culpa eaque ea omn',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 44,
#   'name': 'Harum provident vel quam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 45,
#   'name': 'Aspe',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 46,
#   'name': 'Nisi nequ',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 47,
#   'name': 'Quod tempora',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 48,
#   'name': 'Porro aliq',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 49,
#   'name': 'Quas',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 50,
#   'name': 'Magnam eligendi quia animi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 51,
#   'name': 'Officiis se',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 52,
#   'name': 'Id assumend',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 53,
#   'name': 'Voluptatibus fu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 54,
#   'name': 'Odit rat',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 55,
#   'name': 'Debit',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 56,
#   'name': 'Cum aut quas repudia',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 57,
#   'name': 'Deleniti qui quae quidem',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 58,
#   'name': 'Adipisci voluptas',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 59,
#   'name': 'Debitis sit ratione eos nam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 60,
#   'name': 'Esse illo molestias archi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 61,
#   'name': 'Sunt at itaque voluptatum d',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 62,
#   'name': 'Est totam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 63,
#   'name': 'Reprehenderit commodi eius',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 64,
#   'name': 'Debit',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 65,
#   'name': 'Soluta dol',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 66,
#   'name': 'Vel nesc',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 67,
#   'name': 'Ratione quia ali',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 68,
#   'name': 'Rerum recusandae minima',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 69,
#   'name': 'Totam natus eius fugiat volu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 70,
#   'name': 'Perferendis commodi null',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 71,
#   'name': 'Laudantiu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 72,
#   'name': 'Voluptat',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 73,
#   'name': 'Incidunt nesciun',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 74,
#   'name': 'Illum amet vero',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 75,
#   'name': 'Suscipit exercitationem re',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 76,
#   'name': 'Quas enim error maxime nisi m',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 77,
#   'name': 'Labore qu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 78,
#   'name': 'Repudiandae deleniti unde',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 79,
#   'name': 'Ut do',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 80,
#   'name': 'Quaerat esse labore q',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 81,
#   'name': 'Quidem aliq',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 82,
#   'name': 'Aperiam vitae eos dolor sed',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 83,
#   'name': 'Minus nobis porro',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 84,
#   'name': 'In similique',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 85,
#   'name': 'Culpa repellat unde',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 86,
#   'name': 'Architecto i',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 87,
#   'name': 'A sed pariatur qua',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 88,
#   'name': 'Tempore assumenda aperiam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 89,
#   'name': 'Sed ullam tempora iusto co',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 90,
#   'name': 'Ipsa',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 91,
#   'name': 'Fugiat incidun',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 92,
#   'name': 'Molestiae of',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 93,
#   'name': 'Quae quisquam cons',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 94,
#   'name': 'Repellendus ea non facil',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 95,
#   'name': 'Quod non quibu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 96,
#   'name': 'Numquam velit distinctio',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 97,
#   'name': 'Necessitatibus nihil ex debi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 98,
#   'name': 'Velit tempore nemo, na',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 99,
#   'name': 'Nesciunt v',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 100,
#   'name': 'Dicta enim debitis accusantiu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 101,
#   'name': 'Vitae a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 102,
#   'name': 'Praesentium voluptas u',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 103,
#   'name': 'Unde ullam mollitia? Nu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 104,
#   'name': 'Neque molestias qu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 105,
#   'name': 'Officiis es',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 106,
#   'name': 'Beatae mi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 107,
#   'name': 'Mollitia nam corporis temp',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 108,
#   'name': 'Repudiandae repellat i',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 109,
#   'name': 'Laboriosam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 110,
#   'name': 'Nam minus amet',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 111,
#   'name': 'Harum quae volup',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 112,
#   'name': 'Impedit facere ulla',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 113,
#   'name': 'Enim',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 114,
#   'name': 'Dolore magni',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 115,
#   'name': 'Eaque at corpori',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 116,
#   'name': 'Fug',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 117,
#   'name': 'Dolorum laudanti',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 118,
#   'name': 'Perferendis nat',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 119,
#   'name': 'Cupidi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 120,
#   'name': 'Commodi eius dicta digniss',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 121,
#   'name': 'Debitis eu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 122,
#   'name': 'Nihil repella',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 123,
#   'name': 'Rem quasi minima hic sed anim',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 124,
#   'name': 'Sed ali',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 125,
#   'name': 'Earum vol',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 126,
#   'name': 'Inventore tempore com',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 127,
#   'name': 'Repell',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 128,
#   'name': 'Consequatur quis recusandae qu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 129,
#   'name': 'Dolores ea velit mi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 130,
#   'name': 'Atque blanditiis a aperiam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 131,
#   'name': 'Reprehenderit sequi iu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 132,
#   'name': 'Natus architecto eos, hic blan',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 133,
#   'name': 'Ipsa illo quas',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 134,
#   'name': 'Voluptas ali',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 135,
#   'name': 'Voluptates obcaecati quod e',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 136,
#   'name': 'Dolor adipisci a voluptate',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 137,
#   'name': 'Repellendus natus quae, n',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 138,
#   'name': 'Laudantium earum nam in dol',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 139,
#   'name': 'Molestias face',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 140,
#   'name': 'Maiores suscipit exc',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 141,
#   'name': 'Illum dolore perferen',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 142,
#   'name': 'Explicabo recusandae ma',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 143,
#   'name': 'Odio obcaecati hic nostrum n',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 144,
#   'name': 'Voluptate ali',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 145,
#   'name': 'Repudiandae vitae sapiente mol',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 146,
#   'name': 'Ipsam cumque',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 147,
#   'name': 'Fugiat quos alias eos dese',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 148,
#   'name': 'Eaque impe',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 149,
#   'name': 'Elige',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 150,
#   'name': 'Adip',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 151,
#   'name': 'Fuga nemo vel mo',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 152,
#   'name': 'Libero cumque impedit eveniet',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 153,
#   'name': 'Odio soluta',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 154,
#   'name': 'Vero nostrum duc',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 155,
#   'name': 'Repellend',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 156,
#   'name': 'Quod',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 157,
#   'name': 'Suscipit reiciend',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 158,
#   'name': 'Voluptat',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 159,
#   'name': 'Porro dolor fuga quam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 160,
#   'name': 'Amet quo fugit aliquam sequi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 161,
#   'name': 'Magni adipisci veritatis sit q',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 162,
#   'name': 'Debitis enim cumque cum qu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 163,
#   'name': 'Dolorem eligend',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 164,
#   'name': 'Autem lib',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 165,
#   'name': 'Saepe assumenda perferendis f',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 166,
#   'name': 'Deserunt',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 167,
#   'name': 'Provident soluta simil',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 168,
#   'name': 'In accu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 169,
#   'name': 'Inve',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 170,
#   'name': 'Placeat sapiente',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 171,
#   'name': 'Ducimus architecto ullam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 172,
#   'name': 'Voluptate tempora rerum',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 173,
#   'name': 'Totam incidunt earum perspicia',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 174,
#   'name': 'Optio quas e',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 175,
#   'name': 'Ab illum invento',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 176,
#   'name': 'Repellat quis natus totam, s',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 177,
#   'name': 'Est voluptate accusantium tem',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 178,
#   'name': 'Beatae q',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 179,
#   'name': 'Velit',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 180,
#   'name': 'Minus nequ',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 181,
#   'name': 'Autem eos voluptates off',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 182,
#   'name': 'Vel fug',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 183,
#   'name': 'Architecto repudian',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 184,
#   'name': 'Opti',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 185,
#   'name': 'Iust',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 186,
#   'name': 'Sapiente',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 187,
#   'name': 'Officiis repellat corrupti su',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 188,
#   'name': 'Dicta et natus e',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 189,
#   'name': 'At quos',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 190,
#   'name': 'Laborum ven',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 191,
#   'name': 'Exceptur',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 192,
#   'name': 'Reiciendis assumenda dolo',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 193,
#   'name': 'Poss',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 194,
#   'name': 'Acc',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 195,
#   'name': 'Placeat esse archit',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 196,
#   'name': 'Enim repellendus nihil est te',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 197,
#   'name': 'Ipsam incidunt t',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 198,
#   'name': 'Iure',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 199,
#   'name': 'Illo en',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 200,
#   'name': 'A rem ex',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 201,
#   'name': 'Officiis su',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 202,
#   'name': 'Numquam molestias',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 203,
#   'name': 'Voluptates unde',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 204,
#   'name': 'Quae praesentium vel',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 205,
#   'name': 'Quas',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 206,
#   'name': 'Dolores aliquid inv',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 207,
#   'name': 'Mollitia tempore laborum eaqu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 208,
#   'name': 'Nobis voluptates fugiat quia',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 209,
#   'name': 'Similique dolorem dolore maio',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 210,
#   'name': 'Sapiente',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 211,
#   'name': 'Officia nisi dolore',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 212,
#   'name': 'Distinctio',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 213,
#   'name': 'Eos quia dignissimos saepe vel',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 214,
#   'name': 'Ullam neque sint eligendi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 215,
#   'name': 'Excepturi deleniti ab a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 216,
#   'name': 'Accusa',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 217,
#   'name': 'Reiciendis laboriosam di',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 218,
#   'name': 'Delectus ex',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 219,
#   'name': 'Pari',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 220,
#   'name': 'Veritatis velit facilis iste',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 221,
#   'name': 'Dol',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 222,
#   'name': 'Qui iste pr',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 223,
#   'name': 'Deleni',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 224,
#   'name': 'Reprehenderit volu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 225,
#   'name': 'Accusantium vitae n',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 226,
#   'name': 'Natus consequatur incidun',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 227,
#   'name': 'Dignissimos a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 228,
#   'name': 'Vitae modi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 229,
#   'name': 'Accusantium qu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 230,
#   'name': 'Reiciendis dignissimos ratio',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 231,
#   'name': 'Expedita provident natus volup',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 232,
#   'name': 'Rerum repellat voluptas c',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 233,
#   'name': 'Maiores quos incidunt dolor',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 234,
#   'name': 'Aper',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 235,
#   'name': 'Nulla',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 236,
#   'name': 'Laudantium tempora itaque',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 237,
#   'name': 'Reprehenderit',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 238,
#   'name': 'Aliqu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 239,
#   'name': 'Odio harum nam mole',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 240,
#   'name': 'Arc',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 241,
#   'name': 'Reprehenderit li',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 242,
#   'name': 'Repr',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 243,
#   'name': 'Optio m',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 244,
#   'name': 'Esse odit amet rep',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 245,
#   'name': 'Provident nostrum minima',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 246,
#   'name': 'Ex nihil quae facilis a omni',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 247,
#   'name': 'Dolorem quaerat sunt',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 248,
#   'name': 'Distinctio',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 249,
#   'name': 'Repudiandae ip',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 250,
#   'name': 'Iste debitis dolorum amet m',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 251,
#   'name': 'Non qui vo',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 252,
#   'name': 'Dolorem ma',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 253,
#   'name': 'Molestias labore tempore ita',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 254,
#   'name': 'Vol',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 255,
#   'name': 'Adipisci molest',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 256,
#   'name': 'Omni',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 257,
#   'name': 'Voluptatibus dolor',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 258,
#   'name': 'Quo',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 259,
#   'name': 'Atque aspernatur possi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 260,
#   'name': 'Ullam c',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 261,
#   'name': 'Iusto quas voluptatibu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 262,
#   'name': 'Optio qui sunt dolores, ab',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 263,
#   'name': 'Illum recusandae nulla re',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 264,
#   'name': 'Verita',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 265,
#   'name': 'Expedita quod blanditiis',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 266,
#   'name': 'Mag',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 267,
#   'name': 'Omnis quos aspernatur d',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 268,
#   'name': 'Sunt impedit co',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 269,
#   'name': 'Minima quam ea ad',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 270,
#   'name': 'Suscipit quidem e',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 271,
#   'name': 'Harum',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 272,
#   'name': 'Dolore laborum ips',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 273,
#   'name': 'Magni veniam earum corporis',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 274,
#   'name': 'Optio',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 275,
#   'name': 'Nam fugit vel.',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 276,
#   'name': 'Ut numquam quam eum, alias ius',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 277,
#   'name': 'Error amet tempore nulla',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 278,
#   'name': 'Deserunt a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 279,
#   'name': 'Aperiam sit',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 280,
#   'name': 'Asperi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 281,
#   'name': 'Similique aperiam earum expli',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 282,
#   'name': 'Iure h',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 283,
#   'name': 'At sint ducimus nostrum i',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 284,
#   'name': 'Reprehenderit temporib',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 285,
#   'name': 'Molestiae quaerat maxim',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 286,
#   'name': 'Maior',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 287,
#   'name': 'Unde natus ut ipsa cupi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 288,
#   'name': 'Praesentium atque ear',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 289,
#   'name': 'Rem minima',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 290,
#   'name': 'Provident sed soluta, sed si',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 291,
#   'name': 'Natus quia veritatis',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 292,
#   'name': 'Vero a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 293,
#   'name': 'Optio harum labori',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 294,
#   'name': 'Duci',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 295,
#   'name': 'Ipsa elige',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 296,
#   'name': 'Sunt blanditiis i',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 297,
#   'name': 'Doloremque',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 298,
#   'name': 'Autem ratione vitae quos, do',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 299,
#   'name': 'Voluptatibus aliquid',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 300,
#   'name': 'Quaerat sequi sit eius corpori',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 301,
#   'name': 'Libe',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'sql_id': 302,
#   'name': 'Aliquam n',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1}]

# %%
# Good thing the insert_many method takes a list as a parameter!
db.charactercreator_character.insert_many(documents)

# %%
list(db.charactercreator_character.find())
# Out:
# [{'_id': ObjectId('5cf882acb0e0523ab9fdcb88'),
#   'sql_id': 1,
#   'name': 'Aliquid iste optio reiciendi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb89'),
#   'sql_id': 2,
#   'name': 'Optio dolorem ex a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb8a'),
#   'sql_id': 3,
#   'name': 'Minus c',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb8b'),
#   'sql_id': 4,
#   'name': 'Sit ut repr',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb8c'),
#   'sql_id': 5,
#   'name': 'At id recusandae expl',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb8d'),
#   'sql_id': 6,
#   'name': 'Non nobis et of',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb8e'),
#   'sql_id': 7,
#   'name': 'Perferendis',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb8f'),
#   'sql_id': 8,
#   'name': 'Accusantium amet quidem eve',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb90'),
#   'sql_id': 9,
#   'name': 'Sed nostrum inventore error m',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb91'),
#   'sql_id': 10,
#   'name': 'Harum repellendus omnis od',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb92'),
#   'sql_id': 11,
#   'name': 'Itaque ut commodi,',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb93'),
#   'sql_id': 12,
#   'name': 'Molestiae quis',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb94'),
#   'sql_id': 13,
#   'name': 'Ali',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb95'),
#   'sql_id': 14,
#   'name': 'Tempora quod optio possimus il',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb96'),
#   'sql_id': 15,
#   'name': 'Sed itaque beatae pari',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb97'),
#   'sql_id': 16,
#   'name': 'Quam dolor',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb98'),
#   'sql_id': 17,
#   'name': 'Molestias expedita',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb99'),
#   'sql_id': 18,
#   'name': 'Lauda',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb9a'),
#   'sql_id': 19,
#   'name': 'Incidunt sint perferen',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb9b'),
#   'sql_id': 20,
#   'name': 'Laboriosa',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb9c'),
#   'sql_id': 21,
#   'name': 'Dolore esse nesciunt fugit com',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb9d'),
#   'sql_id': 22,
#   'name': 'Dolorum nam reic',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb9e'),
#   'sql_id': 23,
#   'name': 'Repellat ad numquam volu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcb9f'),
#   'sql_id': 24,
#   'name': 'Facere enim velit eligend',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcba0'),
#   'sql_id': 25,
#   'name': 'Sed ratione quis rep',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcba1'),
#   'sql_id': 26,
#   'name': 'Doloribus neque',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcba2'),
#   'sql_id': 27,
#   'name': 'Ab voluptas se',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcba3'),
#   'sql_id': 28,
#   'name': 'Molestias m',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcba4'),
#   'sql_id': 29,
#   'name': 'In pariatur corpori',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcba5'),
#   'sql_id': 30,
#   'name': 'Possimus ad dignissimos vel, a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcba6'),
#   'sql_id': 31,
#   'name': 'At minus accusa',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcba7'),
#   'sql_id': 32,
#   'name': 'Ad necess',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcba8'),
#   'sql_id': 33,
#   'name': 'Expedita c',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcba9'),
#   'sql_id': 34,
#   'name': 'Voluptates sunt voluptas volu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbaa'),
#   'sql_id': 35,
#   'name': 'Autem mollitia fuga lauda',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbab'),
#   'sql_id': 36,
#   'name': 'Sint quibusdam ob',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbac'),
#   'sql_id': 37,
#   'name': 'Rerum et o',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbad'),
#   'sql_id': 38,
#   'name': 'Doloribus dolore r',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbae'),
#   'sql_id': 39,
#   'name': 'Eaque su',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbaf'),
#   'sql_id': 40,
#   'name': 'Vel molestias numqua',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbb0'),
#   'sql_id': 41,
#   'name': 'Iste assumenda repellat q',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbb1'),
#   'sql_id': 42,
#   'name': 'Animi labo',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbb2'),
#   'sql_id': 43,
#   'name': 'Eum culpa eaque ea omn',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbb3'),
#   'sql_id': 44,
#   'name': 'Harum provident vel quam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbb4'),
#   'sql_id': 45,
#   'name': 'Aspe',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbb5'),
#   'sql_id': 46,
#   'name': 'Nisi nequ',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbb6'),
#   'sql_id': 47,
#   'name': 'Quod tempora',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbb7'),
#   'sql_id': 48,
#   'name': 'Porro aliq',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbb8'),
#   'sql_id': 49,
#   'name': 'Quas',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbb9'),
#   'sql_id': 50,
#   'name': 'Magnam eligendi quia animi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbba'),
#   'sql_id': 51,
#   'name': 'Officiis se',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbbb'),
#   'sql_id': 52,
#   'name': 'Id assumend',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbbc'),
#   'sql_id': 53,
#   'name': 'Voluptatibus fu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbbd'),
#   'sql_id': 54,
#   'name': 'Odit rat',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbbe'),
#   'sql_id': 55,
#   'name': 'Debit',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbbf'),
#   'sql_id': 56,
#   'name': 'Cum aut quas repudia',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbc0'),
#   'sql_id': 57,
#   'name': 'Deleniti qui quae quidem',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbc1'),
#   'sql_id': 58,
#   'name': 'Adipisci voluptas',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbc2'),
#   'sql_id': 59,
#   'name': 'Debitis sit ratione eos nam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbc3'),
#   'sql_id': 60,
#   'name': 'Esse illo molestias archi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbc4'),
#   'sql_id': 61,
#   'name': 'Sunt at itaque voluptatum d',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbc5'),
#   'sql_id': 62,
#   'name': 'Est totam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbc6'),
#   'sql_id': 63,
#   'name': 'Reprehenderit commodi eius',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbc7'),
#   'sql_id': 64,
#   'name': 'Debit',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbc8'),
#   'sql_id': 65,
#   'name': 'Soluta dol',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbc9'),
#   'sql_id': 66,
#   'name': 'Vel nesc',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbca'),
#   'sql_id': 67,
#   'name': 'Ratione quia ali',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbcb'),
#   'sql_id': 68,
#   'name': 'Rerum recusandae minima',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbcc'),
#   'sql_id': 69,
#   'name': 'Totam natus eius fugiat volu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbcd'),
#   'sql_id': 70,
#   'name': 'Perferendis commodi null',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbce'),
#   'sql_id': 71,
#   'name': 'Laudantiu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbcf'),
#   'sql_id': 72,
#   'name': 'Voluptat',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbd0'),
#   'sql_id': 73,
#   'name': 'Incidunt nesciun',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbd1'),
#   'sql_id': 74,
#   'name': 'Illum amet vero',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbd2'),
#   'sql_id': 75,
#   'name': 'Suscipit exercitationem re',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbd3'),
#   'sql_id': 76,
#   'name': 'Quas enim error maxime nisi m',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbd4'),
#   'sql_id': 77,
#   'name': 'Labore qu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbd5'),
#   'sql_id': 78,
#   'name': 'Repudiandae deleniti unde',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbd6'),
#   'sql_id': 79,
#   'name': 'Ut do',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbd7'),
#   'sql_id': 80,
#   'name': 'Quaerat esse labore q',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbd8'),
#   'sql_id': 81,
#   'name': 'Quidem aliq',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbd9'),
#   'sql_id': 82,
#   'name': 'Aperiam vitae eos dolor sed',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbda'),
#   'sql_id': 83,
#   'name': 'Minus nobis porro',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbdb'),
#   'sql_id': 84,
#   'name': 'In similique',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbdc'),
#   'sql_id': 85,
#   'name': 'Culpa repellat unde',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbdd'),
#   'sql_id': 86,
#   'name': 'Architecto i',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbde'),
#   'sql_id': 87,
#   'name': 'A sed pariatur qua',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbdf'),
#   'sql_id': 88,
#   'name': 'Tempore assumenda aperiam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbe0'),
#   'sql_id': 89,
#   'name': 'Sed ullam tempora iusto co',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbe1'),
#   'sql_id': 90,
#   'name': 'Ipsa',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbe2'),
#   'sql_id': 91,
#   'name': 'Fugiat incidun',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbe3'),
#   'sql_id': 92,
#   'name': 'Molestiae of',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbe4'),
#   'sql_id': 93,
#   'name': 'Quae quisquam cons',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbe5'),
#   'sql_id': 94,
#   'name': 'Repellendus ea non facil',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbe6'),
#   'sql_id': 95,
#   'name': 'Quod non quibu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbe7'),
#   'sql_id': 96,
#   'name': 'Numquam velit distinctio',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbe8'),
#   'sql_id': 97,
#   'name': 'Necessitatibus nihil ex debi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbe9'),
#   'sql_id': 98,
#   'name': 'Velit tempore nemo, na',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbea'),
#   'sql_id': 99,
#   'name': 'Nesciunt v',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbeb'),
#   'sql_id': 100,
#   'name': 'Dicta enim debitis accusantiu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbec'),
#   'sql_id': 101,
#   'name': 'Vitae a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbed'),
#   'sql_id': 102,
#   'name': 'Praesentium voluptas u',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbee'),
#   'sql_id': 103,
#   'name': 'Unde ullam mollitia? Nu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbef'),
#   'sql_id': 104,
#   'name': 'Neque molestias qu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbf0'),
#   'sql_id': 105,
#   'name': 'Officiis es',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbf1'),
#   'sql_id': 106,
#   'name': 'Beatae mi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbf2'),
#   'sql_id': 107,
#   'name': 'Mollitia nam corporis temp',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbf3'),
#   'sql_id': 108,
#   'name': 'Repudiandae repellat i',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbf4'),
#   'sql_id': 109,
#   'name': 'Laboriosam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbf5'),
#   'sql_id': 110,
#   'name': 'Nam minus amet',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbf6'),
#   'sql_id': 111,
#   'name': 'Harum quae volup',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbf7'),
#   'sql_id': 112,
#   'name': 'Impedit facere ulla',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbf8'),
#   'sql_id': 113,
#   'name': 'Enim',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbf9'),
#   'sql_id': 114,
#   'name': 'Dolore magni',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbfa'),
#   'sql_id': 115,
#   'name': 'Eaque at corpori',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbfb'),
#   'sql_id': 116,
#   'name': 'Fug',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbfc'),
#   'sql_id': 117,
#   'name': 'Dolorum laudanti',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbfd'),
#   'sql_id': 118,
#   'name': 'Perferendis nat',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbfe'),
#   'sql_id': 119,
#   'name': 'Cupidi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcbff'),
#   'sql_id': 120,
#   'name': 'Commodi eius dicta digniss',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc00'),
#   'sql_id': 121,
#   'name': 'Debitis eu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc01'),
#   'sql_id': 122,
#   'name': 'Nihil repella',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc02'),
#   'sql_id': 123,
#   'name': 'Rem quasi minima hic sed anim',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc03'),
#   'sql_id': 124,
#   'name': 'Sed ali',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc04'),
#   'sql_id': 125,
#   'name': 'Earum vol',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc05'),
#   'sql_id': 126,
#   'name': 'Inventore tempore com',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc06'),
#   'sql_id': 127,
#   'name': 'Repell',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc07'),
#   'sql_id': 128,
#   'name': 'Consequatur quis recusandae qu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc08'),
#   'sql_id': 129,
#   'name': 'Dolores ea velit mi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc09'),
#   'sql_id': 130,
#   'name': 'Atque blanditiis a aperiam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc0a'),
#   'sql_id': 131,
#   'name': 'Reprehenderit sequi iu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc0b'),
#   'sql_id': 132,
#   'name': 'Natus architecto eos, hic blan',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc0c'),
#   'sql_id': 133,
#   'name': 'Ipsa illo quas',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc0d'),
#   'sql_id': 134,
#   'name': 'Voluptas ali',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc0e'),
#   'sql_id': 135,
#   'name': 'Voluptates obcaecati quod e',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc0f'),
#   'sql_id': 136,
#   'name': 'Dolor adipisci a voluptate',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc10'),
#   'sql_id': 137,
#   'name': 'Repellendus natus quae, n',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc11'),
#   'sql_id': 138,
#   'name': 'Laudantium earum nam in dol',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc12'),
#   'sql_id': 139,
#   'name': 'Molestias face',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc13'),
#   'sql_id': 140,
#   'name': 'Maiores suscipit exc',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc14'),
#   'sql_id': 141,
#   'name': 'Illum dolore perferen',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc15'),
#   'sql_id': 142,
#   'name': 'Explicabo recusandae ma',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc16'),
#   'sql_id': 143,
#   'name': 'Odio obcaecati hic nostrum n',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc17'),
#   'sql_id': 144,
#   'name': 'Voluptate ali',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc18'),
#   'sql_id': 145,
#   'name': 'Repudiandae vitae sapiente mol',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc19'),
#   'sql_id': 146,
#   'name': 'Ipsam cumque',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc1a'),
#   'sql_id': 147,
#   'name': 'Fugiat quos alias eos dese',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc1b'),
#   'sql_id': 148,
#   'name': 'Eaque impe',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc1c'),
#   'sql_id': 149,
#   'name': 'Elige',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc1d'),
#   'sql_id': 150,
#   'name': 'Adip',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc1e'),
#   'sql_id': 151,
#   'name': 'Fuga nemo vel mo',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc1f'),
#   'sql_id': 152,
#   'name': 'Libero cumque impedit eveniet',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc20'),
#   'sql_id': 153,
#   'name': 'Odio soluta',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc21'),
#   'sql_id': 154,
#   'name': 'Vero nostrum duc',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc22'),
#   'sql_id': 155,
#   'name': 'Repellend',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc23'),
#   'sql_id': 156,
#   'name': 'Quod',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc24'),
#   'sql_id': 157,
#   'name': 'Suscipit reiciend',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc25'),
#   'sql_id': 158,
#   'name': 'Voluptat',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc26'),
#   'sql_id': 159,
#   'name': 'Porro dolor fuga quam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc27'),
#   'sql_id': 160,
#   'name': 'Amet quo fugit aliquam sequi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc28'),
#   'sql_id': 161,
#   'name': 'Magni adipisci veritatis sit q',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc29'),
#   'sql_id': 162,
#   'name': 'Debitis enim cumque cum qu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc2a'),
#   'sql_id': 163,
#   'name': 'Dolorem eligend',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc2b'),
#   'sql_id': 164,
#   'name': 'Autem lib',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc2c'),
#   'sql_id': 165,
#   'name': 'Saepe assumenda perferendis f',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc2d'),
#   'sql_id': 166,
#   'name': 'Deserunt',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc2e'),
#   'sql_id': 167,
#   'name': 'Provident soluta simil',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc2f'),
#   'sql_id': 168,
#   'name': 'In accu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc30'),
#   'sql_id': 169,
#   'name': 'Inve',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc31'),
#   'sql_id': 170,
#   'name': 'Placeat sapiente',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc32'),
#   'sql_id': 171,
#   'name': 'Ducimus architecto ullam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc33'),
#   'sql_id': 172,
#   'name': 'Voluptate tempora rerum',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc34'),
#   'sql_id': 173,
#   'name': 'Totam incidunt earum perspicia',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc35'),
#   'sql_id': 174,
#   'name': 'Optio quas e',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc36'),
#   'sql_id': 175,
#   'name': 'Ab illum invento',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc37'),
#   'sql_id': 176,
#   'name': 'Repellat quis natus totam, s',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc38'),
#   'sql_id': 177,
#   'name': 'Est voluptate accusantium tem',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc39'),
#   'sql_id': 178,
#   'name': 'Beatae q',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc3a'),
#   'sql_id': 179,
#   'name': 'Velit',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc3b'),
#   'sql_id': 180,
#   'name': 'Minus nequ',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc3c'),
#   'sql_id': 181,
#   'name': 'Autem eos voluptates off',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc3d'),
#   'sql_id': 182,
#   'name': 'Vel fug',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc3e'),
#   'sql_id': 183,
#   'name': 'Architecto repudian',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc3f'),
#   'sql_id': 184,
#   'name': 'Opti',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc40'),
#   'sql_id': 185,
#   'name': 'Iust',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc41'),
#   'sql_id': 186,
#   'name': 'Sapiente',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc42'),
#   'sql_id': 187,
#   'name': 'Officiis repellat corrupti su',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc43'),
#   'sql_id': 188,
#   'name': 'Dicta et natus e',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc44'),
#   'sql_id': 189,
#   'name': 'At quos',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc45'),
#   'sql_id': 190,
#   'name': 'Laborum ven',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc46'),
#   'sql_id': 191,
#   'name': 'Exceptur',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc47'),
#   'sql_id': 192,
#   'name': 'Reiciendis assumenda dolo',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc48'),
#   'sql_id': 193,
#   'name': 'Poss',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc49'),
#   'sql_id': 194,
#   'name': 'Acc',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc4a'),
#   'sql_id': 195,
#   'name': 'Placeat esse archit',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc4b'),
#   'sql_id': 196,
#   'name': 'Enim repellendus nihil est te',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc4c'),
#   'sql_id': 197,
#   'name': 'Ipsam incidunt t',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc4d'),
#   'sql_id': 198,
#   'name': 'Iure',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc4e'),
#   'sql_id': 199,
#   'name': 'Illo en',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc4f'),
#   'sql_id': 200,
#   'name': 'A rem ex',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc50'),
#   'sql_id': 201,
#   'name': 'Officiis su',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc51'),
#   'sql_id': 202,
#   'name': 'Numquam molestias',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc52'),
#   'sql_id': 203,
#   'name': 'Voluptates unde',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc53'),
#   'sql_id': 204,
#   'name': 'Quae praesentium vel',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc54'),
#   'sql_id': 205,
#   'name': 'Quas',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc55'),
#   'sql_id': 206,
#   'name': 'Dolores aliquid inv',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc56'),
#   'sql_id': 207,
#   'name': 'Mollitia tempore laborum eaqu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc57'),
#   'sql_id': 208,
#   'name': 'Nobis voluptates fugiat quia',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc58'),
#   'sql_id': 209,
#   'name': 'Similique dolorem dolore maio',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc59'),
#   'sql_id': 210,
#   'name': 'Sapiente',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc5a'),
#   'sql_id': 211,
#   'name': 'Officia nisi dolore',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc5b'),
#   'sql_id': 212,
#   'name': 'Distinctio',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc5c'),
#   'sql_id': 213,
#   'name': 'Eos quia dignissimos saepe vel',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc5d'),
#   'sql_id': 214,
#   'name': 'Ullam neque sint eligendi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc5e'),
#   'sql_id': 215,
#   'name': 'Excepturi deleniti ab a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc5f'),
#   'sql_id': 216,
#   'name': 'Accusa',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc60'),
#   'sql_id': 217,
#   'name': 'Reiciendis laboriosam di',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc61'),
#   'sql_id': 218,
#   'name': 'Delectus ex',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc62'),
#   'sql_id': 219,
#   'name': 'Pari',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc63'),
#   'sql_id': 220,
#   'name': 'Veritatis velit facilis iste',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc64'),
#   'sql_id': 221,
#   'name': 'Dol',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc65'),
#   'sql_id': 222,
#   'name': 'Qui iste pr',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc66'),
#   'sql_id': 223,
#   'name': 'Deleni',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc67'),
#   'sql_id': 224,
#   'name': 'Reprehenderit volu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc68'),
#   'sql_id': 225,
#   'name': 'Accusantium vitae n',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc69'),
#   'sql_id': 226,
#   'name': 'Natus consequatur incidun',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc6a'),
#   'sql_id': 227,
#   'name': 'Dignissimos a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc6b'),
#   'sql_id': 228,
#   'name': 'Vitae modi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc6c'),
#   'sql_id': 229,
#   'name': 'Accusantium qu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc6d'),
#   'sql_id': 230,
#   'name': 'Reiciendis dignissimos ratio',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc6e'),
#   'sql_id': 231,
#   'name': 'Expedita provident natus volup',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc6f'),
#   'sql_id': 232,
#   'name': 'Rerum repellat voluptas c',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc70'),
#   'sql_id': 233,
#   'name': 'Maiores quos incidunt dolor',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc71'),
#   'sql_id': 234,
#   'name': 'Aper',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc72'),
#   'sql_id': 235,
#   'name': 'Nulla',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc73'),
#   'sql_id': 236,
#   'name': 'Laudantium tempora itaque',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc74'),
#   'sql_id': 237,
#   'name': 'Reprehenderit',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc75'),
#   'sql_id': 238,
#   'name': 'Aliqu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc76'),
#   'sql_id': 239,
#   'name': 'Odio harum nam mole',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc77'),
#   'sql_id': 240,
#   'name': 'Arc',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc78'),
#   'sql_id': 241,
#   'name': 'Reprehenderit li',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc79'),
#   'sql_id': 242,
#   'name': 'Repr',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc7a'),
#   'sql_id': 243,
#   'name': 'Optio m',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc7b'),
#   'sql_id': 244,
#   'name': 'Esse odit amet rep',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc7c'),
#   'sql_id': 245,
#   'name': 'Provident nostrum minima',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc7d'),
#   'sql_id': 246,
#   'name': 'Ex nihil quae facilis a omni',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc7e'),
#   'sql_id': 247,
#   'name': 'Dolorem quaerat sunt',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc7f'),
#   'sql_id': 248,
#   'name': 'Distinctio',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc80'),
#   'sql_id': 249,
#   'name': 'Repudiandae ip',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc81'),
#   'sql_id': 250,
#   'name': 'Iste debitis dolorum amet m',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc82'),
#   'sql_id': 251,
#   'name': 'Non qui vo',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc83'),
#   'sql_id': 252,
#   'name': 'Dolorem ma',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc84'),
#   'sql_id': 253,
#   'name': 'Molestias labore tempore ita',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc85'),
#   'sql_id': 254,
#   'name': 'Vol',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc86'),
#   'sql_id': 255,
#   'name': 'Adipisci molest',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc87'),
#   'sql_id': 256,
#   'name': 'Omni',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc88'),
#   'sql_id': 257,
#   'name': 'Voluptatibus dolor',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc89'),
#   'sql_id': 258,
#   'name': 'Quo',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc8a'),
#   'sql_id': 259,
#   'name': 'Atque aspernatur possi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc8b'),
#   'sql_id': 260,
#   'name': 'Ullam c',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc8c'),
#   'sql_id': 261,
#   'name': 'Iusto quas voluptatibu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc8d'),
#   'sql_id': 262,
#   'name': 'Optio qui sunt dolores, ab',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc8e'),
#   'sql_id': 263,
#   'name': 'Illum recusandae nulla re',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc8f'),
#   'sql_id': 264,
#   'name': 'Verita',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc90'),
#   'sql_id': 265,
#   'name': 'Expedita quod blanditiis',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc91'),
#   'sql_id': 266,
#   'name': 'Mag',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc92'),
#   'sql_id': 267,
#   'name': 'Omnis quos aspernatur d',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc93'),
#   'sql_id': 268,
#   'name': 'Sunt impedit co',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc94'),
#   'sql_id': 269,
#   'name': 'Minima quam ea ad',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc95'),
#   'sql_id': 270,
#   'name': 'Suscipit quidem e',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc96'),
#   'sql_id': 271,
#   'name': 'Harum',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc97'),
#   'sql_id': 272,
#   'name': 'Dolore laborum ips',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc98'),
#   'sql_id': 273,
#   'name': 'Magni veniam earum corporis',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc99'),
#   'sql_id': 274,
#   'name': 'Optio',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc9a'),
#   'sql_id': 275,
#   'name': 'Nam fugit vel.',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc9b'),
#   'sql_id': 276,
#   'name': 'Ut numquam quam eum, alias ius',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc9c'),
#   'sql_id': 277,
#   'name': 'Error amet tempore nulla',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc9d'),
#   'sql_id': 278,
#   'name': 'Deserunt a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc9e'),
#   'sql_id': 279,
#   'name': 'Aperiam sit',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcc9f'),
#   'sql_id': 280,
#   'name': 'Asperi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcca0'),
#   'sql_id': 281,
#   'name': 'Similique aperiam earum expli',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcca1'),
#   'sql_id': 282,
#   'name': 'Iure h',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcca2'),
#   'sql_id': 283,
#   'name': 'At sint ducimus nostrum i',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcca3'),
#   'sql_id': 284,
#   'name': 'Reprehenderit temporib',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcca4'),
#   'sql_id': 285,
#   'name': 'Molestiae quaerat maxim',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcca5'),
#   'sql_id': 286,
#   'name': 'Maior',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcca6'),
#   'sql_id': 287,
#   'name': 'Unde natus ut ipsa cupi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcca7'),
#   'sql_id': 288,
#   'name': 'Praesentium atque ear',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcca8'),
#   'sql_id': 289,
#   'name': 'Rem minima',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdcca9'),
#   'sql_id': 290,
#   'name': 'Provident sed soluta, sed si',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdccaa'),
#   'sql_id': 291,
#   'name': 'Natus quia veritatis',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdccab'),
#   'sql_id': 292,
#   'name': 'Vero a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdccac'),
#   'sql_id': 293,
#   'name': 'Optio harum labori',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdccad'),
#   'sql_id': 294,
#   'name': 'Duci',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdccae'),
#   'sql_id': 295,
#   'name': 'Ipsa elige',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdccaf'),
#   'sql_id': 296,
#   'name': 'Sunt blanditiis i',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdccb0'),
#   'sql_id': 297,
#   'name': 'Doloremque',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdccb1'),
#   'sql_id': 298,
#   'name': 'Autem ratione vitae quos, do',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdccb2'),
#   'sql_id': 299,
#   'name': 'Voluptatibus aliquid',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdccb3'),
#   'sql_id': 300,
#   'name': 'Quaerat sequi sit eius corpori',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdccb4'),
#   'sql_id': 301,
#   'name': 'Libe',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5cf882acb0e0523ab9fdccb5'),
#   'sql_id': 302,
#   'name': 'Aliquam n',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1}]

# %% [markdown]
# ## Titanic Dataset to MongoDB

# %%
# Changing the database that I am working on.
db = client.titanic

df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# I can do a list comprehension to create a list of dictionaries just like the rpg_db. The effect should be the same.

# %%
documents = []

for i in list(range(len(df))):
    document = {
        'Survived' : str(df['Survived'][i]),
        'Pclass' : str(df['Pclass'][i]),
        'Name' : str(df['Name'][i]),
        'Sex' : str(df['Sex'][i]),
        'Age' : str(df['Age'][i]),
        'Siblings_Spouses Aboard' : str(df['Siblings/Spouses Aboard'][i]),
        'Parents_Children Aboard' : str(df['Parents/Children Aboard'][i]),
        'Fare' : str(df['Fare'][i])
    }
    documents.append(document)
    
documents
# Out:
# [{'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Owen Harris Braund',
#   'Sex': 'male',
#   'Age': '22.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.25'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mrs. John Bradley (Florence Briggs Thayer) Cumings',
#   'Sex': 'female',
#   'Age': '38.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '71.2833'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Laina Heikkinen',
#   'Sex': 'female',
#   'Age': '26.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.925'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mrs. Jacques Heath (Lily May Peel) Futrelle',
#   'Sex': 'female',
#   'Age': '35.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '53.1'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. William Henry Allen',
#   'Sex': 'male',
#   'Age': '35.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.05'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. James Moran',
#   'Sex': 'male',
#   'Age': '27.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.4583'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Timothy J McCarthy',
#   'Sex': 'male',
#   'Age': '54.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '51.8625'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Master. Gosta Leonard Palsson',
#   'Sex': 'male',
#   'Age': '2.0',
#   'Siblings_Spouses Aboard': '3',
#   'Parents_Children Aboard': '1',
#   'Fare': '21.075'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson',
#   'Sex': 'female',
#   'Age': '27.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '2',
#   'Fare': '11.1333'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Mrs. Nicholas (Adele Achem) Nasser',
#   'Sex': 'female',
#   'Age': '14.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '30.0708'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Marguerite Rut Sandstrom',
#   'Sex': 'female',
#   'Age': '4.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '1',
#   'Fare': '16.7'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Miss. Elizabeth Bonnell',
#   'Sex': 'female',
#   'Age': '58.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '26.55'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. William Henry Saundercock',
#   'Sex': 'male',
#   'Age': '20.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.05'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Anders Johan Andersson',
#   'Sex': 'male',
#   'Age': '39.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '5',
#   'Fare': '31.275'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Hulda Amanda Adolfina Vestrom',
#   'Sex': 'female',
#   'Age': '14.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8542'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Mrs. (Mary D Kingcome) Hewlett',
#   'Sex': 'female',
#   'Age': '55.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '16.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Master. Eugene Rice',
#   'Sex': 'male',
#   'Age': '2.0',
#   'Siblings_Spouses Aboard': '4',
#   'Parents_Children Aboard': '1',
#   'Fare': '29.125'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Mr. Charles Eugene Williams',
#   'Sex': 'male',
#   'Age': '23.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '13.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mrs. Julius (Emelia Maria Vandemoortele) Vander Planke',
#   'Sex': 'female',
#   'Age': '31.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '18.0'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mrs. Fatima Masselmani',
#   'Sex': 'female',
#   'Age': '22.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.225'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Joseph J Fynney',
#   'Sex': 'male',
#   'Age': '35.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '26.0'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Mr. Lawrence Beesley',
#   'Sex': 'male',
#   'Age': '34.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '13.0'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Anna McGowan',
#   'Sex': 'female',
#   'Age': '15.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.0292'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mr. William Thompson Sloper',
#   'Sex': 'male',
#   'Age': '28.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '35.5'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Torborg Danira Palsson',
#   'Sex': 'female',
#   'Age': '8.0',
#   'Siblings_Spouses Aboard': '3',
#   'Parents_Children Aboard': '1',
#   'Fare': '21.075'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mrs. Carl Oscar (Selma Augusta Emilia Johansson) Asplund',
#   'Sex': 'female',
#   'Age': '38.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '5',
#   'Fare': '31.3875'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Farred Chehab Emir',
#   'Sex': 'male',
#   'Age': '26.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.225'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Charles Alexander Fortune',
#   'Sex': 'male',
#   'Age': '19.0',
#   'Siblings_Spouses Aboard': '3',
#   'Parents_Children Aboard': '2',
#   'Fare': '263.0'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': "Miss. Ellen O'Dwyer",
#   'Sex': 'female',
#   'Age': '24.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8792'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Lalio Todoroff',
#   'Sex': 'male',
#   'Age': '23.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8958'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Don. Manuel E Uruchurtu',
#   'Sex': 'male',
#   'Age': '40.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '27.7208'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mrs. William Augustus (Marie Eugenie) Spencer',
#   'Sex': 'female',
#   'Age': '48.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '146.5208'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Mary Agatha Glynn',
#   'Sex': 'female',
#   'Age': '18.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.75'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Edward H Wheadon',
#   'Sex': 'male',
#   'Age': '66.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '10.5'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Edgar Joseph Meyer',
#   'Sex': 'male',
#   'Age': '28.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '82.1708'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Alexander Oskar Holverson',
#   'Sex': 'male',
#   'Age': '42.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '52.0'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mr. Hanna Mamee',
#   'Sex': 'male',
#   'Age': '18.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.2292'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Ernest Charles Cann',
#   'Sex': 'male',
#   'Age': '21.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.05'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Augusta Maria Vander Planke',
#   'Sex': 'female',
#   'Age': '18.0',
#   'Siblings_Spouses Aboard': '2',
#   'Parents_Children Aboard': '0',
#   'Fare': '18.0'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Jamila Nicola-Yarred',
#   'Sex': 'female',
#   'Age': '14.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '11.2417'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mrs. Johan (Johanna Persdotter Larsson) Ahlin',
#   'Sex': 'female',
#   'Age': '40.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '9.475'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mrs. William John Robert (Dorothy Ann Wonnacott) Turpin',
#   'Sex': 'female',
#   'Age': '27.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '21.0'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Miss. Simonne Marie Anne Andree Laroche',
#   'Sex': 'female',
#   'Age': '3.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '2',
#   'Fare': '41.5792'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Margaret Delia Devaney',
#   'Sex': 'female',
#   'Age': '19.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8792'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. William John Rogers',
#   'Sex': 'male',
#   'Age': '30.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.05'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Denis Lennon',
#   'Sex': 'male',
#   'Age': '20.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '15.5'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': "Miss. Bridget O'Driscoll",
#   'Sex': 'female',
#   'Age': '27.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.75'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Youssef Samaan',
#   'Sex': 'male',
#   'Age': '16.0',
#   'Siblings_Spouses Aboard': '2',
#   'Parents_Children Aboard': '0',
#   'Fare': '21.6792'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mrs. Josef (Josefine Franchi) Arnold-Franchi',
#   'Sex': 'female',
#   'Age': '18.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '17.8'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Master. Juha Niilo Panula',
#   'Sex': 'male',
#   'Age': '7.0',
#   'Siblings_Spouses Aboard': '4',
#   'Parents_Children Aboard': '1',
#   'Fare': '39.6875'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Richard Cater Nosworthy',
#   'Sex': 'male',
#   'Age': '21.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mrs. Henry Sleeper (Myna Haxtun) Harper',
#   'Sex': 'female',
#   'Age': '49.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '76.7292'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Mrs. Lizzie (Elizabeth Anne Wilkinson) Faunthorpe',
#   'Sex': 'female',
#   'Age': '29.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '26.0'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Engelhart Cornelius Ostby',
#   'Sex': 'male',
#   'Age': '65.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '1',
#   'Fare': '61.9792'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mr. Hugh Woolner',
#   'Sex': 'male',
#   'Age': '46.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '35.5'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Miss. Emily Rugg',
#   'Sex': 'female',
#   'Age': '21.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '10.5'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Mansouer Novel',
#   'Sex': 'male',
#   'Age': '28.5',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.2292'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Miss. Constance Mirium West',
#   'Sex': 'female',
#   'Age': '5.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '2',
#   'Fare': '27.75'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Master. William Frederick Goodwin',
#   'Sex': 'male',
#   'Age': '11.0',
#   'Siblings_Spouses Aboard': '5',
#   'Parents_Children Aboard': '2',
#   'Fare': '46.9'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Orsen Sirayanian',
#   'Sex': 'male',
#   'Age': '22.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.2292'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Miss. Amelie Icard',
#   'Sex': 'female',
#   'Age': '38.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '80.0'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Henry Birkhardt Harris',
#   'Sex': 'male',
#   'Age': '45.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '83.475'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Master. Harald Skoog',
#   'Sex': 'male',
#   'Age': '4.0',
#   'Siblings_Spouses Aboard': '3',
#   'Parents_Children Aboard': '2',
#   'Fare': '27.9'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Albert A Stewart',
#   'Sex': 'male',
#   'Age': '64.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '27.7208'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Master. Gerios Moubarek',
#   'Sex': 'male',
#   'Age': '7.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '1',
#   'Fare': '15.2458'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Mrs. (Elizabeth Ramell) Nye',
#   'Sex': 'female',
#   'Age': '29.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '10.5'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Ernest James Crease',
#   'Sex': 'male',
#   'Age': '19.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.1583'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Erna Alexandra Andersson',
#   'Sex': 'female',
#   'Age': '17.0',
#   'Siblings_Spouses Aboard': '4',
#   'Parents_Children Aboard': '2',
#   'Fare': '7.925'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Vincenz Kink',
#   'Sex': 'male',
#   'Age': '26.0',
#   'Siblings_Spouses Aboard': '2',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.6625'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Stephen Curnow Jenkin',
#   'Sex': 'male',
#   'Age': '32.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '10.5'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Lillian Amy Goodwin',
#   'Sex': 'female',
#   'Age': '16.0',
#   'Siblings_Spouses Aboard': '5',
#   'Parents_Children Aboard': '2',
#   'Fare': '46.9'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Ambrose Jr Hood',
#   'Sex': 'male',
#   'Age': '21.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '73.5'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Apostolos Chronopoulos',
#   'Sex': 'male',
#   'Age': '26.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '14.4542'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mr. Lee Bing',
#   'Sex': 'male',
#   'Age': '32.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '56.4958'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Sigurd Hansen Moen',
#   'Sex': 'male',
#   'Age': '25.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.65'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Ivan Staneff',
#   'Sex': 'male',
#   'Age': '23.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8958'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Rahamin Haim Moutal',
#   'Sex': 'male',
#   'Age': '28.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.05'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Master. Alden Gates Caldwell',
#   'Sex': 'male',
#   'Age': '0.83',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '2',
#   'Fare': '29.0'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Elizabeth Dowdell',
#   'Sex': 'female',
#   'Age': '30.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '12.475'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Achille Waelens',
#   'Sex': 'male',
#   'Age': '22.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '9.0'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mr. Jan Baptist Sheerlinck',
#   'Sex': 'male',
#   'Age': '29.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '9.5'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Brigdet Delia McDermott',
#   'Sex': 'female',
#   'Age': '31.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.7875'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Francisco M Carrau',
#   'Sex': 'male',
#   'Age': '28.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '47.1'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Miss. Bertha Ilett',
#   'Sex': 'female',
#   'Age': '17.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '10.5'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mrs. Karl Alfred (Maria Mathilda Gustafsson) Backstrom',
#   'Sex': 'female',
#   'Age': '33.0',
#   'Siblings_Spouses Aboard': '3',
#   'Parents_Children Aboard': '0',
#   'Fare': '15.85'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. William Neal Ford',
#   'Sex': 'male',
#   'Age': '16.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '3',
#   'Fare': '34.375'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Selman Francis Slocovski',
#   'Sex': 'male',
#   'Age': '20.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.05'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Miss. Mabel Helen Fortune',
#   'Sex': 'female',
#   'Age': '23.0',
#   'Siblings_Spouses Aboard': '3',
#   'Parents_Children Aboard': '2',
#   'Fare': '263.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Francesco Celotti',
#   'Sex': 'male',
#   'Age': '24.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.05'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Emil Christmann',
#   'Sex': 'male',
#   'Age': '29.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.05'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Paul Edvin Andreasson',
#   'Sex': 'male',
#   'Age': '20.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8542'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Herbert Fuller Chaffee',
#   'Sex': 'male',
#   'Age': '46.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '61.175'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Bertram Frank Dean',
#   'Sex': 'male',
#   'Age': '26.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '2',
#   'Fare': '20.575'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Daniel Coxon',
#   'Sex': 'male',
#   'Age': '59.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.25'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Charles Joseph Shorney',
#   'Sex': 'male',
#   'Age': '22.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.05'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. George B Goldschmidt',
#   'Sex': 'male',
#   'Age': '71.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '34.6542'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mr. William Bertram Greenfield',
#   'Sex': 'male',
#   'Age': '23.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '1',
#   'Fare': '63.3583'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Mrs. John T (Ada Julia Bone) Doling',
#   'Sex': 'female',
#   'Age': '34.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '1',
#   'Fare': '23.0'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Sinai Kantor',
#   'Sex': 'male',
#   'Age': '34.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '26.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Matilda Petranec',
#   'Sex': 'female',
#   'Age': '28.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8958'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Pastcho Petroff',
#   'Sex': 'male',
#   'Age': '29.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8958'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Richard Frasar White',
#   'Sex': 'male',
#   'Age': '21.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '1',
#   'Fare': '77.2875'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Gustaf Joel Johansson',
#   'Sex': 'male',
#   'Age': '33.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.6542'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Anders Vilhelm Gustafsson',
#   'Sex': 'male',
#   'Age': '37.0',
#   'Siblings_Spouses Aboard': '2',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.925'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Stoytcho Mionoff',
#   'Sex': 'male',
#   'Age': '28.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8958'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Anna Kristine Salkjelsvik',
#   'Sex': 'female',
#   'Age': '21.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.65'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mr. Albert Johan Moss',
#   'Sex': 'male',
#   'Age': '29.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.775'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Tido Rekic',
#   'Sex': 'male',
#   'Age': '38.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8958'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Bertha Moran',
#   'Sex': 'female',
#   'Age': '28.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '24.15'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Walter Chamberlain Porter',
#   'Sex': 'male',
#   'Age': '47.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '52.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Hileni Zabour',
#   'Sex': 'female',
#   'Age': '14.5',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '14.4542'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. David John Barton',
#   'Sex': 'male',
#   'Age': '22.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.05'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Katriina Jussila',
#   'Sex': 'female',
#   'Age': '20.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '9.825'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Malake Attalah',
#   'Sex': 'female',
#   'Age': '17.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '14.4583'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Edvard Pekoniemi',
#   'Sex': 'male',
#   'Age': '21.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.925'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Patrick Connors',
#   'Sex': 'male',
#   'Age': '70.5',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.75'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. William John Robert Turpin',
#   'Sex': 'male',
#   'Age': '29.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '21.0'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Quigg Edmond Baxter',
#   'Sex': 'male',
#   'Age': '24.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '1',
#   'Fare': '247.5208'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Ellis Anna Maria Andersson',
#   'Sex': 'female',
#   'Age': '2.0',
#   'Siblings_Spouses Aboard': '4',
#   'Parents_Children Aboard': '2',
#   'Fare': '31.275'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Stanley George Hickman',
#   'Sex': 'male',
#   'Age': '21.0',
#   'Siblings_Spouses Aboard': '2',
#   'Parents_Children Aboard': '0',
#   'Fare': '73.5'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Leonard Charles Moore',
#   'Sex': 'male',
#   'Age': '19.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.05'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Nicholas Nasser',
#   'Sex': 'male',
#   'Age': '32.5',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '30.0708'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Miss. Susan Webber',
#   'Sex': 'female',
#   'Age': '32.5',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '13.0'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Percival Wayland White',
#   'Sex': 'male',
#   'Age': '54.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '1',
#   'Fare': '77.2875'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Master. Elias Nicola-Yarred',
#   'Sex': 'male',
#   'Age': '12.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '11.2417'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Martin McMahon',
#   'Sex': 'male',
#   'Age': '19.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.75'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mr. Fridtjof Arne Madsen',
#   'Sex': 'male',
#   'Age': '24.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.1417'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Anna Peter',
#   'Sex': 'female',
#   'Age': '2.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '1',
#   'Fare': '22.3583'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Johan Ekstrom',
#   'Sex': 'male',
#   'Age': '45.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '6.975'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Jozef Drazenoic',
#   'Sex': 'male',
#   'Age': '33.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8958'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Domingos Fernandeo Coelho',
#   'Sex': 'male',
#   'Age': '20.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.05'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mrs. Alexander A (Grace Charity Laury) Robins',
#   'Sex': 'female',
#   'Age': '47.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '14.5'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Mrs. Leopold (Mathilde Francoise Pede) Weisz',
#   'Sex': 'female',
#   'Age': '29.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '26.0'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Samuel James Hayden Sobey',
#   'Sex': 'male',
#   'Age': '25.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '13.0'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Emile Richard',
#   'Sex': 'male',
#   'Age': '23.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '15.0458'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Miss. Helen Monypeny Newsom',
#   'Sex': 'female',
#   'Age': '19.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '2',
#   'Fare': '26.2833'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Jacques Heath Futrelle',
#   'Sex': 'male',
#   'Age': '37.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '53.1'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Olaf Elon Osen',
#   'Sex': 'male',
#   'Age': '16.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '9.2167'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Victor Giglio',
#   'Sex': 'male',
#   'Age': '24.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '79.2'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mrs. Joseph (Sultana) Boulos',
#   'Sex': 'female',
#   'Age': '40.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '2',
#   'Fare': '15.2458'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Anna Sofia Nysten',
#   'Sex': 'female',
#   'Age': '22.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.75'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mrs. Pekka Pietari (Elin Matilda Dolck) Hakkarainen',
#   'Sex': 'female',
#   'Age': '24.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '15.85'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Jeremiah Burke',
#   'Sex': 'male',
#   'Age': '19.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '6.75'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Edgardo Samuel Andrew',
#   'Sex': 'male',
#   'Age': '18.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '11.5'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Joseph Charles Nicholls',
#   'Sex': 'male',
#   'Age': '19.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '1',
#   'Fare': '36.75'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mr. August Edvard Andersson',
#   'Sex': 'male',
#   'Age': '27.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.7958'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Robina Maggie Ford',
#   'Sex': 'female',
#   'Age': '9.0',
#   'Siblings_Spouses Aboard': '2',
#   'Parents_Children Aboard': '2',
#   'Fare': '34.375'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Michel Navratil',
#   'Sex': 'male',
#   'Age': '36.5',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '2',
#   'Fare': '26.0'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Rev. Thomas Roussel Davids Byles',
#   'Sex': 'male',
#   'Age': '42.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '13.0'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Rev. Robert James Bateman',
#   'Sex': 'male',
#   'Age': '51.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '12.525'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mrs. Thomas (Edith Wearne) Pears',
#   'Sex': 'female',
#   'Age': '22.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '66.6'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Alfonzo Meo',
#   'Sex': 'male',
#   'Age': '55.5',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.05'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Austin Blyler van Billiard',
#   'Sex': 'male',
#   'Age': '40.5',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '2',
#   'Fare': '14.5'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Ole Martin Olsen',
#   'Sex': 'male',
#   'Age': '27.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.3125'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Charles Duane Williams',
#   'Sex': 'male',
#   'Age': '51.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '1',
#   'Fare': '61.3792'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Katherine Gilnagh',
#   'Sex': 'female',
#   'Age': '16.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.7333'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Harry Corn',
#   'Sex': 'male',
#   'Age': '30.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.05'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Mile Smiljanic',
#   'Sex': 'male',
#   'Age': '37.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.6625'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Master. Thomas Henry Sage',
#   'Sex': 'male',
#   'Age': '5.0',
#   'Siblings_Spouses Aboard': '8',
#   'Parents_Children Aboard': '2',
#   'Fare': '69.55'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. John Hatfield Cribb',
#   'Sex': 'male',
#   'Age': '44.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '1',
#   'Fare': '16.1'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Mrs. James (Elizabeth Inglis Milne) Watt',
#   'Sex': 'female',
#   'Age': '40.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '15.75'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. John Viktor Bengtsson',
#   'Sex': 'male',
#   'Age': '26.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.775'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Jovo Calic',
#   'Sex': 'male',
#   'Age': '17.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.6625'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Master. Eino Viljami Panula',
#   'Sex': 'male',
#   'Age': '1.0',
#   'Siblings_Spouses Aboard': '4',
#   'Parents_Children Aboard': '1',
#   'Fare': '39.6875'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Master. Frank John William Goldsmith',
#   'Sex': 'male',
#   'Age': '9.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '2',
#   'Fare': '20.525'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mrs. (Edith Martha Bowerman) Chibnall',
#   'Sex': 'female',
#   'Age': '48.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '1',
#   'Fare': '55.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mrs. William (Anna Bernhardina Karlsson) Skoog',
#   'Sex': 'female',
#   'Age': '45.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '4',
#   'Fare': '27.9'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. John D Baumann',
#   'Sex': 'male',
#   'Age': '60.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '25.925'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Lee Ling',
#   'Sex': 'male',
#   'Age': '28.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '56.4958'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Wyckoff Van der hoef',
#   'Sex': 'male',
#   'Age': '61.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '33.5'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Master. Arthur Rice',
#   'Sex': 'male',
#   'Age': '4.0',
#   'Siblings_Spouses Aboard': '4',
#   'Parents_Children Aboard': '1',
#   'Fare': '29.125'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Eleanor Ileen Johnson',
#   'Sex': 'female',
#   'Age': '1.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '1',
#   'Fare': '11.1333'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Antti Wilhelm Sivola',
#   'Sex': 'male',
#   'Age': '21.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.925'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. James Clinch Smith',
#   'Sex': 'male',
#   'Age': '56.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '30.6958'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Klas Albin Klasen',
#   'Sex': 'male',
#   'Age': '18.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '1',
#   'Fare': '7.8542'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Master. Henry Forbes Lefebre',
#   'Sex': 'male',
#   'Age': '5.0',
#   'Siblings_Spouses Aboard': '3',
#   'Parents_Children Aboard': '1',
#   'Fare': '25.4667'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Miss. Ann Elizabeth Isham',
#   'Sex': 'female',
#   'Age': '50.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '28.7125'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Reginald Hale',
#   'Sex': 'male',
#   'Age': '30.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '13.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Lionel Leonard',
#   'Sex': 'male',
#   'Age': '36.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '0.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Constance Gladys Sage',
#   'Sex': 'female',
#   'Age': '8.0',
#   'Siblings_Spouses Aboard': '8',
#   'Parents_Children Aboard': '2',
#   'Fare': '69.55'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Rene Pernot',
#   'Sex': 'male',
#   'Age': '39.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '15.05'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Master. Clarence Gustaf Hugo Asplund',
#   'Sex': 'male',
#   'Age': '9.0',
#   'Siblings_Spouses Aboard': '4',
#   'Parents_Children Aboard': '2',
#   'Fare': '31.3875'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Master. Richard F Becker',
#   'Sex': 'male',
#   'Age': '1.0',
#   'Siblings_Spouses Aboard': '2',
#   'Parents_Children Aboard': '1',
#   'Fare': '39.0'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Luise Gretchen Kink-Heilmann',
#   'Sex': 'female',
#   'Age': '4.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '2',
#   'Fare': '22.025'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Hugh Roscoe Rood',
#   'Sex': 'male',
#   'Age': '39.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '50.0'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': "Mrs. Thomas (Johanna Godfrey) O'Brien",
#   'Sex': 'female',
#   'Age': '26.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '15.5'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mr. Charles Hallace Romaine',
#   'Sex': 'male',
#   'Age': '45.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '26.55'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. John Bourke',
#   'Sex': 'male',
#   'Age': '40.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '1',
#   'Fare': '15.5'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Stjepan Turcin',
#   'Sex': 'male',
#   'Age': '36.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8958'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Mrs. (Rosa) Pinsky',
#   'Sex': 'female',
#   'Age': '32.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '13.0'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. William Carbines',
#   'Sex': 'male',
#   'Age': '19.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '13.0'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Carla Christine Nielsine Andersen-Jensen',
#   'Sex': 'female',
#   'Age': '19.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8542'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Master. Michel M Navratil',
#   'Sex': 'male',
#   'Age': '3.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '1',
#   'Fare': '26.0'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mrs. James Joseph (Margaret Tobin) Brown',
#   'Sex': 'female',
#   'Age': '44.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '27.7208'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Miss. Elise Lurette',
#   'Sex': 'female',
#   'Age': '58.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '146.5208'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Robert Mernagh',
#   'Sex': 'male',
#   'Age': '28.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.75'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Karl Siegwart Andreas Olsen',
#   'Sex': 'male',
#   'Age': '42.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '1',
#   'Fare': '8.4042'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Margaret Madigan',
#   'Sex': 'female',
#   'Age': '21.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.75'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Miss. Henriette Yrois',
#   'Sex': 'female',
#   'Age': '24.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '13.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Nestor Cyriel Vande Walle',
#   'Sex': 'male',
#   'Age': '28.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '9.5'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Frederick Sage',
#   'Sex': 'male',
#   'Age': '17.0',
#   'Siblings_Spouses Aboard': '8',
#   'Parents_Children Aboard': '2',
#   'Fare': '69.55'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Jakob Alfred Johanson',
#   'Sex': 'male',
#   'Age': '34.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '6.4958'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Gerious Youseff',
#   'Sex': 'male',
#   'Age': '45.5',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.225'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mr. Gurshon Cohen',
#   'Sex': 'male',
#   'Age': '18.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.05'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Telma Matilda Strom',
#   'Sex': 'female',
#   'Age': '2.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '1',
#   'Fare': '10.4625'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Karl Alfred Backstrom',
#   'Sex': 'male',
#   'Age': '32.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '15.85'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mr. Nassef Cassem Albimona',
#   'Sex': 'male',
#   'Age': '26.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '18.7875'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Helen Carr',
#   'Sex': 'female',
#   'Age': '16.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.75'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mr. Henry Blank',
#   'Sex': 'male',
#   'Age': '40.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '31.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Ahmed Ali',
#   'Sex': 'male',
#   'Age': '24.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.05'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Miss. Clear Annie Cameron',
#   'Sex': 'female',
#   'Age': '35.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '21.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. John Henry Perkin',
#   'Sex': 'male',
#   'Age': '22.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.25'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Hans Kristensen Givard',
#   'Sex': 'male',
#   'Age': '30.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '13.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Philip Kiernan',
#   'Sex': 'male',
#   'Age': '22.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.75'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Miss. Madeleine Newell',
#   'Sex': 'female',
#   'Age': '31.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '113.275'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Eliina Honkanen',
#   'Sex': 'female',
#   'Age': '27.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.925'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Sidney Samuel Jacobsohn',
#   'Sex': 'male',
#   'Age': '42.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '27.0'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Miss. Albina Bazzani',
#   'Sex': 'female',
#   'Age': '32.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '76.2917'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Walter Harris',
#   'Sex': 'male',
#   'Age': '30.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '10.5'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mr. Victor Francis Sunderland',
#   'Sex': 'male',
#   'Age': '16.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.05'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. James H Bracken',
#   'Sex': 'male',
#   'Age': '27.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '13.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. George Henry Green',
#   'Sex': 'male',
#   'Age': '51.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.05'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Christo Nenkoff',
#   'Sex': 'male',
#   'Age': '22.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8958'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mr. Frederick Maxfield Hoyt',
#   'Sex': 'male',
#   'Age': '38.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '90.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Karl Ivar Sven Berglund',
#   'Sex': 'male',
#   'Age': '22.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '9.35'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Mr. William John Mellors',
#   'Sex': 'male',
#   'Age': '19.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '10.5'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. John Hall Lovell',
#   'Sex': 'male',
#   'Age': '20.5',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.25'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Arne Jonas Fahlstrom',
#   'Sex': 'male',
#   'Age': '18.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '13.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Mathilde Lefebre',
#   'Sex': 'female',
#   'Age': '12.0',
#   'Siblings_Spouses Aboard': '3',
#   'Parents_Children Aboard': '1',
#   'Fare': '25.4667'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mrs. Henry Birkhardt (Irene Wallach) Harris',
#   'Sex': 'female',
#   'Age': '35.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '83.475'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Bengt Edvin Larsson',
#   'Sex': 'male',
#   'Age': '29.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.775'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Ernst Adolf Sjostedt',
#   'Sex': 'male',
#   'Age': '59.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '13.5'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Lillian Gertrud Asplund',
#   'Sex': 'female',
#   'Age': '5.0',
#   'Siblings_Spouses Aboard': '4',
#   'Parents_Children Aboard': '2',
#   'Fare': '31.3875'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Robert William Norman Leyson',
#   'Sex': 'male',
#   'Age': '24.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '10.5'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Alice Phoebe Harknett',
#   'Sex': 'female',
#   'Age': '21.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.55'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Stephen Hold',
#   'Sex': 'male',
#   'Age': '44.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '26.0'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Miss. Marjorie Collyer',
#   'Sex': 'female',
#   'Age': '8.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '2',
#   'Fare': '26.25'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Frederick William Pengelly',
#   'Sex': 'male',
#   'Age': '19.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '10.5'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. George Henry Hunt',
#   'Sex': 'male',
#   'Age': '33.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '12.275'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Thamine Zabour',
#   'Sex': 'female',
#   'Age': '19.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '14.4542'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Katherine Murphy',
#   'Sex': 'female',
#   'Age': '18.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '15.5'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Reginald Charles Coleridge',
#   'Sex': 'male',
#   'Age': '29.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '10.5'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Matti Alexanteri Maenpaa',
#   'Sex': 'male',
# ...
#   'Sex': 'male',
#   'Age': '26.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8875'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. James Lester',
#   'Sex': 'male',
#   'Age': '39.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '24.15'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Richard James Slemen',
#   'Sex': 'male',
#   'Age': '35.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '10.5'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Ebba Iris Alfrida Andersson',
#   'Sex': 'female',
#   'Age': '6.0',
#   'Siblings_Spouses Aboard': '4',
#   'Parents_Children Aboard': '2',
#   'Fare': '31.275'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Ernest Portage Tomlin',
#   'Sex': 'male',
#   'Age': '30.5',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.05'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Richard Fry',
#   'Sex': 'male',
#   'Age': '39.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '0.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Wendla Maria Heininen',
#   'Sex': 'female',
#   'Age': '23.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.925'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Albert Mallet',
#   'Sex': 'male',
#   'Age': '31.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '1',
#   'Fare': '37.0042'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. John Fredrik Alexander Holm',
#   'Sex': 'male',
#   'Age': '43.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '6.45'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Master. Karl Thorsten Skoog',
#   'Sex': 'male',
#   'Age': '10.0',
#   'Siblings_Spouses Aboard': '3',
#   'Parents_Children Aboard': '2',
#   'Fare': '27.9'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mrs. Charles Melville (Clara Jennings Gregg) Hays',
#   'Sex': 'female',
#   'Age': '52.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '1',
#   'Fare': '93.5'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mr. Nikola Lulic',
#   'Sex': 'male',
#   'Age': '27.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.6625'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Jonkheer. John George Reuchlin',
#   'Sex': 'male',
#   'Age': '38.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '0.0'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mrs. (Beila) Moor',
#   'Sex': 'female',
#   'Age': '27.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '1',
#   'Fare': '12.475'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Master. Urho Abraham Panula',
#   'Sex': 'male',
#   'Age': '2.0',
#   'Siblings_Spouses Aboard': '4',
#   'Parents_Children Aboard': '1',
#   'Fare': '39.6875'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. John Flynn',
#   'Sex': 'male',
#   'Age': '36.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '6.95'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Len Lam',
#   'Sex': 'male',
#   'Age': '23.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '56.4958'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Master. Andre Mallet',
#   'Sex': 'male',
#   'Age': '1.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '2',
#   'Fare': '37.0042'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mr. Thomas Joseph McCormack',
#   'Sex': 'male',
#   'Age': '19.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.75'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mrs. George Nelson (Martha Evelyn) Stone',
#   'Sex': 'female',
#   'Age': '62.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '80.0'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mrs. Antoni (Selini Alexander) Yasbeck',
#   'Sex': 'female',
#   'Age': '15.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '14.4542'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Master. George Sibley Richards',
#   'Sex': 'male',
#   'Age': '0.83',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '1',
#   'Fare': '18.75'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Amin Saad',
#   'Sex': 'male',
#   'Age': '30.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.2292'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Albert Augustsson',
#   'Sex': 'male',
#   'Age': '23.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8542'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Owen George Allum',
#   'Sex': 'male',
#   'Age': '18.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.3'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Miss. Sara Rebecca Compton',
#   'Sex': 'female',
#   'Age': '39.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '1',
#   'Fare': '83.1583'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Jakob Pasic',
#   'Sex': 'male',
#   'Age': '21.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.6625'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Maurice Sirota',
#   'Sex': 'male',
#   'Age': '20.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.05'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mr. Chang Chip',
#   'Sex': 'male',
#   'Age': '32.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '56.4958'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mr. Pierre Marechal',
#   'Sex': 'male',
#   'Age': '29.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '29.7'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Ilmari Rudolf Alhomaki',
#   'Sex': 'male',
#   'Age': '20.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.925'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Thomas Charles Mudd',
#   'Sex': 'male',
#   'Age': '16.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '10.5'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Miss. Augusta Serepeca',
#   'Sex': 'female',
#   'Age': '30.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '31.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Peter L Lemberopolous',
#   'Sex': 'male',
#   'Age': '34.5',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '6.4375'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Jeso Culumovic',
#   'Sex': 'male',
#   'Age': '17.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '8.6625'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Anthony Abbing',
#   'Sex': 'male',
#   'Age': '42.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.55'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Douglas Bullen Sage',
#   'Sex': 'male',
#   'Age': '18.0',
#   'Siblings_Spouses Aboard': '8',
#   'Parents_Children Aboard': '2',
#   'Fare': '69.55'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Marin Markoff',
#   'Sex': 'male',
#   'Age': '35.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8958'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Rev. John Harper',
#   'Sex': 'male',
#   'Age': '28.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '1',
#   'Fare': '33.0'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mrs. Samuel L (Edwiga Grabowska) Goldenberg',
#   'Sex': 'female',
#   'Age': '40.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '89.1042'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Master. Sigvard Harald Elias Andersson',
#   'Sex': 'male',
#   'Age': '4.0',
#   'Siblings_Spouses Aboard': '4',
#   'Parents_Children Aboard': '2',
#   'Fare': '31.275'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Johan Svensson',
#   'Sex': 'male',
#   'Age': '74.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.775'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Nourelain Boulos',
#   'Sex': 'female',
#   'Age': '9.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '1',
#   'Fare': '15.2458'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Miss. Mary Conover Lines',
#   'Sex': 'female',
#   'Age': '16.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '1',
#   'Fare': '39.4'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mrs. Ernest Courtenay (Lilian Hughes) Carter',
#   'Sex': 'female',
#   'Age': '44.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '26.0'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mrs. Sam (Leah Rosen) Aks',
#   'Sex': 'female',
#   'Age': '18.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '1',
#   'Fare': '9.35'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mrs. George Dennick (Mary Hitchcock) Wick',
#   'Sex': 'female',
#   'Age': '45.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '1',
#   'Fare': '164.8667'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mr. Peter Denis Daly',
#   'Sex': 'male',
#   'Age': '51.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '26.55'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Mrs. Solomon (Latifa Qurban) Baclini',
#   'Sex': 'female',
#   'Age': '24.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '3',
#   'Fare': '19.2583'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Raihed Razi',
#   'Sex': 'male',
#   'Age': '30.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.2292'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Claus Peter Hansen',
#   'Sex': 'male',
#   'Age': '41.0',
#   'Siblings_Spouses Aboard': '2',
#   'Parents_Children Aboard': '0',
#   'Fare': '14.1083'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Frederick Edward Giles',
#   'Sex': 'male',
#   'Age': '21.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '11.5'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mrs. Frederick Joel (Margaret Welles Barron) Swift',
#   'Sex': 'female',
#   'Age': '48.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '25.9292'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Dorothy Edith Sage',
#   'Sex': 'female',
#   'Age': '14.0',
#   'Siblings_Spouses Aboard': '8',
#   'Parents_Children Aboard': '2',
#   'Fare': '69.55'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. John William Gill',
#   'Sex': 'male',
#   'Age': '24.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '13.0'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Mrs. (Karolina) Bystrom',
#   'Sex': 'female',
#   'Age': '42.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '13.0'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Miss. Asuncion Duran y More',
#   'Sex': 'female',
#   'Age': '27.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '13.8583'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Washington Augustus II Roebling',
#   'Sex': 'male',
#   'Age': '31.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '50.4958'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Philemon van Melkebeke',
#   'Sex': 'male',
#   'Age': '23.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '9.5'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Master. Harold Theodor Johnson',
#   'Sex': 'male',
#   'Age': '4.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '1',
#   'Fare': '11.1333'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Cerin Balkic',
#   'Sex': 'male',
#   'Age': '26.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8958'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mrs. Richard Leonard (Sallie Monypeny) Beckwith',
#   'Sex': 'female',
#   'Age': '47.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '1',
#   'Fare': '52.5542'},
#  {'Survived': '0',
#   'Pclass': '1',
#   'Name': 'Mr. Frans Olof Carlsson',
#   'Sex': 'male',
#   'Age': '33.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '5.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Victor Vander Cruyssen',
#   'Sex': 'male',
#   'Age': '47.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '9.0'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Mrs. Samuel (Hannah Wizosky) Abelson',
#   'Sex': 'female',
#   'Age': '28.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '0',
#   'Fare': '24.0'},
#  {'Survived': '1',
#   'Pclass': '3',
#   'Name': 'Miss. Adele Kiamie Najib',
#   'Sex': 'female',
#   'Age': '15.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.225'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Alfred Ossian Gustafsson',
#   'Sex': 'male',
#   'Age': '20.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '9.8458'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Nedelio Petroff',
#   'Sex': 'male',
#   'Age': '19.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8958'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Kristo Laleff',
#   'Sex': 'male',
#   'Age': '23.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8958'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mrs. Thomas Jr (Lily Alexenia Wilson) Potter',
#   'Sex': 'female',
#   'Age': '56.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '1',
#   'Fare': '83.1583'},
#  {'Survived': '1',
#   'Pclass': '2',
#   'Name': 'Mrs. William (Imanita Parrish Hall) Shelley',
#   'Sex': 'female',
#   'Age': '25.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '1',
#   'Fare': '26.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Johann Markun',
#   'Sex': 'male',
#   'Age': '33.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.8958'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Gerda Ulrika Dahlberg',
#   'Sex': 'female',
#   'Age': '22.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '10.5167'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Mr. Frederick James Banfield',
#   'Sex': 'male',
#   'Age': '28.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '10.5'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Henry Jr Sutehall',
#   'Sex': 'male',
#   'Age': '25.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.05'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mrs. William (Margaret Norton) Rice',
#   'Sex': 'female',
#   'Age': '39.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '5',
#   'Fare': '29.125'},
#  {'Survived': '0',
#   'Pclass': '2',
#   'Name': 'Rev. Juozas Montvila',
#   'Sex': 'male',
#   'Age': '27.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '13.0'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Miss. Margaret Edith Graham',
#   'Sex': 'female',
#   'Age': '19.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '30.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Miss. Catherine Helen Johnston',
#   'Sex': 'female',
#   'Age': '7.0',
#   'Siblings_Spouses Aboard': '1',
#   'Parents_Children Aboard': '2',
#   'Fare': '23.45'},
#  {'Survived': '1',
#   'Pclass': '1',
#   'Name': 'Mr. Karl Howell Behr',
#   'Sex': 'male',
#   'Age': '26.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '30.0'},
#  {'Survived': '0',
#   'Pclass': '3',
#   'Name': 'Mr. Patrick Dooley',
#   'Sex': 'male',
#   'Age': '32.0',
#   'Siblings_Spouses Aboard': '0',
#   'Parents_Children Aboard': '0',
#   'Fare': '7.75'}]

# %%
# Another insert_many method
db.titanic.insert_many(documents)
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# <ipython-input-190-f4f84c889703> in <module>
#       1 # Another insert_many method
# ----> 2 db.titanic.insert_many(documents)
#
# /anaconda3/envs/db_builder/lib/python3.7/site-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     751         blk = _Bulk(self, ordered, bypass_document_validation)
#     752         blk.ops = [doc for doc in gen()]
# --> 753         blk.execute(write_concern, session=session)
#     754         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     755
#
# /anaconda3/envs/db_builder/lib/python3.7/site-packages/pymongo/bulk.py in execute(self, write_concern, session)
#     519                 self.execute_no_results(sock_info, generator)
#     520         else:
# --> 521             return self.execute_command(generator, write_concern, session)
#     522
#     523
#
# /anaconda3/envs/db_builder/lib/python3.7/site-packages/pymongo/bulk.py in execute_command(self, generator, write_concern, session)
#     347
#     348         if full_result["writeErrors"] or full_result["writeConcernErrors"]:
# --> 349             _raise_bulk_write_error(full_result)
#     350         return full_result
#     351
#
# /anaconda3/envs/db_builder/lib/python3.7/site-packages/pymongo/bulk.py in _raise_bulk_write_error(full_result)
#     138         full_result["writeErrors"].sort(
#     139             key=lambda error: error["index"])
# --> 140     raise BulkWriteError(full_result)
#     141
#     142
#
# BulkWriteError: batch op errors occurred
