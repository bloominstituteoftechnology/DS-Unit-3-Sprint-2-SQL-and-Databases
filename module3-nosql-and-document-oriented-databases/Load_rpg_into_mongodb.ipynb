# %% [markdown]
# <a href="https://colab.research.google.com/github/iesous-kurios/DS-Unit-3-Sprint-2-SQL-and-Databases/blob/master/module3-nosql-and-document-oriented-databases/Load_rpg_into_mongodb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-dotenv
# !pip install dnspython
import pymongo
import os
from dotenv import load_dotenv
from datetime import datetime
import dns
import json
load_dotenv()
DB_USER = os.getenv("MONGO_USER", default="OOPS")
DB_PASSWORD = os.getenv("MONGO_PASSWORD", default="OOPS")
CLUSTER_NAME = os.getenv("MONGO_CLUSTER_NAME", default="OOPS")


connection_uri = pymongo.MongoClient(f"mongodb+srv://{DB_USER}:{DB_PASSWORD}@{CLUSTER_NAME}.mongodb.net/test?retryWrites=true&w=majority")

test_db = connection_uri.test

# %%
# !wget https://github.com/LambdaSchool/Django-RPG/raw/master/testdata.json
# Out:
# --2020-02-05 05:16:21--  https://github.com/LambdaSchool/Django-RPG/raw/master/testdata.json
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/LambdaSchool/Django-RPG/master/testdata.json [following]
# --2020-02-05 05:16:22--  https://raw.githubusercontent.com/LambdaSchool/Django-RPG/master/testdata.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 123399 (121K) [text/plain]
# Saving to: ‘testdata.json.1’
#
# testdata.json.1     100%[===================>] 120.51K  --.-KB/s    in 0.02s
#
# 2020-02-05 05:16:22 (5.45 MB/s) - ‘testdata.json.1’ saved [123399/123399]

# %%
print("..................")

print('Now inserting rpg data into MongoDB')

try:
    with open('testdata.json') as json_file:
        rpg_data = json.load(json_file)
        print("Data inserted successfully!")
except:
    print("Import failed")
    

#  print the inserted data
cursor = test_db.test.find()
for record in cursor:
    print(record)
# Out:
# ..................
# Now inserting rpg data into MongoDB
# Data inserted successfully!
# {'_id': ObjectId('5e3a48b2b914cba0adbde842'), 'model': 'charactercreator.character', 'pk': 1, 'fields': {'name': 'Aliquid iste optio reiciendi', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1, 'inventory': [20, 58, 85]}}
# {'_id': ObjectId('5e3a48b2b914cba0adbde843'), 'model': 'charactercreator.character', 'pk': 2, 'fields': {'name': 'Optio dolorem ex a', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1, 'inventory': [93, 115, 133]}}
# {'_id': ObjectId('5e3a48b2b914cba0adbde844'), 'model': 'charactercreator.character', 'pk': 3, 'fields': {'name': 'Minus c', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1, 'inventory': [8, 43]}}
# ...

# %%
list(test_db.test.find({'fields': {'hp': '10'}}))
# Out:
# []

# %%
# not having much luck searching data in new mongo db :(
