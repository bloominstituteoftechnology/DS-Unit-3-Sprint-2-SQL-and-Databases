# %% [markdown]
# <a href="https://colab.research.google.com/github/tbradshaw91/DS-Unit-3-Sprint-2-SQL-and-Databases/blob/master/SQLMod1Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports
import pandas as pd
import sqlite3

# %%
# Establishing connection
connection = sqlite3.connect('buddymove_holidayiq.sqlite3')

# %%
# Confirming number of rows and cols
buddy_df.shape
# Out:
# (249, 7)

# %%
# Confirming no nulls
buddy_df.isnull().sum().sum()
# Out:
# 0

# %%
buddy_df.to_sql(name='review',con=connection, if_exists="append", index=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2531: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype, method=method)

# %%
connection.execute("SELECT * FROM review").fetchall()

# %%
# Although I have confirmed rows in Pandas, the assignment asks for SQL
query_1 = 'SELECT count() FROM review;'
print ('Rows:',connection.cursor().execute(query_1).fetchone()[0], '\n')
# Out:
# Rows: 249

# %%
# Creating a DF with SQL 
df = pd.read_sql("SELECT * FROM review", connection)

# %%
df.head()
# Out:
#   User Id  Sports  Religious  Nature  Theatre  Shopping  Picnic
# 0  User 1       2         77      79       69        68      95
# 1  User 2       2         62      76       76        69      68
# 2  User 3       2         50      97       87        50      75
# 3  User 4       2         68      77       95        76      61
# 4  User 5       2         98      54       59        95      86

# %%
df.loc[(df['Nature'] >= 100) & (df['Shopping'] >= 100)]
# Out:
#       User Id  Sports  Religious  Nature  Theatre  Shopping  Picnic
# 52    User 53       4         79     103       68       103      85
# 54    User 55       8         94     140       89       118      92
# 61    User 62       8         94     128       89       128      99
# 63    User 64       6         84     108      138       103      79
# 65    User 66       6         89     108      128       116      81
# 91    User 92       8         94     133       84       125      97
# 109  User 110      12        123     124      109       114     168
# 110  User 111      12         94     133      157       133      95
# 111  User 112      12        104     123      163       128      89
# 113  User 114      14        113     148       99       148     110
# 115  User 116      12        133     104      119       129     133
# 118  User 119      12        123     124      109       129     143
# 119  User 120      12         94     137      148       113     100
# ...

# %% [markdown]
# ### **78 users**
